# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet model definition

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)
    

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3_1 = nn.Conv2d(chann, chann, (3,3), stride=1, padding=(1,1), bias=True)

        # self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3_2 = nn.Conv2d(chann, chann, (3, 3), stride=1, padding=(1*dilated,1*dilated), bias=True, dilation = (dilated,dilated))

        # self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3_1(input)
        # output = F.relu(output)
        # output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3_2(output)
        # output = F.relu(output)
        # output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output


class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target


class CrossEntropyLoss2d(torch.nn.Module):

    def __init__(self, weight=None):
        super().__init__()

        self.loss = torch.nn.NLLLoss2d(weight)

    def forward(self, outputs, targets):
        return self.loss(torch.nn.functional.log_softmax(outputs, dim=1), targets)


def train(args, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = CrossEntropyLoss2d(weight)
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train()
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0])
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 

            loss = criterion(outputs, targets[:, 0])
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Model
    # assert os.path.exists(args.model + ".py"), "Error: model definition not found"
    # model_file = importlib.import_module(args.model)
    model = Net(NUM_CLASSES)
    # copyfile(args.model + ".py", savedir + '/' + args.model + ".py")
    
    if args.cuda:
        model = torch.nn.DataParallel(model).cuda()
    
    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        """
        try:
            model.load_state_dict(torch.load(args.state))
        except AssertionError:
            model.load_state_dict(torch.load(args.state,
                map_location=lambda storage, loc: storage))
        #When model is saved as DataParallel it adds a model. to each key. To remove:
        #state_dict = {k.partition('model.')[2]: v for k,v in state_dict}
        #https://discuss.pytorch.org/t/prefix-parameter-names-in-saved-model-if-trained-by-multi-gpu/494
        """
        def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict keys are there
            own_state = model.state_dict()
            for name, param in state_dict.items():
                if name not in own_state:
                     continue
                own_state[name].copy_(param)
            return model

        #print(torch.load(args.state))
        model = load_my_state_dict(model, torch.load(args.state))

    """
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            #m.weight.data.normal_(0.0, 0.02)
            n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
            m.weight.data.normal_(0, math.sqrt(2. / n))
        elif classname.find('BatchNorm') != -1:
            #m.weight.data.normal_(1.0, 0.02)
            m.weight.data.fill_(1)
            m.bias.data.fill_(0)
    #TO ACCESS MODEL IN DataParallel: next(model.children())
    #next(model.children()).decoder.apply(weights_init)
    #Reinitialize weights for decoder
    
    next(model.children()).decoder.layers.apply(weights_init)
    next(model.children()).decoder.output_conv.apply(weights_init)
    #print(model.state_dict())
    f = open('weights5.txt', 'w')
    f.write(str(model.state_dict()))
    f.close()
    """

    # train(args, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=60)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=6)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.941 (epoch: 1, step: 0) // Avg time/img: 1.2757 s
# loss: 1.263 (epoch: 1, step: 50) // Avg time/img: 0.0849 s
# loss: 1.096 (epoch: 1, step: 100) // Avg time/img: 0.0739 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.254 (epoch: 1, step: 0) // Avg time/img: 0.0287 s
# VAL loss: 1.402 (epoch: 1, step: 50) // Avg time/img: 0.0223 s
# EPOCH IoU on VAL set:  19.59 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 0.7797 (epoch: 2, step: 0) // Avg time/img: 0.0771 s
# loss: 0.8012 (epoch: 2, step: 50) // Avg time/img: 0.0670 s
# loss: 0.7786 (epoch: 2, step: 100) // Avg time/img: 0.0665 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 0.8016 (epoch: 2, step: 0) // Avg time/img: 0.0320 s
# VAL loss: 1.143 (epoch: 2, step: 50) // Avg time/img: 0.0243 s
# EPOCH IoU on VAL set:  21.39 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.8961 (epoch: 3, step: 0) // Avg time/img: 0.0807 s
# loss: 0.6986 (epoch: 3, step: 50) // Avg time/img: 0.0659 s
# loss: 0.6981 (epoch: 3, step: 100) // Avg time/img: 0.0660 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 0.8923 (epoch: 3, step: 0) // Avg time/img: 0.0301 s
# VAL loss: 1.11 (epoch: 3, step: 50) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  22.80 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 0.552 (epoch: 4, step: 0) // Avg time/img: 0.0805 s
# loss: 0.6479 (epoch: 4, step: 50) // Avg time/img: 0.0659 s
# loss: 0.6295 (epoch: 4, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 0.7676 (epoch: 4, step: 0) // Avg time/img: 0.0304 s
# VAL loss: 1.04 (epoch: 4, step: 50) // Avg time/img: 0.0233 s
# EPOCH IoU on VAL set:  24.40 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.9764 (epoch: 5, step: 0) // Avg time/img: 0.0796 s
# loss: 0.6027 (epoch: 5, step: 50) // Avg time/img: 0.0661 s
# loss: 0.5938 (epoch: 5, step: 100) // Avg time/img: 0.0656 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 0.6301 (epoch: 5, step: 0) // Avg time/img: 0.0319 s
# VAL loss: 0.8426 (epoch: 5, step: 50) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  27.77 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 5)
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004623387553722673
# loss: 0.5102 (epoch: 6, step: 0) // Avg time/img: 0.0777 s
# loss: 0.5487 (epoch: 6, step: 50) // Avg time/img: 0.0661 s
# loss: 0.543 (epoch: 6, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 0.8091 (epoch: 6, step: 0) // Avg time/img: 0.0308 s
# VAL loss: 0.9174 (epoch: 6, step: 50) // Avg time/img: 0.0240 s
# EPOCH IoU on VAL set:  26.94 %
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.496 (epoch: 7, step: 0) // Avg time/img: 0.0788 s
# loss: 0.516 (epoch: 7, step: 50) // Avg time/img: 0.0662 s
# loss: 0.5222 (epoch: 7, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 1.049 (epoch: 7, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.9931 (epoch: 7, step: 50) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  28.69 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 7)
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.00044717978378742816
# loss: 0.4596 (epoch: 8, step: 0) // Avg time/img: 0.0726 s
# loss: 0.4785 (epoch: 8, step: 50) // Avg time/img: 0.0662 s
# loss: 0.4731 (epoch: 8, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 0.9094 (epoch: 8, step: 0) // Avg time/img: 0.0339 s
# VAL loss: 0.9326 (epoch: 8, step: 50) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  27.98 %
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.4471 (epoch: 9, step: 0) // Avg time/img: 0.0793 s
# loss: 0.4585 (epoch: 9, step: 50) // Avg time/img: 0.0659 s
# loss: 0.475 (epoch: 9, step: 100) // Avg time/img: 0.0655 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 0.7898 (epoch: 9, step: 0) // Avg time/img: 0.0316 s
# VAL loss: 0.9012 (epoch: 9, step: 50) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  29.52 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 9)
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.00043196348615140955
# loss: 0.5088 (epoch: 10, step: 0) // Avg time/img: 0.0746 s
# loss: 0.4724 (epoch: 10, step: 50) // Avg time/img: 0.0661 s
# loss: 0.4629 (epoch: 10, step: 100) // Avg time/img: 0.0655 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 0.5772 (epoch: 10, step: 0) // Avg time/img: 0.0359 s
# VAL loss: 0.9046 (epoch: 10, step: 50) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  27.00 %
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.5333 (epoch: 11, step: 0) // Avg time/img: 0.0806 s
# loss: 0.4312 (epoch: 11, step: 50) // Avg time/img: 0.0659 s
# loss: 0.4433 (epoch: 11, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.6151 (epoch: 11, step: 0) // Avg time/img: 0.0304 s
# VAL loss: 0.7677 (epoch: 11, step: 50) // Avg time/img: 0.0231 s
# EPOCH IoU on VAL set:  32.34 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 11)
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.0004166873834706844
# loss: 0.3764 (epoch: 12, step: 0) // Avg time/img: 0.0746 s
# loss: 0.4301 (epoch: 12, step: 50) // Avg time/img: 0.0659 s
# loss: 0.4222 (epoch: 12, step: 100) // Avg time/img: 0.0654 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.6021 (epoch: 12, step: 0) // Avg time/img: 0.0314 s
# VAL loss: 0.7635 (epoch: 12, step: 50) // Avg time/img: 0.0234 s
# EPOCH IoU on VAL set:  32.15 %
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.3904 (epoch: 13, step: 0) // Avg time/img: 0.0777 s
# loss: 0.4207 (epoch: 13, step: 50) // Avg time/img: 0.0660 s
# loss: 0.4185 (epoch: 13, step: 100) // Avg time/img: 0.0656 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 0.8461 (epoch: 13, step: 0) // Avg time/img: 0.0345 s
# VAL loss: 0.7778 (epoch: 13, step: 50) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  33.15 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 13)
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.0004013487836640184
# loss: 0.4165 (epoch: 14, step: 0) // Avg time/img: 0.0745 s
# loss: 0.4172 (epoch: 14, step: 50) // Avg time/img: 0.0662 s
# loss: 0.4084 (epoch: 14, step: 100) // Avg time/img: 0.0659 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 0.7449 (epoch: 14, step: 0) // Avg time/img: 0.0312 s
# VAL loss: 0.8392 (epoch: 14, step: 50) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  31.91 %
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.3047 (epoch: 15, step: 0) // Avg time/img: 0.0811 s
# loss: 0.3819 (epoch: 15, step: 50) // Avg time/img: 0.0665 s
# loss: 0.3961 (epoch: 15, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 0.5765 (epoch: 15, step: 0) // Avg time/img: 0.0298 s
# VAL loss: 0.7196 (epoch: 15, step: 50) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  34.74 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 15)
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00038594475336178527
# loss: 0.3039 (epoch: 16, step: 0) // Avg time/img: 0.0762 s
# loss: 0.4031 (epoch: 16, step: 50) // Avg time/img: 0.0662 s
# loss: 0.4019 (epoch: 16, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.5884 (epoch: 16, step: 0) // Avg time/img: 0.0320 s
# VAL loss: 0.7895 (epoch: 16, step: 50) // Avg time/img: 0.0234 s
# EPOCH IoU on VAL set:  34.49 %
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.5768 (epoch: 17, step: 0) // Avg time/img: 0.0730 s
# loss: 0.37 (epoch: 17, step: 50) // Avg time/img: 0.0659 s
# loss: 0.385 (epoch: 17, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.546 (epoch: 17, step: 0) // Avg time/img: 0.0322 s
# VAL loss: 0.6659 (epoch: 17, step: 50) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  36.52 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 17)
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.00037047208454744316
# loss: 0.3474 (epoch: 18, step: 0) // Avg time/img: 0.0760 s
# loss: 0.3532 (epoch: 18, step: 50) // Avg time/img: 0.0663 s
# loss: 0.3551 (epoch: 18, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.6775 (epoch: 18, step: 0) // Avg time/img: 0.0323 s
# VAL loss: 0.7531 (epoch: 18, step: 50) // Avg time/img: 0.0239 s
# EPOCH IoU on VAL set:  35.14 %
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.3575 (epoch: 19, step: 0) // Avg time/img: 0.0803 s
# loss: 0.3578 (epoch: 19, step: 50) // Avg time/img: 0.0665 s
# loss: 0.3594 (epoch: 19, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.4057 (epoch: 19, step: 0) // Avg time/img: 0.0328 s
# VAL loss: 0.6517 (epoch: 19, step: 50) // Avg time/img: 0.0241 s
# EPOCH IoU on VAL set:  38.11 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 19)
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.0003549272548125162
# loss: 0.3441 (epoch: 20, step: 0) // Avg time/img: 0.0783 s
# loss: 0.3658 (epoch: 20, step: 50) // Avg time/img: 0.0660 s
# loss: 0.3723 (epoch: 20, step: 100) // Avg time/img: 0.0656 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.6768 (epoch: 20, step: 0) // Avg time/img: 0.0329 s
# VAL loss: 0.824 (epoch: 20, step: 50) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  35.37 %
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.4192 (epoch: 21, step: 0) // Avg time/img: 0.0766 s
# loss: 0.3393 (epoch: 21, step: 50) // Avg time/img: 0.0660 s
# loss: 0.3421 (epoch: 21, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.571 (epoch: 21, step: 0) // Avg time/img: 0.0315 s
# VAL loss: 0.6559 (epoch: 21, step: 50) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  38.54 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 21)
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.0003393063796290625
# loss: 0.3077 (epoch: 22, step: 0) // Avg time/img: 0.0754 s
# loss: 0.3165 (epoch: 22, step: 50) // Avg time/img: 0.0663 s
# loss: 0.3219 (epoch: 22, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.4409 (epoch: 22, step: 0) // Avg time/img: 0.0308 s
# VAL loss: 0.5891 (epoch: 22, step: 50) // Avg time/img: 0.0242 s
# EPOCH IoU on VAL set:  39.35 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 22)
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.3101 (epoch: 23, step: 0) // Avg time/img: 0.0740 s
# loss: 0.3248 (epoch: 23, step: 50) // Avg time/img: 0.0660 s
# loss: 0.3277 (epoch: 23, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.649 (epoch: 23, step: 0) // Avg time/img: 0.0307 s
# VAL loss: 0.807 (epoch: 23, step: 50) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  35.57 %
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.0003236051545417615
# loss: 0.2848 (epoch: 24, step: 0) // Avg time/img: 0.0768 s
# loss: 0.3182 (epoch: 24, step: 50) // Avg time/img: 0.0665 s
# loss: 0.3161 (epoch: 24, step: 100) // Avg time/img: 0.0660 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 0.525 (epoch: 24, step: 0) // Avg time/img: 0.0322 s
# VAL loss: 0.6698 (epoch: 24, step: 50) // Avg time/img: 0.0234 s
# EPOCH IoU on VAL set:  38.39 %
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.3528 (epoch: 25, step: 0) // Avg time/img: 0.0795 s
# loss: 0.3161 (epoch: 25, step: 50) // Avg time/img: 0.0659 s
# loss: 0.3125 (epoch: 25, step: 100) // Avg time/img: 0.0656 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.6329 (epoch: 25, step: 0) // Avg time/img: 0.0319 s
# VAL loss: 0.6612 (epoch: 25, step: 50) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  37.59 %
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00030781878448615926
# loss: 0.3274 (epoch: 26, step: 0) // Avg time/img: 0.0771 s
# loss: 0.3021 (epoch: 26, step: 50) // Avg time/img: 0.0664 s
# loss: 0.302 (epoch: 26, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.5557 (epoch: 26, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.6541 (epoch: 26, step: 50) // Avg time/img: 0.0240 s
# EPOCH IoU on VAL set:  38.83 %
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.2882 (epoch: 27, step: 0) // Avg time/img: 0.0777 s
# loss: 0.2908 (epoch: 27, step: 50) // Avg time/img: 0.0657 s
# loss: 0.2961 (epoch: 27, step: 100) // Avg time/img: 0.0655 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.8548 (epoch: 27, step: 0) // Avg time/img: 0.0293 s
# VAL loss: 0.7972 (epoch: 27, step: 50) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  37.49 %
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00029194189645999016
# loss: 0.3267 (epoch: 28, step: 0) // Avg time/img: 0.0775 s
# loss: 0.3049 (epoch: 28, step: 50) // Avg time/img: 0.0660 s
# loss: 0.3043 (epoch: 28, step: 100) // Avg time/img: 0.0656 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.3571 (epoch: 28, step: 0) // Avg time/img: 0.0309 s
# VAL loss: 0.6032 (epoch: 28, step: 50) // Avg time/img: 0.0231 s
# EPOCH IoU on VAL set:  39.57 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 28)
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.3215 (epoch: 29, step: 0) // Avg time/img: 0.0769 s
# loss: 0.2999 (epoch: 29, step: 50) // Avg time/img: 0.0663 s
# loss: 0.2939 (epoch: 29, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.5635 (epoch: 29, step: 0) // Avg time/img: 0.0329 s
# VAL loss: 0.6392 (epoch: 29, step: 50) // Avg time/img: 0.0239 s
# EPOCH IoU on VAL set:  39.34 %
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.0002759684303703797
# loss: 0.2126 (epoch: 30, step: 0) // Avg time/img: 0.0780 s
# loss: 0.2882 (epoch: 30, step: 50) // Avg time/img: 0.0658 s
# loss: 0.283 (epoch: 30, step: 100) // Avg time/img: 0.0656 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.5942 (epoch: 30, step: 0) // Avg time/img: 0.0339 s
# VAL loss: 0.6668 (epoch: 30, step: 50) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  39.50 %
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.2641 (epoch: 31, step: 0) // Avg time/img: 0.0752 s
# loss: 0.2621 (epoch: 31, step: 50) // Avg time/img: 0.0664 s
# loss: 0.2668 (epoch: 31, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.5512 (epoch: 31, step: 0) // Avg time/img: 0.0326 s
# VAL loss: 0.6909 (epoch: 31, step: 50) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  39.44 %
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.0002598915008274931
# loss: 0.2919 (epoch: 32, step: 0) // Avg time/img: 0.0748 s
# loss: 0.27 (epoch: 32, step: 50) // Avg time/img: 0.0661 s
# loss: 0.2761 (epoch: 32, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.6179 (epoch: 32, step: 0) // Avg time/img: 0.0335 s
# VAL loss: 0.6249 (epoch: 32, step: 50) // Avg time/img: 0.0231 s
# EPOCH IoU on VAL set:  40.47 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 32)
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.239 (epoch: 33, step: 0) // Avg time/img: 0.0784 s
# loss: 0.2745 (epoch: 33, step: 50) // Avg time/img: 0.0641 s
# loss: 0.2737 (epoch: 33, step: 100) // Avg time/img: 0.0641 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.5765 (epoch: 33, step: 0) // Avg time/img: 0.0314 s
# VAL loss: 0.612 (epoch: 33, step: 50) // Avg time/img: 0.0227 s
# EPOCH IoU on VAL set:  41.05 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 33)
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.00024370321958949772
# loss: 0.2577 (epoch: 34, step: 0) // Avg time/img: 0.0753 s
# loss: 0.2603 (epoch: 34, step: 50) // Avg time/img: 0.0638 s
# loss: 0.2612 (epoch: 34, step: 100) // Avg time/img: 0.0639 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.6899 (epoch: 34, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.7266 (epoch: 34, step: 50) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  39.93 %
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.2007 (epoch: 35, step: 0) // Avg time/img: 0.0746 s
# loss: 0.2753 (epoch: 35, step: 50) // Avg time/img: 0.0641 s
# loss: 0.2738 (epoch: 35, step: 100) // Avg time/img: 0.0640 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.4404 (epoch: 35, step: 0) // Avg time/img: 0.0304 s
# VAL loss: 0.5925 (epoch: 35, step: 50) // Avg time/img: 0.0231 s
# EPOCH IoU on VAL set:  41.78 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 35)
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.00022739446367039517
# loss: 0.273 (epoch: 36, step: 0) // Avg time/img: 0.0811 s
# loss: 0.2545 (epoch: 36, step: 50) // Avg time/img: 0.0638 s
# loss: 0.2528 (epoch: 36, step: 100) // Avg time/img: 0.0639 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.461 (epoch: 36, step: 0) // Avg time/img: 0.0313 s
# VAL loss: 0.5844 (epoch: 36, step: 50) // Avg time/img: 0.0233 s
# EPOCH IoU on VAL set:  42.65 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 36)
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.2288 (epoch: 37, step: 0) // Avg time/img: 0.0759 s
# loss: 0.2428 (epoch: 37, step: 50) // Avg time/img: 0.0639 s
# loss: 0.2502 (epoch: 37, step: 100) // Avg time/img: 0.0639 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.4477 (epoch: 37, step: 0) // Avg time/img: 0.0312 s
# VAL loss: 0.6421 (epoch: 37, step: 50) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  40.45 %
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.00021095456673472888
# loss: 0.3321 (epoch: 38, step: 0) // Avg time/img: 0.0735 s
# loss: 0.2478 (epoch: 38, step: 50) // Avg time/img: 0.0640 s
# loss: 0.2543 (epoch: 38, step: 100) // Avg time/img: 0.0640 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.5346 (epoch: 38, step: 0) // Avg time/img: 0.0302 s
# VAL loss: 0.6172 (epoch: 38, step: 50) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  41.76 %
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.3173 (epoch: 39, step: 0) // Avg time/img: 0.0752 s
# loss: 0.2412 (epoch: 39, step: 50) // Avg time/img: 0.0639 s
# loss: 0.2379 (epoch: 39, step: 100) // Avg time/img: 0.0641 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.42 (epoch: 39, step: 0) // Avg time/img: 0.0305 s
# VAL loss: 0.5992 (epoch: 39, step: 50) // Avg time/img: 0.0245 s
# EPOCH IoU on VAL set:  42.30 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.2151 (epoch: 40, step: 0) // Avg time/img: 0.0755 s
# loss: 0.2277 (epoch: 40, step: 50) // Avg time/img: 0.0661 s
# loss: 0.2346 (epoch: 40, step: 100) // Avg time/img: 0.0659 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.6171 (epoch: 40, step: 0) // Avg time/img: 0.0291 s
# VAL loss: 0.6139 (epoch: 40, step: 50) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  42.78 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 40)
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.2481 (epoch: 41, step: 0) // Avg time/img: 0.0771 s
# loss: 0.2312 (epoch: 41, step: 50) // Avg time/img: 0.0663 s
# loss: 0.2294 (epoch: 41, step: 100) // Avg time/img: 0.0659 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.4713 (epoch: 41, step: 0) // Avg time/img: 0.0328 s
# VAL loss: 0.6033 (epoch: 41, step: 50) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  42.56 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.1978 (epoch: 42, step: 0) // Avg time/img: 0.0743 s
# loss: 0.2302 (epoch: 42, step: 50) // Avg time/img: 0.0661 s
# loss: 0.2315 (epoch: 42, step: 100) // Avg time/img: 0.0659 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.4428 (epoch: 42, step: 0) // Avg time/img: 0.0323 s
# VAL loss: 0.6143 (epoch: 42, step: 50) // Avg time/img: 0.0239 s
# EPOCH IoU on VAL set:  42.53 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.3998 (epoch: 43, step: 0) // Avg time/img: 0.0792 s
# loss: 0.2391 (epoch: 43, step: 50) // Avg time/img: 0.0661 s
# loss: 0.237 (epoch: 43, step: 100) // Avg time/img: 0.0659 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.4472 (epoch: 43, step: 0) // Avg time/img: 0.0319 s
# VAL loss: 0.6129 (epoch: 43, step: 50) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  43.08 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 43)
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.2367 (epoch: 44, step: 0) // Avg time/img: 0.0813 s
# loss: 0.2224 (epoch: 44, step: 50) // Avg time/img: 0.0659 s
# loss: 0.2218 (epoch: 44, step: 100) // Avg time/img: 0.0656 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.376 (epoch: 44, step: 0) // Avg time/img: 0.0315 s
# VAL loss: 0.5787 (epoch: 44, step: 50) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  43.13 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 44)
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.2112 (epoch: 45, step: 0) // Avg time/img: 0.0782 s
# loss: 0.2211 (epoch: 45, step: 50) // Avg time/img: 0.0660 s
# loss: 0.2184 (epoch: 45, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.5181 (epoch: 45, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.6456 (epoch: 45, step: 50) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  43.42 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 45)
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.1675 (epoch: 46, step: 0) // Avg time/img: 0.0834 s
# loss: 0.2188 (epoch: 46, step: 50) // Avg time/img: 0.0667 s
# loss: 0.2201 (epoch: 46, step: 100) // Avg time/img: 0.0661 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.4406 (epoch: 46, step: 0) // Avg time/img: 0.0314 s
# VAL loss: 0.5824 (epoch: 46, step: 50) // Avg time/img: 0.0239 s
# EPOCH IoU on VAL set:  43.88 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 46)
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.2345 (epoch: 47, step: 0) // Avg time/img: 0.0750 s
# loss: 0.2 (epoch: 47, step: 50) // Avg time/img: 0.0661 s
# loss: 0.2097 (epoch: 47, step: 100) // Avg time/img: 0.0660 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.4618 (epoch: 47, step: 0) // Avg time/img: 0.0309 s
# VAL loss: 0.6248 (epoch: 47, step: 50) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  44.02 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 47)
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.2526 (epoch: 48, step: 0) // Avg time/img: 0.0792 s
# loss: 0.2134 (epoch: 48, step: 50) // Avg time/img: 0.0663 s
# loss: 0.2122 (epoch: 48, step: 100) // Avg time/img: 0.0657 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.4198 (epoch: 48, step: 0) // Avg time/img: 0.0304 s
# VAL loss: 0.5718 (epoch: 48, step: 50) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  44.90 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 48)
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.1761 (epoch: 49, step: 0) // Avg time/img: 0.0752 s
# loss: 0.1955 (epoch: 49, step: 50) // Avg time/img: 0.0664 s
# loss: 0.2024 (epoch: 49, step: 100) // Avg time/img: 0.0660 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.3193 (epoch: 49, step: 0) // Avg time/img: 0.0308 s
# VAL loss: 0.5742 (epoch: 49, step: 50) // Avg time/img: 0.0231 s
# EPOCH IoU on VAL set:  45.54 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 49)
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.1956 (epoch: 50, step: 0) // Avg time/img: 0.0823 s
# loss: 0.2068 (epoch: 50, step: 50) // Avg time/img: 0.0663 s
# loss: 0.2037 (epoch: 50, step: 100) // Avg time/img: 0.0659 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.395 (epoch: 50, step: 0) // Avg time/img: 0.0311 s
# VAL loss: 0.5859 (epoch: 50, step: 50) // Avg time/img: 0.0240 s
# EPOCH IoU on VAL set:  44.73 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.2201 (epoch: 51, step: 0) // Avg time/img: 0.0777 s
# loss: 0.2056 (epoch: 51, step: 50) // Avg time/img: 0.0665 s
# loss: 0.203 (epoch: 51, step: 100) // Avg time/img: 0.0660 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.4107 (epoch: 51, step: 0) // Avg time/img: 0.0303 s
# VAL loss: 0.614 (epoch: 51, step: 50) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  43.58 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.1701 (epoch: 52, step: 0) // Avg time/img: 0.0747 s
# loss: 0.2151 (epoch: 52, step: 50) // Avg time/img: 0.0664 s
# loss: 0.2079 (epoch: 52, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.3892 (epoch: 52, step: 0) // Avg time/img: 0.0273 s
# VAL loss: 0.5977 (epoch: 52, step: 50) // Avg time/img: 0.0239 s
# EPOCH IoU on VAL set:  44.41 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.2066 (epoch: 53, step: 0) // Avg time/img: 0.0746 s
# loss: 0.2007 (epoch: 53, step: 50) // Avg time/img: 0.0660 s
# loss: 0.2007 (epoch: 53, step: 100) // Avg time/img: 0.0656 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.345 (epoch: 53, step: 0) // Avg time/img: 0.0325 s
# VAL loss: 0.5674 (epoch: 53, step: 50) // Avg time/img: 0.0234 s
# EPOCH IoU on VAL set:  45.27 %
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.1979 (epoch: 54, step: 0) // Avg time/img: 0.0767 s
# loss: 0.1943 (epoch: 54, step: 50) // Avg time/img: 0.0661 s
# loss: 0.1924 (epoch: 54, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.4253 (epoch: 54, step: 0) // Avg time/img: 0.0341 s
# VAL loss: 0.5643 (epoch: 54, step: 50) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  45.09 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.1731 (epoch: 55, step: 0) // Avg time/img: 0.0740 s
# loss: 0.1874 (epoch: 55, step: 50) // Avg time/img: 0.0661 s
# loss: 0.1901 (epoch: 55, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.3223 (epoch: 55, step: 0) // Avg time/img: 0.0324 s
# VAL loss: 0.5613 (epoch: 55, step: 50) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  45.70 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 55)
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.1851 (epoch: 56, step: 0) // Avg time/img: 0.0759 s
# loss: 0.1902 (epoch: 56, step: 50) // Avg time/img: 0.0662 s
# loss: 0.189 (epoch: 56, step: 100) // Avg time/img: 0.0660 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.3662 (epoch: 56, step: 0) // Avg time/img: 0.0310 s
# VAL loss: 0.5613 (epoch: 56, step: 50) // Avg time/img: 0.0240 s
# EPOCH IoU on VAL set:  45.53 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.1984 (epoch: 57, step: 0) // Avg time/img: 0.0790 s
# loss: 0.1765 (epoch: 57, step: 50) // Avg time/img: 0.0663 s
# loss: 0.185 (epoch: 57, step: 100) // Avg time/img: 0.0659 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.3382 (epoch: 57, step: 0) // Avg time/img: 0.0305 s
# VAL loss: 0.553 (epoch: 57, step: 50) // Avg time/img: 0.0241 s
# EPOCH IoU on VAL set:  46.29 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 57)
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.1673 (epoch: 58, step: 0) // Avg time/img: 0.0769 s
# loss: 0.1884 (epoch: 58, step: 50) // Avg time/img: 0.0666 s
# loss: 0.1834 (epoch: 58, step: 100) // Avg time/img: 0.0663 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.3466 (epoch: 58, step: 0) // Avg time/img: 0.0330 s
# VAL loss: 0.5385 (epoch: 58, step: 50) // Avg time/img: 0.0234 s
# EPOCH IoU on VAL set:  46.32 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_encoder_best.pth (epoch: 58)
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.167 (epoch: 59, step: 0) // Avg time/img: 0.0791 s
# loss: 0.1789 (epoch: 59, step: 50) // Avg time/img: 0.0664 s
# loss: 0.1799 (epoch: 59, step: 100) // Avg time/img: 0.0658 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.3685 (epoch: 59, step: 0) // Avg time/img: 0.0355 s
# VAL loss: 0.5571 (epoch: 59, step: 50) // Avg time/img: 0.0240 s
# EPOCH IoU on VAL set:  46.07 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.1685 (epoch: 60, step: 0) // Avg time/img: 0.0746 s
# loss: 0.1839 (epoch: 60, step: 50) // Avg time/img: 0.0662 s
# loss: 0.1813 (epoch: 60, step: 100) // Avg time/img: 0.0660 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.3545 (epoch: 60, step: 0) // Avg time/img: 0.0308 s
# VAL loss: 0.5513 (epoch: 60, step: 50) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  46.31 %
# ========== DECODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.072 (epoch: 1, step: 0) // Avg time/img: 0.1067 s
# loss: 2.487 (epoch: 1, step: 50) // Avg time/img: 0.0934 s
# loss: 2.073 (epoch: 1, step: 100) // Avg time/img: 0.0936 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.506 (epoch: 1, step: 0) // Avg time/img: 0.0444 s
# VAL loss: 1.571 (epoch: 1, step: 50) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  20.56 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 1.294 (epoch: 2, step: 0) // Avg time/img: 0.1075 s
# loss: 1.064 (epoch: 2, step: 50) // Avg time/img: 0.0943 s
# loss: 0.9886 (epoch: 2, step: 100) // Avg time/img: 0.0938 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 0.761 (epoch: 2, step: 0) // Avg time/img: 0.0468 s
# VAL loss: 1.171 (epoch: 2, step: 50) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  22.60 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.6142 (epoch: 3, step: 0) // Avg time/img: 0.1036 s
# loss: 0.8001 (epoch: 3, step: 50) // Avg time/img: 0.0939 s
# loss: 0.7714 (epoch: 3, step: 100) // Avg time/img: 0.0943 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 0.7327 (epoch: 3, step: 0) // Avg time/img: 0.0445 s
# VAL loss: 1.04 (epoch: 3, step: 50) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  24.57 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 0.7711 (epoch: 4, step: 0) // Avg time/img: 0.0972 s
# loss: 0.671 (epoch: 4, step: 50) // Avg time/img: 0.0929 s
# loss: 0.671 (epoch: 4, step: 100) // Avg time/img: 0.0933 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 0.7693 (epoch: 4, step: 0) // Avg time/img: 0.0474 s
# VAL loss: 1.033 (epoch: 4, step: 50) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  25.80 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.603 (epoch: 5, step: 0) // Avg time/img: 0.1051 s
# loss: 0.6356 (epoch: 5, step: 50) // Avg time/img: 0.0935 s
# loss: 0.601 (epoch: 5, step: 100) // Avg time/img: 0.0935 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 0.728 (epoch: 5, step: 0) // Avg time/img: 0.0455 s
# VAL loss: 0.9122 (epoch: 5, step: 50) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  25.97 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 5)
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004623387553722673
# loss: 0.4832 (epoch: 6, step: 0) // Avg time/img: 0.1062 s
# loss: 0.6024 (epoch: 6, step: 50) // Avg time/img: 0.0932 s
# loss: 0.5799 (epoch: 6, step: 100) // Avg time/img: 0.0932 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 0.7065 (epoch: 6, step: 0) // Avg time/img: 0.0457 s
# VAL loss: 0.8797 (epoch: 6, step: 50) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  29.10 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.5876 (epoch: 7, step: 0) // Avg time/img: 0.1039 s
# loss: 0.5319 (epoch: 7, step: 50) // Avg time/img: 0.0967 s
# loss: 0.527 (epoch: 7, step: 100) // Avg time/img: 0.0959 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 0.5452 (epoch: 7, step: 0) // Avg time/img: 0.0477 s
# VAL loss: 0.8335 (epoch: 7, step: 50) // Avg time/img: 0.0350 s
# EPOCH IoU on VAL set:  30.16 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 7)
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.00044717978378742816
# loss: 0.5763 (epoch: 8, step: 0) // Avg time/img: 0.1122 s
# loss: 0.5216 (epoch: 8, step: 50) // Avg time/img: 0.0959 s
# loss: 0.5006 (epoch: 8, step: 100) // Avg time/img: 0.0956 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 0.4836 (epoch: 8, step: 0) // Avg time/img: 0.0455 s
# VAL loss: 0.8328 (epoch: 8, step: 50) // Avg time/img: 0.0347 s
# EPOCH IoU on VAL set:  30.24 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 8)
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.4007 (epoch: 9, step: 0) // Avg time/img: 0.1076 s
# loss: 0.471 (epoch: 9, step: 50) // Avg time/img: 0.0964 s
# loss: 0.4784 (epoch: 9, step: 100) // Avg time/img: 0.0960 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 0.5909 (epoch: 9, step: 0) // Avg time/img: 0.0462 s
# VAL loss: 0.788 (epoch: 9, step: 50) // Avg time/img: 0.0343 s
# EPOCH IoU on VAL set:  31.38 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 9)
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.00043196348615140955
# loss: 0.2986 (epoch: 10, step: 0) // Avg time/img: 0.1115 s
# loss: 0.4718 (epoch: 10, step: 50) // Avg time/img: 0.0960 s
# loss: 0.4753 (epoch: 10, step: 100) // Avg time/img: 0.0959 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 0.6219 (epoch: 10, step: 0) // Avg time/img: 0.0500 s
# VAL loss: 0.7794 (epoch: 10, step: 50) // Avg time/img: 0.0345 s
# EPOCH IoU on VAL set:  34.67 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 10)
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.4689 (epoch: 11, step: 0) // Avg time/img: 0.1101 s
# loss: 0.499 (epoch: 11, step: 50) // Avg time/img: 0.0963 s
# loss: 0.4939 (epoch: 11, step: 100) // Avg time/img: 0.0958 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.6313 (epoch: 11, step: 0) // Avg time/img: 0.0429 s
# VAL loss: 0.7979 (epoch: 11, step: 50) // Avg time/img: 0.0346 s
# EPOCH IoU on VAL set:  33.71 %
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.0004166873834706844
# loss: 0.3665 (epoch: 12, step: 0) // Avg time/img: 0.1100 s
# loss: 0.4035 (epoch: 12, step: 50) // Avg time/img: 0.0957 s
# loss: 0.4088 (epoch: 12, step: 100) // Avg time/img: 0.0955 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.5873 (epoch: 12, step: 0) // Avg time/img: 0.0446 s
# VAL loss: 0.7708 (epoch: 12, step: 50) // Avg time/img: 0.0350 s
# EPOCH IoU on VAL set:  35.81 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 12)
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.2654 (epoch: 13, step: 0) // Avg time/img: 0.1077 s
# loss: 0.4205 (epoch: 13, step: 50) // Avg time/img: 0.0959 s
# loss: 0.4028 (epoch: 13, step: 100) // Avg time/img: 0.0958 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 0.5092 (epoch: 13, step: 0) // Avg time/img: 0.0481 s
# VAL loss: 0.7102 (epoch: 13, step: 50) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  37.44 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 13)
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.0004013487836640184
# loss: 0.3369 (epoch: 14, step: 0) // Avg time/img: 0.1069 s
# loss: 0.3669 (epoch: 14, step: 50) // Avg time/img: 0.0959 s
# loss: 0.3807 (epoch: 14, step: 100) // Avg time/img: 0.0955 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 0.4728 (epoch: 14, step: 0) // Avg time/img: 0.0472 s
# VAL loss: 0.7096 (epoch: 14, step: 50) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  37.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 14)
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.3509 (epoch: 15, step: 0) // Avg time/img: 0.1059 s
# loss: 0.3731 (epoch: 15, step: 50) // Avg time/img: 0.0965 s
# loss: 0.396 (epoch: 15, step: 100) // Avg time/img: 0.0957 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 0.7058 (epoch: 15, step: 0) // Avg time/img: 0.0452 s
# VAL loss: 0.8174 (epoch: 15, step: 50) // Avg time/img: 0.0345 s
# EPOCH IoU on VAL set:  37.05 %
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00038594475336178527
# loss: 0.2698 (epoch: 16, step: 0) // Avg time/img: 0.1084 s
# loss: 0.3479 (epoch: 16, step: 50) // Avg time/img: 0.0962 s
# loss: 0.3482 (epoch: 16, step: 100) // Avg time/img: 0.0956 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.5627 (epoch: 16, step: 0) // Avg time/img: 0.0464 s
# VAL loss: 0.6875 (epoch: 16, step: 50) // Avg time/img: 0.0348 s
# EPOCH IoU on VAL set:  39.12 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 16)
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.4537 (epoch: 17, step: 0) // Avg time/img: 0.1099 s
# loss: 0.3576 (epoch: 17, step: 50) // Avg time/img: 0.0957 s
# loss: 0.3454 (epoch: 17, step: 100) // Avg time/img: 0.0956 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.4326 (epoch: 17, step: 0) // Avg time/img: 0.0470 s
# VAL loss: 0.6732 (epoch: 17, step: 50) // Avg time/img: 0.0343 s
# EPOCH IoU on VAL set:  40.20 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 17)
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.00037047208454744316
# loss: 0.3516 (epoch: 18, step: 0) // Avg time/img: 0.1047 s
# loss: 0.3391 (epoch: 18, step: 50) // Avg time/img: 0.0961 s
# loss: 0.3355 (epoch: 18, step: 100) // Avg time/img: 0.0955 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.5972 (epoch: 18, step: 0) // Avg time/img: 0.0417 s
# VAL loss: 0.7755 (epoch: 18, step: 50) // Avg time/img: 0.0349 s
# EPOCH IoU on VAL set:  39.17 %
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.3545 (epoch: 19, step: 0) // Avg time/img: 0.1084 s
# loss: 0.3136 (epoch: 19, step: 50) // Avg time/img: 0.0959 s
# loss: 0.3259 (epoch: 19, step: 100) // Avg time/img: 0.0957 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.6886 (epoch: 19, step: 0) // Avg time/img: 0.0461 s
# VAL loss: 0.7546 (epoch: 19, step: 50) // Avg time/img: 0.0347 s
# EPOCH IoU on VAL set:  37.95 %
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.0003549272548125162
# loss: 0.453 (epoch: 20, step: 0) // Avg time/img: 0.1011 s
# loss: 0.3443 (epoch: 20, step: 50) // Avg time/img: 0.0947 s
# loss: 0.3422 (epoch: 20, step: 100) // Avg time/img: 0.0946 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.5027 (epoch: 20, step: 0) // Avg time/img: 0.0473 s
# VAL loss: 0.7185 (epoch: 20, step: 50) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  38.98 %
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.3927 (epoch: 21, step: 0) // Avg time/img: 0.1046 s
# loss: 0.3224 (epoch: 21, step: 50) // Avg time/img: 0.0941 s
# loss: 0.3196 (epoch: 21, step: 100) // Avg time/img: 0.0941 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.5137 (epoch: 21, step: 0) // Avg time/img: 0.0436 s
# VAL loss: 0.6429 (epoch: 21, step: 50) // Avg time/img: 0.0343 s
# EPOCH IoU on VAL set:  41.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 21)
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.0003393063796290625
# loss: 0.2903 (epoch: 22, step: 0) // Avg time/img: 0.1010 s
# loss: 0.3074 (epoch: 22, step: 50) // Avg time/img: 0.0941 s
# loss: 0.312 (epoch: 22, step: 100) // Avg time/img: 0.0943 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.587 (epoch: 22, step: 0) // Avg time/img: 0.0482 s
# VAL loss: 0.7408 (epoch: 22, step: 50) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  40.10 %
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.2211 (epoch: 23, step: 0) // Avg time/img: 0.1047 s
# loss: 0.3093 (epoch: 23, step: 50) // Avg time/img: 0.0943 s
# loss: 0.3145 (epoch: 23, step: 100) // Avg time/img: 0.0943 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.4124 (epoch: 23, step: 0) // Avg time/img: 0.0411 s
# VAL loss: 0.6519 (epoch: 23, step: 50) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  42.55 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 23)
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.0003236051545417615
# loss: 0.3184 (epoch: 24, step: 0) // Avg time/img: 0.1038 s
# loss: 0.3239 (epoch: 24, step: 50) // Avg time/img: 0.0935 s
# loss: 0.3093 (epoch: 24, step: 100) // Avg time/img: 0.0938 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 0.7838 (epoch: 24, step: 0) // Avg time/img: 0.0478 s
# VAL loss: 0.7295 (epoch: 24, step: 50) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  40.46 %
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.4039 (epoch: 25, step: 0) // Avg time/img: 0.1086 s
# loss: 0.3045 (epoch: 25, step: 50) // Avg time/img: 0.0932 s
# loss: 0.2996 (epoch: 25, step: 100) // Avg time/img: 0.0935 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.4521 (epoch: 25, step: 0) // Avg time/img: 0.0500 s
# VAL loss: 0.6406 (epoch: 25, step: 50) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  42.93 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 25)
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00030781878448615926
# loss: 0.3084 (epoch: 26, step: 0) // Avg time/img: 0.1055 s
# loss: 0.2912 (epoch: 26, step: 50) // Avg time/img: 0.0934 s
# loss: 0.2836 (epoch: 26, step: 100) // Avg time/img: 0.0936 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.4754 (epoch: 26, step: 0) // Avg time/img: 0.0486 s
# VAL loss: 0.6234 (epoch: 26, step: 50) // Avg time/img: 0.0345 s
# EPOCH IoU on VAL set:  44.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 26)
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.2881 (epoch: 27, step: 0) // Avg time/img: 0.1044 s
# loss: 0.2862 (epoch: 27, step: 50) // Avg time/img: 0.0958 s
# loss: 0.2876 (epoch: 27, step: 100) // Avg time/img: 0.0955 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.5086 (epoch: 27, step: 0) // Avg time/img: 0.0478 s
# VAL loss: 0.6733 (epoch: 27, step: 50) // Avg time/img: 0.0346 s
# EPOCH IoU on VAL set:  42.00 %
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00029194189645999016
# loss: 0.3854 (epoch: 28, step: 0) // Avg time/img: 0.1081 s
# loss: 0.2779 (epoch: 28, step: 50) // Avg time/img: 0.0954 s
# loss: 0.2864 (epoch: 28, step: 100) // Avg time/img: 0.0950 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.5437 (epoch: 28, step: 0) // Avg time/img: 0.0502 s
# VAL loss: 0.7039 (epoch: 28, step: 50) // Avg time/img: 0.0347 s
# EPOCH IoU on VAL set:  43.64 %
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.2515 (epoch: 29, step: 0) // Avg time/img: 0.1105 s
# loss: 0.27 (epoch: 29, step: 50) // Avg time/img: 0.0959 s
# loss: 0.2675 (epoch: 29, step: 100) // Avg time/img: 0.0955 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.6346 (epoch: 29, step: 0) // Avg time/img: 0.0419 s
# VAL loss: 0.6758 (epoch: 29, step: 50) // Avg time/img: 0.0348 s
# EPOCH IoU on VAL set:  43.62 %
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.0002759684303703797
# loss: 0.276 (epoch: 30, step: 0) // Avg time/img: 0.1093 s
# loss: 0.271 (epoch: 30, step: 50) // Avg time/img: 0.0959 s
# loss: 0.2681 (epoch: 30, step: 100) // Avg time/img: 0.0956 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.4913 (epoch: 30, step: 0) // Avg time/img: 0.0412 s
# VAL loss: 0.6138 (epoch: 30, step: 50) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  44.57 %
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.2326 (epoch: 31, step: 0) // Avg time/img: 0.1142 s
# loss: 0.2642 (epoch: 31, step: 50) // Avg time/img: 0.0960 s
# loss: 0.269 (epoch: 31, step: 100) // Avg time/img: 0.0955 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.7029 (epoch: 31, step: 0) // Avg time/img: 0.0490 s
# VAL loss: 0.6642 (epoch: 31, step: 50) // Avg time/img: 0.0350 s
# EPOCH IoU on VAL set:  42.36 %
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.0002598915008274931
# loss: 0.3653 (epoch: 32, step: 0) // Avg time/img: 0.1114 s
# loss: 0.2526 (epoch: 32, step: 50) // Avg time/img: 0.0960 s
# loss: 0.2548 (epoch: 32, step: 100) // Avg time/img: 0.0955 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.5543 (epoch: 32, step: 0) // Avg time/img: 0.0498 s
# VAL loss: 0.6635 (epoch: 32, step: 50) // Avg time/img: 0.0351 s
# EPOCH IoU on VAL set:  43.46 %
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.3136 (epoch: 33, step: 0) // Avg time/img: 0.1078 s
# loss: 0.242 (epoch: 33, step: 50) // Avg time/img: 0.0957 s
# loss: 0.2445 (epoch: 33, step: 100) // Avg time/img: 0.0952 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.5786 (epoch: 33, step: 0) // Avg time/img: 0.0459 s
# VAL loss: 0.6587 (epoch: 33, step: 50) // Avg time/img: 0.0345 s
# EPOCH IoU on VAL set:  44.79 %
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.00024370321958949772
# loss: 0.2763 (epoch: 34, step: 0) // Avg time/img: 0.1053 s
# loss: 0.266 (epoch: 34, step: 50) // Avg time/img: 0.0957 s
# loss: 0.2587 (epoch: 34, step: 100) // Avg time/img: 0.0957 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.4357 (epoch: 34, step: 0) // Avg time/img: 0.0462 s
# VAL loss: 0.6315 (epoch: 34, step: 50) // Avg time/img: 0.0343 s
# EPOCH IoU on VAL set:  45.92 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 34)
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.3041 (epoch: 35, step: 0) // Avg time/img: 0.1085 s
# loss: 0.2444 (epoch: 35, step: 50) // Avg time/img: 0.0963 s
# loss: 0.2393 (epoch: 35, step: 100) // Avg time/img: 0.0959 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.4743 (epoch: 35, step: 0) // Avg time/img: 0.0475 s
# VAL loss: 0.6173 (epoch: 35, step: 50) // Avg time/img: 0.0348 s
# EPOCH IoU on VAL set:  45.40 %
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.00022739446367039517
# loss: 0.1958 (epoch: 36, step: 0) // Avg time/img: 0.1052 s
# loss: 0.2395 (epoch: 36, step: 50) // Avg time/img: 0.0956 s
# loss: 0.2446 (epoch: 36, step: 100) // Avg time/img: 0.0954 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.3636 (epoch: 36, step: 0) // Avg time/img: 0.0408 s
# VAL loss: 0.6459 (epoch: 36, step: 50) // Avg time/img: 0.0345 s
# EPOCH IoU on VAL set:  46.03 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 36)
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.1796 (epoch: 37, step: 0) // Avg time/img: 0.1145 s
# loss: 0.2315 (epoch: 37, step: 50) // Avg time/img: 0.0964 s
# loss: 0.2363 (epoch: 37, step: 100) // Avg time/img: 0.0957 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.3232 (epoch: 37, step: 0) // Avg time/img: 0.0489 s
# VAL loss: 0.5951 (epoch: 37, step: 50) // Avg time/img: 0.0346 s
# EPOCH IoU on VAL set:  46.74 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 37)
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.00021095456673472888
# loss: 0.1665 (epoch: 38, step: 0) // Avg time/img: 0.1060 s
# loss: 0.2226 (epoch: 38, step: 50) // Avg time/img: 0.0956 s
# loss: 0.2273 (epoch: 38, step: 100) // Avg time/img: 0.0951 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.419 (epoch: 38, step: 0) // Avg time/img: 0.0457 s
# VAL loss: 0.6723 (epoch: 38, step: 50) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  44.95 %
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.2533 (epoch: 39, step: 0) // Avg time/img: 0.1084 s
# loss: 0.2295 (epoch: 39, step: 50) // Avg time/img: 0.0955 s
# loss: 0.2306 (epoch: 39, step: 100) // Avg time/img: 0.0953 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.5355 (epoch: 39, step: 0) // Avg time/img: 0.0450 s
# VAL loss: 0.6514 (epoch: 39, step: 50) // Avg time/img: 0.0347 s
# EPOCH IoU on VAL set:  46.21 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.2126 (epoch: 40, step: 0) // Avg time/img: 0.1063 s
# loss: 0.2195 (epoch: 40, step: 50) // Avg time/img: 0.0965 s
# loss: 0.2272 (epoch: 40, step: 100) // Avg time/img: 0.0956 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.3692 (epoch: 40, step: 0) // Avg time/img: 0.0459 s
# VAL loss: 0.642 (epoch: 40, step: 50) // Avg time/img: 0.0349 s
# EPOCH IoU on VAL set:  46.36 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.3157 (epoch: 41, step: 0) // Avg time/img: 0.1089 s
# loss: 0.2424 (epoch: 41, step: 50) // Avg time/img: 0.0957 s
# loss: 0.2292 (epoch: 41, step: 100) // Avg time/img: 0.0953 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.4673 (epoch: 41, step: 0) // Avg time/img: 0.0485 s
# VAL loss: 0.644 (epoch: 41, step: 50) // Avg time/img: 0.0346 s
# EPOCH IoU on VAL set:  45.97 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.2418 (epoch: 42, step: 0) // Avg time/img: 0.1050 s
# loss: 0.2371 (epoch: 42, step: 50) // Avg time/img: 0.0955 s
# loss: 0.2559 (epoch: 42, step: 100) // Avg time/img: 0.0957 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.6006 (epoch: 42, step: 0) // Avg time/img: 0.0456 s
# VAL loss: 0.676 (epoch: 42, step: 50) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  44.11 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.209 (epoch: 43, step: 0) // Avg time/img: 0.1071 s
# loss: 0.2419 (epoch: 43, step: 50) // Avg time/img: 0.0959 s
# loss: 0.2335 (epoch: 43, step: 100) // Avg time/img: 0.0956 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.4523 (epoch: 43, step: 0) // Avg time/img: 0.0455 s
# VAL loss: 0.6204 (epoch: 43, step: 50) // Avg time/img: 0.0346 s
# EPOCH IoU on VAL set:  46.47 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.2008 (epoch: 44, step: 0) // Avg time/img: 0.1052 s
# loss: 0.2143 (epoch: 44, step: 50) // Avg time/img: 0.0959 s
# loss: 0.2112 (epoch: 44, step: 100) // Avg time/img: 0.0955 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.3559 (epoch: 44, step: 0) // Avg time/img: 0.0490 s
# VAL loss: 0.5936 (epoch: 44, step: 50) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  47.02 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 44)
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.1923 (epoch: 45, step: 0) // Avg time/img: 0.1090 s
# loss: 0.2111 (epoch: 45, step: 50) // Avg time/img: 0.0931 s
# loss: 0.2101 (epoch: 45, step: 100) // Avg time/img: 0.0930 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.4144 (epoch: 45, step: 0) // Avg time/img: 0.0421 s
# VAL loss: 0.6091 (epoch: 45, step: 50) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  47.74 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 45)
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.2344 (epoch: 46, step: 0) // Avg time/img: 0.1052 s
# loss: 0.2091 (epoch: 46, step: 50) // Avg time/img: 0.0928 s
# loss: 0.2058 (epoch: 46, step: 100) // Avg time/img: 0.0928 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.488 (epoch: 46, step: 0) // Avg time/img: 0.0430 s
# VAL loss: 0.6273 (epoch: 46, step: 50) // Avg time/img: 0.0343 s
# EPOCH IoU on VAL set:  47.94 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 46)
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.2292 (epoch: 47, step: 0) // Avg time/img: 0.0993 s
# loss: 0.203 (epoch: 47, step: 50) // Avg time/img: 0.0923 s
# loss: 0.2027 (epoch: 47, step: 100) // Avg time/img: 0.0924 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.5436 (epoch: 47, step: 0) // Avg time/img: 0.0431 s
# VAL loss: 0.5953 (epoch: 47, step: 50) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  48.10 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 47)
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.2135 (epoch: 48, step: 0) // Avg time/img: 0.1091 s
# loss: 0.2046 (epoch: 48, step: 50) // Avg time/img: 0.0928 s
# loss: 0.2045 (epoch: 48, step: 100) // Avg time/img: 0.0928 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.4745 (epoch: 48, step: 0) // Avg time/img: 0.0462 s
# VAL loss: 0.6158 (epoch: 48, step: 50) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  48.28 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 48)
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.2344 (epoch: 49, step: 0) // Avg time/img: 0.1036 s
# loss: 0.1941 (epoch: 49, step: 50) // Avg time/img: 0.0924 s
# loss: 0.1977 (epoch: 49, step: 100) // Avg time/img: 0.0926 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.3697 (epoch: 49, step: 0) // Avg time/img: 0.0499 s
# VAL loss: 0.6205 (epoch: 49, step: 50) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  48.12 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.2223 (epoch: 50, step: 0) // Avg time/img: 0.1020 s
# loss: 0.1934 (epoch: 50, step: 50) // Avg time/img: 0.0925 s
# loss: 0.1933 (epoch: 50, step: 100) // Avg time/img: 0.0926 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.4089 (epoch: 50, step: 0) // Avg time/img: 0.0485 s
# VAL loss: 0.6131 (epoch: 50, step: 50) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  48.61 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 50)
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.2234 (epoch: 51, step: 0) // Avg time/img: 0.1042 s
# loss: 0.1952 (epoch: 51, step: 50) // Avg time/img: 0.0924 s
# loss: 0.1925 (epoch: 51, step: 100) // Avg time/img: 0.0922 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.4624 (epoch: 51, step: 0) // Avg time/img: 0.0397 s
# VAL loss: 0.6043 (epoch: 51, step: 50) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  48.97 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 51)
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.1821 (epoch: 52, step: 0) // Avg time/img: 0.1057 s
# loss: 0.1877 (epoch: 52, step: 50) // Avg time/img: 0.0927 s
# loss: 0.1876 (epoch: 52, step: 100) // Avg time/img: 0.0928 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.4027 (epoch: 52, step: 0) // Avg time/img: 0.0498 s
# VAL loss: 0.607 (epoch: 52, step: 50) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  48.76 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.2072 (epoch: 53, step: 0) // Avg time/img: 0.1078 s
# loss: 0.1885 (epoch: 53, step: 50) // Avg time/img: 0.0926 s
# loss: 0.1881 (epoch: 53, step: 100) // Avg time/img: 0.0927 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.3674 (epoch: 53, step: 0) // Avg time/img: 0.0455 s
# VAL loss: 0.6454 (epoch: 53, step: 50) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  47.81 %
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.1681 (epoch: 54, step: 0) // Avg time/img: 0.1082 s
# loss: 0.1855 (epoch: 54, step: 50) // Avg time/img: 0.0929 s
# loss: 0.1826 (epoch: 54, step: 100) // Avg time/img: 0.0930 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.4037 (epoch: 54, step: 0) // Avg time/img: 0.0461 s
# VAL loss: 0.6149 (epoch: 54, step: 50) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  48.65 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.2008 (epoch: 55, step: 0) // Avg time/img: 0.1082 s
# loss: 0.1842 (epoch: 55, step: 50) // Avg time/img: 0.0929 s
# loss: 0.1854 (epoch: 55, step: 100) // Avg time/img: 0.0930 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.3673 (epoch: 55, step: 0) // Avg time/img: 0.0430 s
# VAL loss: 0.6237 (epoch: 55, step: 50) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  48.60 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.2038 (epoch: 56, step: 0) // Avg time/img: 0.1052 s
# loss: 0.181 (epoch: 56, step: 50) // Avg time/img: 0.0922 s
# loss: 0.1824 (epoch: 56, step: 100) // Avg time/img: 0.0926 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.4231 (epoch: 56, step: 0) // Avg time/img: 0.0410 s
# VAL loss: 0.6459 (epoch: 56, step: 50) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  48.64 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.1591 (epoch: 57, step: 0) // Avg time/img: 0.1073 s
# loss: 0.1743 (epoch: 57, step: 50) // Avg time/img: 0.0924 s
# loss: 0.1775 (epoch: 57, step: 100) // Avg time/img: 0.0925 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.4257 (epoch: 57, step: 0) // Avg time/img: 0.0493 s
# VAL loss: 0.6133 (epoch: 57, step: 50) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  49.11 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 57)
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.2296 (epoch: 58, step: 0) // Avg time/img: 0.0976 s
# loss: 0.185 (epoch: 58, step: 50) // Avg time/img: 0.0918 s
# loss: 0.1778 (epoch: 58, step: 100) // Avg time/img: 0.0923 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.434 (epoch: 58, step: 0) // Avg time/img: 0.0410 s
# VAL loss: 0.6191 (epoch: 58, step: 50) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  49.22 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 58)
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.1839 (epoch: 59, step: 0) // Avg time/img: 0.1066 s
# loss: 0.1797 (epoch: 59, step: 50) // Avg time/img: 0.0923 s
# loss: 0.1748 (epoch: 59, step: 100) // Avg time/img: 0.0924 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.4405 (epoch: 59, step: 0) // Avg time/img: 0.0486 s
# VAL loss: 0.6208 (epoch: 59, step: 50) // Avg time/img: 0.0343 s
# EPOCH IoU on VAL set:  49.30 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher/model_best.pth (epoch: 59)
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.1341 (epoch: 60, step: 0) // Avg time/img: 0.1050 s
# loss: 0.1747 (epoch: 60, step: 50) // Avg time/img: 0.0922 s
# loss: 0.1735 (epoch: 60, step: 100) // Avg time/img: 0.0925 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.4535 (epoch: 60, step: 0) // Avg time/img: 0.0474 s
# VAL loss: 0.6278 (epoch: 60, step: 50) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  49.02 %
# ========== TRAINING FINISHED ===========

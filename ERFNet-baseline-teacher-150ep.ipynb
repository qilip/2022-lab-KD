# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet model definition

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)
    

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3_1 = nn.Conv2d(chann, chann, (3,3), stride=1, padding=(1,1), bias=True)

        # self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3_2 = nn.Conv2d(chann, chann, (3, 3), stride=1, padding=(1*dilated,1*dilated), bias=True, dilation = (dilated,dilated))

        # self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3_1(input)
        # output = F.relu(output)
        # output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3_2(output)
        # output = F.relu(output)
        # output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output


class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target


class CrossEntropyLoss2d(torch.nn.Module):

    def __init__(self, weight=None):
        super().__init__()

        self.loss = torch.nn.NLLLoss2d(weight)

    def forward(self, outputs, targets):
        return self.loss(torch.nn.functional.log_softmax(outputs, dim=1), targets)


def train(args, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = CrossEntropyLoss2d(weight)
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train()
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0])
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 

            loss = criterion(outputs, targets[:, 0])
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Model
    # assert os.path.exists(args.model + ".py"), "Error: model definition not found"
    # model_file = importlib.import_module(args.model)
    model = Net(NUM_CLASSES)
    # copyfile(args.model + ".py", savedir + '/' + args.model + ".py")
    
    if args.cuda:
        model = torch.nn.DataParallel(model).cuda()
    
    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        """
        try:
            model.load_state_dict(torch.load(args.state))
        except AssertionError:
            model.load_state_dict(torch.load(args.state,
                map_location=lambda storage, loc: storage))
        #When model is saved as DataParallel it adds a model. to each key. To remove:
        #state_dict = {k.partition('model.')[2]: v for k,v in state_dict}
        #https://discuss.pytorch.org/t/prefix-parameter-names-in-saved-model-if-trained-by-multi-gpu/494
        """
        def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict keys are there
            own_state = model.state_dict()
            for name, param in state_dict.items():
                if name not in own_state:
                     continue
                own_state[name].copy_(param)
            return model

        #print(torch.load(args.state))
        model = load_my_state_dict(model, torch.load(args.state))

    """
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            #m.weight.data.normal_(0.0, 0.02)
            n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
            m.weight.data.normal_(0, math.sqrt(2. / n))
        elif classname.find('BatchNorm') != -1:
            #m.weight.data.normal_(1.0, 0.02)
            m.weight.data.fill_(1)
            m.bias.data.fill_(0)
    #TO ACCESS MODEL IN DataParallel: next(model.children())
    #next(model.children()).decoder.apply(weights_init)
    #Reinitialize weights for decoder
    
    next(model.children()).decoder.layers.apply(weights_init)
    next(model.children()).decoder.output_conv.apply(weights_init)
    #print(model.state_dict())
    f = open('weights5.txt', 'w')
    f.write(str(model.state_dict()))
    f.close()
    """

    # train(args, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=150)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=3)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 4.459 (epoch: 1, step: 0) // Avg time/img: 2.6936 s
# loss: 1.567 (epoch: 1, step: 50) // Avg time/img: 0.1108 s
# loss: 1.298 (epoch: 1, step: 100) // Avg time/img: 0.0872 s
# loss: 1.194 (epoch: 1, step: 150) // Avg time/img: 0.0797 s
# loss: 1.124 (epoch: 1, step: 200) // Avg time/img: 0.0758 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.145 (epoch: 1, step: 0) // Avg time/img: 0.0325 s
# VAL loss: 1.437 (epoch: 1, step: 50) // Avg time/img: 0.0262 s
# VAL loss: 1.445 (epoch: 1, step: 100) // Avg time/img: 0.0264 s
# VAL loss: 1.306 (epoch: 1, step: 150) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  15.07 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.0004969989975469645
# loss: 0.5573 (epoch: 2, step: 0) // Avg time/img: 0.1027 s
# loss: 0.8999 (epoch: 2, step: 50) // Avg time/img: 0.0647 s
# loss: 0.8748 (epoch: 2, step: 100) // Avg time/img: 0.0638 s
# loss: 0.8481 (epoch: 2, step: 150) // Avg time/img: 0.0634 s
# loss: 0.8295 (epoch: 2, step: 200) // Avg time/img: 0.0634 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.203 (epoch: 2, step: 0) // Avg time/img: 0.0258 s
# VAL loss: 1.286 (epoch: 2, step: 50) // Avg time/img: 0.0250 s
# VAL loss: 1.227 (epoch: 2, step: 100) // Avg time/img: 0.0257 s
# VAL loss: 1.077 (epoch: 2, step: 150) // Avg time/img: 0.0255 s
# EPOCH IoU on VAL set:  20.74 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004939959803064135
# loss: 0.8435 (epoch: 3, step: 0) // Avg time/img: 0.0888 s
# loss: 0.7344 (epoch: 3, step: 50) // Avg time/img: 0.0630 s
# loss: 0.7286 (epoch: 3, step: 100) // Avg time/img: 0.0632 s
# loss: 0.7214 (epoch: 3, step: 150) // Avg time/img: 0.0629 s
# loss: 0.7048 (epoch: 3, step: 200) // Avg time/img: 0.0632 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 4.359 (epoch: 3, step: 0) // Avg time/img: 0.0227 s
# VAL loss: 1.942 (epoch: 3, step: 50) // Avg time/img: 0.0240 s
# VAL loss: 1.779 (epoch: 3, step: 100) // Avg time/img: 0.0276 s
# VAL loss: 1.495 (epoch: 3, step: 150) // Avg time/img: 0.0272 s
# EPOCH IoU on VAL set:  19.40 %
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.0004909909332982877
# loss: 0.6154 (epoch: 4, step: 0) // Avg time/img: 0.0631 s
# loss: 0.6534 (epoch: 4, step: 50) // Avg time/img: 0.0634 s
# loss: 0.6398 (epoch: 4, step: 100) // Avg time/img: 0.0631 s
# loss: 0.6293 (epoch: 4, step: 150) // Avg time/img: 0.0632 s
# loss: 0.6312 (epoch: 4, step: 200) // Avg time/img: 0.0633 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 1.67 (epoch: 4, step: 0) // Avg time/img: 0.0242 s
# VAL loss: 1.111 (epoch: 4, step: 50) // Avg time/img: 0.0240 s
# VAL loss: 1.06 (epoch: 4, step: 100) // Avg time/img: 0.0241 s
# VAL loss: 0.9266 (epoch: 4, step: 150) // Avg time/img: 0.0245 s
# EPOCH IoU on VAL set:  26.05 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00048798384132844874
# loss: 0.6097 (epoch: 5, step: 0) // Avg time/img: 0.0887 s
# loss: 0.6062 (epoch: 5, step: 50) // Avg time/img: 0.0653 s
# loss: 0.581 (epoch: 5, step: 100) // Avg time/img: 0.0650 s
# loss: 0.6005 (epoch: 5, step: 150) // Avg time/img: 0.0649 s
# loss: 0.5889 (epoch: 5, step: 200) // Avg time/img: 0.0648 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 1.06 (epoch: 5, step: 0) // Avg time/img: 0.0235 s
# VAL loss: 1.047 (epoch: 5, step: 50) // Avg time/img: 0.0285 s
# VAL loss: 1.019 (epoch: 5, step: 100) // Avg time/img: 0.0260 s
# VAL loss: 0.9054 (epoch: 5, step: 150) // Avg time/img: 0.0255 s
# EPOCH IoU on VAL set:  25.01 %
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.8959 (epoch: 6, step: 0) // Avg time/img: 0.0917 s
# loss: 0.547 (epoch: 6, step: 50) // Avg time/img: 0.0648 s
# loss: 0.5503 (epoch: 6, step: 100) // Avg time/img: 0.0640 s
# loss: 0.5618 (epoch: 6, step: 150) // Avg time/img: 0.0641 s
# loss: 0.562 (epoch: 6, step: 200) // Avg time/img: 0.0641 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 1.101 (epoch: 6, step: 0) // Avg time/img: 0.0230 s
# VAL loss: 0.9439 (epoch: 6, step: 50) // Avg time/img: 0.0243 s
# VAL loss: 0.8877 (epoch: 6, step: 100) // Avg time/img: 0.0262 s
# VAL loss: 0.7898 (epoch: 6, step: 150) // Avg time/img: 0.0253 s
# EPOCH IoU on VAL set:  27.92 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00048196346062927547
# loss: 0.6559 (epoch: 7, step: 0) // Avg time/img: 0.0894 s
# loss: 0.4836 (epoch: 7, step: 50) // Avg time/img: 0.0647 s
# loss: 0.4991 (epoch: 7, step: 100) // Avg time/img: 0.0640 s
# loss: 0.4966 (epoch: 7, step: 150) // Avg time/img: 0.0638 s
# loss: 0.5124 (epoch: 7, step: 200) // Avg time/img: 0.0636 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 1.024 (epoch: 7, step: 0) // Avg time/img: 0.0226 s
# VAL loss: 0.8619 (epoch: 7, step: 50) // Avg time/img: 0.0234 s
# VAL loss: 0.8335 (epoch: 7, step: 100) // Avg time/img: 0.0233 s
# VAL loss: 0.7321 (epoch: 7, step: 150) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  29.86 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 7)
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.0004789501403997001
# loss: 0.2572 (epoch: 8, step: 0) // Avg time/img: 0.0874 s
# loss: 0.4696 (epoch: 8, step: 50) // Avg time/img: 0.0644 s
# loss: 0.4811 (epoch: 8, step: 100) // Avg time/img: 0.0640 s
# loss: 0.4801 (epoch: 8, step: 150) // Avg time/img: 0.0638 s
# loss: 0.4967 (epoch: 8, step: 200) // Avg time/img: 0.0638 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 1.217 (epoch: 8, step: 0) // Avg time/img: 0.0216 s
# VAL loss: 0.9015 (epoch: 8, step: 50) // Avg time/img: 0.0237 s
# VAL loss: 0.8334 (epoch: 8, step: 100) // Avg time/img: 0.0235 s
# VAL loss: 0.7302 (epoch: 8, step: 150) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  30.00 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 8)
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.0004759347121981738
# loss: 0.4558 (epoch: 9, step: 0) // Avg time/img: 0.0899 s
# loss: 0.4909 (epoch: 9, step: 50) // Avg time/img: 0.0654 s
# loss: 0.499 (epoch: 9, step: 100) // Avg time/img: 0.0654 s
# loss: 0.4995 (epoch: 9, step: 150) // Avg time/img: 0.0652 s
# loss: 0.4945 (epoch: 9, step: 200) // Avg time/img: 0.0660 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 0.9537 (epoch: 9, step: 0) // Avg time/img: 0.0241 s
# VAL loss: 0.8707 (epoch: 9, step: 50) // Avg time/img: 0.0249 s
# VAL loss: 0.8638 (epoch: 9, step: 100) // Avg time/img: 0.0240 s
# VAL loss: 0.7548 (epoch: 9, step: 150) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  30.60 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 9)
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.000472917159689316
# loss: 0.34 (epoch: 10, step: 0) // Avg time/img: 0.0823 s
# loss: 0.4464 (epoch: 10, step: 50) // Avg time/img: 0.0633 s
# loss: 0.4425 (epoch: 10, step: 100) // Avg time/img: 0.0637 s
# loss: 0.4455 (epoch: 10, step: 150) // Avg time/img: 0.0635 s
# loss: 0.448 (epoch: 10, step: 200) // Avg time/img: 0.0635 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 0.8147 (epoch: 10, step: 0) // Avg time/img: 0.0226 s
# VAL loss: 0.8605 (epoch: 10, step: 50) // Avg time/img: 0.0231 s
# VAL loss: 0.8425 (epoch: 10, step: 100) // Avg time/img: 0.0230 s
# VAL loss: 0.7344 (epoch: 10, step: 150) // Avg time/img: 0.0231 s
# EPOCH IoU on VAL set:  31.31 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 10)
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.4016 (epoch: 11, step: 0) // Avg time/img: 0.0622 s
# loss: 0.4303 (epoch: 11, step: 50) // Avg time/img: 0.0633 s
# loss: 0.4397 (epoch: 11, step: 100) // Avg time/img: 0.0634 s
# loss: 0.4402 (epoch: 11, step: 150) // Avg time/img: 0.0646 s
# loss: 0.4413 (epoch: 11, step: 200) // Avg time/img: 0.0645 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.8096 (epoch: 11, step: 0) // Avg time/img: 0.0226 s
# VAL loss: 0.7927 (epoch: 11, step: 50) // Avg time/img: 0.0231 s
# VAL loss: 0.7785 (epoch: 11, step: 100) // Avg time/img: 0.0233 s
# VAL loss: 0.6936 (epoch: 11, step: 150) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  32.31 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 11)
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.00046687561518576686
# loss: 0.2972 (epoch: 12, step: 0) // Avg time/img: 0.0893 s
# loss: 0.4098 (epoch: 12, step: 50) // Avg time/img: 0.0644 s
# loss: 0.4258 (epoch: 12, step: 100) // Avg time/img: 0.0639 s
# loss: 0.4365 (epoch: 12, step: 150) // Avg time/img: 0.0639 s
# loss: 0.4427 (epoch: 12, step: 200) // Avg time/img: 0.0640 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.9904 (epoch: 12, step: 0) // Avg time/img: 0.0266 s
# VAL loss: 0.9014 (epoch: 12, step: 50) // Avg time/img: 0.0244 s
# VAL loss: 0.8771 (epoch: 12, step: 100) // Avg time/img: 0.0241 s
# VAL loss: 0.7443 (epoch: 12, step: 150) // Avg time/img: 0.0242 s
# EPOCH IoU on VAL set:  30.88 %
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.0004638515892816641
# loss: 0.4479 (epoch: 13, step: 0) // Avg time/img: 0.0613 s
# loss: 0.3949 (epoch: 13, step: 50) // Avg time/img: 0.0643 s
# loss: 0.4042 (epoch: 13, step: 100) // Avg time/img: 0.0650 s
# loss: 0.416 (epoch: 13, step: 150) // Avg time/img: 0.0644 s
# loss: 0.4225 (epoch: 13, step: 200) // Avg time/img: 0.0642 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 1.007 (epoch: 13, step: 0) // Avg time/img: 0.0231 s
# VAL loss: 0.8614 (epoch: 13, step: 50) // Avg time/img: 0.0229 s
# VAL loss: 0.8193 (epoch: 13, step: 100) // Avg time/img: 0.0233 s
# VAL loss: 0.7106 (epoch: 13, step: 150) // Avg time/img: 0.0234 s
# EPOCH IoU on VAL set:  32.52 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 13)
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.00046082537124014127
# loss: 0.3098 (epoch: 14, step: 0) // Avg time/img: 0.0872 s
# loss: 0.3919 (epoch: 14, step: 50) // Avg time/img: 0.0642 s
# loss: 0.4011 (epoch: 14, step: 100) // Avg time/img: 0.0639 s
# loss: 0.4122 (epoch: 14, step: 150) // Avg time/img: 0.0637 s
# loss: 0.4151 (epoch: 14, step: 200) // Avg time/img: 0.0638 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 0.9515 (epoch: 14, step: 0) // Avg time/img: 0.0208 s
# VAL loss: 0.7755 (epoch: 14, step: 50) // Avg time/img: 0.0238 s
# VAL loss: 0.7694 (epoch: 14, step: 100) // Avg time/img: 0.0255 s
# VAL loss: 0.6743 (epoch: 14, step: 150) // Avg time/img: 0.0253 s
# EPOCH IoU on VAL set:  33.47 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 14)
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.00045779694345335803
# loss: 0.472 (epoch: 15, step: 0) // Avg time/img: 0.0934 s
# loss: 0.3854 (epoch: 15, step: 50) // Avg time/img: 0.0638 s
# loss: 0.401 (epoch: 15, step: 100) // Avg time/img: 0.0633 s
# loss: 0.3992 (epoch: 15, step: 150) // Avg time/img: 0.0633 s
# loss: 0.3999 (epoch: 15, step: 200) // Avg time/img: 0.0633 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 0.8015 (epoch: 15, step: 0) // Avg time/img: 0.0191 s
# VAL loss: 0.7306 (epoch: 15, step: 50) // Avg time/img: 0.0230 s
# VAL loss: 0.6989 (epoch: 15, step: 100) // Avg time/img: 0.0236 s
# VAL loss: 0.6123 (epoch: 15, step: 150) // Avg time/img: 0.0245 s
# EPOCH IoU on VAL set:  35.61 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 15)
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.338 (epoch: 16, step: 0) // Avg time/img: 0.0879 s
# loss: 0.3935 (epoch: 16, step: 50) // Avg time/img: 0.0634 s
# loss: 0.3942 (epoch: 16, step: 100) // Avg time/img: 0.0632 s
# loss: 0.3996 (epoch: 16, step: 150) // Avg time/img: 0.0632 s
# loss: 0.3974 (epoch: 16, step: 200) // Avg time/img: 0.0633 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.6332 (epoch: 16, step: 0) // Avg time/img: 0.0234 s
# VAL loss: 0.6866 (epoch: 16, step: 50) // Avg time/img: 0.0277 s
# VAL loss: 0.6727 (epoch: 16, step: 100) // Avg time/img: 0.0259 s
# VAL loss: 0.5926 (epoch: 16, step: 150) // Avg time/img: 0.0253 s
# EPOCH IoU on VAL set:  36.53 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 16)
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00045173338684643586
# loss: 0.2883 (epoch: 17, step: 0) // Avg time/img: 0.0586 s
# loss: 0.3794 (epoch: 17, step: 50) // Avg time/img: 0.0631 s
# loss: 0.3658 (epoch: 17, step: 100) // Avg time/img: 0.0631 s
# loss: 0.3731 (epoch: 17, step: 150) // Avg time/img: 0.0632 s
# loss: 0.3827 (epoch: 17, step: 200) // Avg time/img: 0.0634 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.6212 (epoch: 17, step: 0) // Avg time/img: 0.0245 s
# VAL loss: 0.7743 (epoch: 17, step: 50) // Avg time/img: 0.0236 s
# VAL loss: 0.7526 (epoch: 17, step: 100) // Avg time/img: 0.0238 s
# VAL loss: 0.6589 (epoch: 17, step: 150) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  35.59 %
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.0004486982214254669
# loss: 0.3826 (epoch: 18, step: 0) // Avg time/img: 0.0665 s
# loss: 0.3584 (epoch: 18, step: 50) // Avg time/img: 0.0637 s
# loss: 0.3668 (epoch: 18, step: 100) // Avg time/img: 0.0632 s
# loss: 0.3709 (epoch: 18, step: 150) // Avg time/img: 0.0633 s
# loss: 0.3798 (epoch: 18, step: 200) // Avg time/img: 0.0641 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.6398 (epoch: 18, step: 0) // Avg time/img: 0.0212 s
# VAL loss: 0.7557 (epoch: 18, step: 50) // Avg time/img: 0.0226 s
# VAL loss: 0.7058 (epoch: 18, step: 100) // Avg time/img: 0.0232 s
# VAL loss: 0.6196 (epoch: 18, step: 150) // Avg time/img: 0.0234 s
# EPOCH IoU on VAL set:  35.04 %
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00044566077304449995
# loss: 0.3073 (epoch: 19, step: 0) // Avg time/img: 0.0630 s
# loss: 0.3597 (epoch: 19, step: 50) // Avg time/img: 0.0635 s
# loss: 0.3648 (epoch: 19, step: 100) // Avg time/img: 0.0631 s
# loss: 0.3641 (epoch: 19, step: 150) // Avg time/img: 0.0634 s
# loss: 0.3644 (epoch: 19, step: 200) // Avg time/img: 0.0634 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.7633 (epoch: 19, step: 0) // Avg time/img: 0.0228 s
# VAL loss: 0.7506 (epoch: 19, step: 50) // Avg time/img: 0.0236 s
# VAL loss: 0.7309 (epoch: 19, step: 100) // Avg time/img: 0.0237 s
# VAL loss: 0.6478 (epoch: 19, step: 150) // Avg time/img: 0.0241 s
# EPOCH IoU on VAL set:  34.13 %
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.00044262102267129743
# loss: 0.3521 (epoch: 20, step: 0) // Avg time/img: 0.0821 s
# loss: 0.3357 (epoch: 20, step: 50) // Avg time/img: 0.0634 s
# loss: 0.3455 (epoch: 20, step: 100) // Avg time/img: 0.0652 s
# loss: 0.3501 (epoch: 20, step: 150) // Avg time/img: 0.0645 s
# loss: 0.3541 (epoch: 20, step: 200) // Avg time/img: 0.0642 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.8716 (epoch: 20, step: 0) // Avg time/img: 0.0266 s
# VAL loss: 0.7702 (epoch: 20, step: 50) // Avg time/img: 0.0250 s
# VAL loss: 0.7454 (epoch: 20, step: 100) // Avg time/img: 0.0243 s
# VAL loss: 0.6415 (epoch: 20, step: 150) // Avg time/img: 0.0242 s
# EPOCH IoU on VAL set:  35.48 %
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.2667 (epoch: 21, step: 0) // Avg time/img: 0.0886 s
# loss: 0.3522 (epoch: 21, step: 50) // Avg time/img: 0.0645 s
# loss: 0.3434 (epoch: 21, step: 100) // Avg time/img: 0.0640 s
# loss: 0.3532 (epoch: 21, step: 150) // Avg time/img: 0.0638 s
# loss: 0.354 (epoch: 21, step: 200) // Avg time/img: 0.0637 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.6374 (epoch: 21, step: 0) // Avg time/img: 0.0236 s
# VAL loss: 0.7298 (epoch: 21, step: 50) // Avg time/img: 0.0240 s
# VAL loss: 0.7225 (epoch: 21, step: 100) // Avg time/img: 0.0242 s
# VAL loss: 0.6415 (epoch: 21, step: 150) // Avg time/img: 0.0243 s
# EPOCH IoU on VAL set:  36.70 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 21)
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.000436534538285843
# loss: 0.2987 (epoch: 22, step: 0) // Avg time/img: 0.1071 s
# loss: 0.3207 (epoch: 22, step: 50) // Avg time/img: 0.0673 s
# loss: 0.3236 (epoch: 22, step: 100) // Avg time/img: 0.0653 s
# loss: 0.328 (epoch: 22, step: 150) // Avg time/img: 0.0647 s
# loss: 0.3295 (epoch: 22, step: 200) // Avg time/img: 0.0645 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.8428 (epoch: 22, step: 0) // Avg time/img: 0.0250 s
# VAL loss: 0.8552 (epoch: 22, step: 50) // Avg time/img: 0.0243 s
# VAL loss: 0.8219 (epoch: 22, step: 100) // Avg time/img: 0.0243 s
# VAL loss: 0.7012 (epoch: 22, step: 150) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  34.27 %
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.00043348776465364783
# loss: 0.3141 (epoch: 23, step: 0) // Avg time/img: 0.0836 s
# loss: 0.3515 (epoch: 23, step: 50) // Avg time/img: 0.0631 s
# loss: 0.3629 (epoch: 23, step: 100) // Avg time/img: 0.0634 s
# loss: 0.3613 (epoch: 23, step: 150) // Avg time/img: 0.0634 s
# loss: 0.3542 (epoch: 23, step: 200) // Avg time/img: 0.0633 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.5328 (epoch: 23, step: 0) // Avg time/img: 0.0238 s
# VAL loss: 0.6961 (epoch: 23, step: 50) // Avg time/img: 0.0252 s
# VAL loss: 0.6651 (epoch: 23, step: 100) // Avg time/img: 0.0245 s
# VAL loss: 0.5779 (epoch: 23, step: 150) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  37.96 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 23)
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.00043043860977406414
# loss: 0.4141 (epoch: 24, step: 0) // Avg time/img: 0.0895 s
# loss: 0.3256 (epoch: 24, step: 50) // Avg time/img: 0.0634 s
# loss: 0.3232 (epoch: 24, step: 100) // Avg time/img: 0.0632 s
# loss: 0.3277 (epoch: 24, step: 150) // Avg time/img: 0.0634 s
# loss: 0.3261 (epoch: 24, step: 200) // Avg time/img: 0.0634 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 0.6898 (epoch: 24, step: 0) // Avg time/img: 0.0238 s
# VAL loss: 0.7149 (epoch: 24, step: 50) // Avg time/img: 0.0236 s
# VAL loss: 0.6969 (epoch: 24, step: 100) // Avg time/img: 0.0235 s
# VAL loss: 0.6098 (epoch: 24, step: 150) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  37.70 %
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00042738705301356716
# loss: 0.3914 (epoch: 25, step: 0) // Avg time/img: 0.0784 s
# loss: 0.335 (epoch: 25, step: 50) // Avg time/img: 0.0635 s
# loss: 0.3205 (epoch: 25, step: 100) // Avg time/img: 0.0638 s
# loss: 0.3176 (epoch: 25, step: 150) // Avg time/img: 0.0641 s
# loss: 0.3181 (epoch: 25, step: 200) // Avg time/img: 0.0642 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.9169 (epoch: 25, step: 0) // Avg time/img: 0.0235 s
# VAL loss: 0.742 (epoch: 25, step: 50) // Avg time/img: 0.0238 s
# VAL loss: 0.7205 (epoch: 25, step: 100) // Avg time/img: 0.0248 s
# VAL loss: 0.6311 (epoch: 25, step: 150) // Avg time/img: 0.0241 s
# EPOCH IoU on VAL set:  36.20 %
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.4302 (epoch: 26, step: 0) // Avg time/img: 0.0861 s
# loss: 0.3071 (epoch: 26, step: 50) // Avg time/img: 0.0645 s
# loss: 0.32 (epoch: 26, step: 100) // Avg time/img: 0.0641 s
# loss: 0.3184 (epoch: 26, step: 150) // Avg time/img: 0.0640 s
# loss: 0.3237 (epoch: 26, step: 200) // Avg time/img: 0.0639 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.6374 (epoch: 26, step: 0) // Avg time/img: 0.0238 s
# VAL loss: 0.7169 (epoch: 26, step: 50) // Avg time/img: 0.0235 s
# VAL loss: 0.6609 (epoch: 26, step: 100) // Avg time/img: 0.0234 s
# VAL loss: 0.5749 (epoch: 26, step: 150) // Avg time/img: 0.0234 s
# EPOCH IoU on VAL set:  38.13 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 26)
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0004212766495870041
# loss: 0.2956 (epoch: 27, step: 0) // Avg time/img: 0.0623 s
# loss: 0.3208 (epoch: 27, step: 50) // Avg time/img: 0.0638 s
# loss: 0.3284 (epoch: 27, step: 100) // Avg time/img: 0.0637 s
# loss: 0.3184 (epoch: 27, step: 150) // Avg time/img: 0.0636 s
# loss: 0.3231 (epoch: 27, step: 200) // Avg time/img: 0.0638 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.756 (epoch: 27, step: 0) // Avg time/img: 0.0244 s
# VAL loss: 0.7442 (epoch: 27, step: 50) // Avg time/img: 0.0275 s
# VAL loss: 0.7221 (epoch: 27, step: 100) // Avg time/img: 0.0254 s
# VAL loss: 0.6354 (epoch: 27, step: 150) // Avg time/img: 0.0248 s
# EPOCH IoU on VAL set:  37.07 %
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00041821775989926696
# loss: 0.2479 (epoch: 28, step: 0) // Avg time/img: 0.0635 s
# loss: 0.2907 (epoch: 28, step: 50) // Avg time/img: 0.0632 s
# loss: 0.3039 (epoch: 28, step: 100) // Avg time/img: 0.0634 s
# loss: 0.3058 (epoch: 28, step: 150) // Avg time/img: 0.0633 s
# loss: 0.3105 (epoch: 28, step: 200) // Avg time/img: 0.0634 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.4566 (epoch: 28, step: 0) // Avg time/img: 0.0234 s
# VAL loss: 0.7365 (epoch: 28, step: 50) // Avg time/img: 0.0233 s
# VAL loss: 0.693 (epoch: 28, step: 100) // Avg time/img: 0.0235 s
# VAL loss: 0.6049 (epoch: 28, step: 150) // Avg time/img: 0.0242 s
# EPOCH IoU on VAL set:  37.97 %
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.0004151563822693442
# loss: 0.2134 (epoch: 29, step: 0) // Avg time/img: 0.0845 s
# loss: 0.3318 (epoch: 29, step: 50) // Avg time/img: 0.0635 s
# loss: 0.3126 (epoch: 29, step: 100) // Avg time/img: 0.0631 s
# loss: 0.313 (epoch: 29, step: 150) // Avg time/img: 0.0631 s
# loss: 0.3123 (epoch: 29, step: 200) // Avg time/img: 0.0632 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.4319 (epoch: 29, step: 0) // Avg time/img: 0.0333 s
# VAL loss: 0.6367 (epoch: 29, step: 50) // Avg time/img: 0.0261 s
# VAL loss: 0.6574 (epoch: 29, step: 100) // Avg time/img: 0.0248 s
# VAL loss: 0.5863 (epoch: 29, step: 150) // Avg time/img: 0.0244 s
# EPOCH IoU on VAL set:  38.85 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 29)
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.00041209249425527324
# loss: 0.2406 (epoch: 30, step: 0) // Avg time/img: 0.0885 s
# loss: 0.2879 (epoch: 30, step: 50) // Avg time/img: 0.0642 s
# loss: 0.3094 (epoch: 30, step: 100) // Avg time/img: 0.0641 s
# loss: 0.3065 (epoch: 30, step: 150) // Avg time/img: 0.0643 s
# loss: 0.3014 (epoch: 30, step: 200) // Avg time/img: 0.0645 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.5341 (epoch: 30, step: 0) // Avg time/img: 0.0240 s
# VAL loss: 0.8495 (epoch: 30, step: 50) // Avg time/img: 0.0250 s
# VAL loss: 0.9776 (epoch: 30, step: 100) // Avg time/img: 0.0252 s
# VAL loss: 0.8715 (epoch: 30, step: 150) // Avg time/img: 0.0258 s
# EPOCH IoU on VAL set:  36.66 %
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.3856 (epoch: 31, step: 0) // Avg time/img: 0.0877 s
# loss: 0.3067 (epoch: 31, step: 50) // Avg time/img: 0.0641 s
# loss: 0.3009 (epoch: 31, step: 100) // Avg time/img: 0.0640 s
# loss: 0.3089 (epoch: 31, step: 150) // Avg time/img: 0.0639 s
# loss: 0.3093 (epoch: 31, step: 200) // Avg time/img: 0.0642 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.6225 (epoch: 31, step: 0) // Avg time/img: 0.0239 s
# VAL loss: 0.6815 (epoch: 31, step: 50) // Avg time/img: 0.0233 s
# VAL loss: 0.6503 (epoch: 31, step: 100) // Avg time/img: 0.0236 s
# VAL loss: 0.5592 (epoch: 31, step: 150) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  40.21 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 31)
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.00040595709534845345
# loss: 0.404 (epoch: 32, step: 0) // Avg time/img: 0.0995 s
# loss: 0.2825 (epoch: 32, step: 50) // Avg time/img: 0.0643 s
# loss: 0.2815 (epoch: 32, step: 100) // Avg time/img: 0.0639 s
# loss: 0.283 (epoch: 32, step: 150) // Avg time/img: 0.0638 s
# loss: 0.2881 (epoch: 32, step: 200) // Avg time/img: 0.0636 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.8312 (epoch: 32, step: 0) // Avg time/img: 0.0243 s
# VAL loss: 0.6906 (epoch: 32, step: 50) // Avg time/img: 0.0239 s
# VAL loss: 0.6406 (epoch: 32, step: 100) // Avg time/img: 0.0240 s
# VAL loss: 0.5494 (epoch: 32, step: 150) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  40.98 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 32)
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00040288553758283585
# loss: 0.2418 (epoch: 33, step: 0) // Avg time/img: 0.0843 s
# loss: 0.311 (epoch: 33, step: 50) // Avg time/img: 0.0641 s
# loss: 0.2885 (epoch: 33, step: 100) // Avg time/img: 0.0636 s
# loss: 0.2815 (epoch: 33, step: 150) // Avg time/img: 0.0639 s
# loss: 0.2805 (epoch: 33, step: 200) // Avg time/img: 0.0648 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.6462 (epoch: 33, step: 0) // Avg time/img: 0.0266 s
# VAL loss: 0.681 (epoch: 33, step: 50) // Avg time/img: 0.0236 s
# VAL loss: 0.6414 (epoch: 33, step: 100) // Avg time/img: 0.0244 s
# VAL loss: 0.5537 (epoch: 33, step: 150) // Avg time/img: 0.0253 s
# EPOCH IoU on VAL set:  40.35 %
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.0003998113756661346
# loss: 0.1661 (epoch: 34, step: 0) // Avg time/img: 0.0628 s
# loss: 0.2846 (epoch: 34, step: 50) // Avg time/img: 0.0635 s
# loss: 0.285 (epoch: 34, step: 100) // Avg time/img: 0.0636 s
# loss: 0.2867 (epoch: 34, step: 150) // Avg time/img: 0.0639 s
# loss: 0.2876 (epoch: 34, step: 200) // Avg time/img: 0.0638 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.6699 (epoch: 34, step: 0) // Avg time/img: 0.0220 s
# VAL loss: 0.7737 (epoch: 34, step: 50) // Avg time/img: 0.0241 s
# VAL loss: 0.7576 (epoch: 34, step: 100) // Avg time/img: 0.0243 s
# VAL loss: 0.6627 (epoch: 34, step: 150) // Avg time/img: 0.0241 s
# EPOCH IoU on VAL set:  37.96 %
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00039673458510381765
# loss: 0.3181 (epoch: 35, step: 0) // Avg time/img: 0.0632 s
# loss: 0.2868 (epoch: 35, step: 50) // Avg time/img: 0.0638 s
# loss: 0.2818 (epoch: 35, step: 100) // Avg time/img: 0.0639 s
# loss: 0.2809 (epoch: 35, step: 150) // Avg time/img: 0.0647 s
# loss: 0.2783 (epoch: 35, step: 200) // Avg time/img: 0.0646 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.844 (epoch: 35, step: 0) // Avg time/img: 0.0196 s
# VAL loss: 0.6944 (epoch: 35, step: 50) // Avg time/img: 0.0236 s
# VAL loss: 0.7429 (epoch: 35, step: 100) // Avg time/img: 0.0235 s
# VAL loss: 0.641 (epoch: 35, step: 150) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  39.38 %
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.2617 (epoch: 36, step: 0) // Avg time/img: 0.0902 s
# loss: 0.2745 (epoch: 36, step: 50) // Avg time/img: 0.0643 s
# loss: 0.2733 (epoch: 36, step: 100) // Avg time/img: 0.0645 s
# loss: 0.2684 (epoch: 36, step: 150) // Avg time/img: 0.0646 s
# loss: 0.2783 (epoch: 36, step: 200) // Avg time/img: 0.0645 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.6123 (epoch: 36, step: 0) // Avg time/img: 0.0232 s
# VAL loss: 0.6529 (epoch: 36, step: 50) // Avg time/img: 0.0240 s
# VAL loss: 0.6437 (epoch: 36, step: 100) // Avg time/img: 0.0243 s
# VAL loss: 0.5637 (epoch: 36, step: 150) // Avg time/img: 0.0240 s
# EPOCH IoU on VAL set:  40.58 %
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.0003905730178340304
# loss: 0.2736 (epoch: 37, step: 0) // Avg time/img: 0.0629 s
# loss: 0.2497 (epoch: 37, step: 50) // Avg time/img: 0.0638 s
# loss: 0.26 (epoch: 37, step: 100) // Avg time/img: 0.0652 s
# loss: 0.2593 (epoch: 37, step: 150) // Avg time/img: 0.0648 s
# loss: 0.2665 (epoch: 37, step: 200) // Avg time/img: 0.0647 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.4718 (epoch: 37, step: 0) // Avg time/img: 0.0188 s
# VAL loss: 0.5984 (epoch: 37, step: 50) // Avg time/img: 0.0230 s
# VAL loss: 0.5786 (epoch: 37, step: 100) // Avg time/img: 0.0235 s
# VAL loss: 0.5074 (epoch: 37, step: 150) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  43.22 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 37)
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.0003874881898709925
# loss: 0.3676 (epoch: 38, step: 0) // Avg time/img: 0.0836 s
# loss: 0.2591 (epoch: 38, step: 50) // Avg time/img: 0.0637 s
# loss: 0.2633 (epoch: 38, step: 100) // Avg time/img: 0.0633 s
# loss: 0.2651 (epoch: 38, step: 150) // Avg time/img: 0.0637 s
# loss: 0.2666 (epoch: 38, step: 200) // Avg time/img: 0.0637 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 1.013 (epoch: 38, step: 0) // Avg time/img: 0.0222 s
# VAL loss: 0.8763 (epoch: 38, step: 50) // Avg time/img: 0.0235 s
# VAL loss: 0.8977 (epoch: 38, step: 100) // Avg time/img: 0.0236 s
# VAL loss: 0.7611 (epoch: 38, step: 150) // Avg time/img: 0.0239 s
# EPOCH IoU on VAL set:  38.55 %
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.00038440063072596296
# loss: 0.2166 (epoch: 39, step: 0) // Avg time/img: 0.0621 s
# loss: 0.2566 (epoch: 39, step: 50) // Avg time/img: 0.0632 s
# loss: 0.2531 (epoch: 39, step: 100) // Avg time/img: 0.0648 s
# loss: 0.2544 (epoch: 39, step: 150) // Avg time/img: 0.0643 s
# loss: 0.2584 (epoch: 39, step: 200) // Avg time/img: 0.0641 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.7819 (epoch: 39, step: 0) // Avg time/img: 0.0182 s
# VAL loss: 0.7373 (epoch: 39, step: 50) // Avg time/img: 0.0232 s
# VAL loss: 0.7098 (epoch: 39, step: 100) // Avg time/img: 0.0231 s
# VAL loss: 0.5956 (epoch: 39, step: 150) // Avg time/img: 0.0233 s
# EPOCH IoU on VAL set:  40.95 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.0003813103135621442
# loss: 0.1758 (epoch: 40, step: 0) // Avg time/img: 0.0642 s
# loss: 0.2455 (epoch: 40, step: 50) // Avg time/img: 0.0638 s
# loss: 0.2494 (epoch: 40, step: 100) // Avg time/img: 0.0640 s
# loss: 0.2551 (epoch: 40, step: 150) // Avg time/img: 0.0642 s
# loss: 0.2581 (epoch: 40, step: 200) // Avg time/img: 0.0644 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.591 (epoch: 40, step: 0) // Avg time/img: 0.0255 s
# VAL loss: 0.7099 (epoch: 40, step: 50) // Avg time/img: 0.0231 s
# VAL loss: 0.6879 (epoch: 40, step: 100) // Avg time/img: 0.0238 s
# VAL loss: 0.589 (epoch: 40, step: 150) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  40.97 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.3234 (epoch: 41, step: 0) // Avg time/img: 0.0689 s
# loss: 0.2748 (epoch: 41, step: 50) // Avg time/img: 0.0671 s
# loss: 0.2656 (epoch: 41, step: 100) // Avg time/img: 0.0655 s
# loss: 0.2634 (epoch: 41, step: 150) // Avg time/img: 0.0650 s
# loss: 0.2612 (epoch: 41, step: 200) // Avg time/img: 0.0646 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.476 (epoch: 41, step: 0) // Avg time/img: 0.0238 s
# VAL loss: 0.7279 (epoch: 41, step: 50) // Avg time/img: 0.0239 s
# VAL loss: 0.6768 (epoch: 41, step: 100) // Avg time/img: 0.0239 s
# VAL loss: 0.5795 (epoch: 41, step: 150) // Avg time/img: 0.0242 s
# EPOCH IoU on VAL set:  40.60 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00037512129527676405
# loss: 0.2308 (epoch: 42, step: 0) // Avg time/img: 0.0887 s
# loss: 0.2814 (epoch: 42, step: 50) // Avg time/img: 0.0655 s
# loss: 0.2729 (epoch: 42, step: 100) // Avg time/img: 0.0653 s
# loss: 0.2742 (epoch: 42, step: 150) // Avg time/img: 0.0651 s
# loss: 0.2806 (epoch: 42, step: 200) // Avg time/img: 0.0650 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.6324 (epoch: 42, step: 0) // Avg time/img: 0.0230 s
# VAL loss: 0.6417 (epoch: 42, step: 50) // Avg time/img: 0.0237 s
# VAL loss: 0.6239 (epoch: 42, step: 100) // Avg time/img: 0.0236 s
# VAL loss: 0.5435 (epoch: 42, step: 150) // Avg time/img: 0.0233 s
# EPOCH IoU on VAL set:  41.96 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.0003720225378839164
# loss: 0.204 (epoch: 43, step: 0) // Avg time/img: 0.0646 s
# loss: 0.2551 (epoch: 43, step: 50) // Avg time/img: 0.0671 s
# loss: 0.2572 (epoch: 43, step: 100) // Avg time/img: 0.0656 s
# loss: 0.255 (epoch: 43, step: 150) // Avg time/img: 0.0648 s
# loss: 0.2564 (epoch: 43, step: 200) // Avg time/img: 0.0646 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.5673 (epoch: 43, step: 0) // Avg time/img: 0.0218 s
# VAL loss: 0.6854 (epoch: 43, step: 50) // Avg time/img: 0.0236 s
# VAL loss: 0.644 (epoch: 43, step: 100) // Avg time/img: 0.0244 s
# VAL loss: 0.548 (epoch: 43, step: 150) // Avg time/img: 0.0250 s
# EPOCH IoU on VAL set:  42.71 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.00036892090989941846
# loss: 0.2349 (epoch: 44, step: 0) // Avg time/img: 0.0644 s
# loss: 0.2498 (epoch: 44, step: 50) // Avg time/img: 0.0645 s
# loss: 0.2457 (epoch: 44, step: 100) // Avg time/img: 0.0641 s
# loss: 0.2416 (epoch: 44, step: 150) // Avg time/img: 0.0639 s
# loss: 0.2419 (epoch: 44, step: 200) // Avg time/img: 0.0638 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 1.138 (epoch: 44, step: 0) // Avg time/img: 0.0254 s
# VAL loss: 0.7307 (epoch: 44, step: 50) // Avg time/img: 0.0245 s
# VAL loss: 0.7713 (epoch: 44, step: 100) // Avg time/img: 0.0249 s
# VAL loss: 0.658 (epoch: 44, step: 150) // Avg time/img: 0.0252 s
# EPOCH IoU on VAL set:  39.78 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.0003658163817978644
# loss: 0.2275 (epoch: 45, step: 0) // Avg time/img: 0.0864 s
# loss: 0.249 (epoch: 45, step: 50) // Avg time/img: 0.0637 s
# loss: 0.2448 (epoch: 45, step: 100) // Avg time/img: 0.0636 s
# loss: 0.242 (epoch: 45, step: 150) // Avg time/img: 0.0635 s
# loss: 0.2459 (epoch: 45, step: 200) // Avg time/img: 0.0635 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.432 (epoch: 45, step: 0) // Avg time/img: 0.0259 s
# VAL loss: 0.6578 (epoch: 45, step: 50) // Avg time/img: 0.0244 s
# VAL loss: 0.6955 (epoch: 45, step: 100) // Avg time/img: 0.0240 s
# VAL loss: 0.6047 (epoch: 45, step: 150) // Avg time/img: 0.0240 s
# EPOCH IoU on VAL set:  41.85 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.298 (epoch: 46, step: 0) // Avg time/img: 0.0617 s
# loss: 0.2472 (epoch: 46, step: 50) // Avg time/img: 0.0644 s
# loss: 0.2485 (epoch: 46, step: 100) // Avg time/img: 0.0643 s
# loss: 0.2517 (epoch: 46, step: 150) // Avg time/img: 0.0645 s
# loss: 0.2507 (epoch: 46, step: 200) // Avg time/img: 0.0644 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.5349 (epoch: 46, step: 0) // Avg time/img: 0.0215 s
# VAL loss: 0.6435 (epoch: 46, step: 50) // Avg time/img: 0.0242 s
# VAL loss: 0.5918 (epoch: 46, step: 100) // Avg time/img: 0.0253 s
# VAL loss: 0.5099 (epoch: 46, step: 150) // Avg time/img: 0.0247 s
# EPOCH IoU on VAL set:  44.82 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 46)
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.0003595985041984843
# loss: 0.2565 (epoch: 47, step: 0) // Avg time/img: 0.0919 s
# loss: 0.227 (epoch: 47, step: 50) // Avg time/img: 0.0644 s
# loss: 0.2243 (epoch: 47, step: 100) // Avg time/img: 0.0641 s
# loss: 0.2259 (epoch: 47, step: 150) // Avg time/img: 0.0638 s
# loss: 0.2324 (epoch: 47, step: 200) // Avg time/img: 0.0638 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.8312 (epoch: 47, step: 0) // Avg time/img: 0.0205 s
# VAL loss: 0.7133 (epoch: 47, step: 50) // Avg time/img: 0.0235 s
# VAL loss: 0.7052 (epoch: 47, step: 100) // Avg time/img: 0.0236 s
# VAL loss: 0.6154 (epoch: 47, step: 150) // Avg time/img: 0.0232 s
# EPOCH IoU on VAL set:  40.45 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.0003564850926538206
# loss: 0.2148 (epoch: 48, step: 0) // Avg time/img: 0.0840 s
# loss: 0.2355 (epoch: 48, step: 50) // Avg time/img: 0.0635 s
# loss: 0.2383 (epoch: 48, step: 100) // Avg time/img: 0.0636 s
# loss: 0.2389 (epoch: 48, step: 150) // Avg time/img: 0.0636 s
# loss: 0.2363 (epoch: 48, step: 200) // Avg time/img: 0.0637 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.8743 (epoch: 48, step: 0) // Avg time/img: 0.0219 s
# VAL loss: 0.7639 (epoch: 48, step: 50) // Avg time/img: 0.0249 s
# VAL loss: 0.7314 (epoch: 48, step: 100) // Avg time/img: 0.0258 s
# VAL loss: 0.625 (epoch: 48, step: 150) // Avg time/img: 0.0258 s
# EPOCH IoU on VAL set:  38.38 %
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00035336865686177077
# loss: 0.1784 (epoch: 49, step: 0) // Avg time/img: 0.0639 s
# loss: 0.2509 (epoch: 49, step: 50) // Avg time/img: 0.0646 s
# loss: 0.2451 (epoch: 49, step: 100) // Avg time/img: 0.0649 s
# loss: 0.2417 (epoch: 49, step: 150) // Avg time/img: 0.0648 s
# loss: 0.2381 (epoch: 49, step: 200) // Avg time/img: 0.0647 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.5715 (epoch: 49, step: 0) // Avg time/img: 0.0239 s
# VAL loss: 0.6 (epoch: 49, step: 50) // Avg time/img: 0.0235 s
# VAL loss: 0.5588 (epoch: 49, step: 100) // Avg time/img: 0.0234 s
# VAL loss: 0.4809 (epoch: 49, step: 150) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  45.24 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 49)
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.0003502491641908687
# loss: 0.1957 (epoch: 50, step: 0) // Avg time/img: 0.0801 s
# loss: 0.2333 (epoch: 50, step: 50) // Avg time/img: 0.0651 s
# loss: 0.2262 (epoch: 50, step: 100) // Avg time/img: 0.0651 s
# loss: 0.228 (epoch: 50, step: 150) // Avg time/img: 0.0649 s
# loss: 0.2309 (epoch: 50, step: 200) // Avg time/img: 0.0648 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.7207 (epoch: 50, step: 0) // Avg time/img: 0.0237 s
# VAL loss: 0.6738 (epoch: 50, step: 50) // Avg time/img: 0.0261 s
# VAL loss: 0.6374 (epoch: 50, step: 100) // Avg time/img: 0.0252 s
# VAL loss: 0.5499 (epoch: 50, step: 150) // Avg time/img: 0.0248 s
# EPOCH IoU on VAL set:  42.27 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.2922 (epoch: 51, step: 0) // Avg time/img: 0.0651 s
# loss: 0.2288 (epoch: 51, step: 50) // Avg time/img: 0.0637 s
# loss: 0.2385 (epoch: 51, step: 100) // Avg time/img: 0.0636 s
# loss: 0.2382 (epoch: 51, step: 150) // Avg time/img: 0.0637 s
# loss: 0.236 (epoch: 51, step: 200) // Avg time/img: 0.0638 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.4525 (epoch: 51, step: 0) // Avg time/img: 0.0247 s
# VAL loss: 0.6083 (epoch: 51, step: 50) // Avg time/img: 0.0235 s
# VAL loss: 0.5707 (epoch: 51, step: 100) // Avg time/img: 0.0234 s
# VAL loss: 0.4946 (epoch: 51, step: 150) // Avg time/img: 0.0235 s
# EPOCH IoU on VAL set:  45.40 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 51)
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  0.00034400087427136414
# loss: 0.2298 (epoch: 52, step: 0) // Avg time/img: 0.0877 s
# loss: 0.2133 (epoch: 52, step: 50) // Avg time/img: 0.0640 s
# loss: 0.2217 (epoch: 52, step: 100) // Avg time/img: 0.0637 s
# loss: 0.2237 (epoch: 52, step: 150) // Avg time/img: 0.0638 s
# loss: 0.2238 (epoch: 52, step: 200) // Avg time/img: 0.0637 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.423 (epoch: 52, step: 0) // Avg time/img: 0.0226 s
# VAL loss: 0.6156 (epoch: 52, step: 50) // Avg time/img: 0.0239 s
# VAL loss: 0.6058 (epoch: 52, step: 100) // Avg time/img: 0.0238 s
# VAL loss: 0.5163 (epoch: 52, step: 150) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  44.63 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  0.0003408720082805103
# loss: 0.2212 (epoch: 53, step: 0) // Avg time/img: 0.0645 s
# loss: 0.2043 (epoch: 53, step: 50) // Avg time/img: 0.0631 s
# loss: 0.2338 (epoch: 53, step: 100) // Avg time/img: 0.0631 s
# loss: 0.2637 (epoch: 53, step: 150) // Avg time/img: 0.0632 s
# loss: 0.2652 (epoch: 53, step: 200) // Avg time/img: 0.0633 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.4522 (epoch: 53, step: 0) // Avg time/img: 0.0267 s
# VAL loss: 0.6095 (epoch: 53, step: 50) // Avg time/img: 0.0233 s
# VAL loss: 0.6031 (epoch: 53, step: 100) // Avg time/img: 0.0233 s
# VAL loss: 0.5295 (epoch: 53, step: 150) // Avg time/img: 0.0233 s
# EPOCH IoU on VAL set:  43.48 %
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  0.00033773994788152624
# loss: 0.1875 (epoch: 54, step: 0) // Avg time/img: 0.0617 s
# loss: 0.2183 (epoch: 54, step: 50) // Avg time/img: 0.0629 s
# loss: 0.2204 (epoch: 54, step: 100) // Avg time/img: 0.0632 s
# loss: 0.2245 (epoch: 54, step: 150) // Avg time/img: 0.0632 s
# loss: 0.2275 (epoch: 54, step: 200) // Avg time/img: 0.0630 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.4563 (epoch: 54, step: 0) // Avg time/img: 0.0234 s
# VAL loss: 0.6456 (epoch: 54, step: 50) // Avg time/img: 0.0234 s
# VAL loss: 0.648 (epoch: 54, step: 100) // Avg time/img: 0.0240 s
# VAL loss: 0.5665 (epoch: 54, step: 150) // Avg time/img: 0.0239 s
# EPOCH IoU on VAL set:  41.95 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  0.0003346046568292074
# loss: 0.2179 (epoch: 55, step: 0) // Avg time/img: 0.0646 s
# loss: 0.2104 (epoch: 55, step: 50) // Avg time/img: 0.0630 s
# loss: 0.2101 (epoch: 55, step: 100) // Avg time/img: 0.0631 s
# loss: 0.2083 (epoch: 55, step: 150) // Avg time/img: 0.0634 s
# loss: 0.2142 (epoch: 55, step: 200) // Avg time/img: 0.0635 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.6693 (epoch: 55, step: 0) // Avg time/img: 0.0260 s
# VAL loss: 0.702 (epoch: 55, step: 50) // Avg time/img: 0.0239 s
# VAL loss: 0.6698 (epoch: 55, step: 100) // Avg time/img: 0.0238 s
# VAL loss: 0.5734 (epoch: 55, step: 150) // Avg time/img: 0.0237 s
# EPOCH IoU on VAL set:  43.77 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.237 (epoch: 56, step: 0) // Avg time/img: 0.0816 s
# loss: 0.243 (epoch: 56, step: 50) // Avg time/img: 0.0637 s
# loss: 0.2206 (epoch: 56, step: 100) // Avg time/img: 0.0637 s
# loss: 0.2165 (epoch: 56, step: 150) // Avg time/img: 0.0636 s
# loss: 0.2174 (epoch: 56, step: 200) // Avg time/img: 0.0642 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.4313 (epoch: 56, step: 0) // Avg time/img: 0.0209 s
# VAL loss: 0.5833 (epoch: 56, step: 50) // Avg time/img: 0.0241 s
# VAL loss: 0.5708 (epoch: 56, step: 100) // Avg time/img: 0.0239 s
# VAL loss: 0.5003 (epoch: 56, step: 150) // Avg time/img: 0.0238 s
# EPOCH IoU on VAL set:  45.74 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 56)
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  0.000328324233791252
# loss: 0.1304 (epoch: 57, step: 0) // Avg time/img: 0.0809 s
# loss: 0.2044 (epoch: 57, step: 50) // Avg time/img: 0.0652 s
# loss: 0.2062 (epoch: 57, step: 100) // Avg time/img: 0.0649 s
# loss: 0.2087 (epoch: 57, step: 150) // Avg time/img: 0.0649 s
# loss: 0.2116 (epoch: 57, step: 200) // Avg time/img: 0.0646 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 1.121 (epoch: 57, step: 0) // Avg time/img: 0.0219 s
# VAL loss: 0.815 (epoch: 57, step: 50) // Avg time/img: 0.0232 s
# VAL loss: 0.7956 (epoch: 57, step: 100) // Avg time/img: 0.0236 s
# VAL loss: 0.6634 (epoch: 57, step: 150) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  42.75 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  0.000325179025243871
# loss: 0.1777 (epoch: 58, step: 0) // Avg time/img: 0.0683 s
# loss: 0.1991 (epoch: 58, step: 50) // Avg time/img: 0.0638 s
# loss: 0.2015 (epoch: 58, step: 100) // Avg time/img: 0.0635 s
# loss: 0.2078 (epoch: 58, step: 150) // Avg time/img: 0.0642 s
# loss: 0.2291 (epoch: 58, step: 200) // Avg time/img: 0.0642 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.5622 (epoch: 58, step: 0) // Avg time/img: 0.0235 s
# VAL loss: 0.6806 (epoch: 58, step: 50) // Avg time/img: 0.0227 s
# VAL loss: 0.6679 (epoch: 58, step: 100) // Avg time/img: 0.0231 s
# VAL loss: 0.5775 (epoch: 58, step: 150) // Avg time/img: 0.0232 s
# EPOCH IoU on VAL set:  41.28 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  0.00032203043286440806
# loss: 0.2292 (epoch: 59, step: 0) // Avg time/img: 0.0676 s
# loss: 0.2343 (epoch: 59, step: 50) // Avg time/img: 0.0646 s
# loss: 0.2233 (epoch: 59, step: 100) // Avg time/img: 0.0647 s
# loss: 0.2196 (epoch: 59, step: 150) // Avg time/img: 0.0647 s
# loss: 0.2193 (epoch: 59, step: 200) // Avg time/img: 0.0647 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.3967 (epoch: 59, step: 0) // Avg time/img: 0.0305 s
# VAL loss: 0.5905 (epoch: 59, step: 50) // Avg time/img: 0.0232 s
# VAL loss: 0.5417 (epoch: 59, step: 100) // Avg time/img: 0.0234 s
# VAL loss: 0.4743 (epoch: 59, step: 150) // Avg time/img: 0.0234 s
# EPOCH IoU on VAL set:  45.78 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 59)
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  0.0003188784161704182
# loss: 0.1824 (epoch: 60, step: 0) // Avg time/img: 0.0942 s
# loss: 0.2055 (epoch: 60, step: 50) // Avg time/img: 0.0644 s
# loss: 0.2063 (epoch: 60, step: 100) // Avg time/img: 0.0643 s
# loss: 0.2043 (epoch: 60, step: 150) // Avg time/img: 0.0649 s
# loss: 0.2053 (epoch: 60, step: 200) // Avg time/img: 0.0646 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.487 (epoch: 60, step: 0) // Avg time/img: 0.0226 s
# VAL loss: 0.6198 (epoch: 60, step: 50) // Avg time/img: 0.0257 s
# VAL loss: 0.6402 (epoch: 60, step: 100) // Avg time/img: 0.0248 s
# VAL loss: 0.5679 (epoch: 60, step: 150) // Avg time/img: 0.0243 s
# EPOCH IoU on VAL set:  44.21 %
# ----- TRAINING - EPOCH 61 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.1873 (epoch: 61, step: 0) // Avg time/img: 0.0743 s
# loss: 0.2141 (epoch: 61, step: 50) // Avg time/img: 0.0637 s
# loss: 0.2247 (epoch: 61, step: 100) // Avg time/img: 0.0636 s
# loss: 0.2385 (epoch: 61, step: 150) // Avg time/img: 0.0634 s
# loss: 0.2368 (epoch: 61, step: 200) // Avg time/img: 0.0633 s
# ----- VALIDATING - EPOCH 61 -----
# VAL loss: 0.4671 (epoch: 61, step: 0) // Avg time/img: 0.0214 s
# VAL loss: 0.6228 (epoch: 61, step: 50) // Avg time/img: 0.0238 s
# VAL loss: 0.5829 (epoch: 61, step: 100) // Avg time/img: 0.0238 s
# VAL loss: 0.5029 (epoch: 61, step: 150) // Avg time/img: 0.0236 s
# EPOCH IoU on VAL set:  45.39 %
# ----- TRAINING - EPOCH 62 -----
# LEARNING RATE:  0.0003125639432029656
# loss: 0.1575 (epoch: 62, step: 0) // Avg time/img: 0.0670 s
# loss: 0.2459 (epoch: 62, step: 50) // Avg time/img: 0.0646 s
# loss: 0.2457 (epoch: 62, step: 100) // Avg time/img: 0.0648 s
# loss: 0.2329 (epoch: 62, step: 150) // Avg time/img: 0.0654 s
# loss: 0.2292 (epoch: 62, step: 200) // Avg time/img: 0.0650 s
# ----- VALIDATING - EPOCH 62 -----
# VAL loss: 0.4553 (epoch: 62, step: 0) // Avg time/img: 0.0229 s
# VAL loss: 0.5771 (epoch: 62, step: 50) // Avg time/img: 0.0254 s
# VAL loss: 0.5505 (epoch: 62, step: 100) // Avg time/img: 0.0248 s
# VAL loss: 0.479 (epoch: 62, step: 150) // Avg time/img: 0.0245 s
# EPOCH IoU on VAL set:  46.84 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_encoder_best.pth (epoch: 62)
# ----- TRAINING - EPOCH 63 -----
# LEARNING RATE:  0.0003094014011603608
# loss: 0.1614 (epoch: 63, step: 0) // Avg time/img: 0.0792 s
# loss: 0.2046 (epoch: 63, step: 50) // Avg time/img: 0.0636 s
# loss: 0.1982 (epoch: 63, step: 100) // Avg time/img: 0.0635 s
# loss: 0.1979 (epoch: 63, step: 150) // Avg time/img: 0.0633 s
# loss: 0.1964 (epoch: 63, step: 200) // Avg time/img: 0.0634 s
# ----- VALIDATING - EPOCH 63 -----
# VAL loss: 0.4351 (epoch: 63, step: 0) // Avg time/img: 0.0235 s
# VAL loss: 0.6085 (epoch: 63, step: 50) // Avg time/img: 0.0252 s
# VAL loss: 0.5794 (epoch: 63, step: 100) // Avg time/img: 0.0247 s
# VAL loss: 0.4994 (epoch: 63, step: 150) // Avg time/img: 0.0247 s
# EPOCH IoU on VAL set:  45.22 %
# ----- TRAINING - EPOCH 64 -----
# LEARNING RATE:  0.00030623526319596624
# loss: 0.1968 (epoch: 64, step: 0) // Avg time/img: 0.0633 s
# loss: 0.1982 (epoch: 64, step: 50) // Avg time/img: 0.0637 s
# loss: 0.1999 (epoch: 64, step: 100) // Avg time/img: 0.0655 s
# loss: 0.2027 (epoch: 64, step: 150) // Avg time/img: 0.0651 s
# ...
# LEARNING RATE:  8.8852220136671e-05
# loss: 0.09145 (epoch: 129, step: 0) // Avg time/img: 0.1204 s
# loss: 0.1075 (epoch: 129, step: 50) // Avg time/img: 0.0958 s
# loss: 0.1089 (epoch: 129, step: 100) // Avg time/img: 0.0948 s
# loss: 0.1102 (epoch: 129, step: 150) // Avg time/img: 0.0962 s
# loss: 0.1093 (epoch: 129, step: 200) // Avg time/img: 0.0956 s
# ----- VALIDATING - EPOCH 129 -----
# VAL loss: 0.3873 (epoch: 129, step: 0) // Avg time/img: 0.0398 s
# VAL loss: 0.668 (epoch: 129, step: 50) // Avg time/img: 0.0343 s
# VAL loss: 0.6451 (epoch: 129, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.5647 (epoch: 129, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  54.30 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_best.pth (epoch: 129)
# ----- TRAINING - EPOCH 130 -----
# LEARNING RATE:  8.520895446665837e-05
# loss: 0.09173 (epoch: 130, step: 0) // Avg time/img: 0.1172 s
# loss: 0.1129 (epoch: 130, step: 50) // Avg time/img: 0.0951 s
# loss: 0.1125 (epoch: 130, step: 100) // Avg time/img: 0.0948 s
# loss: 0.1103 (epoch: 130, step: 150) // Avg time/img: 0.0946 s
# loss: 0.1091 (epoch: 130, step: 200) // Avg time/img: 0.0943 s
# ----- VALIDATING - EPOCH 130 -----
# VAL loss: 0.3448 (epoch: 130, step: 0) // Avg time/img: 0.0374 s
# VAL loss: 0.6784 (epoch: 130, step: 50) // Avg time/img: 0.0339 s
# VAL loss: 0.6417 (epoch: 130, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.5642 (epoch: 130, step: 150) // Avg time/img: 0.0347 s
# EPOCH IoU on VAL set:  54.73 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/model_best.pth (epoch: 130)
# ----- TRAINING - EPOCH 131 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.133 (epoch: 131, step: 0) // Avg time/img: 0.1213 s
# loss: 0.1103 (epoch: 131, step: 50) // Avg time/img: 0.0950 s
# loss: 0.1087 (epoch: 131, step: 100) // Avg time/img: 0.0946 s
# loss: 0.1071 (epoch: 131, step: 150) // Avg time/img: 0.0945 s
# loss: 0.107 (epoch: 131, step: 200) // Avg time/img: 0.0944 s
# ----- VALIDATING - EPOCH 131 -----
# VAL loss: 0.3469 (epoch: 131, step: 0) // Avg time/img: 0.0362 s
# VAL loss: 0.687 (epoch: 131, step: 50) // Avg time/img: 0.0345 s
# VAL loss: 0.6635 (epoch: 131, step: 100) // Avg time/img: 0.0346 s
# VAL loss: 0.5828 (epoch: 131, step: 150) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  54.01 %
# ----- TRAINING - EPOCH 132 -----
# LEARNING RATE:  7.786927156042975e-05
# loss: 0.1057 (epoch: 132, step: 0) // Avg time/img: 0.1186 s
# loss: 0.1058 (epoch: 132, step: 50) // Avg time/img: 0.0953 s
# loss: 0.1057 (epoch: 132, step: 100) // Avg time/img: 0.0951 s
# loss: 0.1063 (epoch: 132, step: 150) // Avg time/img: 0.0948 s
# loss: 0.1068 (epoch: 132, step: 200) // Avg time/img: 0.0951 s
# ----- VALIDATING - EPOCH 132 -----
# VAL loss: 0.372 (epoch: 132, step: 0) // Avg time/img: 0.0339 s
# VAL loss: 0.6793 (epoch: 132, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.6474 (epoch: 132, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.568 (epoch: 132, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  54.30 %
# ----- TRAINING - EPOCH 133 -----
# LEARNING RATE:  7.417082774876436e-05
# loss: 0.1206 (epoch: 133, step: 0) // Avg time/img: 0.1241 s
# loss: 0.1051 (epoch: 133, step: 50) // Avg time/img: 0.0961 s
# loss: 0.1082 (epoch: 133, step: 100) // Avg time/img: 0.0949 s
# loss: 0.1077 (epoch: 133, step: 150) // Avg time/img: 0.0948 s
# loss: 0.1074 (epoch: 133, step: 200) // Avg time/img: 0.0948 s
# ----- VALIDATING - EPOCH 133 -----
# VAL loss: 0.3824 (epoch: 133, step: 0) // Avg time/img: 0.0366 s
# VAL loss: 0.6908 (epoch: 133, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.6661 (epoch: 133, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.5827 (epoch: 133, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  53.49 %
# ----- TRAINING - EPOCH 134 -----
# LEARNING RATE:  7.045176867237252e-05
# loss: 0.104 (epoch: 134, step: 0) // Avg time/img: 0.1347 s
# loss: 0.1045 (epoch: 134, step: 50) // Avg time/img: 0.0971 s
# loss: 0.1031 (epoch: 134, step: 100) // Avg time/img: 0.0962 s
# loss: 0.1043 (epoch: 134, step: 150) // Avg time/img: 0.0955 s
# loss: 0.1049 (epoch: 134, step: 200) // Avg time/img: 0.0952 s
# ----- VALIDATING - EPOCH 134 -----
# VAL loss: 0.417 (epoch: 134, step: 0) // Avg time/img: 0.0318 s
# VAL loss: 0.7494 (epoch: 134, step: 50) // Avg time/img: 0.0346 s
# VAL loss: 0.7202 (epoch: 134, step: 100) // Avg time/img: 0.0341 s
# VAL loss: 0.6239 (epoch: 134, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  53.74 %
# ----- TRAINING - EPOCH 135 -----
# LEARNING RATE:  6.671075496333931e-05
# loss: 0.07116 (epoch: 135, step: 0) // Avg time/img: 0.1193 s
# loss: 0.1077 (epoch: 135, step: 50) // Avg time/img: 0.0960 s
# loss: 0.1078 (epoch: 135, step: 100) // Avg time/img: 0.0956 s
# loss: 0.1065 (epoch: 135, step: 150) // Avg time/img: 0.0950 s
# loss: 0.1056 (epoch: 135, step: 200) // Avg time/img: 0.0948 s
# ----- VALIDATING - EPOCH 135 -----
# VAL loss: 0.3591 (epoch: 135, step: 0) // Avg time/img: 0.0318 s
# VAL loss: 0.6768 (epoch: 135, step: 50) // Avg time/img: 0.0343 s
# VAL loss: 0.6565 (epoch: 135, step: 100) // Avg time/img: 0.0340 s
# VAL loss: 0.5741 (epoch: 135, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  54.18 %
# ----- TRAINING - EPOCH 136 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.1168 (epoch: 136, step: 0) // Avg time/img: 0.1177 s
# loss: 0.1032 (epoch: 136, step: 50) // Avg time/img: 0.0951 s
# loss: 0.1039 (epoch: 136, step: 100) // Avg time/img: 0.0949 s
# loss: 0.1042 (epoch: 136, step: 150) // Avg time/img: 0.0945 s
# loss: 0.1048 (epoch: 136, step: 200) // Avg time/img: 0.0945 s
# ----- VALIDATING - EPOCH 136 -----
# VAL loss: 0.3854 (epoch: 136, step: 0) // Avg time/img: 0.0370 s
# VAL loss: 0.6903 (epoch: 136, step: 50) // Avg time/img: 0.0349 s
# VAL loss: 0.6621 (epoch: 136, step: 100) // Avg time/img: 0.0347 s
# VAL loss: 0.5735 (epoch: 136, step: 150) // Avg time/img: 0.0343 s
# EPOCH IoU on VAL set:  54.20 %
# ----- TRAINING - EPOCH 137 -----
# LEARNING RATE:  5.9156586125566465e-05
# loss: 0.1043 (epoch: 137, step: 0) // Avg time/img: 0.1175 s
# loss: 0.103 (epoch: 137, step: 50) // Avg time/img: 0.0986 s
# loss: 0.1044 (epoch: 137, step: 100) // Avg time/img: 0.0968 s
# loss: 0.104 (epoch: 137, step: 150) // Avg time/img: 0.0958 s
# loss: 0.1036 (epoch: 137, step: 200) // Avg time/img: 0.0956 s
# ----- VALIDATING - EPOCH 137 -----
# VAL loss: 0.3735 (epoch: 137, step: 0) // Avg time/img: 0.0337 s
# VAL loss: 0.7016 (epoch: 137, step: 50) // Avg time/img: 0.0339 s
# VAL loss: 0.6739 (epoch: 137, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.5839 (epoch: 137, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  54.30 %
# ----- TRAINING - EPOCH 138 -----
# LEARNING RATE:  5.533971118639405e-05
# loss: 0.1537 (epoch: 138, step: 0) // Avg time/img: 0.1181 s
# loss: 0.1007 (epoch: 138, step: 50) // Avg time/img: 0.0952 s
# loss: 0.1031 (epoch: 138, step: 100) // Avg time/img: 0.0954 s
# loss: 0.1021 (epoch: 138, step: 150) // Avg time/img: 0.0952 s
# loss: 0.1018 (epoch: 138, step: 200) // Avg time/img: 0.0950 s
# ----- VALIDATING - EPOCH 138 -----
# VAL loss: 0.3672 (epoch: 138, step: 0) // Avg time/img: 0.0320 s
# VAL loss: 0.6952 (epoch: 138, step: 50) // Avg time/img: 0.0365 s
# VAL loss: 0.6665 (epoch: 138, step: 100) // Avg time/img: 0.0352 s
# VAL loss: 0.5836 (epoch: 138, step: 150) // Avg time/img: 0.0348 s
# EPOCH IoU on VAL set:  54.02 %
# ----- TRAINING - EPOCH 139 -----
# LEARNING RATE:  5.149333174180893e-05
# loss: 0.1105 (epoch: 139, step: 0) // Avg time/img: 0.1220 s
# loss: 0.1011 (epoch: 139, step: 50) // Avg time/img: 0.0955 s
# loss: 0.1025 (epoch: 139, step: 100) // Avg time/img: 0.0952 s
# loss: 0.1019 (epoch: 139, step: 150) // Avg time/img: 0.0949 s
# loss: 0.1023 (epoch: 139, step: 200) // Avg time/img: 0.0949 s
# ----- VALIDATING - EPOCH 139 -----
# VAL loss: 0.3684 (epoch: 139, step: 0) // Avg time/img: 0.0402 s
# VAL loss: 0.6939 (epoch: 139, step: 50) // Avg time/img: 0.0348 s
# VAL loss: 0.6708 (epoch: 139, step: 100) // Avg time/img: 0.0342 s
# VAL loss: 0.5849 (epoch: 139, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  54.09 %
# ----- TRAINING - EPOCH 140 -----
# LEARNING RATE:  4.761472581495845e-05
# loss: 0.08371 (epoch: 140, step: 0) // Avg time/img: 0.0917 s
# loss: 0.1001 (epoch: 140, step: 50) // Avg time/img: 0.0964 s
# loss: 0.1007 (epoch: 140, step: 100) // Avg time/img: 0.0976 s
# loss: 0.1009 (epoch: 140, step: 150) // Avg time/img: 0.0963 s
# loss: 0.1016 (epoch: 140, step: 200) // Avg time/img: 0.0959 s
# ----- VALIDATING - EPOCH 140 -----
# VAL loss: 0.3996 (epoch: 140, step: 0) // Avg time/img: 0.0314 s
# VAL loss: 0.7159 (epoch: 140, step: 50) // Avg time/img: 0.0346 s
# VAL loss: 0.6922 (epoch: 140, step: 100) // Avg time/img: 0.0340 s
# VAL loss: 0.5978 (epoch: 140, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  53.13 %
# ----- TRAINING - EPOCH 141 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.1302 (epoch: 141, step: 0) // Avg time/img: 0.1187 s
# loss: 0.1003 (epoch: 141, step: 50) // Avg time/img: 0.0965 s
# loss: 0.09976 (epoch: 141, step: 100) // Avg time/img: 0.0955 s
# loss: 0.1002 (epoch: 141, step: 150) // Avg time/img: 0.0954 s
# loss: 0.1004 (epoch: 141, step: 200) // Avg time/img: 0.0951 s
# ----- VALIDATING - EPOCH 141 -----
# VAL loss: 0.3791 (epoch: 141, step: 0) // Avg time/img: 0.0361 s
# VAL loss: 0.686 (epoch: 141, step: 50) // Avg time/img: 0.0343 s
# VAL loss: 0.6691 (epoch: 141, step: 100) // Avg time/img: 0.0351 s
# VAL loss: 0.5835 (epoch: 141, step: 150) // Avg time/img: 0.0347 s
# EPOCH IoU on VAL set:  54.02 %
# ----- TRAINING - EPOCH 142 -----
# LEARNING RATE:  3.974716243773811e-05
# loss: 0.1232 (epoch: 142, step: 0) // Avg time/img: 0.1141 s
# loss: 0.1028 (epoch: 142, step: 50) // Avg time/img: 0.0963 s
# loss: 0.1005 (epoch: 142, step: 100) // Avg time/img: 0.0955 s
# loss: 0.1 (epoch: 142, step: 150) // Avg time/img: 0.0947 s
# loss: 0.1 (epoch: 142, step: 200) // Avg time/img: 0.0946 s
# ----- VALIDATING - EPOCH 142 -----
# VAL loss: 0.4168 (epoch: 142, step: 0) // Avg time/img: 0.0338 s
# VAL loss: 0.7034 (epoch: 142, step: 50) // Avg time/img: 0.0342 s
# VAL loss: 0.6821 (epoch: 142, step: 100) // Avg time/img: 0.0337 s
# VAL loss: 0.5997 (epoch: 142, step: 150) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  54.41 %
# ----- TRAINING - EPOCH 143 -----
# LEARNING RATE:  3.574940841773419e-05
# loss: 0.09786 (epoch: 143, step: 0) // Avg time/img: 0.1275 s
# loss: 0.09778 (epoch: 143, step: 50) // Avg time/img: 0.0964 s
# loss: 0.09711 (epoch: 143, step: 100) // Avg time/img: 0.0958 s
# loss: 0.09808 (epoch: 143, step: 150) // Avg time/img: 0.0961 s
# loss: 0.09935 (epoch: 143, step: 200) // Avg time/img: 0.0957 s
# ----- VALIDATING - EPOCH 143 -----
# VAL loss: 0.3894 (epoch: 143, step: 0) // Avg time/img: 0.0338 s
# VAL loss: 0.7257 (epoch: 143, step: 50) // Avg time/img: 0.0338 s
# VAL loss: 0.6988 (epoch: 143, step: 100) // Avg time/img: 0.0337 s
# VAL loss: 0.6086 (epoch: 143, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  53.77 %
# ----- TRAINING - EPOCH 144 -----
# LEARNING RATE:  3.1701229571812366e-05
# loss: 0.07874 (epoch: 144, step: 0) // Avg time/img: 0.1164 s
# loss: 0.09795 (epoch: 144, step: 50) // Avg time/img: 0.0965 s
# loss: 0.09968 (epoch: 144, step: 100) // Avg time/img: 0.0959 s
# loss: 0.09976 (epoch: 144, step: 150) // Avg time/img: 0.0954 s
# loss: 0.09911 (epoch: 144, step: 200) // Avg time/img: 0.0951 s
# ----- VALIDATING - EPOCH 144 -----
# VAL loss: 0.3778 (epoch: 144, step: 0) // Avg time/img: 0.0342 s
# VAL loss: 0.7218 (epoch: 144, step: 50) // Avg time/img: 0.0351 s
# VAL loss: 0.6965 (epoch: 144, step: 100) // Avg time/img: 0.0349 s
# VAL loss: 0.6042 (epoch: 144, step: 150) // Avg time/img: 0.0345 s
# EPOCH IoU on VAL set:  53.62 %
# ----- TRAINING - EPOCH 145 -----
# LEARNING RATE:  2.7594593229224316e-05
# loss: 0.12 (epoch: 145, step: 0) // Avg time/img: 0.1235 s
# loss: 0.1014 (epoch: 145, step: 50) // Avg time/img: 0.0956 s
# loss: 0.09946 (epoch: 145, step: 100) // Avg time/img: 0.0953 s
# loss: 0.09798 (epoch: 145, step: 150) // Avg time/img: 0.0949 s
# loss: 0.09792 (epoch: 145, step: 200) // Avg time/img: 0.0948 s
# ----- VALIDATING - EPOCH 145 -----
# VAL loss: 0.3861 (epoch: 145, step: 0) // Avg time/img: 0.0348 s
# VAL loss: 0.7238 (epoch: 145, step: 50) // Avg time/img: 0.0349 s
# VAL loss: 0.7023 (epoch: 145, step: 100) // Avg time/img: 0.0345 s
# VAL loss: 0.6093 (epoch: 145, step: 150) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  53.51 %
# ----- TRAINING - EPOCH 146 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.1024 (epoch: 146, step: 0) // Avg time/img: 0.1257 s
# loss: 0.1 (epoch: 146, step: 50) // Avg time/img: 0.0960 s
# loss: 0.0995 (epoch: 146, step: 100) // Avg time/img: 0.0956 s
# loss: 0.09851 (epoch: 146, step: 150) // Avg time/img: 0.0950 s
# loss: 0.0983 (epoch: 146, step: 200) // Avg time/img: 0.0947 s
# ----- VALIDATING - EPOCH 146 -----
# VAL loss: 0.3986 (epoch: 146, step: 0) // Avg time/img: 0.0390 s
# VAL loss: 0.7143 (epoch: 146, step: 50) // Avg time/img: 0.0348 s
# VAL loss: 0.6877 (epoch: 146, step: 100) // Avg time/img: 0.0342 s
# VAL loss: 0.5971 (epoch: 146, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  54.49 %
# ----- TRAINING - EPOCH 147 -----
# LEARNING RATE:  1.9157633621749503e-05
# loss: 0.1292 (epoch: 147, step: 0) // Avg time/img: 0.1257 s
# loss: 0.09847 (epoch: 147, step: 50) // Avg time/img: 0.0963 s
# loss: 0.09568 (epoch: 147, step: 100) // Avg time/img: 0.0954 s
# loss: 0.09658 (epoch: 147, step: 150) // Avg time/img: 0.0951 s
# loss: 0.09686 (epoch: 147, step: 200) // Avg time/img: 0.0947 s
# ----- VALIDATING - EPOCH 147 -----
# VAL loss: 0.3884 (epoch: 147, step: 0) // Avg time/img: 0.0367 s
# VAL loss: 0.7241 (epoch: 147, step: 50) // Avg time/img: 0.0353 s
# VAL loss: 0.7016 (epoch: 147, step: 100) // Avg time/img: 0.0345 s
# VAL loss: 0.6062 (epoch: 147, step: 150) // Avg time/img: 0.0345 s
# EPOCH IoU on VAL set:  53.89 %
# ----- TRAINING - EPOCH 148 -----
# LEARNING RATE:  1.4787576366283148e-05
# loss: 0.1104 (epoch: 148, step: 0) // Avg time/img: 0.1243 s
# loss: 0.09885 (epoch: 148, step: 50) // Avg time/img: 0.0957 s
# loss: 0.09712 (epoch: 148, step: 100) // Avg time/img: 0.0952 s
# loss: 0.09785 (epoch: 148, step: 150) // Avg time/img: 0.0950 s
# loss: 0.09752 (epoch: 148, step: 200) // Avg time/img: 0.0946 s
# ----- VALIDATING - EPOCH 148 -----
# VAL loss: 0.4048 (epoch: 148, step: 0) // Avg time/img: 0.0345 s
# VAL loss: 0.715 (epoch: 148, step: 50) // Avg time/img: 0.0346 s
# VAL loss: 0.693 (epoch: 148, step: 100) // Avg time/img: 0.0343 s
# VAL loss: 0.6013 (epoch: 148, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  54.25 %
# ----- TRAINING - EPOCH 149 -----
# LEARNING RATE:  1.0266321660392084e-05
# loss: 0.0772 (epoch: 149, step: 0) // Avg time/img: 0.1130 s
# loss: 0.09588 (epoch: 149, step: 50) // Avg time/img: 0.0955 s
# loss: 0.09469 (epoch: 149, step: 100) // Avg time/img: 0.0953 s
# loss: 0.09582 (epoch: 149, step: 150) // Avg time/img: 0.0952 s
# loss: 0.09732 (epoch: 149, step: 200) // Avg time/img: 0.0951 s
# ----- VALIDATING - EPOCH 149 -----
# VAL loss: 0.4081 (epoch: 149, step: 0) // Avg time/img: 0.0315 s
# VAL loss: 0.7033 (epoch: 149, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.6833 (epoch: 149, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.5951 (epoch: 149, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  54.24 %
# ----- TRAINING - EPOCH 150 -----
# LEARNING RATE:  5.501585556734927e-06
# loss: 0.1116 (epoch: 150, step: 0) // Avg time/img: 0.1211 s
# loss: 0.09289 (epoch: 150, step: 50) // Avg time/img: 0.0960 s
# loss: 0.09533 (epoch: 150, step: 100) // Avg time/img: 0.0952 s
# loss: 0.09675 (epoch: 150, step: 150) // Avg time/img: 0.0950 s
# loss: 0.09607 (epoch: 150, step: 200) // Avg time/img: 0.0950 s
# ----- VALIDATING - EPOCH 150 -----
# VAL loss: 0.3966 (epoch: 150, step: 0) // Avg time/img: 0.0353 s
# VAL loss: 0.6983 (epoch: 150, step: 50) // Avg time/img: 0.0340 s
# VAL loss: 0.6784 (epoch: 150, step: 100) // Avg time/img: 0.0337 s
# VAL loss: 0.5917 (epoch: 150, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  54.40 %
# ========== TRAINING FINISHED ===========

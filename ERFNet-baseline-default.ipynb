# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet model definition

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)
    

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3x1_1 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1,0), bias=True)

        self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3x1_2 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1*dilated,0), bias=True, dilation = (dilated,1))

        self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3x1_1(input)
        output = F.relu(output)
        output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3x1_2(output)
        output = F.relu(output)
        output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output


class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target


class CrossEntropyLoss2d(torch.nn.Module):

    def __init__(self, weight=None):
        super().__init__()

        self.loss = torch.nn.NLLLoss2d(weight)

    def forward(self, outputs, targets):
        return self.loss(torch.nn.functional.log_softmax(outputs, dim=1), targets)


def train(args, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = CrossEntropyLoss2d(weight)
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train()
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0])
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 

            loss = criterion(outputs, targets[:, 0])
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Model
    # assert os.path.exists(args.model + ".py"), "Error: model definition not found"
    # model_file = importlib.import_module(args.model)
    model = Net(NUM_CLASSES)
    # copyfile(args.model + ".py", savedir + '/' + args.model + ".py")
    
    if args.cuda:
        model = torch.nn.DataParallel(model).cuda()
    
    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        """
        try:
            model.load_state_dict(torch.load(args.state))
        except AssertionError:
            model.load_state_dict(torch.load(args.state,
                map_location=lambda storage, loc: storage))
        #When model is saved as DataParallel it adds a model. to each key. To remove:
        #state_dict = {k.partition('model.')[2]: v for k,v in state_dict}
        #https://discuss.pytorch.org/t/prefix-parameter-names-in-saved-model-if-trained-by-multi-gpu/494
        """
        def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict keys are there
            own_state = model.state_dict()
            for name, param in state_dict.items():
                if name not in own_state:
                     continue
                own_state[name].copy_(param)
            return model

        #print(torch.load(args.state))
        model = load_my_state_dict(model, torch.load(args.state))

    """
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            #m.weight.data.normal_(0.0, 0.02)
            n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
            m.weight.data.normal_(0, math.sqrt(2. / n))
        elif classname.find('BatchNorm') != -1:
            #m.weight.data.normal_(1.0, 0.02)
            m.weight.data.fill_(1)
            m.bias.data.fill_(0)
    #TO ACCESS MODEL IN DataParallel: next(model.children())
    #next(model.children()).decoder.apply(weights_init)
    #Reinitialize weights for decoder
    
    next(model.children()).decoder.layers.apply(weights_init)
    next(model.children()).decoder.output_conv.apply(weights_init)
    #print(model.state_dict())
    f = open('weights5.txt', 'w')
    f.write(str(model.state_dict()))
    f.close()
    """

    # train(args, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=60)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=3)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 4.105 (epoch: 1, step: 0) // Avg time/img: 2.4434 s
# loss: 1.516 (epoch: 1, step: 50) // Avg time/img: 0.1260 s
# loss: 1.293 (epoch: 1, step: 100) // Avg time/img: 0.1042 s
# loss: 1.192 (epoch: 1, step: 150) // Avg time/img: 0.0969 s
# loss: 1.129 (epoch: 1, step: 200) // Avg time/img: 0.0928 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.572 (epoch: 1, step: 0) // Avg time/img: 0.0288 s
# VAL loss: 1.374 (epoch: 1, step: 50) // Avg time/img: 0.0268 s
# VAL loss: 1.29 (epoch: 1, step: 100) // Avg time/img: 0.0266 s
# VAL loss: 1.139 (epoch: 1, step: 150) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  18.69 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 0.5538 (epoch: 2, step: 0) // Avg time/img: 0.1174 s
# loss: 0.823 (epoch: 2, step: 50) // Avg time/img: 0.0893 s
# loss: 0.82 (epoch: 2, step: 100) // Avg time/img: 0.0897 s
# loss: 0.8123 (epoch: 2, step: 150) // Avg time/img: 0.0895 s
# loss: 0.8017 (epoch: 2, step: 200) // Avg time/img: 0.0895 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.515 (epoch: 2, step: 0) // Avg time/img: 0.0210 s
# VAL loss: 1.273 (epoch: 2, step: 50) // Avg time/img: 0.0273 s
# VAL loss: 1.188 (epoch: 2, step: 100) // Avg time/img: 0.0274 s
# VAL loss: 1.038 (epoch: 2, step: 150) // Avg time/img: 0.0275 s
# EPOCH IoU on VAL set:  22.48 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.4472 (epoch: 3, step: 0) // Avg time/img: 0.1208 s
# loss: 0.6862 (epoch: 3, step: 50) // Avg time/img: 0.0892 s
# loss: 0.6892 (epoch: 3, step: 100) // Avg time/img: 0.0886 s
# loss: 0.6919 (epoch: 3, step: 150) // Avg time/img: 0.0901 s
# loss: 0.6784 (epoch: 3, step: 200) // Avg time/img: 0.0894 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 1.153 (epoch: 3, step: 0) // Avg time/img: 0.0394 s
# VAL loss: 1.013 (epoch: 3, step: 50) // Avg time/img: 0.0278 s
# VAL loss: 0.9926 (epoch: 3, step: 100) // Avg time/img: 0.0276 s
# VAL loss: 0.8739 (epoch: 3, step: 150) // Avg time/img: 0.0271 s
# EPOCH IoU on VAL set:  25.58 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 0.5661 (epoch: 4, step: 0) // Avg time/img: 0.1042 s
# loss: 0.6068 (epoch: 4, step: 50) // Avg time/img: 0.0886 s
# loss: 0.6232 (epoch: 4, step: 100) // Avg time/img: 0.0882 s
# loss: 0.6315 (epoch: 4, step: 150) // Avg time/img: 0.0879 s
# loss: 0.6321 (epoch: 4, step: 200) // Avg time/img: 0.0875 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 1.206 (epoch: 4, step: 0) // Avg time/img: 0.0284 s
# VAL loss: 1.025 (epoch: 4, step: 50) // Avg time/img: 0.0271 s
# VAL loss: 0.9689 (epoch: 4, step: 100) // Avg time/img: 0.0266 s
# VAL loss: 0.8455 (epoch: 4, step: 150) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  26.05 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.4261 (epoch: 5, step: 0) // Avg time/img: 0.1154 s
# loss: 0.5953 (epoch: 5, step: 50) // Avg time/img: 0.0880 s
# loss: 0.5772 (epoch: 5, step: 100) // Avg time/img: 0.0910 s
# loss: 0.5833 (epoch: 5, step: 150) // Avg time/img: 0.0893 s
# loss: 0.5726 (epoch: 5, step: 200) // Avg time/img: 0.0886 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 1.219 (epoch: 5, step: 0) // Avg time/img: 0.0237 s
# VAL loss: 1.056 (epoch: 5, step: 50) // Avg time/img: 0.0265 s
# VAL loss: 1.031 (epoch: 5, step: 100) // Avg time/img: 0.0262 s
# VAL loss: 0.8948 (epoch: 5, step: 150) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  26.45 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 5)
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004623387553722673
# loss: 0.45 (epoch: 6, step: 0) // Avg time/img: 0.1005 s
# loss: 0.5319 (epoch: 6, step: 50) // Avg time/img: 0.0885 s
# loss: 0.5395 (epoch: 6, step: 100) // Avg time/img: 0.0883 s
# loss: 0.5331 (epoch: 6, step: 150) // Avg time/img: 0.0876 s
# loss: 0.5384 (epoch: 6, step: 200) // Avg time/img: 0.0871 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 1.482 (epoch: 6, step: 0) // Avg time/img: 0.0245 s
# VAL loss: 1.028 (epoch: 6, step: 50) // Avg time/img: 0.0271 s
# VAL loss: 0.9658 (epoch: 6, step: 100) // Avg time/img: 0.0269 s
# VAL loss: 0.839 (epoch: 6, step: 150) // Avg time/img: 0.0269 s
# EPOCH IoU on VAL set:  27.66 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.6496 (epoch: 7, step: 0) // Avg time/img: 0.0830 s
# loss: 0.539 (epoch: 7, step: 50) // Avg time/img: 0.0949 s
# loss: 0.5134 (epoch: 7, step: 100) // Avg time/img: 0.0911 s
# loss: 0.5143 (epoch: 7, step: 150) // Avg time/img: 0.0899 s
# loss: 0.5208 (epoch: 7, step: 200) // Avg time/img: 0.0892 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 0.6989 (epoch: 7, step: 0) // Avg time/img: 0.0217 s
# VAL loss: 0.92 (epoch: 7, step: 50) // Avg time/img: 0.0263 s
# VAL loss: 0.89 (epoch: 7, step: 100) // Avg time/img: 0.0262 s
# VAL loss: 0.7802 (epoch: 7, step: 150) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  29.13 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 7)
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.00044717978378742816
# loss: 0.5057 (epoch: 8, step: 0) // Avg time/img: 0.1187 s
# loss: 0.5037 (epoch: 8, step: 50) // Avg time/img: 0.0884 s
# loss: 0.5089 (epoch: 8, step: 100) // Avg time/img: 0.0876 s
# loss: 0.5094 (epoch: 8, step: 150) // Avg time/img: 0.0873 s
# loss: 0.4936 (epoch: 8, step: 200) // Avg time/img: 0.0872 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 0.8438 (epoch: 8, step: 0) // Avg time/img: 0.0303 s
# VAL loss: 0.9324 (epoch: 8, step: 50) // Avg time/img: 0.0273 s
# VAL loss: 0.8962 (epoch: 8, step: 100) // Avg time/img: 0.0273 s
# VAL loss: 0.7807 (epoch: 8, step: 150) // Avg time/img: 0.0285 s
# EPOCH IoU on VAL set:  29.28 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 8)
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.4679 (epoch: 9, step: 0) // Avg time/img: 0.0964 s
# loss: 0.4873 (epoch: 9, step: 50) // Avg time/img: 0.0877 s
# loss: 0.489 (epoch: 9, step: 100) // Avg time/img: 0.0878 s
# loss: 0.4903 (epoch: 9, step: 150) // Avg time/img: 0.0871 s
# loss: 0.4748 (epoch: 9, step: 200) // Avg time/img: 0.0869 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 0.6605 (epoch: 9, step: 0) // Avg time/img: 0.0280 s
# VAL loss: 0.8549 (epoch: 9, step: 50) // Avg time/img: 0.0276 s
# VAL loss: 0.8507 (epoch: 9, step: 100) // Avg time/img: 0.0273 s
# VAL loss: 0.7406 (epoch: 9, step: 150) // Avg time/img: 0.0269 s
# EPOCH IoU on VAL set:  30.36 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 9)
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.00043196348615140955
# loss: 0.4755 (epoch: 10, step: 0) // Avg time/img: 0.1048 s
# loss: 0.4612 (epoch: 10, step: 50) // Avg time/img: 0.0884 s
# loss: 0.4593 (epoch: 10, step: 100) // Avg time/img: 0.0879 s
# loss: 0.4536 (epoch: 10, step: 150) // Avg time/img: 0.0874 s
# loss: 0.4479 (epoch: 10, step: 200) // Avg time/img: 0.0872 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 0.4433 (epoch: 10, step: 0) // Avg time/img: 0.0264 s
# VAL loss: 0.7681 (epoch: 10, step: 50) // Avg time/img: 0.0268 s
# VAL loss: 0.7459 (epoch: 10, step: 100) // Avg time/img: 0.0284 s
# VAL loss: 0.6647 (epoch: 10, step: 150) // Avg time/img: 0.0279 s
# EPOCH IoU on VAL set:  33.00 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 10)
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.3462 (epoch: 11, step: 0) // Avg time/img: 0.1171 s
# loss: 0.4498 (epoch: 11, step: 50) // Avg time/img: 0.0891 s
# loss: 0.4598 (epoch: 11, step: 100) // Avg time/img: 0.0880 s
# loss: 0.4446 (epoch: 11, step: 150) // Avg time/img: 0.0875 s
# loss: 0.438 (epoch: 11, step: 200) // Avg time/img: 0.0872 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.8044 (epoch: 11, step: 0) // Avg time/img: 0.0267 s
# VAL loss: 0.8069 (epoch: 11, step: 50) // Avg time/img: 0.0270 s
# VAL loss: 0.7928 (epoch: 11, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.6897 (epoch: 11, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  33.15 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 11)
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.0004166873834706844
# loss: 0.3139 (epoch: 12, step: 0) // Avg time/img: 0.1095 s
# loss: 0.3931 (epoch: 12, step: 50) // Avg time/img: 0.0885 s
# loss: 0.4087 (epoch: 12, step: 100) // Avg time/img: 0.0880 s
# loss: 0.4296 (epoch: 12, step: 150) // Avg time/img: 0.0873 s
# loss: 0.4281 (epoch: 12, step: 200) // Avg time/img: 0.0872 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.764 (epoch: 12, step: 0) // Avg time/img: 0.0397 s
# VAL loss: 0.7412 (epoch: 12, step: 50) // Avg time/img: 0.0292 s
# VAL loss: 0.7449 (epoch: 12, step: 100) // Avg time/img: 0.0283 s
# VAL loss: 0.6592 (epoch: 12, step: 150) // Avg time/img: 0.0278 s
# EPOCH IoU on VAL set:  33.16 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 12)
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.4367 (epoch: 13, step: 0) // Avg time/img: 0.1168 s
# loss: 0.4056 (epoch: 13, step: 50) // Avg time/img: 0.0875 s
# loss: 0.3944 (epoch: 13, step: 100) // Avg time/img: 0.0870 s
# loss: 0.4 (epoch: 13, step: 150) // Avg time/img: 0.0871 s
# loss: 0.4136 (epoch: 13, step: 200) // Avg time/img: 0.0870 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 0.7753 (epoch: 13, step: 0) // Avg time/img: 0.0286 s
# VAL loss: 0.7921 (epoch: 13, step: 50) // Avg time/img: 0.0278 s
# VAL loss: 0.7668 (epoch: 13, step: 100) // Avg time/img: 0.0273 s
# VAL loss: 0.6724 (epoch: 13, step: 150) // Avg time/img: 0.0276 s
# EPOCH IoU on VAL set:  33.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 13)
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.0004013487836640184
# loss: 0.3449 (epoch: 14, step: 0) // Avg time/img: 0.1212 s
# loss: 0.408 (epoch: 14, step: 50) // Avg time/img: 0.0892 s
# loss: 0.4064 (epoch: 14, step: 100) // Avg time/img: 0.0884 s
# loss: 0.4065 (epoch: 14, step: 150) // Avg time/img: 0.0875 s
# loss: 0.4074 (epoch: 14, step: 200) // Avg time/img: 0.0887 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 0.7274 (epoch: 14, step: 0) // Avg time/img: 0.0315 s
# VAL loss: 0.7782 (epoch: 14, step: 50) // Avg time/img: 0.0264 s
# VAL loss: 0.737 (epoch: 14, step: 100) // Avg time/img: 0.0266 s
# VAL loss: 0.641 (epoch: 14, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  34.86 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 14)
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.2709 (epoch: 15, step: 0) // Avg time/img: 0.1143 s
# loss: 0.3571 (epoch: 15, step: 50) // Avg time/img: 0.0880 s
# loss: 0.3815 (epoch: 15, step: 100) // Avg time/img: 0.0872 s
# loss: 0.3855 (epoch: 15, step: 150) // Avg time/img: 0.0872 s
# loss: 0.3786 (epoch: 15, step: 200) // Avg time/img: 0.0870 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 0.8935 (epoch: 15, step: 0) // Avg time/img: 0.0319 s
# VAL loss: 0.8747 (epoch: 15, step: 50) // Avg time/img: 0.0284 s
# VAL loss: 0.846 (epoch: 15, step: 100) // Avg time/img: 0.0285 s
# VAL loss: 0.7259 (epoch: 15, step: 150) // Avg time/img: 0.0293 s
# EPOCH IoU on VAL set:  33.50 %
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00038594475336178527
# loss: 0.4321 (epoch: 16, step: 0) // Avg time/img: 0.0847 s
# loss: 0.3495 (epoch: 16, step: 50) // Avg time/img: 0.0884 s
# loss: 0.3566 (epoch: 16, step: 100) // Avg time/img: 0.0875 s
# loss: 0.3577 (epoch: 16, step: 150) // Avg time/img: 0.0871 s
# loss: 0.3716 (epoch: 16, step: 200) // Avg time/img: 0.0867 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.7137 (epoch: 16, step: 0) // Avg time/img: 0.0265 s
# VAL loss: 0.7789 (epoch: 16, step: 50) // Avg time/img: 0.0273 s
# VAL loss: 0.7547 (epoch: 16, step: 100) // Avg time/img: 0.0271 s
# VAL loss: 0.6503 (epoch: 16, step: 150) // Avg time/img: 0.0276 s
# EPOCH IoU on VAL set:  34.78 %
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.4985 (epoch: 17, step: 0) // Avg time/img: 0.1052 s
# loss: 0.3413 (epoch: 17, step: 50) // Avg time/img: 0.0887 s
# loss: 0.3403 (epoch: 17, step: 100) // Avg time/img: 0.0885 s
# loss: 0.3531 (epoch: 17, step: 150) // Avg time/img: 0.0878 s
# loss: 0.3591 (epoch: 17, step: 200) // Avg time/img: 0.0874 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.7617 (epoch: 17, step: 0) // Avg time/img: 0.0269 s
# VAL loss: 0.7152 (epoch: 17, step: 50) // Avg time/img: 0.0265 s
# VAL loss: 0.6841 (epoch: 17, step: 100) // Avg time/img: 0.0290 s
# VAL loss: 0.605 (epoch: 17, step: 150) // Avg time/img: 0.0284 s
# EPOCH IoU on VAL set:  37.16 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 17)
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.00037047208454744316
# loss: 0.2813 (epoch: 18, step: 0) // Avg time/img: 0.1048 s
# loss: 0.348 (epoch: 18, step: 50) // Avg time/img: 0.0889 s
# loss: 0.3418 (epoch: 18, step: 100) // Avg time/img: 0.0878 s
# loss: 0.3392 (epoch: 18, step: 150) // Avg time/img: 0.0875 s
# loss: 0.3441 (epoch: 18, step: 200) // Avg time/img: 0.0871 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.4962 (epoch: 18, step: 0) // Avg time/img: 0.0276 s
# VAL loss: 0.7167 (epoch: 18, step: 50) // Avg time/img: 0.0258 s
# VAL loss: 0.6938 (epoch: 18, step: 100) // Avg time/img: 0.0262 s
# VAL loss: 0.6078 (epoch: 18, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  37.70 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 18)
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.2567 (epoch: 19, step: 0) // Avg time/img: 0.1056 s
# loss: 0.3499 (epoch: 19, step: 50) // Avg time/img: 0.0880 s
# loss: 0.3528 (epoch: 19, step: 100) // Avg time/img: 0.0875 s
# loss: 0.3519 (epoch: 19, step: 150) // Avg time/img: 0.0873 s
# loss: 0.3437 (epoch: 19, step: 200) // Avg time/img: 0.0869 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.6955 (epoch: 19, step: 0) // Avg time/img: 0.0260 s
# VAL loss: 0.7766 (epoch: 19, step: 50) // Avg time/img: 0.0267 s
# VAL loss: 0.7447 (epoch: 19, step: 100) // Avg time/img: 0.0266 s
# VAL loss: 0.6457 (epoch: 19, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  36.23 %
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.0003549272548125162
# loss: 0.2566 (epoch: 20, step: 0) // Avg time/img: 0.0878 s
# loss: 0.3281 (epoch: 20, step: 50) // Avg time/img: 0.0875 s
# loss: 0.3324 (epoch: 20, step: 100) // Avg time/img: 0.0873 s
# loss: 0.3387 (epoch: 20, step: 150) // Avg time/img: 0.0870 s
# loss: 0.3472 (epoch: 20, step: 200) // Avg time/img: 0.0869 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.667 (epoch: 20, step: 0) // Avg time/img: 0.0285 s
# VAL loss: 0.7293 (epoch: 20, step: 50) // Avg time/img: 0.0273 s
# VAL loss: 0.6854 (epoch: 20, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.6022 (epoch: 20, step: 150) // Avg time/img: 0.0267 s
# EPOCH IoU on VAL set:  36.71 %
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.3589 (epoch: 21, step: 0) // Avg time/img: 0.0849 s
# loss: 0.3259 (epoch: 21, step: 50) // Avg time/img: 0.0874 s
# loss: 0.3194 (epoch: 21, step: 100) // Avg time/img: 0.0898 s
# loss: 0.3251 (epoch: 21, step: 150) // Avg time/img: 0.0886 s
# loss: 0.3286 (epoch: 21, step: 200) // Avg time/img: 0.0878 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.6151 (epoch: 21, step: 0) // Avg time/img: 0.0332 s
# VAL loss: 0.714 (epoch: 21, step: 50) // Avg time/img: 0.0272 s
# VAL loss: 0.6995 (epoch: 21, step: 100) // Avg time/img: 0.0270 s
# VAL loss: 0.603 (epoch: 21, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  37.10 %
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.0003393063796290625
# loss: 0.3315 (epoch: 22, step: 0) // Avg time/img: 0.0879 s
# loss: 0.3325 (epoch: 22, step: 50) // Avg time/img: 0.0869 s
# loss: 0.3189 (epoch: 22, step: 100) // Avg time/img: 0.0874 s
# loss: 0.3168 (epoch: 22, step: 150) // Avg time/img: 0.0872 s
# loss: 0.3171 (epoch: 22, step: 200) // Avg time/img: 0.0870 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.6404 (epoch: 22, step: 0) // Avg time/img: 0.0319 s
# VAL loss: 0.7166 (epoch: 22, step: 50) // Avg time/img: 0.0267 s
# VAL loss: 0.6702 (epoch: 22, step: 100) // Avg time/img: 0.0270 s
# VAL loss: 0.5822 (epoch: 22, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  37.46 %
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.3654 (epoch: 23, step: 0) // Avg time/img: 0.1378 s
# loss: 0.3439 (epoch: 23, step: 50) // Avg time/img: 0.0899 s
# loss: 0.3267 (epoch: 23, step: 100) // Avg time/img: 0.0885 s
# loss: 0.3178 (epoch: 23, step: 150) // Avg time/img: 0.0878 s
# loss: 0.3233 (epoch: 23, step: 200) // Avg time/img: 0.0875 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.7997 (epoch: 23, step: 0) // Avg time/img: 0.0319 s
# VAL loss: 0.755 (epoch: 23, step: 50) // Avg time/img: 0.0267 s
# VAL loss: 0.7372 (epoch: 23, step: 100) // Avg time/img: 0.0269 s
# VAL loss: 0.6414 (epoch: 23, step: 150) // Avg time/img: 0.0270 s
# EPOCH IoU on VAL set:  36.75 %
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.0003236051545417615
# loss: 0.4325 (epoch: 24, step: 0) // Avg time/img: 0.0968 s
# loss: 0.3089 (epoch: 24, step: 50) // Avg time/img: 0.0875 s
# loss: 0.3158 (epoch: 24, step: 100) // Avg time/img: 0.0874 s
# loss: 0.3149 (epoch: 24, step: 150) // Avg time/img: 0.0870 s
# loss: 0.306 (epoch: 24, step: 200) // Avg time/img: 0.0869 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 1.01 (epoch: 24, step: 0) // Avg time/img: 0.0267 s
# VAL loss: 0.9006 (epoch: 24, step: 50) // Avg time/img: 0.0269 s
# VAL loss: 0.854 (epoch: 24, step: 100) // Avg time/img: 0.0287 s
# VAL loss: 0.7452 (epoch: 24, step: 150) // Avg time/img: 0.0280 s
# EPOCH IoU on VAL set:  33.88 %
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.3698 (epoch: 25, step: 0) // Avg time/img: 0.1104 s
# loss: 0.3369 (epoch: 25, step: 50) // Avg time/img: 0.0884 s
# loss: 0.3169 (epoch: 25, step: 100) // Avg time/img: 0.0879 s
# loss: 0.3154 (epoch: 25, step: 150) // Avg time/img: 0.0876 s
# loss: 0.3062 (epoch: 25, step: 200) // Avg time/img: 0.0871 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.4112 (epoch: 25, step: 0) // Avg time/img: 0.0295 s
# VAL loss: 0.684 (epoch: 25, step: 50) // Avg time/img: 0.0270 s
# VAL loss: 0.6497 (epoch: 25, step: 100) // Avg time/img: 0.0270 s
# VAL loss: 0.5637 (epoch: 25, step: 150) // Avg time/img: 0.0272 s
# EPOCH IoU on VAL set:  39.65 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 25)
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00030781878448615926
# loss: 0.2253 (epoch: 26, step: 0) // Avg time/img: 0.1112 s
# loss: 0.2905 (epoch: 26, step: 50) // Avg time/img: 0.0886 s
# loss: 0.2886 (epoch: 26, step: 100) // Avg time/img: 0.0876 s
# loss: 0.2931 (epoch: 26, step: 150) // Avg time/img: 0.0874 s
# loss: 0.2931 (epoch: 26, step: 200) // Avg time/img: 0.0877 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.8948 (epoch: 26, step: 0) // Avg time/img: 0.0493 s
# VAL loss: 0.8067 (epoch: 26, step: 50) // Avg time/img: 0.0311 s
# VAL loss: 0.7848 (epoch: 26, step: 100) // Avg time/img: 0.0291 s
# VAL loss: 0.672 (epoch: 26, step: 150) // Avg time/img: 0.0286 s
# EPOCH IoU on VAL set:  37.62 %
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.2712 (epoch: 27, step: 0) // Avg time/img: 0.0905 s
# loss: 0.2969 (epoch: 27, step: 50) // Avg time/img: 0.0888 s
# loss: 0.2943 (epoch: 27, step: 100) // Avg time/img: 0.0882 s
# loss: 0.2844 (epoch: 27, step: 150) // Avg time/img: 0.0874 s
# loss: 0.2853 (epoch: 27, step: 200) // Avg time/img: 0.0869 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.4311 (epoch: 27, step: 0) // Avg time/img: 0.0279 s
# VAL loss: 0.689 (epoch: 27, step: 50) // Avg time/img: 0.0272 s
# VAL loss: 0.6716 (epoch: 27, step: 100) // Avg time/img: 0.0272 s
# VAL loss: 0.5904 (epoch: 27, step: 150) // Avg time/img: 0.0270 s
# EPOCH IoU on VAL set:  39.56 %
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00029194189645999016
# loss: 0.3235 (epoch: 28, step: 0) // Avg time/img: 0.1087 s
# loss: 0.2854 (epoch: 28, step: 50) // Avg time/img: 0.0877 s
# loss: 0.2856 (epoch: 28, step: 100) // Avg time/img: 0.0875 s
# loss: 0.2755 (epoch: 28, step: 150) // Avg time/img: 0.0872 s
# loss: 0.2762 (epoch: 28, step: 200) // Avg time/img: 0.0886 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.6567 (epoch: 28, step: 0) // Avg time/img: 0.0270 s
# VAL loss: 0.6857 (epoch: 28, step: 50) // Avg time/img: 0.0269 s
# VAL loss: 0.6848 (epoch: 28, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.5966 (epoch: 28, step: 150) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  40.36 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 28)
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.2002 (epoch: 29, step: 0) // Avg time/img: 0.1115 s
# loss: 0.2671 (epoch: 29, step: 50) // Avg time/img: 0.0880 s
# loss: 0.2665 (epoch: 29, step: 100) // Avg time/img: 0.0875 s
# loss: 0.2639 (epoch: 29, step: 150) // Avg time/img: 0.0870 s
# loss: 0.2746 (epoch: 29, step: 200) // Avg time/img: 0.0867 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.6724 (epoch: 29, step: 0) // Avg time/img: 0.0279 s
# VAL loss: 0.8479 (epoch: 29, step: 50) // Avg time/img: 0.0268 s
# VAL loss: 0.8186 (epoch: 29, step: 100) // Avg time/img: 0.0269 s
# VAL loss: 0.7022 (epoch: 29, step: 150) // Avg time/img: 0.0272 s
# EPOCH IoU on VAL set:  37.47 %
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.0002759684303703797
# loss: 0.462 (epoch: 30, step: 0) // Avg time/img: 0.1145 s
# loss: 0.2922 (epoch: 30, step: 50) // Avg time/img: 0.0888 s
# loss: 0.2901 (epoch: 30, step: 100) // Avg time/img: 0.0887 s
# loss: 0.2794 (epoch: 30, step: 150) // Avg time/img: 0.0898 s
# loss: 0.2738 (epoch: 30, step: 200) // Avg time/img: 0.0889 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 1.009 (epoch: 30, step: 0) // Avg time/img: 0.0292 s
# VAL loss: 0.9227 (epoch: 30, step: 50) // Avg time/img: 0.0265 s
# VAL loss: 0.8666 (epoch: 30, step: 100) // Avg time/img: 0.0268 s
# VAL loss: 0.7516 (epoch: 30, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  34.15 %
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.2952 (epoch: 31, step: 0) // Avg time/img: 0.0836 s
# loss: 0.2871 (epoch: 31, step: 50) // Avg time/img: 0.0870 s
# loss: 0.2792 (epoch: 31, step: 100) // Avg time/img: 0.0874 s
# loss: 0.2723 (epoch: 31, step: 150) // Avg time/img: 0.0870 s
# loss: 0.2725 (epoch: 31, step: 200) // Avg time/img: 0.0868 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.4171 (epoch: 31, step: 0) // Avg time/img: 0.0243 s
# VAL loss: 0.6275 (epoch: 31, step: 50) // Avg time/img: 0.0264 s
# VAL loss: 0.5949 (epoch: 31, step: 100) // Avg time/img: 0.0268 s
# VAL loss: 0.5231 (epoch: 31, step: 150) // Avg time/img: 0.0267 s
# EPOCH IoU on VAL set:  42.52 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 31)
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.0002598915008274931
# loss: 0.2524 (epoch: 32, step: 0) // Avg time/img: 0.1161 s
# loss: 0.241 (epoch: 32, step: 50) // Avg time/img: 0.0944 s
# loss: 0.2472 (epoch: 32, step: 100) // Avg time/img: 0.0906 s
# loss: 0.2559 (epoch: 32, step: 150) // Avg time/img: 0.0894 s
# loss: 0.2628 (epoch: 32, step: 200) // Avg time/img: 0.0887 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.3731 (epoch: 32, step: 0) // Avg time/img: 0.0309 s
# VAL loss: 0.6846 (epoch: 32, step: 50) // Avg time/img: 0.0267 s
# VAL loss: 0.6933 (epoch: 32, step: 100) // Avg time/img: 0.0265 s
# VAL loss: 0.6122 (epoch: 32, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  39.38 %
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.3183 (epoch: 33, step: 0) // Avg time/img: 0.0845 s
# loss: 0.253 (epoch: 33, step: 50) // Avg time/img: 0.0875 s
# loss: 0.2529 (epoch: 33, step: 100) // Avg time/img: 0.0871 s
# loss: 0.2511 (epoch: 33, step: 150) // Avg time/img: 0.0872 s
# loss: 0.2526 (epoch: 33, step: 200) // Avg time/img: 0.0868 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.3796 (epoch: 33, step: 0) // Avg time/img: 0.0279 s
# VAL loss: 0.61 (epoch: 33, step: 50) // Avg time/img: 0.0282 s
# VAL loss: 0.5898 (epoch: 33, step: 100) // Avg time/img: 0.0273 s
# VAL loss: 0.5202 (epoch: 33, step: 150) // Avg time/img: 0.0277 s
# EPOCH IoU on VAL set:  43.01 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 33)
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.00024370321958949772
# loss: 0.2364 (epoch: 34, step: 0) // Avg time/img: 0.0875 s
# loss: 0.2478 (epoch: 34, step: 50) // Avg time/img: 0.0877 s
# loss: 0.2469 (epoch: 34, step: 100) // Avg time/img: 0.0877 s
# loss: 0.2473 (epoch: 34, step: 150) // Avg time/img: 0.0875 s
# loss: 0.2455 (epoch: 34, step: 200) // Avg time/img: 0.0873 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.4193 (epoch: 34, step: 0) // Avg time/img: 0.0255 s
# VAL loss: 0.6288 (epoch: 34, step: 50) // Avg time/img: 0.0260 s
# VAL loss: 0.6157 (epoch: 34, step: 100) // Avg time/img: 0.0268 s
# VAL loss: 0.5363 (epoch: 34, step: 150) // Avg time/img: 0.0267 s
# EPOCH IoU on VAL set:  42.15 %
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.3682 (epoch: 35, step: 0) // Avg time/img: 0.0945 s
# loss: 0.256 (epoch: 35, step: 50) // Avg time/img: 0.0874 s
# loss: 0.2621 (epoch: 35, step: 100) // Avg time/img: 0.0874 s
# loss: 0.2635 (epoch: 35, step: 150) // Avg time/img: 0.0871 s
# loss: 0.2599 (epoch: 35, step: 200) // Avg time/img: 0.0866 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.7299 (epoch: 35, step: 0) // Avg time/img: 0.0299 s
# VAL loss: 0.742 (epoch: 35, step: 50) // Avg time/img: 0.0273 s
# VAL loss: 0.7153 (epoch: 35, step: 100) // Avg time/img: 0.0297 s
# VAL loss: 0.6217 (epoch: 35, step: 150) // Avg time/img: 0.0293 s
# EPOCH IoU on VAL set:  39.46 %
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.00022739446367039517
# loss: 0.2435 (epoch: 36, step: 0) // Avg time/img: 0.0891 s
# loss: 0.2361 (epoch: 36, step: 50) // Avg time/img: 0.0882 s
# loss: 0.2355 (epoch: 36, step: 100) // Avg time/img: 0.0884 s
# loss: 0.2345 (epoch: 36, step: 150) // Avg time/img: 0.0877 s
# loss: 0.2361 (epoch: 36, step: 200) // Avg time/img: 0.0873 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.6945 (epoch: 36, step: 0) // Avg time/img: 0.0292 s
# VAL loss: 0.7407 (epoch: 36, step: 50) // Avg time/img: 0.0274 s
# VAL loss: 0.7813 (epoch: 36, step: 100) // Avg time/img: 0.0272 s
# VAL loss: 0.6928 (epoch: 36, step: 150) // Avg time/img: 0.0270 s
# EPOCH IoU on VAL set:  38.70 %
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.2065 (epoch: 37, step: 0) // Avg time/img: 0.1152 s
# loss: 0.2446 (epoch: 37, step: 50) // Avg time/img: 0.0882 s
# loss: 0.2321 (epoch: 37, step: 100) // Avg time/img: 0.0876 s
# loss: 0.2296 (epoch: 37, step: 150) // Avg time/img: 0.0872 s
# loss: 0.2323 (epoch: 37, step: 200) // Avg time/img: 0.0870 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 1.811 (epoch: 37, step: 0) // Avg time/img: 0.0332 s
# VAL loss: 1.211 (epoch: 37, step: 50) // Avg time/img: 0.0310 s
# VAL loss: 1.383 (epoch: 37, step: 100) // Avg time/img: 0.0294 s
# VAL loss: 1.182 (epoch: 37, step: 150) // Avg time/img: 0.0295 s
# EPOCH IoU on VAL set:  34.87 %
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.00021095456673472888
# loss: 0.1563 (epoch: 38, step: 0) // Avg time/img: 0.0941 s
# loss: 0.2454 (epoch: 38, step: 50) // Avg time/img: 0.0879 s
# loss: 0.2429 (epoch: 38, step: 100) // Avg time/img: 0.0878 s
# loss: 0.2373 (epoch: 38, step: 150) // Avg time/img: 0.0870 s
# loss: 0.2343 (epoch: 38, step: 200) // Avg time/img: 0.0867 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.4028 (epoch: 38, step: 0) // Avg time/img: 0.0365 s
# VAL loss: 0.6016 (epoch: 38, step: 50) // Avg time/img: 0.0269 s
# VAL loss: 0.5842 (epoch: 38, step: 100) // Avg time/img: 0.0266 s
# VAL loss: 0.5113 (epoch: 38, step: 150) // Avg time/img: 0.0267 s
# EPOCH IoU on VAL set:  43.94 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 38)
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.3503 (epoch: 39, step: 0) // Avg time/img: 0.1133 s
# loss: 0.2297 (epoch: 39, step: 50) // Avg time/img: 0.0878 s
# loss: 0.2259 (epoch: 39, step: 100) // Avg time/img: 0.0872 s
# loss: 0.2262 (epoch: 39, step: 150) // Avg time/img: 0.0868 s
# loss: 0.2233 (epoch: 39, step: 200) // Avg time/img: 0.0865 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.4391 (epoch: 39, step: 0) // Avg time/img: 0.0255 s
# VAL loss: 0.6303 (epoch: 39, step: 50) // Avg time/img: 0.0269 s
# VAL loss: 0.6332 (epoch: 39, step: 100) // Avg time/img: 0.0269 s
# VAL loss: 0.5532 (epoch: 39, step: 150) // Avg time/img: 0.0269 s
# EPOCH IoU on VAL set:  42.90 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.3252 (epoch: 40, step: 0) // Avg time/img: 0.1140 s
# loss: 0.2225 (epoch: 40, step: 50) // Avg time/img: 0.0871 s
# loss: 0.2194 (epoch: 40, step: 100) // Avg time/img: 0.0873 s
# loss: 0.2192 (epoch: 40, step: 150) // Avg time/img: 0.0870 s
# loss: 0.2237 (epoch: 40, step: 200) // Avg time/img: 0.0868 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.4171 (epoch: 40, step: 0) // Avg time/img: 0.0265 s
# VAL loss: 0.6534 (epoch: 40, step: 50) // Avg time/img: 0.0265 s
# VAL loss: 0.6296 (epoch: 40, step: 100) // Avg time/img: 0.0265 s
# VAL loss: 0.5548 (epoch: 40, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  43.57 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.2023 (epoch: 41, step: 0) // Avg time/img: 0.0926 s
# loss: 0.2062 (epoch: 41, step: 50) // Avg time/img: 0.0882 s
# loss: 0.2172 (epoch: 41, step: 100) // Avg time/img: 0.0877 s
# loss: 0.2206 (epoch: 41, step: 150) // Avg time/img: 0.0874 s
# loss: 0.2238 (epoch: 41, step: 200) // Avg time/img: 0.0879 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.6819 (epoch: 41, step: 0) // Avg time/img: 0.0268 s
# VAL loss: 0.6943 (epoch: 41, step: 50) // Avg time/img: 0.0267 s
# VAL loss: 0.6646 (epoch: 41, step: 100) // Avg time/img: 0.0271 s
# VAL loss: 0.575 (epoch: 41, step: 150) // Avg time/img: 0.0270 s
# EPOCH IoU on VAL set:  43.14 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.1569 (epoch: 42, step: 0) // Avg time/img: 0.1088 s
# loss: 0.2135 (epoch: 42, step: 50) // Avg time/img: 0.0880 s
# loss: 0.2171 (epoch: 42, step: 100) // Avg time/img: 0.0876 s
# loss: 0.2144 (epoch: 42, step: 150) // Avg time/img: 0.0873 s
# loss: 0.2154 (epoch: 42, step: 200) // Avg time/img: 0.0868 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.3747 (epoch: 42, step: 0) // Avg time/img: 0.0253 s
# VAL loss: 0.6144 (epoch: 42, step: 50) // Avg time/img: 0.0266 s
# VAL loss: 0.6183 (epoch: 42, step: 100) // Avg time/img: 0.0266 s
# VAL loss: 0.5477 (epoch: 42, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  43.34 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.2225 (epoch: 43, step: 0) // Avg time/img: 0.0835 s
# loss: 0.2101 (epoch: 43, step: 50) // Avg time/img: 0.0886 s
# loss: 0.209 (epoch: 43, step: 100) // Avg time/img: 0.0880 s
# loss: 0.2057 (epoch: 43, step: 150) // Avg time/img: 0.0894 s
# loss: 0.2106 (epoch: 43, step: 200) // Avg time/img: 0.0884 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.4711 (epoch: 43, step: 0) // Avg time/img: 0.0254 s
# VAL loss: 0.7134 (epoch: 43, step: 50) // Avg time/img: 0.0272 s
# VAL loss: 0.6921 (epoch: 43, step: 100) // Avg time/img: 0.0270 s
# VAL loss: 0.6164 (epoch: 43, step: 150) // Avg time/img: 0.0269 s
# EPOCH IoU on VAL set:  41.50 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.2516 (epoch: 44, step: 0) // Avg time/img: 0.0953 s
# loss: 0.208 (epoch: 44, step: 50) // Avg time/img: 0.0875 s
# loss: 0.2037 (epoch: 44, step: 100) // Avg time/img: 0.0873 s
# loss: 0.2012 (epoch: 44, step: 150) // Avg time/img: 0.0871 s
# loss: 0.202 (epoch: 44, step: 200) // Avg time/img: 0.0866 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.3724 (epoch: 44, step: 0) // Avg time/img: 0.0269 s
# VAL loss: 0.6301 (epoch: 44, step: 50) // Avg time/img: 0.0271 s
# VAL loss: 0.5878 (epoch: 44, step: 100) // Avg time/img: 0.0271 s
# VAL loss: 0.5204 (epoch: 44, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  44.24 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 44)
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.1679 (epoch: 45, step: 0) // Avg time/img: 0.1060 s
# loss: 0.2022 (epoch: 45, step: 50) // Avg time/img: 0.0888 s
# loss: 0.2048 (epoch: 45, step: 100) // Avg time/img: 0.0901 s
# loss: 0.2113 (epoch: 45, step: 150) // Avg time/img: 0.0890 s
# loss: 0.209 (epoch: 45, step: 200) // Avg time/img: 0.0883 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.3951 (epoch: 45, step: 0) // Avg time/img: 0.0298 s
# VAL loss: 0.619 (epoch: 45, step: 50) // Avg time/img: 0.0265 s
# VAL loss: 0.5864 (epoch: 45, step: 100) // Avg time/img: 0.0265 s
# VAL loss: 0.5171 (epoch: 45, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  44.87 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 45)
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.1714 (epoch: 46, step: 0) // Avg time/img: 0.0906 s
# loss: 0.194 (epoch: 46, step: 50) // Avg time/img: 0.0886 s
# loss: 0.1994 (epoch: 46, step: 100) // Avg time/img: 0.0878 s
# loss: 0.201 (epoch: 46, step: 150) // Avg time/img: 0.0871 s
# loss: 0.2003 (epoch: 46, step: 200) // Avg time/img: 0.0870 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.3205 (epoch: 46, step: 0) // Avg time/img: 0.0259 s
# VAL loss: 0.5915 (epoch: 46, step: 50) // Avg time/img: 0.0262 s
# VAL loss: 0.5776 (epoch: 46, step: 100) // Avg time/img: 0.0269 s
# VAL loss: 0.5117 (epoch: 46, step: 150) // Avg time/img: 0.0279 s
# EPOCH IoU on VAL set:  45.26 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 46)
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.172 (epoch: 47, step: 0) // Avg time/img: 0.1079 s
# loss: 0.1927 (epoch: 47, step: 50) // Avg time/img: 0.0872 s
# loss: 0.1966 (epoch: 47, step: 100) // Avg time/img: 0.0875 s
# loss: 0.1944 (epoch: 47, step: 150) // Avg time/img: 0.0871 s
# loss: 0.1947 (epoch: 47, step: 200) // Avg time/img: 0.0866 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.3725 (epoch: 47, step: 0) // Avg time/img: 0.0285 s
# VAL loss: 0.6456 (epoch: 47, step: 50) // Avg time/img: 0.0258 s
# VAL loss: 0.6446 (epoch: 47, step: 100) // Avg time/img: 0.0262 s
# VAL loss: 0.5652 (epoch: 47, step: 150) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  45.25 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.2297 (epoch: 48, step: 0) // Avg time/img: 0.0878 s
# loss: 0.1967 (epoch: 48, step: 50) // Avg time/img: 0.0867 s
# loss: 0.1966 (epoch: 48, step: 100) // Avg time/img: 0.0866 s
# loss: 0.1949 (epoch: 48, step: 150) // Avg time/img: 0.0865 s
# loss: 0.1949 (epoch: 48, step: 200) // Avg time/img: 0.0864 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.4086 (epoch: 48, step: 0) // Avg time/img: 0.0276 s
# VAL loss: 0.6539 (epoch: 48, step: 50) // Avg time/img: 0.0273 s
# VAL loss: 0.6511 (epoch: 48, step: 100) // Avg time/img: 0.0295 s
# VAL loss: 0.578 (epoch: 48, step: 150) // Avg time/img: 0.0288 s
# EPOCH IoU on VAL set:  43.86 %
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.1614 (epoch: 49, step: 0) // Avg time/img: 0.1018 s
# loss: 0.1886 (epoch: 49, step: 50) // Avg time/img: 0.0882 s
# loss: 0.1909 (epoch: 49, step: 100) // Avg time/img: 0.0882 s
# loss: 0.1925 (epoch: 49, step: 150) // Avg time/img: 0.0875 s
# loss: 0.1921 (epoch: 49, step: 200) // Avg time/img: 0.0872 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.3739 (epoch: 49, step: 0) // Avg time/img: 0.0281 s
# VAL loss: 0.6147 (epoch: 49, step: 50) // Avg time/img: 0.0267 s
# VAL loss: 0.5925 (epoch: 49, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.5268 (epoch: 49, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  45.41 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 49)
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.291 (epoch: 50, step: 0) // Avg time/img: 0.1126 s
# loss: 0.1897 (epoch: 50, step: 50) // Avg time/img: 0.0883 s
# loss: 0.1849 (epoch: 50, step: 100) // Avg time/img: 0.0879 s
# loss: 0.1873 (epoch: 50, step: 150) // Avg time/img: 0.0874 s
# loss: 0.1869 (epoch: 50, step: 200) // Avg time/img: 0.0872 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.3175 (epoch: 50, step: 0) // Avg time/img: 0.0266 s
# VAL loss: 0.6097 (epoch: 50, step: 50) // Avg time/img: 0.0300 s
# VAL loss: 0.6184 (epoch: 50, step: 100) // Avg time/img: 0.0281 s
# VAL loss: 0.5631 (epoch: 50, step: 150) // Avg time/img: 0.0276 s
# EPOCH IoU on VAL set:  44.96 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.1885 (epoch: 51, step: 0) // Avg time/img: 0.1048 s
# loss: 0.1905 (epoch: 51, step: 50) // Avg time/img: 0.0878 s
# loss: 0.1812 (epoch: 51, step: 100) // Avg time/img: 0.0872 s
# loss: 0.1805 (epoch: 51, step: 150) // Avg time/img: 0.0867 s
# loss: 0.1819 (epoch: 51, step: 200) // Avg time/img: 0.0865 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.4509 (epoch: 51, step: 0) // Avg time/img: 0.0290 s
# VAL loss: 0.6237 (epoch: 51, step: 50) // Avg time/img: 0.0270 s
# VAL loss: 0.631 (epoch: 51, step: 100) // Avg time/img: 0.0264 s
# VAL loss: 0.5676 (epoch: 51, step: 150) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  45.07 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.2297 (epoch: 52, step: 0) // Avg time/img: 0.0895 s
# loss: 0.1826 (epoch: 52, step: 50) // Avg time/img: 0.0871 s
# loss: 0.1836 (epoch: 52, step: 100) // Avg time/img: 0.0868 s
# loss: 0.1819 (epoch: 52, step: 150) // Avg time/img: 0.0863 s
# loss: 0.1833 (epoch: 52, step: 200) // Avg time/img: 0.0862 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.4759 (epoch: 52, step: 0) // Avg time/img: 0.0290 s
# VAL loss: 0.651 (epoch: 52, step: 50) // Avg time/img: 0.0269 s
# VAL loss: 0.6606 (epoch: 52, step: 100) // Avg time/img: 0.0268 s
# VAL loss: 0.5851 (epoch: 52, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  44.33 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.2786 (epoch: 53, step: 0) // Avg time/img: 0.0900 s
# loss: 0.177 (epoch: 53, step: 50) // Avg time/img: 0.0870 s
# loss: 0.1811 (epoch: 53, step: 100) // Avg time/img: 0.0868 s
# loss: 0.1792 (epoch: 53, step: 150) // Avg time/img: 0.0866 s
# loss: 0.1785 (epoch: 53, step: 200) // Avg time/img: 0.0863 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.3715 (epoch: 53, step: 0) // Avg time/img: 0.0267 s
# VAL loss: 0.5963 (epoch: 53, step: 50) // Avg time/img: 0.0261 s
# VAL loss: 0.6077 (epoch: 53, step: 100) // Avg time/img: 0.0266 s
# VAL loss: 0.5426 (epoch: 53, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  45.97 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.1588 (epoch: 54, step: 0) // Avg time/img: 0.1235 s
# loss: 0.1673 (epoch: 54, step: 50) // Avg time/img: 0.0887 s
# loss: 0.173 (epoch: 54, step: 100) // Avg time/img: 0.0880 s
# loss: 0.1734 (epoch: 54, step: 150) // Avg time/img: 0.0874 s
# loss: 0.1744 (epoch: 54, step: 200) // Avg time/img: 0.0880 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.358 (epoch: 54, step: 0) // Avg time/img: 0.0403 s
# VAL loss: 0.5854 (epoch: 54, step: 50) // Avg time/img: 0.0276 s
# VAL loss: 0.6002 (epoch: 54, step: 100) // Avg time/img: 0.0269 s
# VAL loss: 0.5362 (epoch: 54, step: 150) // Avg time/img: 0.0270 s
# EPOCH IoU on VAL set:  45.93 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.2515 (epoch: 55, step: 0) // Avg time/img: 0.0960 s
# loss: 0.171 (epoch: 55, step: 50) // Avg time/img: 0.0873 s
# loss: 0.1758 (epoch: 55, step: 100) // Avg time/img: 0.0871 s
# loss: 0.1744 (epoch: 55, step: 150) // Avg time/img: 0.0865 s
# loss: 0.1751 (epoch: 55, step: 200) // Avg time/img: 0.0863 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.3347 (epoch: 55, step: 0) // Avg time/img: 0.0318 s
# VAL loss: 0.5998 (epoch: 55, step: 50) // Avg time/img: 0.0269 s
# VAL loss: 0.6033 (epoch: 55, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.5375 (epoch: 55, step: 150) // Avg time/img: 0.0267 s
# EPOCH IoU on VAL set:  45.91 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.1745 (epoch: 56, step: 0) // Avg time/img: 0.0926 s
# loss: 0.1692 (epoch: 56, step: 50) // Avg time/img: 0.0883 s
# loss: 0.1684 (epoch: 56, step: 100) // Avg time/img: 0.0876 s
# loss: 0.1698 (epoch: 56, step: 150) // Avg time/img: 0.0887 s
# loss: 0.1706 (epoch: 56, step: 200) // Avg time/img: 0.0880 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.3294 (epoch: 56, step: 0) // Avg time/img: 0.0258 s
# VAL loss: 0.5838 (epoch: 56, step: 50) // Avg time/img: 0.0264 s
# VAL loss: 0.5864 (epoch: 56, step: 100) // Avg time/img: 0.0264 s
# VAL loss: 0.5235 (epoch: 56, step: 150) // Avg time/img: 0.0267 s
# EPOCH IoU on VAL set:  46.31 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 56)
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.1351 (epoch: 57, step: 0) // Avg time/img: 0.0944 s
# loss: 0.1726 (epoch: 57, step: 50) // Avg time/img: 0.0881 s
# loss: 0.1718 (epoch: 57, step: 100) // Avg time/img: 0.0878 s
# loss: 0.1673 (epoch: 57, step: 150) // Avg time/img: 0.0872 s
# loss: 0.1681 (epoch: 57, step: 200) // Avg time/img: 0.0868 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.3534 (epoch: 57, step: 0) // Avg time/img: 0.0285 s
# VAL loss: 0.6238 (epoch: 57, step: 50) // Avg time/img: 0.0268 s
# VAL loss: 0.6423 (epoch: 57, step: 100) // Avg time/img: 0.0269 s
# VAL loss: 0.5722 (epoch: 57, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  45.56 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.1812 (epoch: 58, step: 0) // Avg time/img: 0.1102 s
# loss: 0.1666 (epoch: 58, step: 50) // Avg time/img: 0.0907 s
# loss: 0.1646 (epoch: 58, step: 100) // Avg time/img: 0.0898 s
# loss: 0.1664 (epoch: 58, step: 150) // Avg time/img: 0.0884 s
# loss: 0.1666 (epoch: 58, step: 200) // Avg time/img: 0.0879 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.3321 (epoch: 58, step: 0) // Avg time/img: 0.0266 s
# VAL loss: 0.6039 (epoch: 58, step: 50) // Avg time/img: 0.0263 s
# VAL loss: 0.622 (epoch: 58, step: 100) // Avg time/img: 0.0265 s
# VAL loss: 0.5586 (epoch: 58, step: 150) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  46.53 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 58)
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.1529 (epoch: 59, step: 0) // Avg time/img: 0.1092 s
# loss: 0.1593 (epoch: 59, step: 50) // Avg time/img: 0.0888 s
# loss: 0.1647 (epoch: 59, step: 100) // Avg time/img: 0.0881 s
# loss: 0.163 (epoch: 59, step: 150) // Avg time/img: 0.0876 s
# loss: 0.1631 (epoch: 59, step: 200) // Avg time/img: 0.0872 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.3539 (epoch: 59, step: 0) // Avg time/img: 0.0308 s
# VAL loss: 0.5978 (epoch: 59, step: 50) // Avg time/img: 0.0267 s
# VAL loss: 0.6152 (epoch: 59, step: 100) // Avg time/img: 0.0266 s
# VAL loss: 0.5519 (epoch: 59, step: 150) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  46.00 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.1472 (epoch: 60, step: 0) // Avg time/img: 0.0964 s
# loss: 0.1612 (epoch: 60, step: 50) // Avg time/img: 0.0921 s
# loss: 0.1644 (epoch: 60, step: 100) // Avg time/img: 0.0892 s
# loss: 0.1642 (epoch: 60, step: 150) // Avg time/img: 0.0883 s
# loss: 0.1647 (epoch: 60, step: 200) // Avg time/img: 0.0877 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.3444 (epoch: 60, step: 0) // Avg time/img: 0.0346 s
# VAL loss: 0.5766 (epoch: 60, step: 50) // Avg time/img: 0.0275 s
# VAL loss: 0.5911 (epoch: 60, step: 100) // Avg time/img: 0.0279 s
# VAL loss: 0.5317 (epoch: 60, step: 150) // Avg time/img: 0.0276 s
# EPOCH IoU on VAL set:  46.81 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_encoder_best.pth (epoch: 60)
# ========== DECODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.033 (epoch: 1, step: 0) // Avg time/img: 0.1822 s
# loss: 2.592 (epoch: 1, step: 50) // Avg time/img: 0.1253 s
# loss: 2.243 (epoch: 1, step: 100) // Avg time/img: 0.1231 s
# loss: 1.987 (epoch: 1, step: 150) // Avg time/img: 0.1217 s
# loss: 1.788 (epoch: 1, step: 200) // Avg time/img: 0.1212 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 2.085 (epoch: 1, step: 0) // Avg time/img: 0.0441 s
# VAL loss: 1.622 (epoch: 1, step: 50) // Avg time/img: 0.0380 s
# VAL loss: 1.499 (epoch: 1, step: 100) // Avg time/img: 0.0395 s
# VAL loss: 1.349 (epoch: 1, step: 150) // Avg time/img: 0.0388 s
# EPOCH IoU on VAL set:  19.53 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 1.093 (epoch: 2, step: 0) // Avg time/img: 0.1481 s
# loss: 1.019 (epoch: 2, step: 50) // Avg time/img: 0.1258 s
# loss: 0.9514 (epoch: 2, step: 100) // Avg time/img: 0.1229 s
# loss: 0.8749 (epoch: 2, step: 150) // Avg time/img: 0.1217 s
# loss: 0.8573 (epoch: 2, step: 200) // Avg time/img: 0.1212 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 0.8026 (epoch: 2, step: 0) // Avg time/img: 0.0518 s
# VAL loss: 1.169 (epoch: 2, step: 50) // Avg time/img: 0.0385 s
# VAL loss: 1.082 (epoch: 2, step: 100) // Avg time/img: 0.0381 s
# VAL loss: 0.9515 (epoch: 2, step: 150) // Avg time/img: 0.0378 s
# EPOCH IoU on VAL set:  24.55 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.7371 (epoch: 3, step: 0) // Avg time/img: 0.1521 s
# loss: 0.7215 (epoch: 3, step: 50) // Avg time/img: 0.1239 s
# loss: 0.7201 (epoch: 3, step: 100) // Avg time/img: 0.1219 s
# loss: 0.71 (epoch: 3, step: 150) // Avg time/img: 0.1247 s
# loss: 0.6986 (epoch: 3, step: 200) // Avg time/img: 0.1234 s
# ----- VALIDATING - EPOCH 3 -----
# ...
# VAL loss: 0.4708 (epoch: 39, step: 0) // Avg time/img: 0.0447 s
# VAL loss: 0.7383 (epoch: 39, step: 50) // Avg time/img: 0.0378 s
# VAL loss: 0.7322 (epoch: 39, step: 100) // Avg time/img: 0.0373 s
# VAL loss: 0.6333 (epoch: 39, step: 150) // Avg time/img: 0.0373 s
# EPOCH IoU on VAL set:  45.81 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.1666 (epoch: 40, step: 0) // Avg time/img: 0.1408 s
# loss: 0.2072 (epoch: 40, step: 50) // Avg time/img: 0.1225 s
# loss: 0.2156 (epoch: 40, step: 100) // Avg time/img: 0.1210 s
# loss: 0.2197 (epoch: 40, step: 150) // Avg time/img: 0.1203 s
# loss: 0.2169 (epoch: 40, step: 200) // Avg time/img: 0.1222 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.4546 (epoch: 40, step: 0) // Avg time/img: 0.0404 s
# VAL loss: 0.6581 (epoch: 40, step: 50) // Avg time/img: 0.0380 s
# VAL loss: 0.6614 (epoch: 40, step: 100) // Avg time/img: 0.0377 s
# VAL loss: 0.5809 (epoch: 40, step: 150) // Avg time/img: 0.0374 s
# EPOCH IoU on VAL set:  47.03 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 40)
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.1647 (epoch: 41, step: 0) // Avg time/img: 0.1408 s
# loss: 0.2088 (epoch: 41, step: 50) // Avg time/img: 0.1238 s
# loss: 0.2133 (epoch: 41, step: 100) // Avg time/img: 0.1219 s
# loss: 0.2135 (epoch: 41, step: 150) // Avg time/img: 0.1209 s
# loss: 0.2129 (epoch: 41, step: 200) // Avg time/img: 0.1205 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.4476 (epoch: 41, step: 0) // Avg time/img: 0.0333 s
# VAL loss: 0.6544 (epoch: 41, step: 50) // Avg time/img: 0.0372 s
# VAL loss: 0.6795 (epoch: 41, step: 100) // Avg time/img: 0.0375 s
# VAL loss: 0.607 (epoch: 41, step: 150) // Avg time/img: 0.0376 s
# EPOCH IoU on VAL set:  45.98 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.1815 (epoch: 42, step: 0) // Avg time/img: 0.1556 s
# loss: 0.2004 (epoch: 42, step: 50) // Avg time/img: 0.1316 s
# loss: 0.202 (epoch: 42, step: 100) // Avg time/img: 0.1262 s
# loss: 0.2047 (epoch: 42, step: 150) // Avg time/img: 0.1238 s
# loss: 0.2079 (epoch: 42, step: 200) // Avg time/img: 0.1228 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.3996 (epoch: 42, step: 0) // Avg time/img: 0.0422 s
# VAL loss: 0.6498 (epoch: 42, step: 50) // Avg time/img: 0.0383 s
# VAL loss: 0.6556 (epoch: 42, step: 100) // Avg time/img: 0.0376 s
# VAL loss: 0.5827 (epoch: 42, step: 150) // Avg time/img: 0.0375 s
# EPOCH IoU on VAL set:  46.88 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.1485 (epoch: 43, step: 0) // Avg time/img: 0.1496 s
# loss: 0.1935 (epoch: 43, step: 50) // Avg time/img: 0.1244 s
# loss: 0.199 (epoch: 43, step: 100) // Avg time/img: 0.1220 s
# loss: 0.2039 (epoch: 43, step: 150) // Avg time/img: 0.1209 s
# loss: 0.204 (epoch: 43, step: 200) // Avg time/img: 0.1207 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.3989 (epoch: 43, step: 0) // Avg time/img: 0.0424 s
# VAL loss: 0.6704 (epoch: 43, step: 50) // Avg time/img: 0.0406 s
# VAL loss: 0.6856 (epoch: 43, step: 100) // Avg time/img: 0.0389 s
# VAL loss: 0.6079 (epoch: 43, step: 150) // Avg time/img: 0.0382 s
# EPOCH IoU on VAL set:  46.67 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.2177 (epoch: 44, step: 0) // Avg time/img: 0.1503 s
# loss: 0.1954 (epoch: 44, step: 50) // Avg time/img: 0.1239 s
# loss: 0.1942 (epoch: 44, step: 100) // Avg time/img: 0.1218 s
# loss: 0.1928 (epoch: 44, step: 150) // Avg time/img: 0.1208 s
# loss: 0.1939 (epoch: 44, step: 200) // Avg time/img: 0.1206 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.3636 (epoch: 44, step: 0) // Avg time/img: 0.0430 s
# VAL loss: 0.6318 (epoch: 44, step: 50) // Avg time/img: 0.0380 s
# VAL loss: 0.638 (epoch: 44, step: 100) // Avg time/img: 0.0378 s
# VAL loss: 0.5572 (epoch: 44, step: 150) // Avg time/img: 0.0374 s
# EPOCH IoU on VAL set:  48.17 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 44)
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.1597 (epoch: 45, step: 0) // Avg time/img: 0.1525 s
# loss: 0.1988 (epoch: 45, step: 50) // Avg time/img: 0.1235 s
# loss: 0.1907 (epoch: 45, step: 100) // Avg time/img: 0.1218 s
# loss: 0.1891 (epoch: 45, step: 150) // Avg time/img: 0.1213 s
# loss: 0.1919 (epoch: 45, step: 200) // Avg time/img: 0.1233 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.41 (epoch: 45, step: 0) // Avg time/img: 0.0443 s
# VAL loss: 0.6918 (epoch: 45, step: 50) // Avg time/img: 0.0374 s
# VAL loss: 0.7597 (epoch: 45, step: 100) // Avg time/img: 0.0372 s
# VAL loss: 0.6681 (epoch: 45, step: 150) // Avg time/img: 0.0372 s
# EPOCH IoU on VAL set:  45.45 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.2289 (epoch: 46, step: 0) // Avg time/img: 0.1469 s
# loss: 0.1958 (epoch: 46, step: 50) // Avg time/img: 0.1234 s
# loss: 0.1937 (epoch: 46, step: 100) // Avg time/img: 0.1216 s
# loss: 0.1949 (epoch: 46, step: 150) // Avg time/img: 0.1209 s
# loss: 0.1936 (epoch: 46, step: 200) // Avg time/img: 0.1205 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.333 (epoch: 46, step: 0) // Avg time/img: 0.0425 s
# VAL loss: 0.6731 (epoch: 46, step: 50) // Avg time/img: 0.0378 s
# VAL loss: 0.6498 (epoch: 46, step: 100) // Avg time/img: 0.0378 s
# VAL loss: 0.5701 (epoch: 46, step: 150) // Avg time/img: 0.0378 s
# EPOCH IoU on VAL set:  48.22 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 46)
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.158 (epoch: 47, step: 0) // Avg time/img: 0.1561 s
# loss: 0.1916 (epoch: 47, step: 50) // Avg time/img: 0.1332 s
# loss: 0.1888 (epoch: 47, step: 100) // Avg time/img: 0.1265 s
# loss: 0.1871 (epoch: 47, step: 150) // Avg time/img: 0.1243 s
# loss: 0.1892 (epoch: 47, step: 200) // Avg time/img: 0.1232 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.4104 (epoch: 47, step: 0) // Avg time/img: 0.0510 s
# VAL loss: 0.6823 (epoch: 47, step: 50) // Avg time/img: 0.0375 s
# VAL loss: 0.7005 (epoch: 47, step: 100) // Avg time/img: 0.0374 s
# VAL loss: 0.6101 (epoch: 47, step: 150) // Avg time/img: 0.0373 s
# EPOCH IoU on VAL set:  47.09 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.2021 (epoch: 48, step: 0) // Avg time/img: 0.1414 s
# loss: 0.1729 (epoch: 48, step: 50) // Avg time/img: 0.1233 s
# loss: 0.1776 (epoch: 48, step: 100) // Avg time/img: 0.1220 s
# loss: 0.1811 (epoch: 48, step: 150) // Avg time/img: 0.1210 s
# loss: 0.1817 (epoch: 48, step: 200) // Avg time/img: 0.1206 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.3708 (epoch: 48, step: 0) // Avg time/img: 0.0392 s
# VAL loss: 0.6345 (epoch: 48, step: 50) // Avg time/img: 0.0413 s
# VAL loss: 0.644 (epoch: 48, step: 100) // Avg time/img: 0.0395 s
# VAL loss: 0.5665 (epoch: 48, step: 150) // Avg time/img: 0.0388 s
# EPOCH IoU on VAL set:  49.32 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 48)
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.1677 (epoch: 49, step: 0) // Avg time/img: 0.1460 s
# loss: 0.17 (epoch: 49, step: 50) // Avg time/img: 0.1244 s
# loss: 0.1784 (epoch: 49, step: 100) // Avg time/img: 0.1221 s
# loss: 0.1765 (epoch: 49, step: 150) // Avg time/img: 0.1212 s
# loss: 0.1781 (epoch: 49, step: 200) // Avg time/img: 0.1208 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.4113 (epoch: 49, step: 0) // Avg time/img: 0.0388 s
# VAL loss: 0.6392 (epoch: 49, step: 50) // Avg time/img: 0.0384 s
# VAL loss: 0.6466 (epoch: 49, step: 100) // Avg time/img: 0.0381 s
# VAL loss: 0.5634 (epoch: 49, step: 150) // Avg time/img: 0.0379 s
# EPOCH IoU on VAL set:  48.58 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.1717 (epoch: 50, step: 0) // Avg time/img: 0.1472 s
# loss: 0.1758 (epoch: 50, step: 50) // Avg time/img: 0.1233 s
# loss: 0.1745 (epoch: 50, step: 100) // Avg time/img: 0.1217 s
# loss: 0.1769 (epoch: 50, step: 150) // Avg time/img: 0.1237 s
# loss: 0.1775 (epoch: 50, step: 200) // Avg time/img: 0.1231 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.37 (epoch: 50, step: 0) // Avg time/img: 0.0442 s
# VAL loss: 0.6657 (epoch: 50, step: 50) // Avg time/img: 0.0380 s
# VAL loss: 0.6523 (epoch: 50, step: 100) // Avg time/img: 0.0375 s
# VAL loss: 0.5664 (epoch: 50, step: 150) // Avg time/img: 0.0376 s
# EPOCH IoU on VAL set:  49.36 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 50)
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.2094 (epoch: 51, step: 0) // Avg time/img: 0.1534 s
# loss: 0.1713 (epoch: 51, step: 50) // Avg time/img: 0.1235 s
# loss: 0.1768 (epoch: 51, step: 100) // Avg time/img: 0.1217 s
# loss: 0.1775 (epoch: 51, step: 150) // Avg time/img: 0.1209 s
# loss: 0.1763 (epoch: 51, step: 200) // Avg time/img: 0.1206 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.4142 (epoch: 51, step: 0) // Avg time/img: 0.0512 s
# VAL loss: 0.6803 (epoch: 51, step: 50) // Avg time/img: 0.0382 s
# VAL loss: 0.6788 (epoch: 51, step: 100) // Avg time/img: 0.0378 s
# VAL loss: 0.5902 (epoch: 51, step: 150) // Avg time/img: 0.0378 s
# EPOCH IoU on VAL set:  48.77 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.2066 (epoch: 52, step: 0) // Avg time/img: 0.1321 s
# loss: 0.1727 (epoch: 52, step: 50) // Avg time/img: 0.1343 s
# loss: 0.1701 (epoch: 52, step: 100) // Avg time/img: 0.1272 s
# loss: 0.1711 (epoch: 52, step: 150) // Avg time/img: 0.1248 s
# loss: 0.173 (epoch: 52, step: 200) // Avg time/img: 0.1236 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.4395 (epoch: 52, step: 0) // Avg time/img: 0.0405 s
# VAL loss: 0.6756 (epoch: 52, step: 50) // Avg time/img: 0.0383 s
# VAL loss: 0.6836 (epoch: 52, step: 100) // Avg time/img: 0.0377 s
# VAL loss: 0.5935 (epoch: 52, step: 150) // Avg time/img: 0.0375 s
# EPOCH IoU on VAL set:  48.76 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.1651 (epoch: 53, step: 0) // Avg time/img: 0.1496 s
# loss: 0.1581 (epoch: 53, step: 50) // Avg time/img: 0.1228 s
# loss: 0.1674 (epoch: 53, step: 100) // Avg time/img: 0.1215 s
# loss: 0.1694 (epoch: 53, step: 150) // Avg time/img: 0.1206 s
# loss: 0.1694 (epoch: 53, step: 200) // Avg time/img: 0.1203 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.4363 (epoch: 53, step: 0) // Avg time/img: 0.0421 s
# VAL loss: 0.66 (epoch: 53, step: 50) // Avg time/img: 0.0382 s
# VAL loss: 0.6743 (epoch: 53, step: 100) // Avg time/img: 0.0391 s
# VAL loss: 0.5911 (epoch: 53, step: 150) // Avg time/img: 0.0384 s
# EPOCH IoU on VAL set:  49.27 %
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.1423 (epoch: 54, step: 0) // Avg time/img: 0.1448 s
# loss: 0.1695 (epoch: 54, step: 50) // Avg time/img: 0.1238 s
# loss: 0.1706 (epoch: 54, step: 100) // Avg time/img: 0.1221 s
# loss: 0.171 (epoch: 54, step: 150) // Avg time/img: 0.1211 s
# loss: 0.1683 (epoch: 54, step: 200) // Avg time/img: 0.1206 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.4395 (epoch: 54, step: 0) // Avg time/img: 0.0421 s
# VAL loss: 0.6742 (epoch: 54, step: 50) // Avg time/img: 0.0379 s
# VAL loss: 0.6935 (epoch: 54, step: 100) // Avg time/img: 0.0376 s
# VAL loss: 0.6009 (epoch: 54, step: 150) // Avg time/img: 0.0377 s
# EPOCH IoU on VAL set:  49.03 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.2544 (epoch: 55, step: 0) // Avg time/img: 0.1564 s
# loss: 0.1664 (epoch: 55, step: 50) // Avg time/img: 0.1236 s
# loss: 0.165 (epoch: 55, step: 100) // Avg time/img: 0.1216 s
# loss: 0.164 (epoch: 55, step: 150) // Avg time/img: 0.1211 s
# loss: 0.1618 (epoch: 55, step: 200) // Avg time/img: 0.1233 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.4045 (epoch: 55, step: 0) // Avg time/img: 0.0446 s
# VAL loss: 0.6397 (epoch: 55, step: 50) // Avg time/img: 0.0381 s
# VAL loss: 0.6317 (epoch: 55, step: 100) // Avg time/img: 0.0373 s
# VAL loss: 0.552 (epoch: 55, step: 150) // Avg time/img: 0.0372 s
# EPOCH IoU on VAL set:  50.13 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 55)
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.2217 (epoch: 56, step: 0) // Avg time/img: 0.1613 s
# loss: 0.1605 (epoch: 56, step: 50) // Avg time/img: 0.1238 s
# loss: 0.1603 (epoch: 56, step: 100) // Avg time/img: 0.1219 s
# loss: 0.1615 (epoch: 56, step: 150) // Avg time/img: 0.1213 s
# loss: 0.1629 (epoch: 56, step: 200) // Avg time/img: 0.1208 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.4096 (epoch: 56, step: 0) // Avg time/img: 0.0402 s
# VAL loss: 0.6597 (epoch: 56, step: 50) // Avg time/img: 0.0375 s
# VAL loss: 0.6695 (epoch: 56, step: 100) // Avg time/img: 0.0375 s
# VAL loss: 0.5815 (epoch: 56, step: 150) // Avg time/img: 0.0372 s
# EPOCH IoU on VAL set:  49.89 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.155 (epoch: 57, step: 0) // Avg time/img: 0.1315 s
# loss: 0.1613 (epoch: 57, step: 50) // Avg time/img: 0.1323 s
# loss: 0.1618 (epoch: 57, step: 100) // Avg time/img: 0.1267 s
# loss: 0.1619 (epoch: 57, step: 150) // Avg time/img: 0.1244 s
# loss: 0.1621 (epoch: 57, step: 200) // Avg time/img: 0.1231 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.4317 (epoch: 57, step: 0) // Avg time/img: 0.0386 s
# VAL loss: 0.692 (epoch: 57, step: 50) // Avg time/img: 0.0383 s
# VAL loss: 0.694 (epoch: 57, step: 100) // Avg time/img: 0.0381 s
# VAL loss: 0.595 (epoch: 57, step: 150) // Avg time/img: 0.0377 s
# EPOCH IoU on VAL set:  49.93 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.1562 (epoch: 58, step: 0) // Avg time/img: 0.1319 s
# loss: 0.1589 (epoch: 58, step: 50) // Avg time/img: 0.1240 s
# loss: 0.158 (epoch: 58, step: 100) // Avg time/img: 0.1220 s
# loss: 0.1594 (epoch: 58, step: 150) // Avg time/img: 0.1211 s
# loss: 0.1575 (epoch: 58, step: 200) // Avg time/img: 0.1209 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.4062 (epoch: 58, step: 0) // Avg time/img: 0.0428 s
# VAL loss: 0.6737 (epoch: 58, step: 50) // Avg time/img: 0.0377 s
# VAL loss: 0.6714 (epoch: 58, step: 100) // Avg time/img: 0.0390 s
# VAL loss: 0.5806 (epoch: 58, step: 150) // Avg time/img: 0.0385 s
# EPOCH IoU on VAL set:  50.28 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 58)
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.1186 (epoch: 59, step: 0) // Avg time/img: 0.1492 s
# loss: 0.1587 (epoch: 59, step: 50) // Avg time/img: 0.1252 s
# loss: 0.1593 (epoch: 59, step: 100) // Avg time/img: 0.1227 s
# loss: 0.1595 (epoch: 59, step: 150) // Avg time/img: 0.1213 s
# loss: 0.1593 (epoch: 59, step: 200) // Avg time/img: 0.1209 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.4064 (epoch: 59, step: 0) // Avg time/img: 0.0431 s
# VAL loss: 0.6574 (epoch: 59, step: 50) // Avg time/img: 0.0378 s
# VAL loss: 0.6665 (epoch: 59, step: 100) // Avg time/img: 0.0381 s
# VAL loss: 0.5771 (epoch: 59, step: 150) // Avg time/img: 0.0379 s
# EPOCH IoU on VAL set:  50.41 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default/model_best.pth (epoch: 59)
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.1574 (epoch: 60, step: 0) // Avg time/img: 0.1546 s
# loss: 0.1528 (epoch: 60, step: 50) // Avg time/img: 0.1241 s
# loss: 0.1548 (epoch: 60, step: 100) // Avg time/img: 0.1222 s
# loss: 0.1564 (epoch: 60, step: 150) // Avg time/img: 0.1213 s
# loss: 0.157 (epoch: 60, step: 200) // Avg time/img: 0.1209 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.4096 (epoch: 60, step: 0) // Avg time/img: 0.0470 s
# VAL loss: 0.6628 (epoch: 60, step: 50) // Avg time/img: 0.0378 s
# VAL loss: 0.681 (epoch: 60, step: 100) // Avg time/img: 0.0377 s
# VAL loss: 0.5908 (epoch: 60, step: 150) // Avg time/img: 0.0378 s
# EPOCH IoU on VAL set:  49.90 %
# ========== TRAINING FINISHED ===========

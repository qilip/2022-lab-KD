# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet model definition

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)
    

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3x1_1 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1,0), bias=True)

        self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3x1_2 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1*dilated,0), bias=True, dilation = (dilated,1))

        self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3x1_1(input)
        output = F.relu(output)
        output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3x1_2(output)
        output = F.relu(output)
        output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output


class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target


class CrossEntropyLoss2d(torch.nn.Module):

    def __init__(self, weight=None):
        super().__init__()

        self.loss = torch.nn.NLLLoss2d(weight)

    def forward(self, outputs, targets):
        return self.loss(torch.nn.functional.log_softmax(outputs, dim=1), targets)


def train(args, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = CrossEntropyLoss2d(weight)
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train()
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0])
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 

            loss = criterion(outputs, targets[:, 0])
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Model
    # assert os.path.exists(args.model + ".py"), "Error: model definition not found"
    # model_file = importlib.import_module(args.model)
    model = Net(NUM_CLASSES)
    # copyfile(args.model + ".py", savedir + '/' + args.model + ".py")
    
    if args.cuda:
        model = torch.nn.DataParallel(model).cuda()
    
    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        """
        try:
            model.load_state_dict(torch.load(args.state))
        except AssertionError:
            model.load_state_dict(torch.load(args.state,
                map_location=lambda storage, loc: storage))
        #When model is saved as DataParallel it adds a model. to each key. To remove:
        #state_dict = {k.partition('model.')[2]: v for k,v in state_dict}
        #https://discuss.pytorch.org/t/prefix-parameter-names-in-saved-model-if-trained-by-multi-gpu/494
        """
        def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict keys are there
            own_state = model.state_dict()
            for name, param in state_dict.items():
                if name not in own_state:
                     continue
                own_state[name].copy_(param)
            return model

        #print(torch.load(args.state))
        model = load_my_state_dict(model, torch.load(args.state))

    """
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            #m.weight.data.normal_(0.0, 0.02)
            n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
            m.weight.data.normal_(0, math.sqrt(2. / n))
        elif classname.find('BatchNorm') != -1:
            #m.weight.data.normal_(1.0, 0.02)
            m.weight.data.fill_(1)
            m.bias.data.fill_(0)
    #TO ACCESS MODEL IN DataParallel: next(model.children())
    #next(model.children()).decoder.apply(weights_init)
    #Reinitialize weights for decoder
    
    next(model.children()).decoder.layers.apply(weights_init)
    next(model.children()).decoder.output_conv.apply(weights_init)
    #print(model.state_dict())
    f = open('weights5.txt', 'w')
    f.write(str(model.state_dict()))
    f.close()
    """

    # train(args, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=150)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=6)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 4.067 (epoch: 1, step: 0) // Avg time/img: 1.7316 s
# loss: 1.388 (epoch: 1, step: 50) // Avg time/img: 0.1127 s
# loss: 1.187 (epoch: 1, step: 100) // Avg time/img: 0.0971 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.512 (epoch: 1, step: 0) // Avg time/img: 0.0311 s
# VAL loss: 1.308 (epoch: 1, step: 50) // Avg time/img: 0.0246 s
# EPOCH IoU on VAL set:  18.92 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.0004969989975469645
# loss: 0.716 (epoch: 2, step: 0) // Avg time/img: 0.0983 s
# loss: 0.8202 (epoch: 2, step: 50) // Avg time/img: 0.0851 s
# loss: 0.8115 (epoch: 2, step: 100) // Avg time/img: 0.0842 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.099 (epoch: 2, step: 0) // Avg time/img: 0.0348 s
# VAL loss: 1.145 (epoch: 2, step: 50) // Avg time/img: 0.0271 s
# EPOCH IoU on VAL set:  21.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004939959803064135
# loss: 1.154 (epoch: 3, step: 0) // Avg time/img: 0.0946 s
# loss: 0.7334 (epoch: 3, step: 50) // Avg time/img: 0.0831 s
# loss: 0.7164 (epoch: 3, step: 100) // Avg time/img: 0.0829 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 0.8609 (epoch: 3, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.9732 (epoch: 3, step: 50) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  24.26 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.0004909909332982877
# loss: 0.6246 (epoch: 4, step: 0) // Avg time/img: 0.0904 s
# loss: 0.6614 (epoch: 4, step: 50) // Avg time/img: 0.0832 s
# loss: 0.6712 (epoch: 4, step: 100) // Avg time/img: 0.0828 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 0.7038 (epoch: 4, step: 0) // Avg time/img: 0.0351 s
# VAL loss: 0.9586 (epoch: 4, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  25.21 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00048798384132844874
# loss: 0.5657 (epoch: 5, step: 0) // Avg time/img: 0.0924 s
# loss: 0.6063 (epoch: 5, step: 50) // Avg time/img: 0.0833 s
# loss: 0.6138 (epoch: 5, step: 100) // Avg time/img: 0.0829 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 1.375 (epoch: 5, step: 0) // Avg time/img: 0.0335 s
# VAL loss: 1.078 (epoch: 5, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  25.98 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 5)
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.555 (epoch: 6, step: 0) // Avg time/img: 0.0888 s
# loss: 0.5797 (epoch: 6, step: 50) // Avg time/img: 0.0827 s
# loss: 0.5689 (epoch: 6, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 0.9396 (epoch: 6, step: 0) // Avg time/img: 0.0326 s
# VAL loss: 1.036 (epoch: 6, step: 50) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  26.58 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00048196346062927547
# loss: 0.4099 (epoch: 7, step: 0) // Avg time/img: 0.0940 s
# loss: 0.5371 (epoch: 7, step: 50) // Avg time/img: 0.0837 s
# loss: 0.5386 (epoch: 7, step: 100) // Avg time/img: 0.0828 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 1.371 (epoch: 7, step: 0) // Avg time/img: 0.0317 s
# VAL loss: 1.026 (epoch: 7, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  27.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 7)
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.0004789501403997001
# loss: 0.5047 (epoch: 8, step: 0) // Avg time/img: 0.0879 s
# loss: 0.5362 (epoch: 8, step: 50) // Avg time/img: 0.0829 s
# loss: 0.5168 (epoch: 8, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 0.9338 (epoch: 8, step: 0) // Avg time/img: 0.0341 s
# VAL loss: 0.9911 (epoch: 8, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  28.19 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 8)
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.0004759347121981738
# loss: 0.4738 (epoch: 9, step: 0) // Avg time/img: 0.0879 s
# loss: 0.4885 (epoch: 9, step: 50) // Avg time/img: 0.0831 s
# loss: 0.5016 (epoch: 9, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 0.6585 (epoch: 9, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.8578 (epoch: 9, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  30.00 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 9)
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.000472917159689316
# loss: 0.4243 (epoch: 10, step: 0) // Avg time/img: 0.0975 s
# loss: 0.4901 (epoch: 10, step: 50) // Avg time/img: 0.0834 s
# loss: 0.4736 (epoch: 10, step: 100) // Avg time/img: 0.0827 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 1.078 (epoch: 10, step: 0) // Avg time/img: 0.0343 s
# VAL loss: 0.915 (epoch: 10, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  28.90 %
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.4162 (epoch: 11, step: 0) // Avg time/img: 0.0911 s
# loss: 0.4794 (epoch: 11, step: 50) // Avg time/img: 0.0832 s
# loss: 0.4867 (epoch: 11, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.5455 (epoch: 11, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.7823 (epoch: 11, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  31.59 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 11)
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.00046687561518576686
# loss: 0.5638 (epoch: 12, step: 0) // Avg time/img: 0.0932 s
# loss: 0.4299 (epoch: 12, step: 50) // Avg time/img: 0.0829 s
# loss: 0.4378 (epoch: 12, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.4988 (epoch: 12, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.7413 (epoch: 12, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  33.50 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 12)
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.0004638515892816641
# loss: 0.6411 (epoch: 13, step: 0) // Avg time/img: 0.0886 s
# loss: 0.4191 (epoch: 13, step: 50) // Avg time/img: 0.0830 s
# loss: 0.4284 (epoch: 13, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 0.5432 (epoch: 13, step: 0) // Avg time/img: 0.0338 s
# VAL loss: 0.708 (epoch: 13, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  33.81 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 13)
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.00046082537124014127
# loss: 0.4697 (epoch: 14, step: 0) // Avg time/img: 0.0913 s
# loss: 0.4198 (epoch: 14, step: 50) // Avg time/img: 0.0833 s
# loss: 0.4104 (epoch: 14, step: 100) // Avg time/img: 0.0828 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 1.372 (epoch: 14, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.9699 (epoch: 14, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  31.59 %
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.00045779694345335803
# loss: 0.4583 (epoch: 15, step: 0) // Avg time/img: 0.0931 s
# loss: 0.4103 (epoch: 15, step: 50) // Avg time/img: 0.0833 s
# loss: 0.4251 (epoch: 15, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 0.608 (epoch: 15, step: 0) // Avg time/img: 0.0340 s
# VAL loss: 0.7284 (epoch: 15, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  33.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 15)
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.3155 (epoch: 16, step: 0) // Avg time/img: 0.0954 s
# loss: 0.4133 (epoch: 16, step: 50) // Avg time/img: 0.0830 s
# loss: 0.4034 (epoch: 16, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.7647 (epoch: 16, step: 0) // Avg time/img: 0.0347 s
# VAL loss: 0.8661 (epoch: 16, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  32.60 %
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00045173338684643586
# loss: 0.2745 (epoch: 17, step: 0) // Avg time/img: 0.0922 s
# loss: 0.3993 (epoch: 17, step: 50) // Avg time/img: 0.0832 s
# loss: 0.3813 (epoch: 17, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.8033 (epoch: 17, step: 0) // Avg time/img: 0.0321 s
# VAL loss: 0.8559 (epoch: 17, step: 50) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  32.61 %
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.0004486982214254669
# loss: 0.6592 (epoch: 18, step: 0) // Avg time/img: 0.0957 s
# loss: 0.3958 (epoch: 18, step: 50) // Avg time/img: 0.0832 s
# loss: 0.378 (epoch: 18, step: 100) // Avg time/img: 0.0827 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.557 (epoch: 18, step: 0) // Avg time/img: 0.0323 s
# VAL loss: 0.7249 (epoch: 18, step: 50) // Avg time/img: 0.0258 s
# EPOCH IoU on VAL set:  36.08 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 18)
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00044566077304449995
# loss: 0.3048 (epoch: 19, step: 0) // Avg time/img: 0.0934 s
# loss: 0.3464 (epoch: 19, step: 50) // Avg time/img: 0.0830 s
# loss: 0.3599 (epoch: 19, step: 100) // Avg time/img: 0.0827 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.916 (epoch: 19, step: 0) // Avg time/img: 0.0325 s
# VAL loss: 0.8711 (epoch: 19, step: 50) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  32.74 %
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.00044262102267129743
# loss: 0.3563 (epoch: 20, step: 0) // Avg time/img: 0.0922 s
# loss: 0.3664 (epoch: 20, step: 50) // Avg time/img: 0.0828 s
# loss: 0.3684 (epoch: 20, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.6592 (epoch: 20, step: 0) // Avg time/img: 0.0310 s
# VAL loss: 0.7172 (epoch: 20, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  36.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 20)
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.3533 (epoch: 21, step: 0) // Avg time/img: 0.0962 s
# loss: 0.3597 (epoch: 21, step: 50) // Avg time/img: 0.0835 s
# loss: 0.3507 (epoch: 21, step: 100) // Avg time/img: 0.0829 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.7881 (epoch: 21, step: 0) // Avg time/img: 0.0336 s
# VAL loss: 0.8726 (epoch: 21, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  33.91 %
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.000436534538285843
# loss: 0.3863 (epoch: 22, step: 0) // Avg time/img: 0.0886 s
# loss: 0.3424 (epoch: 22, step: 50) // Avg time/img: 0.0827 s
# loss: 0.3539 (epoch: 22, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.4215 (epoch: 22, step: 0) // Avg time/img: 0.0328 s
# VAL loss: 0.6836 (epoch: 22, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  37.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 22)
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.00043348776465364783
# loss: 0.2755 (epoch: 23, step: 0) // Avg time/img: 0.0882 s
# loss: 0.3268 (epoch: 23, step: 50) // Avg time/img: 0.0835 s
# loss: 0.3284 (epoch: 23, step: 100) // Avg time/img: 0.0827 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.7341 (epoch: 23, step: 0) // Avg time/img: 0.0328 s
# VAL loss: 0.7832 (epoch: 23, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  35.81 %
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.00043043860977406414
# loss: 0.2683 (epoch: 24, step: 0) // Avg time/img: 0.0955 s
# loss: 0.3249 (epoch: 24, step: 50) // Avg time/img: 0.0828 s
# loss: 0.3288 (epoch: 24, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 1.033 (epoch: 24, step: 0) // Avg time/img: 0.0320 s
# VAL loss: 0.8944 (epoch: 24, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  33.97 %
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00042738705301356716
# loss: 0.3006 (epoch: 25, step: 0) // Avg time/img: 0.0876 s
# loss: 0.3195 (epoch: 25, step: 50) // Avg time/img: 0.0828 s
# loss: 0.3307 (epoch: 25, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.8634 (epoch: 25, step: 0) // Avg time/img: 0.0305 s
# VAL loss: 0.8781 (epoch: 25, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  34.82 %
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.4184 (epoch: 26, step: 0) // Avg time/img: 0.0946 s
# loss: 0.3141 (epoch: 26, step: 50) // Avg time/img: 0.0834 s
# loss: 0.3252 (epoch: 26, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.5023 (epoch: 26, step: 0) // Avg time/img: 0.0326 s
# VAL loss: 0.6869 (epoch: 26, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  37.76 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 26)
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0004212766495870041
# loss: 0.4126 (epoch: 27, step: 0) // Avg time/img: 0.0994 s
# loss: 0.3221 (epoch: 27, step: 50) // Avg time/img: 0.0835 s
# loss: 0.3142 (epoch: 27, step: 100) // Avg time/img: 0.0827 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.5819 (epoch: 27, step: 0) // Avg time/img: 0.0346 s
# VAL loss: 0.722 (epoch: 27, step: 50) // Avg time/img: 0.0258 s
# EPOCH IoU on VAL set:  37.55 %
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00041821775989926696
# loss: 0.3508 (epoch: 28, step: 0) // Avg time/img: 0.0939 s
# loss: 0.2988 (epoch: 28, step: 50) // Avg time/img: 0.0832 s
# loss: 0.3067 (epoch: 28, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.4817 (epoch: 28, step: 0) // Avg time/img: 0.0352 s
# VAL loss: 0.6964 (epoch: 28, step: 50) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  38.33 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 28)
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.0004151563822693442
# loss: 0.2524 (epoch: 29, step: 0) // Avg time/img: 0.0951 s
# loss: 0.2844 (epoch: 29, step: 50) // Avg time/img: 0.0836 s
# loss: 0.2887 (epoch: 29, step: 100) // Avg time/img: 0.0828 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.6029 (epoch: 29, step: 0) // Avg time/img: 0.0330 s
# VAL loss: 0.7494 (epoch: 29, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  38.96 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 29)
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.00041209249425527324
# loss: 0.272 (epoch: 30, step: 0) // Avg time/img: 0.0885 s
# loss: 0.2817 (epoch: 30, step: 50) // Avg time/img: 0.0829 s
# loss: 0.294 (epoch: 30, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.5944 (epoch: 30, step: 0) // Avg time/img: 0.0371 s
# VAL loss: 0.6671 (epoch: 30, step: 50) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  40.36 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 30)
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.2425 (epoch: 31, step: 0) // Avg time/img: 0.0935 s
# loss: 0.287 (epoch: 31, step: 50) // Avg time/img: 0.0829 s
# loss: 0.3037 (epoch: 31, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.6877 (epoch: 31, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.7502 (epoch: 31, step: 50) // Avg time/img: 0.0256 s
# EPOCH IoU on VAL set:  38.14 %
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.00040595709534845345
# loss: 0.2913 (epoch: 32, step: 0) // Avg time/img: 0.0889 s
# loss: 0.2992 (epoch: 32, step: 50) // Avg time/img: 0.0830 s
# loss: 0.2971 (epoch: 32, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.6088 (epoch: 32, step: 0) // Avg time/img: 0.0315 s
# VAL loss: 0.718 (epoch: 32, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  36.98 %
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00040288553758283585
# loss: 0.3448 (epoch: 33, step: 0) // Avg time/img: 0.0909 s
# loss: 0.2764 (epoch: 33, step: 50) // Avg time/img: 0.0830 s
# loss: 0.2845 (epoch: 33, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.604 (epoch: 33, step: 0) // Avg time/img: 0.0329 s
# VAL loss: 0.6516 (epoch: 33, step: 50) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  40.49 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 33)
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.0003998113756661346
# loss: 0.2477 (epoch: 34, step: 0) // Avg time/img: 0.0911 s
# loss: 0.272 (epoch: 34, step: 50) // Avg time/img: 0.0830 s
# loss: 0.2784 (epoch: 34, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.6355 (epoch: 34, step: 0) // Avg time/img: 0.0308 s
# VAL loss: 0.6834 (epoch: 34, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  39.94 %
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00039673458510381765
# loss: 0.2317 (epoch: 35, step: 0) // Avg time/img: 0.0962 s
# loss: 0.2671 (epoch: 35, step: 50) // Avg time/img: 0.0829 s
# loss: 0.2739 (epoch: 35, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.734 (epoch: 35, step: 0) // Avg time/img: 0.0336 s
# VAL loss: 0.7261 (epoch: 35, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  37.66 %
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.2861 (epoch: 36, step: 0) // Avg time/img: 0.0925 s
# loss: 0.2638 (epoch: 36, step: 50) // Avg time/img: 0.0833 s
# loss: 0.2648 (epoch: 36, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.6229 (epoch: 36, step: 0) // Avg time/img: 0.0293 s
# VAL loss: 0.6575 (epoch: 36, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  39.76 %
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.0003905730178340304
# loss: 0.2563 (epoch: 37, step: 0) // Avg time/img: 0.0899 s
# loss: 0.3522 (epoch: 37, step: 50) // Avg time/img: 0.0832 s
# loss: 0.328 (epoch: 37, step: 100) // Avg time/img: 0.0827 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.4249 (epoch: 37, step: 0) // Avg time/img: 0.0343 s
# VAL loss: 0.6956 (epoch: 37, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  38.81 %
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.0003874881898709925
# loss: 0.3192 (epoch: 38, step: 0) // Avg time/img: 0.0930 s
# loss: 0.2602 (epoch: 38, step: 50) // Avg time/img: 0.0832 s
# loss: 0.2614 (epoch: 38, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.4654 (epoch: 38, step: 0) // Avg time/img: 0.0306 s
# VAL loss: 0.6521 (epoch: 38, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  41.40 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 38)
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.00038440063072596296
# loss: 0.3387 (epoch: 39, step: 0) // Avg time/img: 0.0921 s
# loss: 0.26 (epoch: 39, step: 50) // Avg time/img: 0.0857 s
# loss: 0.2563 (epoch: 39, step: 100) // Avg time/img: 0.0843 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.5173 (epoch: 39, step: 0) // Avg time/img: 0.0342 s
# VAL loss: 0.7162 (epoch: 39, step: 50) // Avg time/img: 0.0272 s
# EPOCH IoU on VAL set:  41.04 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.0003813103135621442
# loss: 0.229 (epoch: 40, step: 0) // Avg time/img: 0.0888 s
# loss: 0.2944 (epoch: 40, step: 50) // Avg time/img: 0.0837 s
# loss: 0.2808 (epoch: 40, step: 100) // Avg time/img: 0.0831 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.5944 (epoch: 40, step: 0) // Avg time/img: 0.0388 s
# VAL loss: 0.6953 (epoch: 40, step: 50) // Avg time/img: 0.0272 s
# EPOCH IoU on VAL set:  40.05 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.3048 (epoch: 41, step: 0) // Avg time/img: 0.0936 s
# loss: 0.253 (epoch: 41, step: 50) // Avg time/img: 0.0843 s
# loss: 0.2504 (epoch: 41, step: 100) // Avg time/img: 0.0832 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.7824 (epoch: 41, step: 0) // Avg time/img: 0.0318 s
# VAL loss: 0.7525 (epoch: 41, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  39.13 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00037512129527676405
# loss: 0.2076 (epoch: 42, step: 0) // Avg time/img: 0.0943 s
# loss: 0.2441 (epoch: 42, step: 50) // Avg time/img: 0.0828 s
# loss: 0.2438 (epoch: 42, step: 100) // Avg time/img: 0.0827 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.3824 (epoch: 42, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.6327 (epoch: 42, step: 50) // Avg time/img: 0.0271 s
# EPOCH IoU on VAL set:  42.69 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 42)
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.0003720225378839164
# loss: 0.2267 (epoch: 43, step: 0) // Avg time/img: 0.0931 s
# loss: 0.2411 (epoch: 43, step: 50) // Avg time/img: 0.0838 s
# loss: 0.2386 (epoch: 43, step: 100) // Avg time/img: 0.0831 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.3361 (epoch: 43, step: 0) // Avg time/img: 0.0334 s
# VAL loss: 0.638 (epoch: 43, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  43.03 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 43)
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.00036892090989941846
# loss: 0.2087 (epoch: 44, step: 0) // Avg time/img: 0.0929 s
# loss: 0.2363 (epoch: 44, step: 50) // Avg time/img: 0.0829 s
# loss: 0.2355 (epoch: 44, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.4492 (epoch: 44, step: 0) // Avg time/img: 0.0342 s
# VAL loss: 0.6217 (epoch: 44, step: 50) // Avg time/img: 0.0273 s
# EPOCH IoU on VAL set:  42.38 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.0003658163817978644
# loss: 0.265 (epoch: 45, step: 0) // Avg time/img: 0.0929 s
# loss: 0.2401 (epoch: 45, step: 50) // Avg time/img: 0.0830 s
# loss: 0.2424 (epoch: 45, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.9174 (epoch: 45, step: 0) // Avg time/img: 0.0345 s
# VAL loss: 0.8625 (epoch: 45, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  40.89 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.2639 (epoch: 46, step: 0) // Avg time/img: 0.1006 s
# loss: 0.3299 (epoch: 46, step: 50) // Avg time/img: 0.0826 s
# loss: 0.305 (epoch: 46, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.6371 (epoch: 46, step: 0) // Avg time/img: 0.0289 s
# VAL loss: 0.6867 (epoch: 46, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  41.66 %
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.0003595985041984843
# loss: 0.1702 (epoch: 47, step: 0) // Avg time/img: 0.0890 s
# loss: 0.2394 (epoch: 47, step: 50) // Avg time/img: 0.0825 s
# loss: 0.2458 (epoch: 47, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.5164 (epoch: 47, step: 0) // Avg time/img: 0.0334 s
# VAL loss: 0.6015 (epoch: 47, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  43.10 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 47)
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.0003564850926538206
# loss: 0.251 (epoch: 48, step: 0) // Avg time/img: 0.0921 s
# loss: 0.2379 (epoch: 48, step: 50) // Avg time/img: 0.0835 s
# loss: 0.2263 (epoch: 48, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.5934 (epoch: 48, step: 0) // Avg time/img: 0.0335 s
# VAL loss: 0.6906 (epoch: 48, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  41.71 %
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00035336865686177077
# loss: 0.2108 (epoch: 49, step: 0) // Avg time/img: 0.0896 s
# loss: 0.2219 (epoch: 49, step: 50) // Avg time/img: 0.0837 s
# loss: 0.2257 (epoch: 49, step: 100) // Avg time/img: 0.0828 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.4209 (epoch: 49, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.5789 (epoch: 49, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  44.04 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 49)
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.0003502491641908687
# loss: 0.176 (epoch: 50, step: 0) // Avg time/img: 0.0903 s
# loss: 0.2142 (epoch: 50, step: 50) // Avg time/img: 0.0827 s
# loss: 0.2192 (epoch: 50, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.4042 (epoch: 50, step: 0) // Avg time/img: 0.0326 s
# VAL loss: 0.6927 (epoch: 50, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  41.59 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.2056 (epoch: 51, step: 0) // Avg time/img: 0.0928 s
# loss: 0.233 (epoch: 51, step: 50) // Avg time/img: 0.0839 s
# loss: 0.2521 (epoch: 51, step: 100) // Avg time/img: 0.0829 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.4972 (epoch: 51, step: 0) // Avg time/img: 0.0338 s
# VAL loss: 0.5962 (epoch: 51, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  43.19 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  0.00034400087427136414
# loss: 0.2236 (epoch: 52, step: 0) // Avg time/img: 0.0915 s
# loss: 0.265 (epoch: 52, step: 50) // Avg time/img: 0.0826 s
# loss: 0.2496 (epoch: 52, step: 100) // Avg time/img: 0.0820 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.4064 (epoch: 52, step: 0) // Avg time/img: 0.0342 s
# VAL loss: 0.6081 (epoch: 52, step: 50) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  43.97 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  0.0003408720082805103
# loss: 0.1952 (epoch: 53, step: 0) // Avg time/img: 0.0970 s
# loss: 0.2093 (epoch: 53, step: 50) // Avg time/img: 0.0831 s
# loss: 0.2113 (epoch: 53, step: 100) // Avg time/img: 0.0828 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.5083 (epoch: 53, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.6201 (epoch: 53, step: 50) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  44.27 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  0.00033773994788152624
# loss: 0.1959 (epoch: 54, step: 0) // Avg time/img: 0.0956 s
# loss: 0.2051 (epoch: 54, step: 50) // Avg time/img: 0.0826 s
# loss: 0.2068 (epoch: 54, step: 100) // Avg time/img: 0.0822 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.4328 (epoch: 54, step: 0) // Avg time/img: 0.0327 s
# VAL loss: 0.6524 (epoch: 54, step: 50) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  43.98 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  0.0003346046568292074
# loss: 0.2155 (epoch: 55, step: 0) // Avg time/img: 0.0871 s
# loss: 0.1973 (epoch: 55, step: 50) // Avg time/img: 0.0827 s
# loss: 0.2036 (epoch: 55, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.561 (epoch: 55, step: 0) // Avg time/img: 0.0345 s
# VAL loss: 0.6218 (epoch: 55, step: 50) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  43.91 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.217 (epoch: 56, step: 0) // Avg time/img: 0.0880 s
# loss: 0.2103 (epoch: 56, step: 50) // Avg time/img: 0.0830 s
# loss: 0.2103 (epoch: 56, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.482 (epoch: 56, step: 0) // Avg time/img: 0.0315 s
# VAL loss: 0.7299 (epoch: 56, step: 50) // Avg time/img: 0.0257 s
# EPOCH IoU on VAL set:  43.06 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  0.000328324233791252
# loss: 0.1759 (epoch: 57, step: 0) // Avg time/img: 0.0908 s
# loss: 0.2042 (epoch: 57, step: 50) // Avg time/img: 0.0828 s
# loss: 0.199 (epoch: 57, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.6552 (epoch: 57, step: 0) // Avg time/img: 0.0331 s
# VAL loss: 0.6928 (epoch: 57, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  42.17 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  0.000325179025243871
# loss: 0.1557 (epoch: 58, step: 0) // Avg time/img: 0.0923 s
# loss: 0.238 (epoch: 58, step: 50) // Avg time/img: 0.0826 s
# loss: 0.2314 (epoch: 58, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.4416 (epoch: 58, step: 0) // Avg time/img: 0.0332 s
# VAL loss: 0.6239 (epoch: 58, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  44.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 58)
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  0.00032203043286440806
# loss: 0.1448 (epoch: 59, step: 0) // Avg time/img: 0.0941 s
# loss: 0.2024 (epoch: 59, step: 50) // Avg time/img: 0.0833 s
# loss: 0.1994 (epoch: 59, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.4425 (epoch: 59, step: 0) // Avg time/img: 0.0330 s
# VAL loss: 0.6466 (epoch: 59, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  43.83 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  0.0003188784161704182
# loss: 0.1663 (epoch: 60, step: 0) // Avg time/img: 0.0893 s
# loss: 0.198 (epoch: 60, step: 50) // Avg time/img: 0.0836 s
# loss: 0.1993 (epoch: 60, step: 100) // Avg time/img: 0.0829 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.6342 (epoch: 60, step: 0) // Avg time/img: 0.0326 s
# VAL loss: 0.699 (epoch: 60, step: 50) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  42.86 %
# ----- TRAINING - EPOCH 61 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.209 (epoch: 61, step: 0) // Avg time/img: 0.0885 s
# loss: 0.1942 (epoch: 61, step: 50) // Avg time/img: 0.0828 s
# loss: 0.1937 (epoch: 61, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 61 -----
# VAL loss: 0.3661 (epoch: 61, step: 0) // Avg time/img: 0.0340 s
# VAL loss: 0.6124 (epoch: 61, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  46.16 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 61)
# ----- TRAINING - EPOCH 62 -----
# LEARNING RATE:  0.0003125639432029656
# loss: 0.2076 (epoch: 62, step: 0) // Avg time/img: 0.0959 s
# loss: 0.1899 (epoch: 62, step: 50) // Avg time/img: 0.0837 s
# loss: 0.1915 (epoch: 62, step: 100) // Avg time/img: 0.0829 s
# ----- VALIDATING - EPOCH 62 -----
# VAL loss: 0.4625 (epoch: 62, step: 0) // Avg time/img: 0.0308 s
# VAL loss: 0.6528 (epoch: 62, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  44.50 %
# ----- TRAINING - EPOCH 63 -----
# LEARNING RATE:  0.0003094014011603608
# loss: 0.1906 (epoch: 63, step: 0) // Avg time/img: 0.0917 s
# loss: 0.1873 (epoch: 63, step: 50) // Avg time/img: 0.0830 s
# loss: 0.1949 (epoch: 63, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 63 -----
# VAL loss: 0.4304 (epoch: 63, step: 0) // Avg time/img: 0.0333 s
# VAL loss: 0.6017 (epoch: 63, step: 50) // Avg time/img: 0.0267 s
# EPOCH IoU on VAL set:  45.96 %
# ----- TRAINING - EPOCH 64 -----
# LEARNING RATE:  0.00030623526319596624
# loss: 0.1556 (epoch: 64, step: 0) // Avg time/img: 0.0919 s
# loss: 0.2342 (epoch: 64, step: 50) // Avg time/img: 0.0828 s
# loss: 0.2277 (epoch: 64, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 64 -----
# VAL loss: 0.4374 (epoch: 64, step: 0) // Avg time/img: 0.0325 s
# VAL loss: 0.7091 (epoch: 64, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  43.07 %
# ----- TRAINING - EPOCH 65 -----
# LEARNING RATE:  0.00030306548381597083
# loss: 0.2044 (epoch: 65, step: 0) // Avg time/img: 0.0921 s
# loss: 0.1942 (epoch: 65, step: 50) // Avg time/img: 0.0827 s
# loss: 0.1965 (epoch: 65, step: 100) // Avg time/img: 0.0821 s
# ----- VALIDATING - EPOCH 65 -----
# VAL loss: 0.4793 (epoch: 65, step: 0) // Avg time/img: 0.0299 s
# VAL loss: 0.5887 (epoch: 65, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  47.21 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 65)
# ----- TRAINING - EPOCH 66 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.1651 (epoch: 66, step: 0) // Avg time/img: 0.0924 s
# loss: 0.1792 (epoch: 66, step: 50) // Avg time/img: 0.0830 s
# loss: 0.1809 (epoch: 66, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 66 -----
# VAL loss: 0.3408 (epoch: 66, step: 0) // Avg time/img: 0.0322 s
# VAL loss: 0.5975 (epoch: 66, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  46.35 %
# ----- TRAINING - EPOCH 67 -----
# LEARNING RATE:  0.00029671481323529297
# loss: 0.2169 (epoch: 67, step: 0) // Avg time/img: 0.0872 s
# loss: 0.1767 (epoch: 67, step: 50) // Avg time/img: 0.0824 s
# loss: 0.1792 (epoch: 67, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 67 -----
# VAL loss: 0.3984 (epoch: 67, step: 0) // Avg time/img: 0.0336 s
# VAL loss: 0.5848 (epoch: 67, step: 50) // Avg time/img: 0.0258 s
# EPOCH IoU on VAL set:  46.92 %
# ----- TRAINING - EPOCH 68 -----
# LEARNING RATE:  0.00029353382532465916
# loss: 0.167 (epoch: 68, step: 0) // Avg time/img: 0.0956 s
# loss: 0.1792 (epoch: 68, step: 50) // Avg time/img: 0.0833 s
# loss: 0.1769 (epoch: 68, step: 100) // Avg time/img: 0.0829 s
# ----- VALIDATING - EPOCH 68 -----
# VAL loss: 0.5609 (epoch: 68, step: 0) // Avg time/img: 0.0335 s
# VAL loss: 0.7225 (epoch: 68, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  43.05 %
# ----- TRAINING - EPOCH 69 -----
# LEARNING RATE:  0.0002903490024913187
# loss: 0.2023 (epoch: 69, step: 0) // Avg time/img: 0.0893 s
# loss: 0.1775 (epoch: 69, step: 50) // Avg time/img: 0.0835 s
# loss: 0.1813 (epoch: 69, step: 100) // Avg time/img: 0.0828 s
# ----- VALIDATING - EPOCH 69 -----
# VAL loss: 0.4572 (epoch: 69, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.7226 (epoch: 69, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  44.05 %
# ----- TRAINING - EPOCH 70 -----
# LEARNING RATE:  0.00028716029325726706
# loss: 0.1842 (epoch: 70, step: 0) // Avg time/img: 0.0907 s
# loss: 0.1768 (epoch: 70, step: 50) // Avg time/img: 0.0833 s
# loss: 0.1747 (epoch: 70, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 70 -----
# VAL loss: 0.3999 (epoch: 70, step: 0) // Avg time/img: 0.0306 s
# VAL loss: 0.6149 (epoch: 70, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  46.67 %
# ----- TRAINING - EPOCH 71 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.1992 (epoch: 71, step: 0) // Avg time/img: 0.0967 s
# loss: 0.1689 (epoch: 71, step: 50) // Avg time/img: 0.0831 s
# loss: 0.1721 (epoch: 71, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 71 -----
# VAL loss: 0.4563 (epoch: 71, step: 0) // Avg time/img: 0.0330 s
# VAL loss: 0.5929 (epoch: 71, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  46.81 %
# ----- TRAINING - EPOCH 72 -----
# LEARNING RATE:  0.0002807710029455323
# loss: 0.1568 (epoch: 72, step: 0) // Avg time/img: 0.0892 s
# loss: 0.1732 (epoch: 72, step: 50) // Avg time/img: 0.0830 s
# loss: 0.1733 (epoch: 72, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 72 -----
# VAL loss: 0.4253 (epoch: 72, step: 0) // Avg time/img: 0.0360 s
# VAL loss: 0.6218 (epoch: 72, step: 50) // Avg time/img: 0.0271 s
# EPOCH IoU on VAL set:  45.86 %
# ----- TRAINING - EPOCH 73 -----
# LEARNING RATE:  0.00027757031202430184
# loss: 0.2005 (epoch: 73, step: 0) // Avg time/img: 0.0934 s
# loss: 0.1742 (epoch: 73, step: 50) // Avg time/img: 0.0831 s
# loss: 0.177 (epoch: 73, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 73 -----
# VAL loss: 0.4535 (epoch: 73, step: 0) // Avg time/img: 0.0322 s
# VAL loss: 0.5846 (epoch: 73, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  46.95 %
# ----- TRAINING - EPOCH 74 -----
# LEARNING RATE:  0.00027436551490344014
# loss: 0.119 (epoch: 74, step: 0) // Avg time/img: 0.0964 s
# loss: 0.1668 (epoch: 74, step: 50) // Avg time/img: 0.0843 s
# loss: 0.1701 (epoch: 74, step: 100) // Avg time/img: 0.0833 s
# ----- VALIDATING - EPOCH 74 -----
# VAL loss: 0.6855 (epoch: 74, step: 0) // Avg time/img: 0.0332 s
# VAL loss: 0.7171 (epoch: 74, step: 50) // Avg time/img: 0.0258 s
# EPOCH IoU on VAL set:  44.68 %
# ----- TRAINING - EPOCH 75 -----
# LEARNING RATE:  0.0002711565528815638
# loss: 0.1626 (epoch: 75, step: 0) // Avg time/img: 0.0934 s
# loss: 0.1749 (epoch: 75, step: 50) // Avg time/img: 0.0830 s
# loss: 0.1778 (epoch: 75, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 75 -----
# VAL loss: 0.3616 (epoch: 75, step: 0) // Avg time/img: 0.0324 s
# VAL loss: 0.6418 (epoch: 75, step: 50) // Avg time/img: 0.0270 s
# EPOCH IoU on VAL set:  44.28 %
# ----- TRAINING - EPOCH 76 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.239 (epoch: 76, step: 0) // Avg time/img: 0.0903 s
# loss: 0.1791 (epoch: 76, step: 50) // Avg time/img: 0.0834 s
# loss: 0.1847 (epoch: 76, step: 100) // Avg time/img: 0.0828 s
# ----- VALIDATING - EPOCH 76 -----
# VAL loss: 0.4866 (epoch: 76, step: 0) // Avg time/img: 0.0318 s
# VAL loss: 0.7636 (epoch: 76, step: 50) // Avg time/img: 0.0274 s
# EPOCH IoU on VAL set:  42.08 %
# ----- TRAINING - EPOCH 77 -----
# LEARNING RATE:  0.0002647258911460076
# loss: 0.1954 (epoch: 77, step: 0) // Avg time/img: 0.0876 s
# loss: 0.186 (epoch: 77, step: 50) // Avg time/img: 0.0833 s
# loss: 0.1928 (epoch: 77, step: 100) // Avg time/img: 0.0837 s
# ----- VALIDATING - EPOCH 77 -----
# VAL loss: 0.3848 (epoch: 77, step: 0) // Avg time/img: 0.0357 s
# VAL loss: 0.6223 (epoch: 77, step: 50) // Avg time/img: 0.0271 s
# EPOCH IoU on VAL set:  44.25 %
# ----- TRAINING - EPOCH 78 -----
# LEARNING RATE:  0.0002615040656411763
# loss: 0.1603 (epoch: 78, step: 0) // Avg time/img: 0.0957 s
# loss: 0.2 (epoch: 78, step: 50) // Avg time/img: 0.0837 s
# loss: 0.19 (epoch: 78, step: 100) // Avg time/img: 0.0831 s
# ----- VALIDATING - EPOCH 78 -----
# VAL loss: 0.5543 (epoch: 78, step: 0) // Avg time/img: 0.0345 s
# VAL loss: 0.603 (epoch: 78, step: 50) // Avg time/img: 0.0276 s
# EPOCH IoU on VAL set:  47.44 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 78)
# ----- TRAINING - EPOCH 79 -----
# LEARNING RATE:  0.0002582778235073065
# loss: 0.1829 (epoch: 79, step: 0) // Avg time/img: 0.0917 s
# loss: 0.1724 (epoch: 79, step: 50) // Avg time/img: 0.0839 s
# loss: 0.1759 (epoch: 79, step: 100) // Avg time/img: 0.0832 s
# ----- VALIDATING - EPOCH 79 -----
# VAL loss: 0.4123 (epoch: 79, step: 0) // Avg time/img: 0.0343 s
# VAL loss: 0.6928 (epoch: 79, step: 50) // Avg time/img: 0.0271 s
# EPOCH IoU on VAL set:  43.49 %
# ----- TRAINING - EPOCH 80 -----
# LEARNING RATE:  0.0002550470972169255
# loss: 0.163 (epoch: 80, step: 0) // Avg time/img: 0.0882 s
# loss: 0.1724 (epoch: 80, step: 50) // Avg time/img: 0.0830 s
# loss: 0.1693 (epoch: 80, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 80 -----
# VAL loss: 0.3934 (epoch: 80, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.6274 (epoch: 80, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  47.37 %
# ----- TRAINING - EPOCH 81 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.1411 (epoch: 81, step: 0) // Avg time/img: 0.0960 s
# loss: 0.1572 (epoch: 81, step: 50) // Avg time/img: 0.0829 s
# loss: 0.1567 (epoch: 81, step: 100) // Avg time/img: 0.0821 s
# ----- VALIDATING - EPOCH 81 -----
# VAL loss: 0.4272 (epoch: 81, step: 0) // Avg time/img: 0.0318 s
# VAL loss: 0.6136 (epoch: 81, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  47.32 %
# ----- TRAINING - EPOCH 82 -----
# LEARNING RATE:  0.0002485719119736858
# loss: 0.1743 (epoch: 82, step: 0) // Avg time/img: 0.0888 s
# loss: 0.1517 (epoch: 82, step: 50) // Avg time/img: 0.0832 s
# loss: 0.1535 (epoch: 82, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 82 -----
# VAL loss: 0.4386 (epoch: 82, step: 0) // Avg time/img: 0.0354 s
# VAL loss: 0.7269 (epoch: 82, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  45.19 %
# ----- TRAINING - EPOCH 83 -----
# LEARNING RATE:  0.0002453273076117686
# loss: 0.1656 (epoch: 83, step: 0) // Avg time/img: 0.0904 s
# loss: 0.1537 (epoch: 83, step: 50) // Avg time/img: 0.0829 s
# loss: 0.1545 (epoch: 83, step: 100) // Avg time/img: 0.0822 s
# ----- VALIDATING - EPOCH 83 -----
# VAL loss: 0.311 (epoch: 83, step: 0) // Avg time/img: 0.0299 s
# VAL loss: 0.5929 (epoch: 83, step: 50) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  49.10 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 83)
# ----- TRAINING - EPOCH 84 -----
# LEARNING RATE:  0.00024207792808182566
# loss: 0.1485 (epoch: 84, step: 0) // Avg time/img: 0.0931 s
# loss: 0.1537 (epoch: 84, step: 50) // Avg time/img: 0.0826 s
# loss: 0.1575 (epoch: 84, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 84 -----
# VAL loss: 0.3264 (epoch: 84, step: 0) // Avg time/img: 0.0321 s
# VAL loss: 0.6225 (epoch: 84, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  46.17 %
# ----- TRAINING - EPOCH 85 -----
# LEARNING RATE:  0.0002388236949212524
# loss: 0.1699 (epoch: 85, step: 0) // Avg time/img: 0.0940 s
# loss: 0.1646 (epoch: 85, step: 50) // Avg time/img: 0.0826 s
# loss: 0.1619 (epoch: 85, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 85 -----
# VAL loss: 0.3583 (epoch: 85, step: 0) // Avg time/img: 0.0332 s
# VAL loss: 0.6931 (epoch: 85, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  47.20 %
# ----- TRAINING - EPOCH 86 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.1437 (epoch: 86, step: 0) // Avg time/img: 0.0925 s
# loss: 0.1676 (epoch: 86, step: 50) // Avg time/img: 0.0829 s
# loss: 0.1612 (epoch: 86, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 86 -----
# VAL loss: 0.3813 (epoch: 86, step: 0) // Avg time/img: 0.0369 s
# VAL loss: 0.69 (epoch: 86, step: 50) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  47.21 %
# ----- TRAINING - EPOCH 87 -----
# LEARNING RATE:  0.00023230034124497895
# loss: 0.1068 (epoch: 87, step: 0) // Avg time/img: 0.0919 s
# loss: 0.1541 (epoch: 87, step: 50) // Avg time/img: 0.0830 s
# loss: 0.159 (epoch: 87, step: 100) // Avg time/img: 0.0822 s
# ----- VALIDATING - EPOCH 87 -----
# VAL loss: 0.4239 (epoch: 87, step: 0) // Avg time/img: 0.0357 s
# VAL loss: 0.93 (epoch: 87, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  42.46 %
# ----- TRAINING - EPOCH 88 -----
# LEARNING RATE:  0.00022903105082576662
# loss: 0.143 (epoch: 88, step: 0) // Avg time/img: 0.0944 s
# loss: 0.1714 (epoch: 88, step: 50) // Avg time/img: 0.0829 s
# loss: 0.1682 (epoch: 88, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 88 -----
# VAL loss: 0.4003 (epoch: 88, step: 0) // Avg time/img: 0.0310 s
# VAL loss: 0.7348 (epoch: 88, step: 50) // Avg time/img: 0.0260 s
# EPOCH IoU on VAL set:  43.74 %
# ----- TRAINING - EPOCH 89 -----
# LEARNING RATE:  0.000225756566706776
# loss: 0.1236 (epoch: 89, step: 0) // Avg time/img: 0.0913 s
# loss: 0.1907 (epoch: 89, step: 50) // Avg time/img: 0.0832 s
# loss: 0.1796 (epoch: 89, step: 100) // Avg time/img: 0.0827 s
# ----- VALIDATING - EPOCH 89 -----
# VAL loss: 0.3355 (epoch: 89, step: 0) // Avg time/img: 0.0324 s
# VAL loss: 0.6699 (epoch: 89, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  46.65 %
# ----- TRAINING - EPOCH 90 -----
# LEARNING RATE:  0.00022247679665942795
# loss: 0.1714 (epoch: 90, step: 0) // Avg time/img: 0.0946 s
# loss: 0.1554 (epoch: 90, step: 50) // Avg time/img: 0.0828 s
# loss: 0.1561 (epoch: 90, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 90 -----
# VAL loss: 0.3689 (epoch: 90, step: 0) // Avg time/img: 0.0333 s
# VAL loss: 0.6348 (epoch: 90, step: 50) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  47.69 %
# ----- TRAINING - EPOCH 91 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.1539 (epoch: 91, step: 0) // Avg time/img: 0.0900 s
# loss: 0.1468 (epoch: 91, step: 50) // Avg time/img: 0.0829 s
# loss: 0.1507 (epoch: 91, step: 100) // Avg time/img: 0.0823 s
# ----- VALIDATING - EPOCH 91 -----
# VAL loss: 0.9177 (epoch: 91, step: 0) // Avg time/img: 0.0342 s
# VAL loss: 0.8153 (epoch: 91, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  44.96 %
# ----- TRAINING - EPOCH 92 -----
# LEARNING RATE:  0.0002159010138104759
# loss: 0.1559 (epoch: 92, step: 0) // Avg time/img: 0.0957 s
# loss: 0.1574 (epoch: 92, step: 50) // Avg time/img: 0.0834 s
# loss: 0.1544 (epoch: 92, step: 100) // Avg time/img: 0.0826 s
# ----- VALIDATING - EPOCH 92 -----
# VAL loss: 0.3291 (epoch: 92, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.676 (epoch: 92, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  47.19 %
# ----- TRAINING - EPOCH 93 -----
# LEARNING RATE:  0.00021260479999230916
# loss: 0.1517 (epoch: 93, step: 0) // Avg time/img: 0.0935 s
# loss: 0.1445 (epoch: 93, step: 50) // Avg time/img: 0.0830 s
# loss: 0.1464 (epoch: 93, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 93 -----
# VAL loss: 0.2806 (epoch: 93, step: 0) // Avg time/img: 0.0320 s
# VAL loss: 0.6534 (epoch: 93, step: 50) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  46.98 %
# ----- TRAINING - EPOCH 94 -----
# LEARNING RATE:  0.00020930289784861406
# loss: 0.1717 (epoch: 94, step: 0) // Avg time/img: 0.0880 s
# loss: 0.1447 (epoch: 94, step: 50) // Avg time/img: 0.0827 s
# loss: 0.1439 (epoch: 94, step: 100) // Avg time/img: 0.0825 s
# ----- VALIDATING - EPOCH 94 -----
# VAL loss: 0.3273 (epoch: 94, step: 0) // Avg time/img: 0.0355 s
# VAL loss: 0.6427 (epoch: 94, step: 50) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  48.59 %
# ----- TRAINING - EPOCH 95 -----
# LEARNING RATE:  0.00020599519749715014
# loss: 0.1166 (epoch: 95, step: 0) // Avg time/img: 0.0892 s
# loss: 0.1424 (epoch: 95, step: 50) // Avg time/img: 0.0832 s
# loss: 0.1421 (epoch: 95, step: 100) // Avg time/img: 0.0827 s
# ----- VALIDATING - EPOCH 95 -----
# VAL loss: 0.2887 (epoch: 95, step: 0) // Avg time/img: 0.0345 s
# VAL loss: 0.6706 (epoch: 95, step: 50) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  47.37 %
# ----- TRAINING - EPOCH 96 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.1373 (epoch: 96, step: 0) // Avg time/img: 0.0899 s
# loss: 0.1412 (epoch: 96, step: 50) // Avg time/img: 0.0828 s
# loss: 0.1411 (epoch: 96, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 96 -----
# VAL loss: 0.2778 (epoch: 96, step: 0) // Avg time/img: 0.0332 s
# VAL loss: 0.5953 (epoch: 96, step: 50) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  49.68 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_encoder_best.pth (epoch: 96)
# ----- TRAINING - EPOCH 97 -----
# LEARNING RATE:  0.0001993619417846922
# loss: 0.1285 (epoch: 97, step: 0) // Avg time/img: 0.0877 s
# loss: 0.1348 (epoch: 97, step: 50) // Avg time/img: 0.0832 s
# loss: 0.1384 (epoch: 97, step: 100) // Avg time/img: 0.0824 s
# ----- VALIDATING - EPOCH 97 -----
# VAL loss: 0.3223 (epoch: 97, step: 0) // Avg time/img: 0.0348 s
# VAL loss: 0.6194 (epoch: 97, step: 50) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  48.89 %
# ----- TRAINING - EPOCH 98 -----
# LEARNING RATE:  0.00019603614508599792
# loss: 0.1372 (epoch: 98, step: 0) // Avg time/img: 0.0945 s
# loss: 0.1345 (epoch: 98, step: 50) // Avg time/img: 0.0827 s
# loss: 0.1393 (epoch: 98, step: 100) // Avg time/img: 0.0822 s
# ...
# VAL loss: 0.7349 (epoch: 116, step: 50) // Avg time/img: 0.0377 s
# EPOCH IoU on VAL set:  53.57 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_best.pth (epoch: 116)
# ----- TRAINING - EPOCH 117 -----
# LEARNING RATE:  0.00013146764896688576
# loss: 0.1253 (epoch: 117, step: 0) // Avg time/img: 0.1260 s
# loss: 0.1161 (epoch: 117, step: 50) // Avg time/img: 0.1192 s
# loss: 0.1144 (epoch: 117, step: 100) // Avg time/img: 0.1178 s
# ----- VALIDATING - EPOCH 117 -----
# VAL loss: 0.4835 (epoch: 117, step: 0) // Avg time/img: 0.0479 s
# VAL loss: 0.764 (epoch: 117, step: 50) // Avg time/img: 0.0373 s
# EPOCH IoU on VAL set:  52.17 %
# ----- TRAINING - EPOCH 118 -----
# LEARNING RATE:  0.00012798244922073102
# loss: 0.1204 (epoch: 118, step: 0) // Avg time/img: 0.1274 s
# loss: 0.115 (epoch: 118, step: 50) // Avg time/img: 0.1178 s
# loss: 0.1146 (epoch: 118, step: 100) // Avg time/img: 0.1176 s
# ----- VALIDATING - EPOCH 118 -----
# VAL loss: 0.4616 (epoch: 118, step: 0) // Avg time/img: 0.0464 s
# VAL loss: 0.7355 (epoch: 118, step: 50) // Avg time/img: 0.0376 s
# EPOCH IoU on VAL set:  51.96 %
# ----- TRAINING - EPOCH 119 -----
# LEARNING RATE:  0.00012448667054224682
# loss: 0.1067 (epoch: 119, step: 0) // Avg time/img: 0.1286 s
# loss: 0.1112 (epoch: 119, step: 50) // Avg time/img: 0.1178 s
# loss: 0.1138 (epoch: 119, step: 100) // Avg time/img: 0.1175 s
# ----- VALIDATING - EPOCH 119 -----
# VAL loss: 0.4721 (epoch: 119, step: 0) // Avg time/img: 0.0479 s
# VAL loss: 0.7277 (epoch: 119, step: 50) // Avg time/img: 0.0373 s
# EPOCH IoU on VAL set:  52.00 %
# ----- TRAINING - EPOCH 120 -----
# LEARNING RATE:  0.00012097994859481348
# loss: 0.1132 (epoch: 120, step: 0) // Avg time/img: 0.1259 s
# loss: 0.1101 (epoch: 120, step: 50) // Avg time/img: 0.1181 s
# loss: 0.1104 (epoch: 120, step: 100) // Avg time/img: 0.1177 s
# ----- VALIDATING - EPOCH 120 -----
# VAL loss: 0.5631 (epoch: 120, step: 0) // Avg time/img: 0.0494 s
# VAL loss: 0.7457 (epoch: 120, step: 50) // Avg time/img: 0.0384 s
# EPOCH IoU on VAL set:  52.50 %
# ----- TRAINING - EPOCH 121 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.1167 (epoch: 121, step: 0) // Avg time/img: 0.1300 s
# loss: 0.1106 (epoch: 121, step: 50) // Avg time/img: 0.1183 s
# loss: 0.1089 (epoch: 121, step: 100) // Avg time/img: 0.1176 s
# ----- VALIDATING - EPOCH 121 -----
# VAL loss: 0.4217 (epoch: 121, step: 0) // Avg time/img: 0.0459 s
# VAL loss: 0.7498 (epoch: 121, step: 50) // Avg time/img: 0.0376 s
# EPOCH IoU on VAL set:  53.45 %
# ----- TRAINING - EPOCH 122 -----
# LEARNING RATE:  0.00011393209131979663
# loss: 0.1047 (epoch: 122, step: 0) // Avg time/img: 0.1301 s
# loss: 0.1099 (epoch: 122, step: 50) // Avg time/img: 0.1178 s
# loss: 0.1096 (epoch: 122, step: 100) // Avg time/img: 0.1170 s
# ----- VALIDATING - EPOCH 122 -----
# VAL loss: 0.5738 (epoch: 122, step: 0) // Avg time/img: 0.0468 s
# VAL loss: 0.8006 (epoch: 122, step: 50) // Avg time/img: 0.0377 s
# EPOCH IoU on VAL set:  50.30 %
# ----- TRAINING - EPOCH 123 -----
# LEARNING RATE:  0.00011039009304368409
# loss: 0.123 (epoch: 123, step: 0) // Avg time/img: 0.1304 s
# loss: 0.1138 (epoch: 123, step: 50) // Avg time/img: 0.1181 s
# loss: 0.1107 (epoch: 123, step: 100) // Avg time/img: 0.1168 s
# ----- VALIDATING - EPOCH 123 -----
# VAL loss: 0.4863 (epoch: 123, step: 0) // Avg time/img: 0.0446 s
# VAL loss: 0.7591 (epoch: 123, step: 50) // Avg time/img: 0.0378 s
# EPOCH IoU on VAL set:  53.56 %
# ----- TRAINING - EPOCH 124 -----
# LEARNING RATE:  0.00010683541932226925
# loss: 0.09816 (epoch: 124, step: 0) // Avg time/img: 0.1289 s
# loss: 0.1118 (epoch: 124, step: 50) // Avg time/img: 0.1178 s
# loss: 0.11 (epoch: 124, step: 100) // Avg time/img: 0.1170 s
# ----- VALIDATING - EPOCH 124 -----
# VAL loss: 0.4577 (epoch: 124, step: 0) // Avg time/img: 0.0502 s
# VAL loss: 0.726 (epoch: 124, step: 50) // Avg time/img: 0.0383 s
# EPOCH IoU on VAL set:  53.45 %
# ----- TRAINING - EPOCH 125 -----
# LEARNING RATE:  0.00010326755255804833
# loss: 0.1101 (epoch: 125, step: 0) // Avg time/img: 0.1292 s
# loss: 0.1082 (epoch: 125, step: 50) // Avg time/img: 0.1184 s
# loss: 0.1071 (epoch: 125, step: 100) // Avg time/img: 0.1169 s
# ----- VALIDATING - EPOCH 125 -----
# VAL loss: 0.552 (epoch: 125, step: 0) // Avg time/img: 0.0496 s
# VAL loss: 0.7875 (epoch: 125, step: 50) // Avg time/img: 0.0381 s
# EPOCH IoU on VAL set:  52.51 %
# ----- TRAINING - EPOCH 126 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.08778 (epoch: 126, step: 0) // Avg time/img: 0.1342 s
# loss: 0.1127 (epoch: 126, step: 50) // Avg time/img: 0.1179 s
# loss: 0.1081 (epoch: 126, step: 100) // Avg time/img: 0.1169 s
# ----- VALIDATING - EPOCH 126 -----
# VAL loss: 0.4721 (epoch: 126, step: 0) // Avg time/img: 0.0446 s
# VAL loss: 0.7392 (epoch: 126, step: 50) // Avg time/img: 0.0382 s
# EPOCH IoU on VAL set:  53.33 %
# ----- TRAINING - EPOCH 127 -----
# LEARNING RATE:  9.608995471851451e-05
# loss: 0.09948 (epoch: 127, step: 0) // Avg time/img: 0.1303 s
# loss: 0.1063 (epoch: 127, step: 50) // Avg time/img: 0.1182 s
# loss: 0.1071 (epoch: 127, step: 100) // Avg time/img: 0.1168 s
# ----- VALIDATING - EPOCH 127 -----
# VAL loss: 0.4989 (epoch: 127, step: 0) // Avg time/img: 0.0500 s
# VAL loss: 0.7626 (epoch: 127, step: 50) // Avg time/img: 0.0376 s
# EPOCH IoU on VAL set:  53.37 %
# ----- TRAINING - EPOCH 128 -----
# LEARNING RATE:  9.247895712258216e-05
# loss: 0.1171 (epoch: 128, step: 0) // Avg time/img: 0.1255 s
# loss: 0.108 (epoch: 128, step: 50) // Avg time/img: 0.1185 s
# loss: 0.1077 (epoch: 128, step: 100) // Avg time/img: 0.1171 s
# ----- VALIDATING - EPOCH 128 -----
# VAL loss: 0.4971 (epoch: 128, step: 0) // Avg time/img: 0.0459 s
# VAL loss: 0.7834 (epoch: 128, step: 50) // Avg time/img: 0.0374 s
# EPOCH IoU on VAL set:  52.05 %
# ----- TRAINING - EPOCH 129 -----
# LEARNING RATE:  8.8852220136671e-05
# loss: 0.08027 (epoch: 129, step: 0) // Avg time/img: 0.1255 s
# loss: 0.1048 (epoch: 129, step: 50) // Avg time/img: 0.1181 s
# loss: 0.1048 (epoch: 129, step: 100) // Avg time/img: 0.1170 s
# ----- VALIDATING - EPOCH 129 -----
# VAL loss: 0.4509 (epoch: 129, step: 0) // Avg time/img: 0.0464 s
# VAL loss: 0.7742 (epoch: 129, step: 50) // Avg time/img: 0.0373 s
# EPOCH IoU on VAL set:  52.21 %
# ----- TRAINING - EPOCH 130 -----
# LEARNING RATE:  8.520895446665837e-05
# loss: 0.1276 (epoch: 130, step: 0) // Avg time/img: 0.1362 s
# loss: 0.1041 (epoch: 130, step: 50) // Avg time/img: 0.1190 s
# loss: 0.1057 (epoch: 130, step: 100) // Avg time/img: 0.1179 s
# ----- VALIDATING - EPOCH 130 -----
# VAL loss: 0.4236 (epoch: 130, step: 0) // Avg time/img: 0.0508 s
# VAL loss: 0.7355 (epoch: 130, step: 50) // Avg time/img: 0.0375 s
# EPOCH IoU on VAL set:  53.77 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_best.pth (epoch: 130)
# ----- TRAINING - EPOCH 131 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.0939 (epoch: 131, step: 0) // Avg time/img: 0.1254 s
# loss: 0.1043 (epoch: 131, step: 50) // Avg time/img: 0.1191 s
# loss: 0.1034 (epoch: 131, step: 100) // Avg time/img: 0.1174 s
# ----- VALIDATING - EPOCH 131 -----
# VAL loss: 0.4669 (epoch: 131, step: 0) // Avg time/img: 0.0467 s
# VAL loss: 0.8118 (epoch: 131, step: 50) // Avg time/img: 0.0370 s
# EPOCH IoU on VAL set:  51.79 %
# ----- TRAINING - EPOCH 132 -----
# LEARNING RATE:  7.786927156042975e-05
# loss: 0.09515 (epoch: 132, step: 0) // Avg time/img: 0.1273 s
# loss: 0.1016 (epoch: 132, step: 50) // Avg time/img: 0.1194 s
# loss: 0.1026 (epoch: 132, step: 100) // Avg time/img: 0.1177 s
# ----- VALIDATING - EPOCH 132 -----
# VAL loss: 0.4655 (epoch: 132, step: 0) // Avg time/img: 0.0520 s
# VAL loss: 0.7778 (epoch: 132, step: 50) // Avg time/img: 0.0380 s
# EPOCH IoU on VAL set:  52.86 %
# ----- TRAINING - EPOCH 133 -----
# LEARNING RATE:  7.417082774876436e-05
# loss: 0.09929 (epoch: 133, step: 0) // Avg time/img: 0.1300 s
# loss: 0.1012 (epoch: 133, step: 50) // Avg time/img: 0.1183 s
# loss: 0.1025 (epoch: 133, step: 100) // Avg time/img: 0.1178 s
# ----- VALIDATING - EPOCH 133 -----
# VAL loss: 0.5146 (epoch: 133, step: 0) // Avg time/img: 0.0451 s
# VAL loss: 0.7759 (epoch: 133, step: 50) // Avg time/img: 0.0378 s
# EPOCH IoU on VAL set:  52.62 %
# ----- TRAINING - EPOCH 134 -----
# LEARNING RATE:  7.045176867237252e-05
# loss: 0.1049 (epoch: 134, step: 0) // Avg time/img: 0.1309 s
# loss: 0.1031 (epoch: 134, step: 50) // Avg time/img: 0.1181 s
# loss: 0.1011 (epoch: 134, step: 100) // Avg time/img: 0.1175 s
# ----- VALIDATING - EPOCH 134 -----
# VAL loss: 0.4632 (epoch: 134, step: 0) // Avg time/img: 0.0490 s
# VAL loss: 0.7377 (epoch: 134, step: 50) // Avg time/img: 0.0374 s
# EPOCH IoU on VAL set:  53.39 %
# ----- TRAINING - EPOCH 135 -----
# LEARNING RATE:  6.671075496333931e-05
# loss: 0.1126 (epoch: 135, step: 0) // Avg time/img: 0.1294 s
# loss: 0.09915 (epoch: 135, step: 50) // Avg time/img: 0.1181 s
# loss: 0.1025 (epoch: 135, step: 100) // Avg time/img: 0.1175 s
# ----- VALIDATING - EPOCH 135 -----
# VAL loss: 0.4896 (epoch: 135, step: 0) // Avg time/img: 0.0468 s
# VAL loss: 0.7467 (epoch: 135, step: 50) // Avg time/img: 0.0381 s
# EPOCH IoU on VAL set:  53.49 %
# ----- TRAINING - EPOCH 136 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.1104 (epoch: 136, step: 0) // Avg time/img: 0.1308 s
# loss: 0.1016 (epoch: 136, step: 50) // Avg time/img: 0.1181 s
# loss: 0.1006 (epoch: 136, step: 100) // Avg time/img: 0.1168 s
# ----- VALIDATING - EPOCH 136 -----
# VAL loss: 0.5114 (epoch: 136, step: 0) // Avg time/img: 0.0466 s
# VAL loss: 0.78 (epoch: 136, step: 50) // Avg time/img: 0.0373 s
# EPOCH IoU on VAL set:  53.25 %
# ----- TRAINING - EPOCH 137 -----
# LEARNING RATE:  5.9156586125566465e-05
# loss: 0.0951 (epoch: 137, step: 0) // Avg time/img: 0.1241 s
# loss: 0.1004 (epoch: 137, step: 50) // Avg time/img: 0.1177 s
# loss: 0.101 (epoch: 137, step: 100) // Avg time/img: 0.1168 s
# ----- VALIDATING - EPOCH 137 -----
# VAL loss: 0.4614 (epoch: 137, step: 0) // Avg time/img: 0.0477 s
# VAL loss: 0.7526 (epoch: 137, step: 50) // Avg time/img: 0.0382 s
# EPOCH IoU on VAL set:  53.41 %
# ----- TRAINING - EPOCH 138 -----
# LEARNING RATE:  5.533971118639405e-05
# loss: 0.09243 (epoch: 138, step: 0) // Avg time/img: 0.1287 s
# loss: 0.1002 (epoch: 138, step: 50) // Avg time/img: 0.1175 s
# loss: 0.1005 (epoch: 138, step: 100) // Avg time/img: 0.1167 s
# ----- VALIDATING - EPOCH 138 -----
# VAL loss: 0.4469 (epoch: 138, step: 0) // Avg time/img: 0.0476 s
# VAL loss: 0.7557 (epoch: 138, step: 50) // Avg time/img: 0.0374 s
# EPOCH IoU on VAL set:  53.74 %
# ----- TRAINING - EPOCH 139 -----
# LEARNING RATE:  5.149333174180893e-05
# loss: 0.1109 (epoch: 139, step: 0) // Avg time/img: 0.1272 s
# loss: 0.09716 (epoch: 139, step: 50) // Avg time/img: 0.1180 s
# loss: 0.09979 (epoch: 139, step: 100) // Avg time/img: 0.1169 s
# ----- VALIDATING - EPOCH 139 -----
# VAL loss: 0.4996 (epoch: 139, step: 0) // Avg time/img: 0.0494 s
# VAL loss: 0.79 (epoch: 139, step: 50) // Avg time/img: 0.0382 s
# EPOCH IoU on VAL set:  53.17 %
# ----- TRAINING - EPOCH 140 -----
# LEARNING RATE:  4.761472581495845e-05
# loss: 0.1076 (epoch: 140, step: 0) // Avg time/img: 0.1277 s
# loss: 0.09834 (epoch: 140, step: 50) // Avg time/img: 0.1176 s
# loss: 0.09925 (epoch: 140, step: 100) // Avg time/img: 0.1167 s
# ----- VALIDATING - EPOCH 140 -----
# VAL loss: 0.506 (epoch: 140, step: 0) // Avg time/img: 0.0526 s
# VAL loss: 0.8008 (epoch: 140, step: 50) // Avg time/img: 0.0379 s
# EPOCH IoU on VAL set:  52.94 %
# ----- TRAINING - EPOCH 141 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.07834 (epoch: 141, step: 0) // Avg time/img: 0.1293 s
# loss: 0.09812 (epoch: 141, step: 50) // Avg time/img: 0.1187 s
# loss: 0.09813 (epoch: 141, step: 100) // Avg time/img: 0.1174 s
# ----- VALIDATING - EPOCH 141 -----
# VAL loss: 0.4363 (epoch: 141, step: 0) // Avg time/img: 0.0472 s
# VAL loss: 0.771 (epoch: 141, step: 50) // Avg time/img: 0.0380 s
# EPOCH IoU on VAL set:  53.47 %
# ----- TRAINING - EPOCH 142 -----
# LEARNING RATE:  3.974716243773811e-05
# loss: 0.07878 (epoch: 142, step: 0) // Avg time/img: 0.1327 s
# loss: 0.09728 (epoch: 142, step: 50) // Avg time/img: 0.1198 s
# loss: 0.09724 (epoch: 142, step: 100) // Avg time/img: 0.1179 s
# ----- VALIDATING - EPOCH 142 -----
# VAL loss: 0.5103 (epoch: 142, step: 0) // Avg time/img: 0.0463 s
# VAL loss: 0.7857 (epoch: 142, step: 50) // Avg time/img: 0.0379 s
# EPOCH IoU on VAL set:  52.93 %
# ----- TRAINING - EPOCH 143 -----
# LEARNING RATE:  3.574940841773419e-05
# loss: 0.1034 (epoch: 143, step: 0) // Avg time/img: 0.1285 s
# loss: 0.09556 (epoch: 143, step: 50) // Avg time/img: 0.1184 s
# loss: 0.0973 (epoch: 143, step: 100) // Avg time/img: 0.1179 s
# ----- VALIDATING - EPOCH 143 -----
# VAL loss: 0.4525 (epoch: 143, step: 0) // Avg time/img: 0.0454 s
# VAL loss: 0.8075 (epoch: 143, step: 50) // Avg time/img: 0.0376 s
# EPOCH IoU on VAL set:  52.67 %
# ----- TRAINING - EPOCH 144 -----
# LEARNING RATE:  3.1701229571812366e-05
# loss: 0.1035 (epoch: 144, step: 0) // Avg time/img: 0.1257 s
# loss: 0.09775 (epoch: 144, step: 50) // Avg time/img: 0.1177 s
# loss: 0.0978 (epoch: 144, step: 100) // Avg time/img: 0.1174 s
# ----- VALIDATING - EPOCH 144 -----
# VAL loss: 0.4677 (epoch: 144, step: 0) // Avg time/img: 0.0490 s
# VAL loss: 0.7846 (epoch: 144, step: 50) // Avg time/img: 0.0377 s
# EPOCH IoU on VAL set:  53.35 %
# ----- TRAINING - EPOCH 145 -----
# LEARNING RATE:  2.7594593229224316e-05
# loss: 0.1102 (epoch: 145, step: 0) // Avg time/img: 0.1321 s
# loss: 0.09784 (epoch: 145, step: 50) // Avg time/img: 0.1183 s
# loss: 0.09762 (epoch: 145, step: 100) // Avg time/img: 0.1171 s
# ----- VALIDATING - EPOCH 145 -----
# VAL loss: 0.4818 (epoch: 145, step: 0) // Avg time/img: 0.0507 s
# VAL loss: 0.7993 (epoch: 145, step: 50) // Avg time/img: 0.0378 s
# EPOCH IoU on VAL set:  53.13 %
# ----- TRAINING - EPOCH 146 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.066 (epoch: 146, step: 0) // Avg time/img: 0.1293 s
# loss: 0.09394 (epoch: 146, step: 50) // Avg time/img: 0.1186 s
# loss: 0.09561 (epoch: 146, step: 100) // Avg time/img: 0.1174 s
# ----- VALIDATING - EPOCH 146 -----
# VAL loss: 0.4703 (epoch: 146, step: 0) // Avg time/img: 0.0464 s
# VAL loss: 0.7581 (epoch: 146, step: 50) // Avg time/img: 0.0382 s
# EPOCH IoU on VAL set:  53.71 %
# ----- TRAINING - EPOCH 147 -----
# LEARNING RATE:  1.9157633621749503e-05
# loss: 0.1005 (epoch: 147, step: 0) // Avg time/img: 0.1301 s
# loss: 0.09625 (epoch: 147, step: 50) // Avg time/img: 0.1183 s
# loss: 0.09637 (epoch: 147, step: 100) // Avg time/img: 0.1168 s
# ----- VALIDATING - EPOCH 147 -----
# VAL loss: 0.4967 (epoch: 147, step: 0) // Avg time/img: 0.0502 s
# VAL loss: 0.7775 (epoch: 147, step: 50) // Avg time/img: 0.0381 s
# EPOCH IoU on VAL set:  53.54 %
# ----- TRAINING - EPOCH 148 -----
# LEARNING RATE:  1.4787576366283148e-05
# loss: 0.06885 (epoch: 148, step: 0) // Avg time/img: 0.1285 s
# loss: 0.09372 (epoch: 148, step: 50) // Avg time/img: 0.1182 s
# loss: 0.09545 (epoch: 148, step: 100) // Avg time/img: 0.1172 s
# ----- VALIDATING - EPOCH 148 -----
# VAL loss: 0.4775 (epoch: 148, step: 0) // Avg time/img: 0.0481 s
# VAL loss: 0.7819 (epoch: 148, step: 50) // Avg time/img: 0.0379 s
# EPOCH IoU on VAL set:  53.27 %
# ----- TRAINING - EPOCH 149 -----
# LEARNING RATE:  1.0266321660392084e-05
# loss: 0.1127 (epoch: 149, step: 0) // Avg time/img: 0.1281 s
# loss: 0.09544 (epoch: 149, step: 50) // Avg time/img: 0.1178 s
# loss: 0.09542 (epoch: 149, step: 100) // Avg time/img: 0.1172 s
# ----- VALIDATING - EPOCH 149 -----
# VAL loss: 0.4667 (epoch: 149, step: 0) // Avg time/img: 0.0536 s
# VAL loss: 0.7627 (epoch: 149, step: 50) // Avg time/img: 0.0378 s
# EPOCH IoU on VAL set:  53.87 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-default-150ep/model_best.pth (epoch: 149)
# ----- TRAINING - EPOCH 150 -----
# LEARNING RATE:  5.501585556734927e-06
# loss: 0.1023 (epoch: 150, step: 0) // Avg time/img: 0.1332 s
# loss: 0.09342 (epoch: 150, step: 50) // Avg time/img: 0.1195 s
# loss: 0.09557 (epoch: 150, step: 100) // Avg time/img: 0.1181 s
# ----- VALIDATING - EPOCH 150 -----
# VAL loss: 0.4778 (epoch: 150, step: 0) // Avg time/img: 0.0450 s
# VAL loss: 0.8085 (epoch: 150, step: 50) // Avg time/img: 0.0374 s
# EPOCH IoU on VAL set:  52.83 %
# ========== TRAINING FINISHED ===========

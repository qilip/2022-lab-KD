# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet Model Common module

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)

class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

# %% [markdown]
# ## ERFNet Model [Teacher]

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class non_bottleneck (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3_1 = nn.Conv2d(chann, chann, (3,3), stride=1, padding=(1,1), bias=True)

        # self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3_2 = nn.Conv2d(chann, chann, (3, 3), stride=1, padding=(1*dilated,1*dilated), bias=True, dilation = (dilated,dilated))

        # self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3_1(input)
        # output = F.relu(output)
        # output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3_2(output)
        # output = F.relu(output)
        # output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class TEncoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck(128, 0.3, 2))
            self.layers.append(non_bottleneck(128, 0.3, 4))
            self.layers.append(non_bottleneck(128, 0.3, 8))
            self.layers.append(non_bottleneck(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output

class TDecoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck(64, 0, 1))
        self.layers.append(non_bottleneck(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck(16, 0, 1))
        self.layers.append(non_bottleneck(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet Teacher
class TNet(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = TEncoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = TDecoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## ERFNet model definition [Student]

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3x1_1 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1,0), bias=True)

        self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3x1_2 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1*dilated,0), bias=True, dilation = (dilated,1))

        self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3x1_1(input)
        output = F.relu(output)
        output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3x1_2(output)
        output = F.relu(output)
        output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target

class MainLoss(torch.nn.Module):
    def __init__(self, weight=None):
      super().__init__()
      self.celoss = torch.nn.NLLLoss2d(weight) # CrossEntropyLoss2d
      # self.kdloss = torch.nn.KLDivLoss(reduction='batchmean')
      self.kdloss = torch.nn.MSELoss()
    
    def forward(self, outputs, targets, toutputs):
      T = 4 # Temperature
      alpha = 0.6 # alpha

      # 기본 Loss
      general_loss = self.celoss(torch.nn.functional.log_softmax(outputs, dim=1), targets)

      # KD Loss
      # toutputs[0].detach()
      # kd_loss = self.kdloss(F.log_softmax(outputs[0] / T, dim=1), F.softmax(toutputs[0] / T, dim=1)) * (T*T)
      # kd_loss = self.kdloss(F.log_softmax(outputs / T, dim=1), F.softmax(toutputs / T, dim=1)) * (T*T)
      kd_loss = self.kdloss(outputs / T, toutputs / T) * (T*T)

      # Loss
      loss = alpha * general_loss + (1-alpha) * kd_loss
      return loss


def train(args, tmodel, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = MainLoss(weight) # Loss 변경부분
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train() # student model (train mode)
        tmodel.eval() # teacher model (eval mode)
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)
            toutputs = tmodel(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0], toutputs) # Loss
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        tmodel.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 
            toutputs = tmodel(inputs, only_encode=enc)

            loss = criterion(outputs, targets[:, 0], toutputs)
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Teacher Model
    tweightspath = args.tloadDir + args.tloadWeights
    tmodel = TNet(NUM_CLASSES)

    #Load Model
    model = Net(NUM_CLASSES)
    
    if args.cuda:
        tmodel = torch.nn.DataParallel(tmodel).cuda()
        model = torch.nn.DataParallel(model).cuda()

    def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict elements
        own_state = model.state_dict()
        for name, param in state_dict.items():
            if name not in own_state:
                 continue
            own_state[name].copy_(param)
        return model

    tmodel = load_my_state_dict(tmodel, torch.load(tweightspath))
    print ("Teacher Model and weights LOADED successfully")

    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        model = load_my_state_dict(model, torch.load(args.state))


    # train(args, tmodel, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, tmodel, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, tmodel, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--tloadDir',default="/content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/")
    parser.add_argument('--tloadWeights', default="model_best.pth")

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=60)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=3)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# Teacher Model and weights LOADED successfully
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.MainLoss'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.494 (epoch: 1, step: 0) // Avg time/img: 2.3601 s
# loss: 1.566 (epoch: 1, step: 50) // Avg time/img: 0.1712 s
# loss: 1.406 (epoch: 1, step: 100) // Avg time/img: 0.1512 s
# loss: 1.312 (epoch: 1, step: 150) // Avg time/img: 0.1459 s
# loss: 1.258 (epoch: 1, step: 200) // Avg time/img: 0.1431 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 3.254 (epoch: 1, step: 0) // Avg time/img: 0.0571 s
# VAL loss: 1.836 (epoch: 1, step: 50) // Avg time/img: 0.0434 s
# VAL loss: 1.736 (epoch: 1, step: 100) // Avg time/img: 0.0421 s
# VAL loss: 1.583 (epoch: 1, step: 150) // Avg time/img: 0.0415 s
# EPOCH IoU on VAL set:  13.68 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 1.072 (epoch: 2, step: 0) // Avg time/img: 0.1682 s
# loss: 1.012 (epoch: 2, step: 50) // Avg time/img: 0.1377 s
# loss: 1.004 (epoch: 2, step: 100) // Avg time/img: 0.1363 s
# loss: 0.9902 (epoch: 2, step: 150) // Avg time/img: 0.1356 s
# loss: 0.9843 (epoch: 2, step: 200) // Avg time/img: 0.1352 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.106 (epoch: 2, step: 0) // Avg time/img: 0.0433 s
# VAL loss: 1.092 (epoch: 2, step: 50) // Avg time/img: 0.0468 s
# VAL loss: 1.063 (epoch: 2, step: 100) // Avg time/img: 0.0470 s
# VAL loss: 1.001 (epoch: 2, step: 150) // Avg time/img: 0.0470 s
# EPOCH IoU on VAL set:  20.02 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.9611 (epoch: 3, step: 0) // Avg time/img: 0.1600 s
# loss: 0.9132 (epoch: 3, step: 50) // Avg time/img: 0.1363 s
# loss: 0.9104 (epoch: 3, step: 100) // Avg time/img: 0.1357 s
# loss: 0.9106 (epoch: 3, step: 150) // Avg time/img: 0.1350 s
# loss: 0.9032 (epoch: 3, step: 200) // Avg time/img: 0.1348 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 1.044 (epoch: 3, step: 0) // Avg time/img: 0.0593 s
# VAL loss: 1.015 (epoch: 3, step: 50) // Avg time/img: 0.0471 s
# VAL loss: 1.01 (epoch: 3, step: 100) // Avg time/img: 0.0469 s
# VAL loss: 0.9505 (epoch: 3, step: 150) // Avg time/img: 0.0469 s
# EPOCH IoU on VAL set:  21.92 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 0.8816 (epoch: 4, step: 0) // Avg time/img: 0.1550 s
# loss: 0.8755 (epoch: 4, step: 50) // Avg time/img: 0.1373 s
# loss: 0.8705 (epoch: 4, step: 100) // Avg time/img: 0.1362 s
# loss: 0.8678 (epoch: 4, step: 150) // Avg time/img: 0.1356 s
# loss: 0.8574 (epoch: 4, step: 200) // Avg time/img: 0.1354 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 0.8054 (epoch: 4, step: 0) // Avg time/img: 0.0460 s
# VAL loss: 0.9718 (epoch: 4, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.976 (epoch: 4, step: 100) // Avg time/img: 0.0476 s
# VAL loss: 0.9198 (epoch: 4, step: 150) // Avg time/img: 0.0470 s
# EPOCH IoU on VAL set:  23.78 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.8122 (epoch: 5, step: 0) // Avg time/img: 0.1538 s
# loss: 0.8549 (epoch: 5, step: 50) // Avg time/img: 0.1380 s
# loss: 0.8346 (epoch: 5, step: 100) // Avg time/img: 0.1361 s
# loss: 0.8269 (epoch: 5, step: 150) // Avg time/img: 0.1354 s
# loss: 0.8218 (epoch: 5, step: 200) // Avg time/img: 0.1352 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 1.01 (epoch: 5, step: 0) // Avg time/img: 0.0463 s
# VAL loss: 1.025 (epoch: 5, step: 50) // Avg time/img: 0.0458 s
# VAL loss: 1.035 (epoch: 5, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.9643 (epoch: 5, step: 150) // Avg time/img: 0.0458 s
# EPOCH IoU on VAL set:  22.82 %
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004623387553722673
# loss: 0.7399 (epoch: 6, step: 0) // Avg time/img: 0.1416 s
# loss: 0.8013 (epoch: 6, step: 50) // Avg time/img: 0.1366 s
# loss: 0.8036 (epoch: 6, step: 100) // Avg time/img: 0.1354 s
# loss: 0.8049 (epoch: 6, step: 150) // Avg time/img: 0.1350 s
# loss: 0.8029 (epoch: 6, step: 200) // Avg time/img: 0.1348 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 0.9329 (epoch: 6, step: 0) // Avg time/img: 0.0441 s
# VAL loss: 0.9481 (epoch: 6, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.9294 (epoch: 6, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.8727 (epoch: 6, step: 150) // Avg time/img: 0.0458 s
# EPOCH IoU on VAL set:  27.19 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.6384 (epoch: 7, step: 0) // Avg time/img: 0.1363 s
# loss: 0.7792 (epoch: 7, step: 50) // Avg time/img: 0.1491 s
# loss: 0.7915 (epoch: 7, step: 100) // Avg time/img: 0.1420 s
# loss: 0.7863 (epoch: 7, step: 150) // Avg time/img: 0.1395 s
# loss: 0.7851 (epoch: 7, step: 200) // Avg time/img: 0.1382 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 0.9802 (epoch: 7, step: 0) // Avg time/img: 0.0443 s
# VAL loss: 0.9882 (epoch: 7, step: 50) // Avg time/img: 0.0448 s
# VAL loss: 0.9713 (epoch: 7, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.9107 (epoch: 7, step: 150) // Avg time/img: 0.0451 s
# EPOCH IoU on VAL set:  25.68 %
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.00044717978378742816
# loss: 0.8079 (epoch: 8, step: 0) // Avg time/img: 0.1352 s
# loss: 0.76 (epoch: 8, step: 50) // Avg time/img: 0.1363 s
# loss: 0.7616 (epoch: 8, step: 100) // Avg time/img: 0.1355 s
# loss: 0.7556 (epoch: 8, step: 150) // Avg time/img: 0.1350 s
# loss: 0.7581 (epoch: 8, step: 200) // Avg time/img: 0.1347 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 0.9929 (epoch: 8, step: 0) // Avg time/img: 0.0443 s
# VAL loss: 0.9379 (epoch: 8, step: 50) // Avg time/img: 0.0464 s
# VAL loss: 0.9281 (epoch: 8, step: 100) // Avg time/img: 0.0458 s
# VAL loss: 0.8728 (epoch: 8, step: 150) // Avg time/img: 0.0457 s
# EPOCH IoU on VAL set:  27.16 %
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.7007 (epoch: 9, step: 0) // Avg time/img: 0.1420 s
# loss: 0.7475 (epoch: 9, step: 50) // Avg time/img: 0.1368 s
# loss: 0.7543 (epoch: 9, step: 100) // Avg time/img: 0.1355 s
# loss: 0.7584 (epoch: 9, step: 150) // Avg time/img: 0.1373 s
# loss: 0.7591 (epoch: 9, step: 200) // Avg time/img: 0.1364 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 0.8301 (epoch: 9, step: 0) // Avg time/img: 0.0401 s
# VAL loss: 0.9109 (epoch: 9, step: 50) // Avg time/img: 0.0456 s
# VAL loss: 0.9012 (epoch: 9, step: 100) // Avg time/img: 0.0455 s
# VAL loss: 0.8497 (epoch: 9, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  28.69 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 9)
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.00043196348615140955
# loss: 0.7754 (epoch: 10, step: 0) // Avg time/img: 0.1606 s
# loss: 0.7308 (epoch: 10, step: 50) // Avg time/img: 0.1360 s
# loss: 0.7359 (epoch: 10, step: 100) // Avg time/img: 0.1362 s
# loss: 0.7377 (epoch: 10, step: 150) // Avg time/img: 0.1353 s
# loss: 0.7357 (epoch: 10, step: 200) // Avg time/img: 0.1350 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 0.9777 (epoch: 10, step: 0) // Avg time/img: 0.0455 s
# VAL loss: 0.9419 (epoch: 10, step: 50) // Avg time/img: 0.0445 s
# VAL loss: 0.9188 (epoch: 10, step: 100) // Avg time/img: 0.0449 s
# VAL loss: 0.8659 (epoch: 10, step: 150) // Avg time/img: 0.0451 s
# EPOCH IoU on VAL set:  29.46 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 10)
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.7452 (epoch: 11, step: 0) // Avg time/img: 0.1623 s
# loss: 0.7182 (epoch: 11, step: 50) // Avg time/img: 0.1370 s
# loss: 0.7327 (epoch: 11, step: 100) // Avg time/img: 0.1356 s
# loss: 0.7271 (epoch: 11, step: 150) // Avg time/img: 0.1349 s
# loss: 0.7248 (epoch: 11, step: 200) // Avg time/img: 0.1346 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.823 (epoch: 11, step: 0) // Avg time/img: 0.0486 s
# VAL loss: 0.8963 (epoch: 11, step: 50) // Avg time/img: 0.0464 s
# VAL loss: 0.8994 (epoch: 11, step: 100) // Avg time/img: 0.0458 s
# VAL loss: 0.8544 (epoch: 11, step: 150) // Avg time/img: 0.0455 s
# EPOCH IoU on VAL set:  29.17 %
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.0004166873834706844
# loss: 0.7658 (epoch: 12, step: 0) // Avg time/img: 0.1457 s
# loss: 0.7056 (epoch: 12, step: 50) // Avg time/img: 0.1364 s
# loss: 0.7101 (epoch: 12, step: 100) // Avg time/img: 0.1354 s
# loss: 0.7192 (epoch: 12, step: 150) // Avg time/img: 0.1346 s
# loss: 0.7167 (epoch: 12, step: 200) // Avg time/img: 0.1345 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.8256 (epoch: 12, step: 0) // Avg time/img: 0.0444 s
# VAL loss: 0.8997 (epoch: 12, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.8791 (epoch: 12, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.825 (epoch: 12, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  31.12 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 12)
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.6812 (epoch: 13, step: 0) // Avg time/img: 0.1519 s
# loss: 0.7 (epoch: 13, step: 50) // Avg time/img: 0.1365 s
# loss: 0.7097 (epoch: 13, step: 100) // Avg time/img: 0.1354 s
# loss: 0.7092 (epoch: 13, step: 150) // Avg time/img: 0.1347 s
# loss: 0.7113 (epoch: 13, step: 200) // Avg time/img: 0.1344 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 0.8335 (epoch: 13, step: 0) // Avg time/img: 0.0468 s
# VAL loss: 0.9008 (epoch: 13, step: 50) // Avg time/img: 0.0457 s
# VAL loss: 0.8843 (epoch: 13, step: 100) // Avg time/img: 0.0454 s
# VAL loss: 0.8346 (epoch: 13, step: 150) // Avg time/img: 0.0454 s
# EPOCH IoU on VAL set:  30.89 %
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.0004013487836640184
# loss: 0.6934 (epoch: 14, step: 0) // Avg time/img: 0.1441 s
# loss: 0.7218 (epoch: 14, step: 50) // Avg time/img: 0.1360 s
# loss: 0.709 (epoch: 14, step: 100) // Avg time/img: 0.1349 s
# loss: 0.7161 (epoch: 14, step: 150) // Avg time/img: 0.1371 s
# loss: 0.7116 (epoch: 14, step: 200) // Avg time/img: 0.1370 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 1.08 (epoch: 14, step: 0) // Avg time/img: 0.0492 s
# VAL loss: 1.009 (epoch: 14, step: 50) // Avg time/img: 0.0450 s
# VAL loss: 0.9813 (epoch: 14, step: 100) // Avg time/img: 0.0452 s
# VAL loss: 0.9058 (epoch: 14, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  29.77 %
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.7387 (epoch: 15, step: 0) // Avg time/img: 0.1401 s
# loss: 0.696 (epoch: 15, step: 50) // Avg time/img: 0.1372 s
# loss: 0.7104 (epoch: 15, step: 100) // Avg time/img: 0.1357 s
# loss: 0.7053 (epoch: 15, step: 150) // Avg time/img: 0.1350 s
# loss: 0.7037 (epoch: 15, step: 200) // Avg time/img: 0.1346 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 0.8604 (epoch: 15, step: 0) // Avg time/img: 0.0518 s
# VAL loss: 0.8889 (epoch: 15, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.864 (epoch: 15, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.8113 (epoch: 15, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  31.72 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 15)
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00038594475336178527
# loss: 0.6282 (epoch: 16, step: 0) // Avg time/img: 0.1560 s
# loss: 0.6927 (epoch: 16, step: 50) // Avg time/img: 0.1360 s
# loss: 0.6813 (epoch: 16, step: 100) // Avg time/img: 0.1349 s
# loss: 0.688 (epoch: 16, step: 150) // Avg time/img: 0.1344 s
# loss: 0.6882 (epoch: 16, step: 200) // Avg time/img: 0.1342 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.7417 (epoch: 16, step: 0) // Avg time/img: 0.0445 s
# VAL loss: 0.8744 (epoch: 16, step: 50) // Avg time/img: 0.0450 s
# VAL loss: 0.8613 (epoch: 16, step: 100) // Avg time/img: 0.0448 s
# VAL loss: 0.8142 (epoch: 16, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  31.85 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 16)
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.7178 (epoch: 17, step: 0) // Avg time/img: 0.1638 s
# loss: 0.6814 (epoch: 17, step: 50) // Avg time/img: 0.1362 s
# loss: 0.6881 (epoch: 17, step: 100) // Avg time/img: 0.1350 s
# loss: 0.691 (epoch: 17, step: 150) // Avg time/img: 0.1376 s
# loss: 0.6867 (epoch: 17, step: 200) // Avg time/img: 0.1366 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.6873 (epoch: 17, step: 0) // Avg time/img: 0.0459 s
# VAL loss: 0.8671 (epoch: 17, step: 50) // Avg time/img: 0.0457 s
# VAL loss: 0.8606 (epoch: 17, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.8196 (epoch: 17, step: 150) // Avg time/img: 0.0457 s
# EPOCH IoU on VAL set:  33.75 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 17)
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.00037047208454744316
# loss: 0.7017 (epoch: 18, step: 0) // Avg time/img: 0.1453 s
# loss: 0.6876 (epoch: 18, step: 50) // Avg time/img: 0.1360 s
# loss: 0.6777 (epoch: 18, step: 100) // Avg time/img: 0.1348 s
# loss: 0.6754 (epoch: 18, step: 150) // Avg time/img: 0.1343 s
# loss: 0.6754 (epoch: 18, step: 200) // Avg time/img: 0.1340 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.7517 (epoch: 18, step: 0) // Avg time/img: 0.0491 s
# VAL loss: 0.8533 (epoch: 18, step: 50) // Avg time/img: 0.0449 s
# VAL loss: 0.8313 (epoch: 18, step: 100) // Avg time/img: 0.0452 s
# VAL loss: 0.7879 (epoch: 18, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  35.35 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 18)
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.6443 (epoch: 19, step: 0) // Avg time/img: 0.1536 s
# loss: 0.6685 (epoch: 19, step: 50) // Avg time/img: 0.1388 s
# loss: 0.6725 (epoch: 19, step: 100) // Avg time/img: 0.1363 s
# loss: 0.6756 (epoch: 19, step: 150) // Avg time/img: 0.1352 s
# loss: 0.676 (epoch: 19, step: 200) // Avg time/img: 0.1348 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.9378 (epoch: 19, step: 0) // Avg time/img: 0.0451 s
# VAL loss: 0.8739 (epoch: 19, step: 50) // Avg time/img: 0.0455 s
# VAL loss: 0.8602 (epoch: 19, step: 100) // Avg time/img: 0.0454 s
# VAL loss: 0.8107 (epoch: 19, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  34.05 %
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.0003549272548125162
# loss: 0.6807 (epoch: 20, step: 0) // Avg time/img: 0.1431 s
# loss: 0.6617 (epoch: 20, step: 50) // Avg time/img: 0.1361 s
# loss: 0.662 (epoch: 20, step: 100) // Avg time/img: 0.1354 s
# loss: 0.66 (epoch: 20, step: 150) // Avg time/img: 0.1346 s
# loss: 0.6619 (epoch: 20, step: 200) // Avg time/img: 0.1345 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.7348 (epoch: 20, step: 0) // Avg time/img: 0.0529 s
# VAL loss: 0.8862 (epoch: 20, step: 50) // Avg time/img: 0.0456 s
# VAL loss: 0.8545 (epoch: 20, step: 100) // Avg time/img: 0.0454 s
# VAL loss: 0.8037 (epoch: 20, step: 150) // Avg time/img: 0.0455 s
# EPOCH IoU on VAL set:  34.06 %
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.5732 (epoch: 21, step: 0) // Avg time/img: 0.1408 s
# loss: 0.6686 (epoch: 21, step: 50) // Avg time/img: 0.1358 s
# loss: 0.6603 (epoch: 21, step: 100) // Avg time/img: 0.1350 s
# loss: 0.6553 (epoch: 21, step: 150) // Avg time/img: 0.1345 s
# loss: 0.6606 (epoch: 21, step: 200) // Avg time/img: 0.1342 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.7935 (epoch: 21, step: 0) // Avg time/img: 0.0467 s
# VAL loss: 0.8736 (epoch: 21, step: 50) // Avg time/img: 0.0477 s
# VAL loss: 0.8557 (epoch: 21, step: 100) // Avg time/img: 0.0477 s
# VAL loss: 0.8053 (epoch: 21, step: 150) // Avg time/img: 0.0470 s
# EPOCH IoU on VAL set:  34.58 %
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.0003393063796290625
# loss: 0.6402 (epoch: 22, step: 0) // Avg time/img: 0.1722 s
# loss: 0.6609 (epoch: 22, step: 50) // Avg time/img: 0.1359 s
# loss: 0.6584 (epoch: 22, step: 100) // Avg time/img: 0.1348 s
# loss: 0.6639 (epoch: 22, step: 150) // Avg time/img: 0.1343 s
# loss: 0.6614 (epoch: 22, step: 200) // Avg time/img: 0.1341 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.7265 (epoch: 22, step: 0) // Avg time/img: 0.0420 s
# VAL loss: 0.8601 (epoch: 22, step: 50) // Avg time/img: 0.0446 s
# VAL loss: 0.8298 (epoch: 22, step: 100) // Avg time/img: 0.0449 s
# VAL loss: 0.7848 (epoch: 22, step: 150) // Avg time/img: 0.0451 s
# EPOCH IoU on VAL set:  36.46 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 22)
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.6119 (epoch: 23, step: 0) // Avg time/img: 0.1580 s
# loss: 0.6743 (epoch: 23, step: 50) // Avg time/img: 0.1361 s
# loss: 0.6678 (epoch: 23, step: 100) // Avg time/img: 0.1350 s
# loss: 0.6629 (epoch: 23, step: 150) // Avg time/img: 0.1353 s
# loss: 0.6599 (epoch: 23, step: 200) // Avg time/img: 0.1347 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.91 (epoch: 23, step: 0) // Avg time/img: 0.0486 s
# VAL loss: 0.912 (epoch: 23, step: 50) // Avg time/img: 0.0454 s
# VAL loss: 0.8893 (epoch: 23, step: 100) // Avg time/img: 0.0464 s
# VAL loss: 0.8307 (epoch: 23, step: 150) // Avg time/img: 0.0466 s
# EPOCH IoU on VAL set:  35.32 %
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.0003236051545417615
# loss: 0.5977 (epoch: 24, step: 0) // Avg time/img: 0.1464 s
# loss: 0.6527 (epoch: 24, step: 50) // Avg time/img: 0.1363 s
# loss: 0.6452 (epoch: 24, step: 100) // Avg time/img: 0.1352 s
# loss: 0.6487 (epoch: 24, step: 150) // Avg time/img: 0.1346 s
# loss: 0.6519 (epoch: 24, step: 200) // Avg time/img: 0.1342 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 0.6921 (epoch: 24, step: 0) // Avg time/img: 0.0476 s
# VAL loss: 0.8112 (epoch: 24, step: 50) // Avg time/img: 0.0456 s
# VAL loss: 0.819 (epoch: 24, step: 100) // Avg time/img: 0.0463 s
# VAL loss: 0.781 (epoch: 24, step: 150) // Avg time/img: 0.0458 s
# EPOCH IoU on VAL set:  36.96 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 24)
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.7609 (epoch: 25, step: 0) // Avg time/img: 0.1405 s
# loss: 0.6534 (epoch: 25, step: 50) // Avg time/img: 0.1356 s
# loss: 0.6495 (epoch: 25, step: 100) // Avg time/img: 0.1347 s
# loss: 0.6455 (epoch: 25, step: 150) // Avg time/img: 0.1350 s
# loss: 0.6526 (epoch: 25, step: 200) // Avg time/img: 0.1345 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.6474 (epoch: 25, step: 0) // Avg time/img: 0.0460 s
# VAL loss: 0.8075 (epoch: 25, step: 50) // Avg time/img: 0.0459 s
# VAL loss: 0.8016 (epoch: 25, step: 100) // Avg time/img: 0.0454 s
# VAL loss: 0.7668 (epoch: 25, step: 150) // Avg time/img: 0.0456 s
# EPOCH IoU on VAL set:  36.36 %
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00030781878448615926
# loss: 0.5894 (epoch: 26, step: 0) // Avg time/img: 0.1685 s
# loss: 0.6404 (epoch: 26, step: 50) // Avg time/img: 0.1370 s
# loss: 0.6439 (epoch: 26, step: 100) // Avg time/img: 0.1365 s
# loss: 0.6462 (epoch: 26, step: 150) // Avg time/img: 0.1355 s
# loss: 0.6449 (epoch: 26, step: 200) // Avg time/img: 0.1348 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.7242 (epoch: 26, step: 0) // Avg time/img: 0.0469 s
# VAL loss: 0.8139 (epoch: 26, step: 50) // Avg time/img: 0.0463 s
# VAL loss: 0.8105 (epoch: 26, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.7724 (epoch: 26, step: 150) // Avg time/img: 0.0455 s
# EPOCH IoU on VAL set:  37.34 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 26)
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.6462 (epoch: 27, step: 0) // Avg time/img: 0.1564 s
# loss: 0.6343 (epoch: 27, step: 50) // Avg time/img: 0.1358 s
# loss: 0.6393 (epoch: 27, step: 100) // Avg time/img: 0.1347 s
# loss: 0.6411 (epoch: 27, step: 150) // Avg time/img: 0.1342 s
# loss: 0.638 (epoch: 27, step: 200) // Avg time/img: 0.1340 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.7007 (epoch: 27, step: 0) // Avg time/img: 0.0470 s
# VAL loss: 0.8717 (epoch: 27, step: 50) // Avg time/img: 0.0462 s
# VAL loss: 0.8775 (epoch: 27, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.8308 (epoch: 27, step: 150) // Avg time/img: 0.0468 s
# EPOCH IoU on VAL set:  35.45 %
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00029194189645999016
# loss: 0.7817 (epoch: 28, step: 0) // Avg time/img: 0.1421 s
# loss: 0.6512 (epoch: 28, step: 50) // Avg time/img: 0.1358 s
# loss: 0.648 (epoch: 28, step: 100) // Avg time/img: 0.1361 s
# loss: 0.6454 (epoch: 28, step: 150) // Avg time/img: 0.1351 s
# loss: 0.6417 (epoch: 28, step: 200) // Avg time/img: 0.1347 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.7444 (epoch: 28, step: 0) // Avg time/img: 0.0540 s
# VAL loss: 0.8908 (epoch: 28, step: 50) // Avg time/img: 0.0454 s
# VAL loss: 0.8544 (epoch: 28, step: 100) // Avg time/img: 0.0452 s
# VAL loss: 0.7996 (epoch: 28, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  36.53 %
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.6561 (epoch: 29, step: 0) // Avg time/img: 0.1417 s
# loss: 0.6411 (epoch: 29, step: 50) // Avg time/img: 0.1363 s
# loss: 0.6428 (epoch: 29, step: 100) // Avg time/img: 0.1360 s
# loss: 0.64 (epoch: 29, step: 150) // Avg time/img: 0.1350 s
# loss: 0.6376 (epoch: 29, step: 200) // Avg time/img: 0.1345 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.7146 (epoch: 29, step: 0) // Avg time/img: 0.0586 s
# VAL loss: 0.8207 (epoch: 29, step: 50) // Avg time/img: 0.0460 s
# VAL loss: 0.8334 (epoch: 29, step: 100) // Avg time/img: 0.0453 s
# VAL loss: 0.7889 (epoch: 29, step: 150) // Avg time/img: 0.0460 s
# EPOCH IoU on VAL set:  37.45 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 29)
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.0002759684303703797
# loss: 0.6638 (epoch: 30, step: 0) // Avg time/img: 0.1657 s
# loss: 0.6362 (epoch: 30, step: 50) // Avg time/img: 0.1364 s
# loss: 0.6325 (epoch: 30, step: 100) // Avg time/img: 0.1350 s
# loss: 0.6325 (epoch: 30, step: 150) // Avg time/img: 0.1342 s
# loss: 0.6276 (epoch: 30, step: 200) // Avg time/img: 0.1339 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.7427 (epoch: 30, step: 0) // Avg time/img: 0.0597 s
# VAL loss: 0.7977 (epoch: 30, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.7891 (epoch: 30, step: 100) // Avg time/img: 0.0450 s
# VAL loss: 0.7563 (epoch: 30, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  39.19 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 30)
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.6218 (epoch: 31, step: 0) // Avg time/img: 0.1587 s
# loss: 0.6414 (epoch: 31, step: 50) // Avg time/img: 0.1392 s
# loss: 0.6323 (epoch: 31, step: 100) // Avg time/img: 0.1364 s
# loss: 0.6295 (epoch: 31, step: 150) // Avg time/img: 0.1354 s
# loss: 0.6278 (epoch: 31, step: 200) // Avg time/img: 0.1350 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.7159 (epoch: 31, step: 0) // Avg time/img: 0.0463 s
# VAL loss: 0.8141 (epoch: 31, step: 50) // Avg time/img: 0.0455 s
# VAL loss: 0.8035 (epoch: 31, step: 100) // Avg time/img: 0.0454 s
# VAL loss: 0.7614 (epoch: 31, step: 150) // Avg time/img: 0.0454 s
# EPOCH IoU on VAL set:  38.91 %
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.0002598915008274931
# loss: 0.6213 (epoch: 32, step: 0) // Avg time/img: 0.1422 s
# loss: 0.62 (epoch: 32, step: 50) // Avg time/img: 0.1449 s
# loss: 0.6158 (epoch: 32, step: 100) // Avg time/img: 0.1395 s
# loss: 0.6188 (epoch: 32, step: 150) // Avg time/img: 0.1374 s
# loss: 0.6214 (epoch: 32, step: 200) // Avg time/img: 0.1370 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.738 (epoch: 32, step: 0) // Avg time/img: 0.0518 s
# VAL loss: 0.8147 (epoch: 32, step: 50) // Avg time/img: 0.0454 s
# VAL loss: 0.8189 (epoch: 32, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.773 (epoch: 32, step: 150) // Avg time/img: 0.0454 s
# EPOCH IoU on VAL set:  38.87 %
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.6127 (epoch: 33, step: 0) // Avg time/img: 0.1386 s
# loss: 0.6131 (epoch: 33, step: 50) // Avg time/img: 0.1355 s
# loss: 0.6171 (epoch: 33, step: 100) // Avg time/img: 0.1349 s
# loss: 0.6161 (epoch: 33, step: 150) // Avg time/img: 0.1343 s
# loss: 0.6168 (epoch: 33, step: 200) // Avg time/img: 0.1341 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.8692 (epoch: 33, step: 0) // Avg time/img: 0.0399 s
# VAL loss: 0.9042 (epoch: 33, step: 50) // Avg time/img: 0.0465 s
# VAL loss: 0.9012 (epoch: 33, step: 100) // Avg time/img: 0.0458 s
# VAL loss: 0.8359 (epoch: 33, step: 150) // Avg time/img: 0.0456 s
# EPOCH IoU on VAL set:  36.58 %
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.00024370321958949772
# loss: 0.5871 (epoch: 34, step: 0) // Avg time/img: 0.1408 s
# loss: 0.6187 (epoch: 34, step: 50) // Avg time/img: 0.1385 s
# loss: 0.6205 (epoch: 34, step: 100) // Avg time/img: 0.1368 s
# loss: 0.6211 (epoch: 34, step: 150) // Avg time/img: 0.1375 s
# loss: 0.6228 (epoch: 34, step: 200) // Avg time/img: 0.1364 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.688 (epoch: 34, step: 0) // Avg time/img: 0.0432 s
# VAL loss: 0.8068 (epoch: 34, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.8118 (epoch: 34, step: 100) // Avg time/img: 0.0453 s
# VAL loss: 0.7725 (epoch: 34, step: 150) // Avg time/img: 0.0451 s
# EPOCH IoU on VAL set:  38.55 %
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.603 (epoch: 35, step: 0) // Avg time/img: 0.1382 s
# loss: 0.6194 (epoch: 35, step: 50) // Avg time/img: 0.1363 s
# loss: 0.6159 (epoch: 35, step: 100) // Avg time/img: 0.1364 s
# loss: 0.6157 (epoch: 35, step: 150) // Avg time/img: 0.1354 s
# loss: 0.617 (epoch: 35, step: 200) // Avg time/img: 0.1355 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.8024 (epoch: 35, step: 0) // Avg time/img: 0.0488 s
# VAL loss: 0.8267 (epoch: 35, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.8353 (epoch: 35, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.7938 (epoch: 35, step: 150) // Avg time/img: 0.0454 s
# EPOCH IoU on VAL set:  38.88 %
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.00022739446367039517
# loss: 0.6405 (epoch: 36, step: 0) // Avg time/img: 0.1397 s
# loss: 0.6147 (epoch: 36, step: 50) // Avg time/img: 0.1358 s
# loss: 0.6161 (epoch: 36, step: 100) // Avg time/img: 0.1348 s
# loss: 0.6196 (epoch: 36, step: 150) // Avg time/img: 0.1364 s
# loss: 0.6172 (epoch: 36, step: 200) // Avg time/img: 0.1356 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.6985 (epoch: 36, step: 0) // Avg time/img: 0.0438 s
# VAL loss: 0.818 (epoch: 36, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.8051 (epoch: 36, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.7619 (epoch: 36, step: 150) // Avg time/img: 0.0459 s
# EPOCH IoU on VAL set:  38.77 %
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.5954 (epoch: 37, step: 0) // Avg time/img: 0.1398 s
# loss: 0.6108 (epoch: 37, step: 50) // Avg time/img: 0.1356 s
# loss: 0.6154 (epoch: 37, step: 100) // Avg time/img: 0.1346 s
# loss: 0.6154 (epoch: 37, step: 150) // Avg time/img: 0.1343 s
# loss: 0.6138 (epoch: 37, step: 200) // Avg time/img: 0.1340 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.6951 (epoch: 37, step: 0) // Avg time/img: 0.0456 s
# VAL loss: 0.8024 (epoch: 37, step: 50) // Avg time/img: 0.0446 s
# VAL loss: 0.7886 (epoch: 37, step: 100) // Avg time/img: 0.0449 s
# VAL loss: 0.7476 (epoch: 37, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  40.73 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 37)
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.00021095456673472888
# loss: 0.6136 (epoch: 38, step: 0) // Avg time/img: 0.1577 s
# loss: 0.6179 (epoch: 38, step: 50) // Avg time/img: 0.1363 s
# loss: 0.6119 (epoch: 38, step: 100) // Avg time/img: 0.1362 s
# loss: 0.6071 (epoch: 38, step: 150) // Avg time/img: 0.1356 s
# loss: 0.607 (epoch: 38, step: 200) // Avg time/img: 0.1372 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.7256 (epoch: 38, step: 0) // Avg time/img: 0.0505 s
# VAL loss: 0.8187 (epoch: 38, step: 50) // Avg time/img: 0.0455 s
# VAL loss: 0.8122 (epoch: 38, step: 100) // Avg time/img: 0.0452 s
# VAL loss: 0.7699 (epoch: 38, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  39.71 %
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.6459 (epoch: 39, step: 0) // Avg time/img: 0.1420 s
# loss: 0.6061 (epoch: 39, step: 50) // Avg time/img: 0.1350 s
# loss: 0.6074 (epoch: 39, step: 100) // Avg time/img: 0.1344 s
# loss: 0.6071 (epoch: 39, step: 150) // Avg time/img: 0.1341 s
# loss: 0.6065 (epoch: 39, step: 200) // Avg time/img: 0.1339 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.7009 (epoch: 39, step: 0) // Avg time/img: 0.0522 s
# VAL loss: 0.7809 (epoch: 39, step: 50) // Avg time/img: 0.0450 s
# VAL loss: 0.7863 (epoch: 39, step: 100) // Avg time/img: 0.0454 s
# VAL loss: 0.7512 (epoch: 39, step: 150) // Avg time/img: 0.0455 s
# EPOCH IoU on VAL set:  41.66 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 39)
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.5969 (epoch: 40, step: 0) // Avg time/img: 0.1457 s
# loss: 0.6074 (epoch: 40, step: 50) // Avg time/img: 0.1360 s
# loss: 0.6033 (epoch: 40, step: 100) // Avg time/img: 0.1349 s
# loss: 0.6008 (epoch: 40, step: 150) // Avg time/img: 0.1342 s
# loss: 0.5981 (epoch: 40, step: 200) // Avg time/img: 0.1352 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.6899 (epoch: 40, step: 0) // Avg time/img: 0.0480 s
# VAL loss: 0.7928 (epoch: 40, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.7876 (epoch: 40, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.7463 (epoch: 40, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  42.13 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 40)
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.5832 (epoch: 41, step: 0) // Avg time/img: 0.1625 s
# loss: 0.5971 (epoch: 41, step: 50) // Avg time/img: 0.1397 s
# loss: 0.5928 (epoch: 41, step: 100) // Avg time/img: 0.1379 s
# loss: 0.594 (epoch: 41, step: 150) // Avg time/img: 0.1363 s
# loss: 0.5983 (epoch: 41, step: 200) // Avg time/img: 0.1354 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.6712 (epoch: 41, step: 0) // Avg time/img: 0.0489 s
# VAL loss: 0.8793 (epoch: 41, step: 50) // Avg time/img: 0.0449 s
# VAL loss: 0.856 (epoch: 41, step: 100) // Avg time/img: 0.0448 s
# VAL loss: 0.8015 (epoch: 41, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  41.72 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.5646 (epoch: 42, step: 0) // Avg time/img: 0.1412 s
# loss: 0.6017 (epoch: 42, step: 50) // Avg time/img: 0.1357 s
# loss: 0.601 (epoch: 42, step: 100) // Avg time/img: 0.1345 s
# loss: 0.6009 (epoch: 42, step: 150) // Avg time/img: 0.1341 s
# loss: 0.6008 (epoch: 42, step: 200) // Avg time/img: 0.1355 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.6318 (epoch: 42, step: 0) // Avg time/img: 0.0390 s
# VAL loss: 0.7612 (epoch: 42, step: 50) // Avg time/img: 0.0446 s
# VAL loss: 0.7514 (epoch: 42, step: 100) // Avg time/img: 0.0449 s
# VAL loss: 0.7171 (epoch: 42, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  43.46 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 42)
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.67 (epoch: 43, step: 0) // Avg time/img: 0.1587 s
# loss: 0.5991 (epoch: 43, step: 50) // Avg time/img: 0.1363 s
# loss: 0.5967 (epoch: 43, step: 100) // Avg time/img: 0.1350 s
# loss: 0.595 (epoch: 43, step: 150) // Avg time/img: 0.1343 s
# loss: 0.596 (epoch: 43, step: 200) // Avg time/img: 0.1339 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.6608 (epoch: 43, step: 0) // Avg time/img: 0.0495 s
# VAL loss: 0.7975 (epoch: 43, step: 50) // Avg time/img: 0.0454 s
# VAL loss: 0.8055 (epoch: 43, step: 100) // Avg time/img: 0.0458 s
# VAL loss: 0.7664 (epoch: 43, step: 150) // Avg time/img: 0.0459 s
# EPOCH IoU on VAL set:  41.73 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.6128 (epoch: 44, step: 0) // Avg time/img: 0.1366 s
# loss: 0.5869 (epoch: 44, step: 50) // Avg time/img: 0.1356 s
# loss: 0.5858 (epoch: 44, step: 100) // Avg time/img: 0.1347 s
# loss: 0.5883 (epoch: 44, step: 150) // Avg time/img: 0.1342 s
# loss: 0.5912 (epoch: 44, step: 200) // Avg time/img: 0.1338 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.7481 (epoch: 44, step: 0) // Avg time/img: 0.0460 s
# VAL loss: 0.7833 (epoch: 44, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.7829 (epoch: 44, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.7421 (epoch: 44, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  41.69 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.5851 (epoch: 45, step: 0) // Avg time/img: 0.1382 s
# loss: 0.6109 (epoch: 45, step: 50) // Avg time/img: 0.1377 s
# loss: 0.6038 (epoch: 45, step: 100) // Avg time/img: 0.1403 s
# loss: 0.5998 (epoch: 45, step: 150) // Avg time/img: 0.1380 s
# loss: 0.5967 (epoch: 45, step: 200) // Avg time/img: 0.1368 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.6876 (epoch: 45, step: 0) // Avg time/img: 0.0565 s
# VAL loss: 0.7767 (epoch: 45, step: 50) // Avg time/img: 0.0457 s
# VAL loss: 0.7843 (epoch: 45, step: 100) // Avg time/img: 0.0455 s
# VAL loss: 0.7484 (epoch: 45, step: 150) // Avg time/img: 0.0456 s
# EPOCH IoU on VAL set:  42.07 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.5545 (epoch: 46, step: 0) // Avg time/img: 0.1407 s
# loss: 0.5847 (epoch: 46, step: 50) // Avg time/img: 0.1352 s
# loss: 0.5858 (epoch: 46, step: 100) // Avg time/img: 0.1347 s
# loss: 0.5879 (epoch: 46, step: 150) // Avg time/img: 0.1343 s
# loss: 0.5883 (epoch: 46, step: 200) // Avg time/img: 0.1348 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.7357 (epoch: 46, step: 0) // Avg time/img: 0.0481 s
# VAL loss: 0.7661 (epoch: 46, step: 50) // Avg time/img: 0.0454 s
# VAL loss: 0.781 (epoch: 46, step: 100) // Avg time/img: 0.0458 s
# VAL loss: 0.746 (epoch: 46, step: 150) // Avg time/img: 0.0455 s
# EPOCH IoU on VAL set:  42.81 %
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.5873 (epoch: 47, step: 0) // Avg time/img: 0.1479 s
# loss: 0.5818 (epoch: 47, step: 50) // Avg time/img: 0.1358 s
# loss: 0.5825 (epoch: 47, step: 100) // Avg time/img: 0.1379 s
# loss: 0.5858 (epoch: 47, step: 150) // Avg time/img: 0.1366 s
# loss: 0.5854 (epoch: 47, step: 200) // Avg time/img: 0.1359 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.7022 (epoch: 47, step: 0) // Avg time/img: 0.0506 s
# VAL loss: 0.7715 (epoch: 47, step: 50) // Avg time/img: 0.0456 s
# VAL loss: 0.7674 (epoch: 47, step: 100) // Avg time/img: 0.0461 s
# VAL loss: 0.733 (epoch: 47, step: 150) // Avg time/img: 0.0459 s
# EPOCH IoU on VAL set:  42.48 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.5896 (epoch: 48, step: 0) // Avg time/img: 0.1387 s
# loss: 0.5816 (epoch: 48, step: 50) // Avg time/img: 0.1352 s
# loss: 0.5811 (epoch: 48, step: 100) // Avg time/img: 0.1360 s
# loss: 0.582 (epoch: 48, step: 150) // Avg time/img: 0.1352 s
# loss: 0.582 (epoch: 48, step: 200) // Avg time/img: 0.1347 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.7081 (epoch: 48, step: 0) // Avg time/img: 0.0421 s
# VAL loss: 0.7665 (epoch: 48, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.7747 (epoch: 48, step: 100) // Avg time/img: 0.0453 s
# VAL loss: 0.7367 (epoch: 48, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  42.89 %
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.551 (epoch: 49, step: 0) // Avg time/img: 0.1439 s
# loss: 0.5831 (epoch: 49, step: 50) // Avg time/img: 0.1359 s
# loss: 0.5812 (epoch: 49, step: 100) // Avg time/img: 0.1394 s
# loss: 0.5841 (epoch: 49, step: 150) // Avg time/img: 0.1379 s
# loss: 0.586 (epoch: 49, step: 200) // Avg time/img: 0.1374 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.7555 (epoch: 49, step: 0) // Avg time/img: 0.0452 s
# VAL loss: 0.7924 (epoch: 49, step: 50) // Avg time/img: 0.0454 s
# VAL loss: 0.799 (epoch: 49, step: 100) // Avg time/img: 0.0453 s
# VAL loss: 0.758 (epoch: 49, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  41.15 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.6139 (epoch: 50, step: 0) // Avg time/img: 0.1343 s
# loss: 0.5875 (epoch: 50, step: 50) // Avg time/img: 0.1355 s
# loss: 0.5824 (epoch: 50, step: 100) // Avg time/img: 0.1346 s
# loss: 0.5829 (epoch: 50, step: 150) // Avg time/img: 0.1341 s
# loss: 0.5825 (epoch: 50, step: 200) // Avg time/img: 0.1338 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.6923 (epoch: 50, step: 0) // Avg time/img: 0.0456 s
# VAL loss: 0.7662 (epoch: 50, step: 50) // Avg time/img: 0.0445 s
# VAL loss: 0.7695 (epoch: 50, step: 100) // Avg time/img: 0.0449 s
# VAL loss: 0.7333 (epoch: 50, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  43.18 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.587 (epoch: 51, step: 0) // Avg time/img: 0.1418 s
# loss: 0.5764 (epoch: 51, step: 50) // Avg time/img: 0.1354 s
# loss: 0.5742 (epoch: 51, step: 100) // Avg time/img: 0.1358 s
# loss: 0.5756 (epoch: 51, step: 150) // Avg time/img: 0.1350 s
# loss: 0.5755 (epoch: 51, step: 200) // Avg time/img: 0.1346 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.6691 (epoch: 51, step: 0) // Avg time/img: 0.0465 s
# VAL loss: 0.7654 (epoch: 51, step: 50) // Avg time/img: 0.0451 s
# VAL loss: 0.77 (epoch: 51, step: 100) // Avg time/img: 0.0452 s
# VAL loss: 0.7328 (epoch: 51, step: 150) // Avg time/img: 0.0457 s
# EPOCH IoU on VAL set:  43.38 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.5412 (epoch: 52, step: 0) // Avg time/img: 0.1526 s
# loss: 0.5725 (epoch: 52, step: 50) // Avg time/img: 0.1359 s
# loss: 0.575 (epoch: 52, step: 100) // Avg time/img: 0.1349 s
# loss: 0.5745 (epoch: 52, step: 150) // Avg time/img: 0.1342 s
# loss: 0.5741 (epoch: 52, step: 200) // Avg time/img: 0.1340 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.7481 (epoch: 52, step: 0) // Avg time/img: 0.0514 s
# VAL loss: 0.785 (epoch: 52, step: 50) // Avg time/img: 0.0455 s
# VAL loss: 0.788 (epoch: 52, step: 100) // Avg time/img: 0.0454 s
# VAL loss: 0.7496 (epoch: 52, step: 150) // Avg time/img: 0.0456 s
# EPOCH IoU on VAL set:  42.72 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.5696 (epoch: 53, step: 0) // Avg time/img: 0.1461 s
# loss: 0.5669 (epoch: 53, step: 50) // Avg time/img: 0.1361 s
# loss: 0.5684 (epoch: 53, step: 100) // Avg time/img: 0.1348 s
# loss: 0.5709 (epoch: 53, step: 150) // Avg time/img: 0.1352 s
# loss: 0.5721 (epoch: 53, step: 200) // Avg time/img: 0.1348 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.7009 (epoch: 53, step: 0) // Avg time/img: 0.0474 s
# VAL loss: 0.7609 (epoch: 53, step: 50) // Avg time/img: 0.0449 s
# VAL loss: 0.7675 (epoch: 53, step: 100) // Avg time/img: 0.0452 s
# VAL loss: 0.7313 (epoch: 53, step: 150) // Avg time/img: 0.0464 s
# EPOCH IoU on VAL set:  43.92 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.567 (epoch: 54, step: 0) // Avg time/img: 0.1624 s
# loss: 0.575 (epoch: 54, step: 50) // Avg time/img: 0.1363 s
# loss: 0.5726 (epoch: 54, step: 100) // Avg time/img: 0.1350 s
# loss: 0.5719 (epoch: 54, step: 150) // Avg time/img: 0.1345 s
# loss: 0.5716 (epoch: 54, step: 200) // Avg time/img: 0.1342 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.6599 (epoch: 54, step: 0) // Avg time/img: 0.0470 s
# VAL loss: 0.7755 (epoch: 54, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.7672 (epoch: 54, step: 100) // Avg time/img: 0.0449 s
# VAL loss: 0.7277 (epoch: 54, step: 150) // Avg time/img: 0.0448 s
# EPOCH IoU on VAL set:  43.85 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.5449 (epoch: 55, step: 0) // Avg time/img: 0.1378 s
# loss: 0.5742 (epoch: 55, step: 50) // Avg time/img: 0.1351 s
# loss: 0.5725 (epoch: 55, step: 100) // Avg time/img: 0.1345 s
# loss: 0.5722 (epoch: 55, step: 150) // Avg time/img: 0.1347 s
# loss: 0.5703 (epoch: 55, step: 200) // Avg time/img: 0.1344 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.6515 (epoch: 55, step: 0) // Avg time/img: 0.0439 s
# VAL loss: 0.7654 (epoch: 55, step: 50) // Avg time/img: 0.0451 s
# VAL loss: 0.7594 (epoch: 55, step: 100) // Avg time/img: 0.0464 s
# VAL loss: 0.7225 (epoch: 55, step: 150) // Avg time/img: 0.0468 s
# EPOCH IoU on VAL set:  44.58 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 55)
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.536 (epoch: 56, step: 0) // Avg time/img: 0.1564 s
# loss: 0.5729 (epoch: 56, step: 50) // Avg time/img: 0.1364 s
# loss: 0.5697 (epoch: 56, step: 100) // Avg time/img: 0.1353 s
# loss: 0.5687 (epoch: 56, step: 150) // Avg time/img: 0.1346 s
# loss: 0.5677 (epoch: 56, step: 200) // Avg time/img: 0.1342 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.7229 (epoch: 56, step: 0) // Avg time/img: 0.0445 s
# VAL loss: 0.7803 (epoch: 56, step: 50) // Avg time/img: 0.0456 s
# VAL loss: 0.7817 (epoch: 56, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.7423 (epoch: 56, step: 150) // Avg time/img: 0.0455 s
# EPOCH IoU on VAL set:  43.63 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.633 (epoch: 57, step: 0) // Avg time/img: 0.1386 s
# loss: 0.5611 (epoch: 57, step: 50) // Avg time/img: 0.1357 s
# loss: 0.564 (epoch: 57, step: 100) // Avg time/img: 0.1357 s
# loss: 0.5649 (epoch: 57, step: 150) // Avg time/img: 0.1351 s
# loss: 0.5656 (epoch: 57, step: 200) // Avg time/img: 0.1346 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.746 (epoch: 57, step: 0) // Avg time/img: 0.0499 s
# VAL loss: 0.7758 (epoch: 57, step: 50) // Avg time/img: 0.0465 s
# VAL loss: 0.7773 (epoch: 57, step: 100) // Avg time/img: 0.0470 s
# VAL loss: 0.7374 (epoch: 57, step: 150) // Avg time/img: 0.0468 s
# EPOCH IoU on VAL set:  43.99 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.5472 (epoch: 58, step: 0) // Avg time/img: 0.1444 s
# loss: 0.5616 (epoch: 58, step: 50) // Avg time/img: 0.1357 s
# loss: 0.5645 (epoch: 58, step: 100) // Avg time/img: 0.1349 s
# loss: 0.5628 (epoch: 58, step: 150) // Avg time/img: 0.1342 s
# loss: 0.5646 (epoch: 58, step: 200) // Avg time/img: 0.1341 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.6955 (epoch: 58, step: 0) // Avg time/img: 0.0420 s
# VAL loss: 0.7736 (epoch: 58, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.7767 (epoch: 58, step: 100) // Avg time/img: 0.0450 s
# VAL loss: 0.7361 (epoch: 58, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  43.84 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.5514 (epoch: 59, step: 0) // Avg time/img: 0.1433 s
# loss: 0.5645 (epoch: 59, step: 50) // Avg time/img: 0.1358 s
# loss: 0.5641 (epoch: 59, step: 100) // Avg time/img: 0.1351 s
# loss: 0.5633 (epoch: 59, step: 150) // Avg time/img: 0.1344 s
# loss: 0.5637 (epoch: 59, step: 200) // Avg time/img: 0.1341 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.7176 (epoch: 59, step: 0) // Avg time/img: 0.0473 s
# VAL loss: 0.7728 (epoch: 59, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.7807 (epoch: 59, step: 100) // Avg time/img: 0.0449 s
# VAL loss: 0.7408 (epoch: 59, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  44.02 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.5519 (epoch: 60, step: 0) // Avg time/img: 0.1669 s
# loss: 0.5616 (epoch: 60, step: 50) // Avg time/img: 0.1360 s
# loss: 0.5605 (epoch: 60, step: 100) // Avg time/img: 0.1402 s
# loss: 0.5612 (epoch: 60, step: 150) // Avg time/img: 0.1378 s
# loss: 0.5616 (epoch: 60, step: 200) // Avg time/img: 0.1367 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.6705 (epoch: 60, step: 0) // Avg time/img: 0.0482 s
# VAL loss: 0.7608 (epoch: 60, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.7588 (epoch: 60, step: 100) // Avg time/img: 0.0452 s
# VAL loss: 0.7218 (epoch: 60, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  44.85 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_encoder_best.pth (epoch: 60)
# ========== DECODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.MainLoss'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 13.74 (epoch: 1, step: 0) // Avg time/img: 0.2514 s
# loss: 11.9 (epoch: 1, step: 50) // Avg time/img: 0.1992 s
# loss: 10.62 (epoch: 1, step: 100) // Avg time/img: 0.1977 s
# loss: 9.437 (epoch: 1, step: 150) // Avg time/img: 0.1973 s
# loss: 8.469 (epoch: 1, step: 200) // Avg time/img: 0.1969 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 3.683 (epoch: 1, step: 0) // Avg time/img: 0.0698 s
# VAL loss: 4.391 (epoch: 1, step: 50) // Avg time/img: 0.0633 s
# VAL loss: 4.265 (epoch: 1, step: 100) // Avg time/img: 0.0644 s
# VAL loss: 4.123 (epoch: 1, step: 150) // Avg time/img: 0.0641 s
# EPOCH IoU on VAL set:  14.06 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 3.86 (epoch: 2, step: 0) // Avg time/img: 0.2227 s
# loss: 3.867 (epoch: 2, step: 50) // Avg time/img: 0.1982 s
# loss: 3.546 (epoch: 2, step: 100) // Avg time/img: 0.1968 s
# loss: 3.351 (epoch: 2, step: 150) // Avg time/img: 0.1967 s
# loss: 3.145 (epoch: 2, step: 200) // Avg time/img: 0.1963 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 2.148 (epoch: 2, step: 0) // Avg time/img: 0.0701 s
# VAL loss: 2.606 (epoch: 2, step: 50) // Avg time/img: 0.0636 s
# VAL loss: 2.497 (epoch: 2, step: 100) // Avg time/img: 0.0632 s
# VAL loss: 2.386 (epoch: 2, step: 150) // Avg time/img: 0.0632 s
# EPOCH IoU on VAL set:  22.42 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 1.98 (epoch: 3, step: 0) // Avg time/img: 0.2281 s
# loss: 2.265 (epoch: 3, step: 50) // Avg time/img: 0.1974 s
# loss: 2.175 (epoch: 3, step: 100) // Avg time/img: 0.1981 s
# loss: 2.164 (epoch: 3, step: 150) // Avg time/img: 0.1986 s
# loss: 2.085 (epoch: 3, step: 200) // Avg time/img: 0.1978 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 1.758 (epoch: 3, step: 0) // Avg time/img: 0.0645 s
# VAL loss: 2.176 (epoch: 3, step: 50) // Avg time/img: 0.0633 s
# VAL loss: 2.124 (epoch: 3, step: 100) // Avg time/img: 0.0631 s
# VAL loss: 2.004 (epoch: 3, step: 150) // Avg time/img: 0.0629 s
# EPOCH IoU on VAL set:  24.52 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 1.644 (epoch: 4, step: 0) // Avg time/img: 0.2307 s
# loss: 1.654 (epoch: 4, step: 50) // Avg time/img: 0.1977 s
# loss: 1.646 (epoch: 4, step: 100) // Avg time/img: 0.1969 s
# loss: 1.658 (epoch: 4, step: 150) // Avg time/img: 0.1961 s
# loss: 1.678 (epoch: 4, step: 200) // Avg time/img: 0.1963 s
# ...
# VAL loss: 1.125 (epoch: 38, step: 150) // Avg time/img: 0.0632 s
# EPOCH IoU on VAL set:  45.35 %
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.6444 (epoch: 39, step: 0) // Avg time/img: 0.2319 s
# loss: 0.5056 (epoch: 39, step: 50) // Avg time/img: 0.1978 s
# loss: 0.4959 (epoch: 39, step: 100) // Avg time/img: 0.1966 s
# loss: 0.495 (epoch: 39, step: 150) // Avg time/img: 0.1963 s
# loss: 0.5077 (epoch: 39, step: 200) // Avg time/img: 0.1963 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 1.487 (epoch: 39, step: 0) // Avg time/img: 0.0693 s
# VAL loss: 1.315 (epoch: 39, step: 50) // Avg time/img: 0.0638 s
# VAL loss: 1.34 (epoch: 39, step: 100) // Avg time/img: 0.0635 s
# VAL loss: 1.203 (epoch: 39, step: 150) // Avg time/img: 0.0633 s
# EPOCH IoU on VAL set:  45.15 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.8222 (epoch: 40, step: 0) // Avg time/img: 0.2138 s
# loss: 0.5108 (epoch: 40, step: 50) // Avg time/img: 0.1976 s
# loss: 0.5255 (epoch: 40, step: 100) // Avg time/img: 0.1971 s
# loss: 0.5345 (epoch: 40, step: 150) // Avg time/img: 0.1963 s
# loss: 0.5285 (epoch: 40, step: 200) // Avg time/img: 0.1966 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.8408 (epoch: 40, step: 0) // Avg time/img: 0.0729 s
# VAL loss: 1.133 (epoch: 40, step: 50) // Avg time/img: 0.0656 s
# VAL loss: 1.133 (epoch: 40, step: 100) // Avg time/img: 0.0644 s
# VAL loss: 1.013 (epoch: 40, step: 150) // Avg time/img: 0.0643 s
# EPOCH IoU on VAL set:  48.13 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_best.pth (epoch: 40)
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.3588 (epoch: 41, step: 0) // Avg time/img: 0.2320 s
# loss: 0.4969 (epoch: 41, step: 50) // Avg time/img: 0.1976 s
# loss: 0.5152 (epoch: 41, step: 100) // Avg time/img: 0.1971 s
# loss: 0.5015 (epoch: 41, step: 150) // Avg time/img: 0.1964 s
# loss: 0.5035 (epoch: 41, step: 200) // Avg time/img: 0.1961 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 1.1 (epoch: 41, step: 0) // Avg time/img: 0.0702 s
# VAL loss: 1.239 (epoch: 41, step: 50) // Avg time/img: 0.0638 s
# VAL loss: 1.376 (epoch: 41, step: 100) // Avg time/img: 0.0643 s
# VAL loss: 1.242 (epoch: 41, step: 150) // Avg time/img: 0.0648 s
# EPOCH IoU on VAL set:  45.72 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.4884 (epoch: 42, step: 0) // Avg time/img: 0.2065 s
# loss: 0.5121 (epoch: 42, step: 50) // Avg time/img: 0.1988 s
# loss: 0.4863 (epoch: 42, step: 100) // Avg time/img: 0.1970 s
# loss: 0.4994 (epoch: 42, step: 150) // Avg time/img: 0.1964 s
# loss: 0.5129 (epoch: 42, step: 200) // Avg time/img: 0.1962 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.877 (epoch: 42, step: 0) // Avg time/img: 0.0789 s
# VAL loss: 1.189 (epoch: 42, step: 50) // Avg time/img: 0.0641 s
# VAL loss: 1.228 (epoch: 42, step: 100) // Avg time/img: 0.0642 s
# VAL loss: 1.103 (epoch: 42, step: 150) // Avg time/img: 0.0639 s
# EPOCH IoU on VAL set:  46.39 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.4384 (epoch: 43, step: 0) // Avg time/img: 0.2256 s
# loss: 0.4809 (epoch: 43, step: 50) // Avg time/img: 0.1975 s
# loss: 0.4795 (epoch: 43, step: 100) // Avg time/img: 0.1964 s
# loss: 0.4902 (epoch: 43, step: 150) // Avg time/img: 0.1964 s
# loss: 0.4945 (epoch: 43, step: 200) // Avg time/img: 0.1963 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 1.003 (epoch: 43, step: 0) // Avg time/img: 0.0690 s
# VAL loss: 1.212 (epoch: 43, step: 50) // Avg time/img: 0.0640 s
# VAL loss: 1.218 (epoch: 43, step: 100) // Avg time/img: 0.0636 s
# VAL loss: 1.083 (epoch: 43, step: 150) // Avg time/img: 0.0634 s
# EPOCH IoU on VAL set:  47.10 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.349 (epoch: 44, step: 0) // Avg time/img: 0.2153 s
# loss: 0.4631 (epoch: 44, step: 50) // Avg time/img: 0.2022 s
# loss: 0.476 (epoch: 44, step: 100) // Avg time/img: 0.1989 s
# loss: 0.4804 (epoch: 44, step: 150) // Avg time/img: 0.1981 s
# loss: 0.483 (epoch: 44, step: 200) // Avg time/img: 0.1974 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.901 (epoch: 44, step: 0) // Avg time/img: 0.0631 s
# VAL loss: 1.17 (epoch: 44, step: 50) // Avg time/img: 0.0639 s
# VAL loss: 1.146 (epoch: 44, step: 100) // Avg time/img: 0.0637 s
# VAL loss: 1.002 (epoch: 44, step: 150) // Avg time/img: 0.0637 s
# EPOCH IoU on VAL set:  46.82 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.414 (epoch: 45, step: 0) // Avg time/img: 0.2141 s
# loss: 0.4862 (epoch: 45, step: 50) // Avg time/img: 0.1978 s
# loss: 0.4741 (epoch: 45, step: 100) // Avg time/img: 0.1972 s
# loss: 0.4787 (epoch: 45, step: 150) // Avg time/img: 0.1980 s
# loss: 0.4778 (epoch: 45, step: 200) // Avg time/img: 0.1974 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 1.164 (epoch: 45, step: 0) // Avg time/img: 0.0662 s
# VAL loss: 1.15 (epoch: 45, step: 50) // Avg time/img: 0.0624 s
# VAL loss: 1.187 (epoch: 45, step: 100) // Avg time/img: 0.0628 s
# VAL loss: 1.057 (epoch: 45, step: 150) // Avg time/img: 0.0632 s
# EPOCH IoU on VAL set:  47.95 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.4028 (epoch: 46, step: 0) // Avg time/img: 0.2109 s
# loss: 0.4436 (epoch: 46, step: 50) // Avg time/img: 0.1973 s
# loss: 0.465 (epoch: 46, step: 100) // Avg time/img: 0.1962 s
# loss: 0.4681 (epoch: 46, step: 150) // Avg time/img: 0.1978 s
# loss: 0.4711 (epoch: 46, step: 200) // Avg time/img: 0.1973 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.8662 (epoch: 46, step: 0) // Avg time/img: 0.0729 s
# VAL loss: 1.119 (epoch: 46, step: 50) // Avg time/img: 0.0624 s
# VAL loss: 1.093 (epoch: 46, step: 100) // Avg time/img: 0.0629 s
# VAL loss: 0.9673 (epoch: 46, step: 150) // Avg time/img: 0.0630 s
# EPOCH IoU on VAL set:  47.84 %
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.7711 (epoch: 47, step: 0) // Avg time/img: 0.2072 s
# loss: 0.4917 (epoch: 47, step: 50) // Avg time/img: 0.1969 s
# loss: 0.4736 (epoch: 47, step: 100) // Avg time/img: 0.1967 s
# loss: 0.4736 (epoch: 47, step: 150) // Avg time/img: 0.1962 s
# loss: 0.472 (epoch: 47, step: 200) // Avg time/img: 0.1960 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.9696 (epoch: 47, step: 0) // Avg time/img: 0.0724 s
# VAL loss: 1.16 (epoch: 47, step: 50) // Avg time/img: 0.0634 s
# VAL loss: 1.171 (epoch: 47, step: 100) // Avg time/img: 0.0632 s
# VAL loss: 1.029 (epoch: 47, step: 150) // Avg time/img: 0.0635 s
# EPOCH IoU on VAL set:  48.11 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.7283 (epoch: 48, step: 0) // Avg time/img: 0.2116 s
# loss: 0.4636 (epoch: 48, step: 50) // Avg time/img: 0.1975 s
# loss: 0.4654 (epoch: 48, step: 100) // Avg time/img: 0.1965 s
# loss: 0.4608 (epoch: 48, step: 150) // Avg time/img: 0.1965 s
# loss: 0.4596 (epoch: 48, step: 200) // Avg time/img: 0.1961 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.7086 (epoch: 48, step: 0) // Avg time/img: 0.0700 s
# VAL loss: 1.088 (epoch: 48, step: 50) // Avg time/img: 0.0673 s
# VAL loss: 1.086 (epoch: 48, step: 100) // Avg time/img: 0.0652 s
# VAL loss: 0.9593 (epoch: 48, step: 150) // Avg time/img: 0.0647 s
# EPOCH IoU on VAL set:  48.99 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_best.pth (epoch: 48)
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.4268 (epoch: 49, step: 0) // Avg time/img: 0.2251 s
# loss: 0.4779 (epoch: 49, step: 50) // Avg time/img: 0.1989 s
# loss: 0.47 (epoch: 49, step: 100) // Avg time/img: 0.1971 s
# loss: 0.4631 (epoch: 49, step: 150) // Avg time/img: 0.1964 s
# loss: 0.4514 (epoch: 49, step: 200) // Avg time/img: 0.1966 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.8751 (epoch: 49, step: 0) // Avg time/img: 0.0721 s
# VAL loss: 1.175 (epoch: 49, step: 50) // Avg time/img: 0.0635 s
# VAL loss: 1.225 (epoch: 49, step: 100) // Avg time/img: 0.0651 s
# VAL loss: 1.105 (epoch: 49, step: 150) // Avg time/img: 0.0645 s
# EPOCH IoU on VAL set:  47.64 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.3705 (epoch: 50, step: 0) // Avg time/img: 0.2156 s
# loss: 0.4257 (epoch: 50, step: 50) // Avg time/img: 0.1977 s
# loss: 0.4318 (epoch: 50, step: 100) // Avg time/img: 0.1969 s
# loss: 0.4365 (epoch: 50, step: 150) // Avg time/img: 0.1962 s
# loss: 0.4375 (epoch: 50, step: 200) // Avg time/img: 0.1961 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.9455 (epoch: 50, step: 0) // Avg time/img: 0.0688 s
# VAL loss: 1.181 (epoch: 50, step: 50) // Avg time/img: 0.0638 s
# VAL loss: 1.252 (epoch: 50, step: 100) // Avg time/img: 0.0634 s
# VAL loss: 1.125 (epoch: 50, step: 150) // Avg time/img: 0.0633 s
# EPOCH IoU on VAL set:  47.31 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.4329 (epoch: 51, step: 0) // Avg time/img: 0.2147 s
# loss: 0.4356 (epoch: 51, step: 50) // Avg time/img: 0.1987 s
# loss: 0.4337 (epoch: 51, step: 100) // Avg time/img: 0.1969 s
# loss: 0.4317 (epoch: 51, step: 150) // Avg time/img: 0.1982 s
# loss: 0.4333 (epoch: 51, step: 200) // Avg time/img: 0.1976 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.7379 (epoch: 51, step: 0) // Avg time/img: 0.0649 s
# VAL loss: 1.108 (epoch: 51, step: 50) // Avg time/img: 0.0639 s
# VAL loss: 1.109 (epoch: 51, step: 100) // Avg time/img: 0.0637 s
# VAL loss: 0.9869 (epoch: 51, step: 150) // Avg time/img: 0.0633 s
# EPOCH IoU on VAL set:  48.60 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.3998 (epoch: 52, step: 0) // Avg time/img: 0.2129 s
# loss: 0.4118 (epoch: 52, step: 50) // Avg time/img: 0.1988 s
# loss: 0.4348 (epoch: 52, step: 100) // Avg time/img: 0.1970 s
# loss: 0.4376 (epoch: 52, step: 150) // Avg time/img: 0.1974 s
# loss: 0.4318 (epoch: 52, step: 200) // Avg time/img: 0.1971 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.7961 (epoch: 52, step: 0) // Avg time/img: 0.0713 s
# VAL loss: 1.152 (epoch: 52, step: 50) // Avg time/img: 0.0636 s
# VAL loss: 1.144 (epoch: 52, step: 100) // Avg time/img: 0.0637 s
# VAL loss: 1.013 (epoch: 52, step: 150) // Avg time/img: 0.0636 s
# EPOCH IoU on VAL set:  48.39 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.3995 (epoch: 53, step: 0) // Avg time/img: 0.2263 s
# loss: 0.4117 (epoch: 53, step: 50) // Avg time/img: 0.1977 s
# loss: 0.4223 (epoch: 53, step: 100) // Avg time/img: 0.1965 s
# loss: 0.4247 (epoch: 53, step: 150) // Avg time/img: 0.1960 s
# loss: 0.4271 (epoch: 53, step: 200) // Avg time/img: 0.1977 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.798 (epoch: 53, step: 0) // Avg time/img: 0.0785 s
# VAL loss: 1.104 (epoch: 53, step: 50) // Avg time/img: 0.0635 s
# VAL loss: 1.104 (epoch: 53, step: 100) // Avg time/img: 0.0634 s
# VAL loss: 0.9768 (epoch: 53, step: 150) // Avg time/img: 0.0633 s
# EPOCH IoU on VAL set:  49.29 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.4332 (epoch: 54, step: 0) // Avg time/img: 0.2249 s
# loss: 0.4272 (epoch: 54, step: 50) // Avg time/img: 0.1976 s
# loss: 0.4366 (epoch: 54, step: 100) // Avg time/img: 0.1972 s
# loss: 0.4304 (epoch: 54, step: 150) // Avg time/img: 0.1968 s
# loss: 0.4273 (epoch: 54, step: 200) // Avg time/img: 0.1964 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.7611 (epoch: 54, step: 0) // Avg time/img: 0.0685 s
# VAL loss: 1.112 (epoch: 54, step: 50) // Avg time/img: 0.0641 s
# VAL loss: 1.116 (epoch: 54, step: 100) // Avg time/img: 0.0634 s
# VAL loss: 0.9883 (epoch: 54, step: 150) // Avg time/img: 0.0637 s
# EPOCH IoU on VAL set:  48.28 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.3936 (epoch: 55, step: 0) // Avg time/img: 0.2221 s
# loss: 0.3995 (epoch: 55, step: 50) // Avg time/img: 0.1994 s
# loss: 0.4265 (epoch: 55, step: 100) // Avg time/img: 0.1973 s
# loss: 0.426 (epoch: 55, step: 150) // Avg time/img: 0.1965 s
# loss: 0.4228 (epoch: 55, step: 200) // Avg time/img: 0.1961 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.7878 (epoch: 55, step: 0) // Avg time/img: 0.0713 s
# VAL loss: 1.104 (epoch: 55, step: 50) // Avg time/img: 0.0691 s
# VAL loss: 1.1 (epoch: 55, step: 100) // Avg time/img: 0.0661 s
# VAL loss: 0.9701 (epoch: 55, step: 150) // Avg time/img: 0.0652 s
# EPOCH IoU on VAL set:  49.25 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.3667 (epoch: 56, step: 0) // Avg time/img: 0.2284 s
# loss: 0.4 (epoch: 56, step: 50) // Avg time/img: 0.1972 s
# loss: 0.4091 (epoch: 56, step: 100) // Avg time/img: 0.1962 s
# loss: 0.4099 (epoch: 56, step: 150) // Avg time/img: 0.1958 s
# loss: 0.4142 (epoch: 56, step: 200) // Avg time/img: 0.1963 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.795 (epoch: 56, step: 0) // Avg time/img: 0.0654 s
# VAL loss: 1.088 (epoch: 56, step: 50) // Avg time/img: 0.0644 s
# VAL loss: 1.072 (epoch: 56, step: 100) // Avg time/img: 0.0649 s
# VAL loss: 0.9521 (epoch: 56, step: 150) // Avg time/img: 0.0644 s
# EPOCH IoU on VAL set:  48.88 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.4058 (epoch: 57, step: 0) // Avg time/img: 0.2040 s
# loss: 0.3884 (epoch: 57, step: 50) // Avg time/img: 0.1973 s
# loss: 0.4026 (epoch: 57, step: 100) // Avg time/img: 0.1968 s
# loss: 0.4131 (epoch: 57, step: 150) // Avg time/img: 0.1968 s
# loss: 0.4083 (epoch: 57, step: 200) // Avg time/img: 0.1965 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.8366 (epoch: 57, step: 0) // Avg time/img: 0.0676 s
# VAL loss: 1.095 (epoch: 57, step: 50) // Avg time/img: 0.0659 s
# VAL loss: 1.1 (epoch: 57, step: 100) // Avg time/img: 0.0648 s
# VAL loss: 0.983 (epoch: 57, step: 150) // Avg time/img: 0.0646 s
# EPOCH IoU on VAL set:  49.13 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.3978 (epoch: 58, step: 0) // Avg time/img: 0.2241 s
# loss: 0.3951 (epoch: 58, step: 50) // Avg time/img: 0.1969 s
# loss: 0.4087 (epoch: 58, step: 100) // Avg time/img: 0.1961 s
# loss: 0.4069 (epoch: 58, step: 150) // Avg time/img: 0.1956 s
# loss: 0.412 (epoch: 58, step: 200) // Avg time/img: 0.1955 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.804 (epoch: 58, step: 0) // Avg time/img: 0.0697 s
# VAL loss: 1.109 (epoch: 58, step: 50) // Avg time/img: 0.0651 s
# VAL loss: 1.14 (epoch: 58, step: 100) // Avg time/img: 0.0647 s
# VAL loss: 1.033 (epoch: 58, step: 150) // Avg time/img: 0.0648 s
# EPOCH IoU on VAL set:  48.38 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.3136 (epoch: 59, step: 0) // Avg time/img: 0.2247 s
# loss: 0.4257 (epoch: 59, step: 50) // Avg time/img: 0.1974 s
# loss: 0.4056 (epoch: 59, step: 100) // Avg time/img: 0.1963 s
# loss: 0.4071 (epoch: 59, step: 150) // Avg time/img: 0.1965 s
# loss: 0.4061 (epoch: 59, step: 200) // Avg time/img: 0.1963 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.7834 (epoch: 59, step: 0) // Avg time/img: 0.0779 s
# VAL loss: 1.067 (epoch: 59, step: 50) // Avg time/img: 0.0633 s
# VAL loss: 1.078 (epoch: 59, step: 100) // Avg time/img: 0.0633 s
# VAL loss: 0.9701 (epoch: 59, step: 150) // Avg time/img: 0.0641 s
# EPOCH IoU on VAL set:  49.60 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/6/model_best.pth (epoch: 59)
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.3457 (epoch: 60, step: 0) // Avg time/img: 0.2326 s
# loss: 0.4109 (epoch: 60, step: 50) // Avg time/img: 0.1994 s
# loss: 0.4008 (epoch: 60, step: 100) // Avg time/img: 0.1981 s
# loss: 0.4019 (epoch: 60, step: 150) // Avg time/img: 0.1971 s
# loss: 0.4023 (epoch: 60, step: 200) // Avg time/img: 0.1967 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.7953 (epoch: 60, step: 0) // Avg time/img: 0.0703 s
# VAL loss: 1.094 (epoch: 60, step: 50) // Avg time/img: 0.0633 s
# VAL loss: 1.107 (epoch: 60, step: 100) // Avg time/img: 0.0629 s
# VAL loss: 0.9899 (epoch: 60, step: 150) // Avg time/img: 0.0629 s
# EPOCH IoU on VAL set:  49.36 %
# ========== TRAINING FINISHED ===========

# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet Model Common module

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)

class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

# %% [markdown]
# ## ERFNet Model [Teacher]

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class non_bottleneck (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3_1 = nn.Conv2d(chann, chann, (3,3), stride=1, padding=(1,1), bias=True)

        # self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3_2 = nn.Conv2d(chann, chann, (3, 3), stride=1, padding=(1*dilated,1*dilated), bias=True, dilation = (dilated,dilated))

        # self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3_1(input)
        # output = F.relu(output)
        # output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3_2(output)
        # output = F.relu(output)
        # output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class TEncoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck(128, 0.3, 2))
            self.layers.append(non_bottleneck(128, 0.3, 4))
            self.layers.append(non_bottleneck(128, 0.3, 8))
            self.layers.append(non_bottleneck(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output

class TDecoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck(64, 0, 1))
        self.layers.append(non_bottleneck(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck(16, 0, 1))
        self.layers.append(non_bottleneck(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet Teacher
class TNet(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = TEncoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = TDecoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## ERFNet model definition [Student]

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3x1_1 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1,0), bias=True)

        self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3x1_2 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1*dilated,0), bias=True, dilation = (dilated,1))

        self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3x1_1(input)
        output = F.relu(output)
        output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3x1_2(output)
        output = F.relu(output)
        output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target

class MainLoss(torch.nn.Module):
    def __init__(self, weight=None):
      super().__init__()
      self.celoss = torch.nn.NLLLoss2d(weight) # CrossEntropyLoss2d
      # self.kdloss = torch.nn.KLDivLoss(reduction='batchmean')
      self.kdloss = torch.nn.MSELoss()
    
    def forward(self, outputs, targets, toutputs):
      T = 4 # Temperature
      alpha = 0.4 # alpha

      # 기본 Loss
      general_loss = self.celoss(torch.nn.functional.log_softmax(outputs, dim=1), targets)

      # KD Loss
      # toutputs[0].detach()
      # kd_loss = self.kdloss(F.log_softmax(outputs[0] / T, dim=1), F.softmax(toutputs[0] / T, dim=1)) * (T*T)
      # kd_loss = self.kdloss(F.log_softmax(outputs / T, dim=1), F.softmax(toutputs / T, dim=1)) * (T*T)
      kd_loss = self.kdloss(outputs / T, toutputs / T) * (T*T)

      # Loss
      loss = alpha * general_loss + (1-alpha) * kd_loss
      return loss


def train(args, tmodel, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = MainLoss(weight) # Loss 변경부분
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train() # student model (train mode)
        tmodel.eval() # teacher model (eval mode)
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)
            toutputs = tmodel(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0], toutputs) # Loss
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        tmodel.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 
            toutputs = tmodel(inputs, only_encode=enc)

            loss = criterion(outputs, targets[:, 0], toutputs)
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Teacher Model
    tweightspath = args.tloadDir + args.tloadWeights
    tmodel = TNet(NUM_CLASSES)

    #Load Model
    model = Net(NUM_CLASSES)
    
    if args.cuda:
        tmodel = torch.nn.DataParallel(tmodel).cuda()
        model = torch.nn.DataParallel(model).cuda()

    def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict elements
        own_state = model.state_dict()
        for name, param in state_dict.items():
            if name not in own_state:
                 continue
            own_state[name].copy_(param)
        return model

    tmodel = load_my_state_dict(tmodel, torch.load(tweightspath))
    print ("Teacher Model and weights LOADED successfully")

    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        model = load_my_state_dict(model, torch.load(args.state))


    # train(args, tmodel, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, tmodel, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, tmodel, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--tloadDir',default="/content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/")
    parser.add_argument('--tloadWeights', default="model_best.pth")

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=60)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=3)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# Teacher Model and weights LOADED successfully
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.MainLoss'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.893 (epoch: 1, step: 0) // Avg time/img: 2.2578 s
# loss: 1.466 (epoch: 1, step: 50) // Avg time/img: 0.1717 s
# loss: 1.276 (epoch: 1, step: 100) // Avg time/img: 0.1525 s
# loss: 1.179 (epoch: 1, step: 150) // Avg time/img: 0.1471 s
# loss: 1.124 (epoch: 1, step: 200) // Avg time/img: 0.1446 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 0.9404 (epoch: 1, step: 0) // Avg time/img: 0.0560 s
# VAL loss: 0.9107 (epoch: 1, step: 50) // Avg time/img: 0.0440 s
# VAL loss: 0.8991 (epoch: 1, step: 100) // Avg time/img: 0.0440 s
# VAL loss: 0.8683 (epoch: 1, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  16.26 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 0.9174 (epoch: 2, step: 0) // Avg time/img: 0.1466 s
# loss: 0.8795 (epoch: 2, step: 50) // Avg time/img: 0.1367 s
# loss: 0.8601 (epoch: 2, step: 100) // Avg time/img: 0.1349 s
# loss: 0.8452 (epoch: 2, step: 150) // Avg time/img: 0.1341 s
# loss: 0.8345 (epoch: 2, step: 200) // Avg time/img: 0.1337 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 0.894 (epoch: 2, step: 0) // Avg time/img: 0.0439 s
# VAL loss: 0.8893 (epoch: 2, step: 50) // Avg time/img: 0.0470 s
# VAL loss: 0.882 (epoch: 2, step: 100) // Avg time/img: 0.0471 s
# VAL loss: 0.8515 (epoch: 2, step: 150) // Avg time/img: 0.0468 s
# EPOCH IoU on VAL set:  18.29 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.9314 (epoch: 3, step: 0) // Avg time/img: 0.1484 s
# loss: 0.8057 (epoch: 3, step: 50) // Avg time/img: 0.1349 s
# loss: 0.7939 (epoch: 3, step: 100) // Avg time/img: 0.1334 s
# loss: 0.7898 (epoch: 3, step: 150) // Avg time/img: 0.1328 s
# loss: 0.7845 (epoch: 3, step: 200) // Avg time/img: 0.1326 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 0.8384 (epoch: 3, step: 0) // Avg time/img: 0.0433 s
# VAL loss: 0.861 (epoch: 3, step: 50) // Avg time/img: 0.0457 s
# VAL loss: 0.8526 (epoch: 3, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.8116 (epoch: 3, step: 150) // Avg time/img: 0.0458 s
# EPOCH IoU on VAL set:  19.31 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 0.782 (epoch: 4, step: 0) // Avg time/img: 0.1684 s
# loss: 0.7647 (epoch: 4, step: 50) // Avg time/img: 0.1358 s
# loss: 0.7538 (epoch: 4, step: 100) // Avg time/img: 0.1340 s
# loss: 0.7479 (epoch: 4, step: 150) // Avg time/img: 0.1332 s
# loss: 0.745 (epoch: 4, step: 200) // Avg time/img: 0.1330 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 0.8059 (epoch: 4, step: 0) // Avg time/img: 0.0508 s
# VAL loss: 0.8799 (epoch: 4, step: 50) // Avg time/img: 0.0450 s
# VAL loss: 0.87 (epoch: 4, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.822 (epoch: 4, step: 150) // Avg time/img: 0.0463 s
# EPOCH IoU on VAL set:  20.13 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.6951 (epoch: 5, step: 0) // Avg time/img: 0.1692 s
# loss: 0.7382 (epoch: 5, step: 50) // Avg time/img: 0.1385 s
# loss: 0.7285 (epoch: 5, step: 100) // Avg time/img: 0.1357 s
# loss: 0.7297 (epoch: 5, step: 150) // Avg time/img: 0.1345 s
# loss: 0.7261 (epoch: 5, step: 200) // Avg time/img: 0.1337 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 1.031 (epoch: 5, step: 0) // Avg time/img: 0.0475 s
# VAL loss: 0.9421 (epoch: 5, step: 50) // Avg time/img: 0.0444 s
# VAL loss: 0.9254 (epoch: 5, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.8604 (epoch: 5, step: 150) // Avg time/img: 0.0448 s
# EPOCH IoU on VAL set:  18.77 %
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004623387553722673
# loss: 0.6702 (epoch: 6, step: 0) // Avg time/img: 0.1392 s
# loss: 0.6987 (epoch: 6, step: 50) // Avg time/img: 0.1346 s
# loss: 0.7025 (epoch: 6, step: 100) // Avg time/img: 0.1336 s
# loss: 0.7011 (epoch: 6, step: 150) // Avg time/img: 0.1330 s
# loss: 0.7082 (epoch: 6, step: 200) // Avg time/img: 0.1327 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 0.7947 (epoch: 6, step: 0) // Avg time/img: 0.0478 s
# VAL loss: 0.805 (epoch: 6, step: 50) // Avg time/img: 0.0459 s
# VAL loss: 0.7899 (epoch: 6, step: 100) // Avg time/img: 0.0454 s
# VAL loss: 0.7559 (epoch: 6, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  24.21 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.6913 (epoch: 7, step: 0) // Avg time/img: 0.1560 s
# loss: 0.7059 (epoch: 7, step: 50) // Avg time/img: 0.1345 s
# loss: 0.6992 (epoch: 7, step: 100) // Avg time/img: 0.1336 s
# loss: 0.6953 (epoch: 7, step: 150) // Avg time/img: 0.1355 s
# loss: 0.6936 (epoch: 7, step: 200) // Avg time/img: 0.1347 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 0.9351 (epoch: 7, step: 0) // Avg time/img: 0.0509 s
# VAL loss: 0.8539 (epoch: 7, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.8375 (epoch: 7, step: 100) // Avg time/img: 0.0450 s
# VAL loss: 0.7896 (epoch: 7, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  22.49 %
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.00044717978378742816
# loss: 0.6776 (epoch: 8, step: 0) // Avg time/img: 0.1389 s
# loss: 0.6858 (epoch: 8, step: 50) // Avg time/img: 0.1347 s
# loss: 0.6789 (epoch: 8, step: 100) // Avg time/img: 0.1336 s
# loss: 0.6775 (epoch: 8, step: 150) // Avg time/img: 0.1341 s
# loss: 0.6809 (epoch: 8, step: 200) // Avg time/img: 0.1336 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 0.808 (epoch: 8, step: 0) // Avg time/img: 0.0410 s
# VAL loss: 0.7787 (epoch: 8, step: 50) // Avg time/img: 0.0451 s
# VAL loss: 0.7673 (epoch: 8, step: 100) // Avg time/img: 0.0450 s
# VAL loss: 0.7373 (epoch: 8, step: 150) // Avg time/img: 0.0448 s
# EPOCH IoU on VAL set:  25.72 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 8)
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.6774 (epoch: 9, step: 0) // Avg time/img: 0.1541 s
# loss: 0.6712 (epoch: 9, step: 50) // Avg time/img: 0.1347 s
# loss: 0.6765 (epoch: 9, step: 100) // Avg time/img: 0.1335 s
# loss: 0.6787 (epoch: 9, step: 150) // Avg time/img: 0.1329 s
# loss: 0.6797 (epoch: 9, step: 200) // Avg time/img: 0.1326 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 0.9763 (epoch: 9, step: 0) // Avg time/img: 0.0463 s
# VAL loss: 0.8858 (epoch: 9, step: 50) // Avg time/img: 0.0448 s
# VAL loss: 0.8593 (epoch: 9, step: 100) // Avg time/img: 0.0455 s
# VAL loss: 0.8134 (epoch: 9, step: 150) // Avg time/img: 0.0455 s
# EPOCH IoU on VAL set:  25.04 %
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.00043196348615140955
# loss: 0.6492 (epoch: 10, step: 0) // Avg time/img: 0.1331 s
# loss: 0.6771 (epoch: 10, step: 50) // Avg time/img: 0.1346 s
# loss: 0.6725 (epoch: 10, step: 100) // Avg time/img: 0.1335 s
# loss: 0.6719 (epoch: 10, step: 150) // Avg time/img: 0.1329 s
# loss: 0.67 (epoch: 10, step: 200) // Avg time/img: 0.1326 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 0.8914 (epoch: 10, step: 0) // Avg time/img: 0.0453 s
# VAL loss: 0.7973 (epoch: 10, step: 50) // Avg time/img: 0.0448 s
# VAL loss: 0.7785 (epoch: 10, step: 100) // Avg time/img: 0.0448 s
# VAL loss: 0.7414 (epoch: 10, step: 150) // Avg time/img: 0.0449 s
# EPOCH IoU on VAL set:  25.38 %
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.6484 (epoch: 11, step: 0) // Avg time/img: 0.1392 s
# loss: 0.6595 (epoch: 11, step: 50) // Avg time/img: 0.1339 s
# loss: 0.6617 (epoch: 11, step: 100) // Avg time/img: 0.1333 s
# loss: 0.6611 (epoch: 11, step: 150) // Avg time/img: 0.1327 s
# loss: 0.6597 (epoch: 11, step: 200) // Avg time/img: 0.1324 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.8432 (epoch: 11, step: 0) // Avg time/img: 0.0456 s
# VAL loss: 0.7926 (epoch: 11, step: 50) // Avg time/img: 0.0443 s
# VAL loss: 0.78 (epoch: 11, step: 100) // Avg time/img: 0.0446 s
# VAL loss: 0.7407 (epoch: 11, step: 150) // Avg time/img: 0.0447 s
# EPOCH IoU on VAL set:  27.51 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 11)
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.0004166873834706844
# loss: 0.6365 (epoch: 12, step: 0) // Avg time/img: 0.1650 s
# loss: 0.64 (epoch: 12, step: 50) // Avg time/img: 0.1347 s
# loss: 0.6526 (epoch: 12, step: 100) // Avg time/img: 0.1334 s
# loss: 0.6586 (epoch: 12, step: 150) // Avg time/img: 0.1363 s
# loss: 0.6568 (epoch: 12, step: 200) // Avg time/img: 0.1352 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.9067 (epoch: 12, step: 0) // Avg time/img: 0.0495 s
# VAL loss: 0.8027 (epoch: 12, step: 50) // Avg time/img: 0.0446 s
# VAL loss: 0.7847 (epoch: 12, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.746 (epoch: 12, step: 150) // Avg time/img: 0.0447 s
# EPOCH IoU on VAL set:  27.28 %
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.6439 (epoch: 13, step: 0) // Avg time/img: 0.1343 s
# loss: 0.6634 (epoch: 13, step: 50) // Avg time/img: 0.1341 s
# loss: 0.6546 (epoch: 13, step: 100) // Avg time/img: 0.1330 s
# loss: 0.6538 (epoch: 13, step: 150) // Avg time/img: 0.1326 s
# loss: 0.6526 (epoch: 13, step: 200) // Avg time/img: 0.1323 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 0.9744 (epoch: 13, step: 0) // Avg time/img: 0.0503 s
# VAL loss: 0.8958 (epoch: 13, step: 50) // Avg time/img: 0.0442 s
# VAL loss: 0.8661 (epoch: 13, step: 100) // Avg time/img: 0.0446 s
# VAL loss: 0.8083 (epoch: 13, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  24.83 %
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.0004013487836640184
# loss: 0.688 (epoch: 14, step: 0) // Avg time/img: 0.1427 s
# loss: 0.6432 (epoch: 14, step: 50) // Avg time/img: 0.1340 s
# loss: 0.6435 (epoch: 14, step: 100) // Avg time/img: 0.1330 s
# loss: 0.648 (epoch: 14, step: 150) // Avg time/img: 0.1325 s
# loss: 0.648 (epoch: 14, step: 200) // Avg time/img: 0.1323 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 1.218 (epoch: 14, step: 0) // Avg time/img: 0.0464 s
# VAL loss: 1.021 (epoch: 14, step: 50) // Avg time/img: 0.0451 s
# VAL loss: 0.9811 (epoch: 14, step: 100) // Avg time/img: 0.0449 s
# VAL loss: 0.9299 (epoch: 14, step: 150) // Avg time/img: 0.0449 s
# EPOCH IoU on VAL set:  27.22 %
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.6326 (epoch: 15, step: 0) // Avg time/img: 0.1395 s
# loss: 0.6432 (epoch: 15, step: 50) // Avg time/img: 0.1348 s
# loss: 0.6404 (epoch: 15, step: 100) // Avg time/img: 0.1333 s
# loss: 0.6441 (epoch: 15, step: 150) // Avg time/img: 0.1360 s
# loss: 0.6417 (epoch: 15, step: 200) // Avg time/img: 0.1351 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 1.063 (epoch: 15, step: 0) // Avg time/img: 0.0451 s
# VAL loss: 1.071 (epoch: 15, step: 50) // Avg time/img: 0.0449 s
# VAL loss: 1.057 (epoch: 15, step: 100) // Avg time/img: 0.0446 s
# VAL loss: 0.9434 (epoch: 15, step: 150) // Avg time/img: 0.0448 s
# EPOCH IoU on VAL set:  21.97 %
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00038594475336178527
# loss: 0.6756 (epoch: 16, step: 0) // Avg time/img: 0.1446 s
# loss: 0.6499 (epoch: 16, step: 50) // Avg time/img: 0.1343 s
# loss: 0.6428 (epoch: 16, step: 100) // Avg time/img: 0.1334 s
# loss: 0.6402 (epoch: 16, step: 150) // Avg time/img: 0.1331 s
# loss: 0.641 (epoch: 16, step: 200) // Avg time/img: 0.1327 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.7071 (epoch: 16, step: 0) // Avg time/img: 0.0406 s
# VAL loss: 0.7431 (epoch: 16, step: 50) // Avg time/img: 0.0449 s
# VAL loss: 0.7435 (epoch: 16, step: 100) // Avg time/img: 0.0446 s
# VAL loss: 0.7123 (epoch: 16, step: 150) // Avg time/img: 0.0446 s
# EPOCH IoU on VAL set:  30.27 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 16)
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.6214 (epoch: 17, step: 0) // Avg time/img: 0.1324 s
# loss: 0.6336 (epoch: 17, step: 50) // Avg time/img: 0.1341 s
# loss: 0.6363 (epoch: 17, step: 100) // Avg time/img: 0.1343 s
# loss: 0.638 (epoch: 17, step: 150) // Avg time/img: 0.1334 s
# loss: 0.6382 (epoch: 17, step: 200) // Avg time/img: 0.1330 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.7121 (epoch: 17, step: 0) // Avg time/img: 0.0477 s
# VAL loss: 0.7312 (epoch: 17, step: 50) // Avg time/img: 0.0491 s
# VAL loss: 0.7243 (epoch: 17, step: 100) // Avg time/img: 0.0471 s
# VAL loss: 0.6972 (epoch: 17, step: 150) // Avg time/img: 0.0465 s
# EPOCH IoU on VAL set:  31.70 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 17)
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.00037047208454744316
# loss: 0.5796 (epoch: 18, step: 0) // Avg time/img: 0.1486 s
# loss: 0.627 (epoch: 18, step: 50) // Avg time/img: 0.1348 s
# loss: 0.6291 (epoch: 18, step: 100) // Avg time/img: 0.1335 s
# loss: 0.6249 (epoch: 18, step: 150) // Avg time/img: 0.1329 s
# loss: 0.6288 (epoch: 18, step: 200) // Avg time/img: 0.1326 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.817 (epoch: 18, step: 0) // Avg time/img: 0.0739 s
# VAL loss: 0.7685 (epoch: 18, step: 50) // Avg time/img: 0.0465 s
# VAL loss: 0.7627 (epoch: 18, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.737 (epoch: 18, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  31.21 %
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.6736 (epoch: 19, step: 0) // Avg time/img: 0.1336 s
# loss: 0.6383 (epoch: 19, step: 50) // Avg time/img: 0.1334 s
# loss: 0.6359 (epoch: 19, step: 100) // Avg time/img: 0.1327 s
# loss: 0.6302 (epoch: 19, step: 150) // Avg time/img: 0.1322 s
# loss: 0.6289 (epoch: 19, step: 200) // Avg time/img: 0.1321 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.7338 (epoch: 19, step: 0) // Avg time/img: 0.0468 s
# VAL loss: 0.737 (epoch: 19, step: 50) // Avg time/img: 0.0445 s
# VAL loss: 0.7282 (epoch: 19, step: 100) // Avg time/img: 0.0458 s
# VAL loss: 0.7 (epoch: 19, step: 150) // Avg time/img: 0.0458 s
# EPOCH IoU on VAL set:  31.19 %
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.0003549272548125162
# loss: 0.5905 (epoch: 20, step: 0) // Avg time/img: 0.1622 s
# loss: 0.6214 (epoch: 20, step: 50) // Avg time/img: 0.1361 s
# loss: 0.6245 (epoch: 20, step: 100) // Avg time/img: 0.1347 s
# loss: 0.6241 (epoch: 20, step: 150) // Avg time/img: 0.1337 s
# loss: 0.6256 (epoch: 20, step: 200) // Avg time/img: 0.1333 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.7291 (epoch: 20, step: 0) // Avg time/img: 0.0452 s
# VAL loss: 0.759 (epoch: 20, step: 50) // Avg time/img: 0.0442 s
# VAL loss: 0.7446 (epoch: 20, step: 100) // Avg time/img: 0.0444 s
# VAL loss: 0.7155 (epoch: 20, step: 150) // Avg time/img: 0.0445 s
# EPOCH IoU on VAL set:  31.35 %
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.6109 (epoch: 21, step: 0) // Avg time/img: 0.1392 s
# loss: 0.6258 (epoch: 21, step: 50) // Avg time/img: 0.1344 s
# loss: 0.6223 (epoch: 21, step: 100) // Avg time/img: 0.1333 s
# loss: 0.6225 (epoch: 21, step: 150) // Avg time/img: 0.1325 s
# loss: 0.6238 (epoch: 21, step: 200) // Avg time/img: 0.1330 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.8581 (epoch: 21, step: 0) // Avg time/img: 0.0510 s
# VAL loss: 0.769 (epoch: 21, step: 50) // Avg time/img: 0.0443 s
# VAL loss: 0.7545 (epoch: 21, step: 100) // Avg time/img: 0.0443 s
# VAL loss: 0.717 (epoch: 21, step: 150) // Avg time/img: 0.0443 s
# EPOCH IoU on VAL set:  29.69 %
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.0003393063796290625
# loss: 0.6351 (epoch: 22, step: 0) // Avg time/img: 0.1475 s
# loss: 0.6339 (epoch: 22, step: 50) // Avg time/img: 0.1407 s
# loss: 0.629 (epoch: 22, step: 100) // Avg time/img: 0.1366 s
# loss: 0.6249 (epoch: 22, step: 150) // Avg time/img: 0.1349 s
# loss: 0.623 (epoch: 22, step: 200) // Avg time/img: 0.1340 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.7976 (epoch: 22, step: 0) // Avg time/img: 0.0457 s
# VAL loss: 0.7467 (epoch: 22, step: 50) // Avg time/img: 0.0446 s
# VAL loss: 0.7399 (epoch: 22, step: 100) // Avg time/img: 0.0446 s
# VAL loss: 0.7092 (epoch: 22, step: 150) // Avg time/img: 0.0447 s
# EPOCH IoU on VAL set:  33.40 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 22)
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.591 (epoch: 23, step: 0) // Avg time/img: 0.1661 s
# loss: 0.6159 (epoch: 23, step: 50) // Avg time/img: 0.1346 s
# loss: 0.6171 (epoch: 23, step: 100) // Avg time/img: 0.1333 s
# loss: 0.6153 (epoch: 23, step: 150) // Avg time/img: 0.1329 s
# loss: 0.618 (epoch: 23, step: 200) // Avg time/img: 0.1333 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.6546 (epoch: 23, step: 0) // Avg time/img: 0.0442 s
# VAL loss: 0.7115 (epoch: 23, step: 50) // Avg time/img: 0.0450 s
# VAL loss: 0.7093 (epoch: 23, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.6856 (epoch: 23, step: 150) // Avg time/img: 0.0448 s
# EPOCH IoU on VAL set:  34.13 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 23)
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.0003236051545417615
# loss: 0.6274 (epoch: 24, step: 0) // Avg time/img: 0.1553 s
# loss: 0.6118 (epoch: 24, step: 50) // Avg time/img: 0.1379 s
# loss: 0.6145 (epoch: 24, step: 100) // Avg time/img: 0.1368 s
# loss: 0.6157 (epoch: 24, step: 150) // Avg time/img: 0.1349 s
# loss: 0.6179 (epoch: 24, step: 200) // Avg time/img: 0.1347 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 0.6599 (epoch: 24, step: 0) // Avg time/img: 0.0423 s
# VAL loss: 0.7015 (epoch: 24, step: 50) // Avg time/img: 0.0446 s
# VAL loss: 0.6987 (epoch: 24, step: 100) // Avg time/img: 0.0444 s
# VAL loss: 0.6766 (epoch: 24, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  35.78 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 24)
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.6901 (epoch: 25, step: 0) // Avg time/img: 0.1480 s
# loss: 0.6152 (epoch: 25, step: 50) // Avg time/img: 0.1343 s
# loss: 0.6128 (epoch: 25, step: 100) // Avg time/img: 0.1332 s
# loss: 0.6122 (epoch: 25, step: 150) // Avg time/img: 0.1326 s
# loss: 0.6131 (epoch: 25, step: 200) // Avg time/img: 0.1323 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.8266 (epoch: 25, step: 0) // Avg time/img: 0.0463 s
# VAL loss: 0.7374 (epoch: 25, step: 50) // Avg time/img: 0.0444 s
# VAL loss: 0.7187 (epoch: 25, step: 100) // Avg time/img: 0.0450 s
# VAL loss: 0.6916 (epoch: 25, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  34.34 %
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00030781878448615926
# loss: 0.5919 (epoch: 26, step: 0) // Avg time/img: 0.1418 s
# loss: 0.6156 (epoch: 26, step: 50) // Avg time/img: 0.1400 s
# loss: 0.6158 (epoch: 26, step: 100) // Avg time/img: 0.1365 s
# loss: 0.6155 (epoch: 26, step: 150) // Avg time/img: 0.1355 s
# loss: 0.6169 (epoch: 26, step: 200) // Avg time/img: 0.1346 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.668 (epoch: 26, step: 0) // Avg time/img: 0.0434 s
# VAL loss: 0.7024 (epoch: 26, step: 50) // Avg time/img: 0.0446 s
# VAL loss: 0.7008 (epoch: 26, step: 100) // Avg time/img: 0.0444 s
# VAL loss: 0.6776 (epoch: 26, step: 150) // Avg time/img: 0.0444 s
# EPOCH IoU on VAL set:  35.77 %
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.5751 (epoch: 27, step: 0) // Avg time/img: 0.1430 s
# loss: 0.6229 (epoch: 27, step: 50) // Avg time/img: 0.1340 s
# loss: 0.617 (epoch: 27, step: 100) // Avg time/img: 0.1331 s
# loss: 0.6139 (epoch: 27, step: 150) // Avg time/img: 0.1325 s
# loss: 0.6129 (epoch: 27, step: 200) // Avg time/img: 0.1330 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.6847 (epoch: 27, step: 0) // Avg time/img: 0.0448 s
# VAL loss: 0.7114 (epoch: 27, step: 50) // Avg time/img: 0.0447 s
# VAL loss: 0.7015 (epoch: 27, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.6789 (epoch: 27, step: 150) // Avg time/img: 0.0454 s
# EPOCH IoU on VAL set:  35.15 %
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00029194189645999016
# loss: 0.5933 (epoch: 28, step: 0) // Avg time/img: 0.1405 s
# loss: 0.6141 (epoch: 28, step: 50) // Avg time/img: 0.1401 s
# loss: 0.6123 (epoch: 28, step: 100) // Avg time/img: 0.1365 s
# loss: 0.6088 (epoch: 28, step: 150) // Avg time/img: 0.1348 s
# loss: 0.6063 (epoch: 28, step: 200) // Avg time/img: 0.1340 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.6476 (epoch: 28, step: 0) // Avg time/img: 0.0437 s
# VAL loss: 0.7102 (epoch: 28, step: 50) // Avg time/img: 0.0450 s
# VAL loss: 0.701 (epoch: 28, step: 100) // Avg time/img: 0.0448 s
# VAL loss: 0.6765 (epoch: 28, step: 150) // Avg time/img: 0.0455 s
# EPOCH IoU on VAL set:  35.63 %
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.6536 (epoch: 29, step: 0) // Avg time/img: 0.1398 s
# loss: 0.6122 (epoch: 29, step: 50) // Avg time/img: 0.1337 s
# loss: 0.609 (epoch: 29, step: 100) // Avg time/img: 0.1329 s
# loss: 0.6063 (epoch: 29, step: 150) // Avg time/img: 0.1335 s
# loss: 0.6074 (epoch: 29, step: 200) // Avg time/img: 0.1329 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.6649 (epoch: 29, step: 0) // Avg time/img: 0.0488 s
# VAL loss: 0.7077 (epoch: 29, step: 50) // Avg time/img: 0.0443 s
# VAL loss: 0.7085 (epoch: 29, step: 100) // Avg time/img: 0.0442 s
# VAL loss: 0.6849 (epoch: 29, step: 150) // Avg time/img: 0.0444 s
# EPOCH IoU on VAL set:  36.80 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 29)
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.0002759684303703797
# loss: 0.558 (epoch: 30, step: 0) // Avg time/img: 0.1472 s
# loss: 0.6019 (epoch: 30, step: 50) // Avg time/img: 0.1344 s
# loss: 0.5997 (epoch: 30, step: 100) // Avg time/img: 0.1362 s
# loss: 0.6015 (epoch: 30, step: 150) // Avg time/img: 0.1359 s
# loss: 0.6027 (epoch: 30, step: 200) // Avg time/img: 0.1349 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.682 (epoch: 30, step: 0) // Avg time/img: 0.0500 s
# VAL loss: 0.695 (epoch: 30, step: 50) // Avg time/img: 0.0471 s
# VAL loss: 0.6931 (epoch: 30, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.6739 (epoch: 30, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  37.16 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 30)
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.6048 (epoch: 31, step: 0) // Avg time/img: 0.1585 s
# loss: 0.5893 (epoch: 31, step: 50) // Avg time/img: 0.1338 s
# loss: 0.5955 (epoch: 31, step: 100) // Avg time/img: 0.1327 s
# loss: 0.5971 (epoch: 31, step: 150) // Avg time/img: 0.1323 s
# loss: 0.5978 (epoch: 31, step: 200) // Avg time/img: 0.1320 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.7019 (epoch: 31, step: 0) // Avg time/img: 0.0466 s
# VAL loss: 0.7024 (epoch: 31, step: 50) // Avg time/img: 0.0447 s
# VAL loss: 0.6892 (epoch: 31, step: 100) // Avg time/img: 0.0450 s
# VAL loss: 0.6657 (epoch: 31, step: 150) // Avg time/img: 0.0449 s
# EPOCH IoU on VAL set:  37.43 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 31)
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.0002598915008274931
# loss: 0.6153 (epoch: 32, step: 0) // Avg time/img: 0.1582 s
# loss: 0.6024 (epoch: 32, step: 50) // Avg time/img: 0.1346 s
# loss: 0.6091 (epoch: 32, step: 100) // Avg time/img: 0.1334 s
# loss: 0.6074 (epoch: 32, step: 150) // Avg time/img: 0.1336 s
# loss: 0.6069 (epoch: 32, step: 200) // Avg time/img: 0.1347 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.7447 (epoch: 32, step: 0) // Avg time/img: 0.0448 s
# VAL loss: 0.7275 (epoch: 32, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.7221 (epoch: 32, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.6933 (epoch: 32, step: 150) // Avg time/img: 0.0446 s
# EPOCH IoU on VAL set:  33.66 %
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.6645 (epoch: 33, step: 0) // Avg time/img: 0.1416 s
# loss: 0.6028 (epoch: 33, step: 50) // Avg time/img: 0.1344 s
# loss: 0.5999 (epoch: 33, step: 100) // Avg time/img: 0.1333 s
# loss: 0.598 (epoch: 33, step: 150) // Avg time/img: 0.1324 s
# loss: 0.5994 (epoch: 33, step: 200) // Avg time/img: 0.1331 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.7226 (epoch: 33, step: 0) // Avg time/img: 0.0422 s
# VAL loss: 0.7316 (epoch: 33, step: 50) // Avg time/img: 0.0457 s
# VAL loss: 0.73 (epoch: 33, step: 100) // Avg time/img: 0.0448 s
# VAL loss: 0.7035 (epoch: 33, step: 150) // Avg time/img: 0.0448 s
# EPOCH IoU on VAL set:  34.63 %
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.00024370321958949772
# loss: 0.6249 (epoch: 34, step: 0) // Avg time/img: 0.1404 s
# loss: 0.6001 (epoch: 34, step: 50) // Avg time/img: 0.1338 s
# loss: 0.5984 (epoch: 34, step: 100) // Avg time/img: 0.1328 s
# loss: 0.5983 (epoch: 34, step: 150) // Avg time/img: 0.1324 s
# loss: 0.5968 (epoch: 34, step: 200) // Avg time/img: 0.1338 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.6967 (epoch: 34, step: 0) // Avg time/img: 0.0472 s
# VAL loss: 0.7137 (epoch: 34, step: 50) // Avg time/img: 0.0444 s
# VAL loss: 0.7188 (epoch: 34, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.6945 (epoch: 34, step: 150) // Avg time/img: 0.0451 s
# EPOCH IoU on VAL set:  36.29 %
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.555 (epoch: 35, step: 0) // Avg time/img: 0.1365 s
# loss: 0.5964 (epoch: 35, step: 50) // Avg time/img: 0.1337 s
# loss: 0.6007 (epoch: 35, step: 100) // Avg time/img: 0.1341 s
# loss: 0.6018 (epoch: 35, step: 150) // Avg time/img: 0.1330 s
# loss: 0.5986 (epoch: 35, step: 200) // Avg time/img: 0.1328 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.7041 (epoch: 35, step: 0) // Avg time/img: 0.0391 s
# VAL loss: 0.7042 (epoch: 35, step: 50) // Avg time/img: 0.0443 s
# VAL loss: 0.6995 (epoch: 35, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.6761 (epoch: 35, step: 150) // Avg time/img: 0.0446 s
# EPOCH IoU on VAL set:  37.67 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 35)
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.00022739446367039517
# loss: 0.6246 (epoch: 36, step: 0) // Avg time/img: 0.1422 s
# loss: 0.5941 (epoch: 36, step: 50) // Avg time/img: 0.1345 s
# loss: 0.5942 (epoch: 36, step: 100) // Avg time/img: 0.1331 s
# loss: 0.596 (epoch: 36, step: 150) // Avg time/img: 0.1324 s
# loss: 0.5955 (epoch: 36, step: 200) // Avg time/img: 0.1327 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.6357 (epoch: 36, step: 0) // Avg time/img: 0.0771 s
# VAL loss: 0.6902 (epoch: 36, step: 50) // Avg time/img: 0.0485 s
# VAL loss: 0.6825 (epoch: 36, step: 100) // Avg time/img: 0.0470 s
# VAL loss: 0.6613 (epoch: 36, step: 150) // Avg time/img: 0.0464 s
# EPOCH IoU on VAL set:  38.77 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 36)
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.5629 (epoch: 37, step: 0) // Avg time/img: 0.1568 s
# loss: 0.588 (epoch: 37, step: 50) // Avg time/img: 0.1340 s
# loss: 0.5884 (epoch: 37, step: 100) // Avg time/img: 0.1327 s
# loss: 0.5889 (epoch: 37, step: 150) // Avg time/img: 0.1323 s
# loss: 0.5911 (epoch: 37, step: 200) // Avg time/img: 0.1320 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.6663 (epoch: 37, step: 0) // Avg time/img: 0.0510 s
# VAL loss: 0.6973 (epoch: 37, step: 50) // Avg time/img: 0.0448 s
# VAL loss: 0.6973 (epoch: 37, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.6774 (epoch: 37, step: 150) // Avg time/img: 0.0453 s
# EPOCH IoU on VAL set:  37.83 %
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.00021095456673472888
# loss: 0.5741 (epoch: 38, step: 0) // Avg time/img: 0.1409 s
# loss: 0.5917 (epoch: 38, step: 50) // Avg time/img: 0.1369 s
# loss: 0.5907 (epoch: 38, step: 100) // Avg time/img: 0.1345 s
# loss: 0.5915 (epoch: 38, step: 150) // Avg time/img: 0.1335 s
# loss: 0.5922 (epoch: 38, step: 200) // Avg time/img: 0.1329 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.6754 (epoch: 38, step: 0) // Avg time/img: 0.0505 s
# VAL loss: 0.7027 (epoch: 38, step: 50) // Avg time/img: 0.0458 s
# VAL loss: 0.7036 (epoch: 38, step: 100) // Avg time/img: 0.0464 s
# VAL loss: 0.6823 (epoch: 38, step: 150) // Avg time/img: 0.0459 s
# EPOCH IoU on VAL set:  38.21 %
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.5598 (epoch: 39, step: 0) // Avg time/img: 0.1403 s
# loss: 0.5954 (epoch: 39, step: 50) // Avg time/img: 0.1340 s
# loss: 0.5935 (epoch: 39, step: 100) // Avg time/img: 0.1331 s
# loss: 0.5912 (epoch: 39, step: 150) // Avg time/img: 0.1334 s
# loss: 0.5906 (epoch: 39, step: 200) // Avg time/img: 0.1336 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.6832 (epoch: 39, step: 0) // Avg time/img: 0.0423 s
# VAL loss: 0.7177 (epoch: 39, step: 50) // Avg time/img: 0.0446 s
# VAL loss: 0.7135 (epoch: 39, step: 100) // Avg time/img: 0.0445 s
# VAL loss: 0.6903 (epoch: 39, step: 150) // Avg time/img: 0.0445 s
# EPOCH IoU on VAL set:  36.85 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.5791 (epoch: 40, step: 0) // Avg time/img: 0.1420 s
# loss: 0.5851 (epoch: 40, step: 50) // Avg time/img: 0.1347 s
# loss: 0.5879 (epoch: 40, step: 100) // Avg time/img: 0.1332 s
# loss: 0.5871 (epoch: 40, step: 150) // Avg time/img: 0.1326 s
# loss: 0.5884 (epoch: 40, step: 200) // Avg time/img: 0.1323 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.7447 (epoch: 40, step: 0) // Avg time/img: 0.0479 s
# VAL loss: 0.7166 (epoch: 40, step: 50) // Avg time/img: 0.0503 s
# VAL loss: 0.7165 (epoch: 40, step: 100) // Avg time/img: 0.0485 s
# VAL loss: 0.6883 (epoch: 40, step: 150) // Avg time/img: 0.0472 s
# EPOCH IoU on VAL set:  38.20 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.6602 (epoch: 41, step: 0) // Avg time/img: 0.1438 s
# loss: 0.5852 (epoch: 41, step: 50) // Avg time/img: 0.1344 s
# loss: 0.5862 (epoch: 41, step: 100) // Avg time/img: 0.1333 s
# loss: 0.5836 (epoch: 41, step: 150) // Avg time/img: 0.1325 s
# loss: 0.5837 (epoch: 41, step: 200) // Avg time/img: 0.1322 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.7228 (epoch: 41, step: 0) // Avg time/img: 0.0441 s
# VAL loss: 0.704 (epoch: 41, step: 50) // Avg time/img: 0.0452 s
# VAL loss: 0.7031 (epoch: 41, step: 100) // Avg time/img: 0.0448 s
# VAL loss: 0.6783 (epoch: 41, step: 150) // Avg time/img: 0.0447 s
# EPOCH IoU on VAL set:  37.95 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.5838 (epoch: 42, step: 0) // Avg time/img: 0.1382 s
# loss: 0.5825 (epoch: 42, step: 50) // Avg time/img: 0.1347 s
# loss: 0.5831 (epoch: 42, step: 100) // Avg time/img: 0.1347 s
# loss: 0.5816 (epoch: 42, step: 150) // Avg time/img: 0.1338 s
# loss: 0.5821 (epoch: 42, step: 200) // Avg time/img: 0.1334 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.6942 (epoch: 42, step: 0) // Avg time/img: 0.0445 s
# VAL loss: 0.6874 (epoch: 42, step: 50) // Avg time/img: 0.0446 s
# VAL loss: 0.6917 (epoch: 42, step: 100) // Avg time/img: 0.0448 s
# VAL loss: 0.6699 (epoch: 42, step: 150) // Avg time/img: 0.0448 s
# EPOCH IoU on VAL set:  39.29 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 42)
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.5782 (epoch: 43, step: 0) // Avg time/img: 0.1532 s
# loss: 0.5766 (epoch: 43, step: 50) // Avg time/img: 0.1341 s
# loss: 0.5783 (epoch: 43, step: 100) // Avg time/img: 0.1332 s
# loss: 0.581 (epoch: 43, step: 150) // Avg time/img: 0.1360 s
# loss: 0.5816 (epoch: 43, step: 200) // Avg time/img: 0.1354 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.6581 (epoch: 43, step: 0) // Avg time/img: 0.0513 s
# VAL loss: 0.6866 (epoch: 43, step: 50) // Avg time/img: 0.0448 s
# VAL loss: 0.6893 (epoch: 43, step: 100) // Avg time/img: 0.0446 s
# VAL loss: 0.6677 (epoch: 43, step: 150) // Avg time/img: 0.0447 s
# EPOCH IoU on VAL set:  39.51 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 43)
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.5531 (epoch: 44, step: 0) // Avg time/img: 0.1570 s
# loss: 0.5796 (epoch: 44, step: 50) // Avg time/img: 0.1344 s
# loss: 0.5766 (epoch: 44, step: 100) // Avg time/img: 0.1332 s
# loss: 0.5775 (epoch: 44, step: 150) // Avg time/img: 0.1325 s
# loss: 0.5816 (epoch: 44, step: 200) // Avg time/img: 0.1323 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.7726 (epoch: 44, step: 0) // Avg time/img: 0.0448 s
# VAL loss: 0.7122 (epoch: 44, step: 50) // Avg time/img: 0.0460 s
# VAL loss: 0.7026 (epoch: 44, step: 100) // Avg time/img: 0.0455 s
# VAL loss: 0.6755 (epoch: 44, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  37.85 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.5612 (epoch: 45, step: 0) // Avg time/img: 0.1404 s
# loss: 0.5878 (epoch: 45, step: 50) // Avg time/img: 0.1367 s
# loss: 0.5829 (epoch: 45, step: 100) // Avg time/img: 0.1341 s
# loss: 0.5815 (epoch: 45, step: 150) // Avg time/img: 0.1329 s
# loss: 0.5817 (epoch: 45, step: 200) // Avg time/img: 0.1343 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.7019 (epoch: 45, step: 0) // Avg time/img: 0.0489 s
# VAL loss: 0.6834 (epoch: 45, step: 50) // Avg time/img: 0.0450 s
# VAL loss: 0.6829 (epoch: 45, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.6619 (epoch: 45, step: 150) // Avg time/img: 0.0447 s
# EPOCH IoU on VAL set:  40.10 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 45)
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.5603 (epoch: 46, step: 0) // Avg time/img: 0.1527 s
# loss: 0.5781 (epoch: 46, step: 50) // Avg time/img: 0.1369 s
# loss: 0.5776 (epoch: 46, step: 100) // Avg time/img: 0.1348 s
# loss: 0.5777 (epoch: 46, step: 150) // Avg time/img: 0.1336 s
# loss: 0.5765 (epoch: 46, step: 200) // Avg time/img: 0.1337 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.7091 (epoch: 46, step: 0) // Avg time/img: 0.0402 s
# VAL loss: 0.694 (epoch: 46, step: 50) // Avg time/img: 0.0445 s
# VAL loss: 0.6964 (epoch: 46, step: 100) // Avg time/img: 0.0445 s
# VAL loss: 0.6738 (epoch: 46, step: 150) // Avg time/img: 0.0446 s
# EPOCH IoU on VAL set:  39.78 %
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.5742 (epoch: 47, step: 0) // Avg time/img: 0.1532 s
# loss: 0.5748 (epoch: 47, step: 50) // Avg time/img: 0.1344 s
# loss: 0.5726 (epoch: 47, step: 100) // Avg time/img: 0.1335 s
# loss: 0.5747 (epoch: 47, step: 150) // Avg time/img: 0.1327 s
# loss: 0.5748 (epoch: 47, step: 200) // Avg time/img: 0.1354 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.6961 (epoch: 47, step: 0) // Avg time/img: 0.0450 s
# VAL loss: 0.6813 (epoch: 47, step: 50) // Avg time/img: 0.0447 s
# VAL loss: 0.6764 (epoch: 47, step: 100) // Avg time/img: 0.0456 s
# VAL loss: 0.6559 (epoch: 47, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  40.76 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 47)
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.5994 (epoch: 48, step: 0) // Avg time/img: 0.1546 s
# loss: 0.5758 (epoch: 48, step: 50) // Avg time/img: 0.1344 s
# loss: 0.5767 (epoch: 48, step: 100) // Avg time/img: 0.1333 s
# loss: 0.5756 (epoch: 48, step: 150) // Avg time/img: 0.1325 s
# loss: 0.5761 (epoch: 48, step: 200) // Avg time/img: 0.1322 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.7246 (epoch: 48, step: 0) // Avg time/img: 0.0468 s
# VAL loss: 0.6908 (epoch: 48, step: 50) // Avg time/img: 0.0443 s
# VAL loss: 0.6913 (epoch: 48, step: 100) // Avg time/img: 0.0443 s
# VAL loss: 0.6685 (epoch: 48, step: 150) // Avg time/img: 0.0445 s
# EPOCH IoU on VAL set:  40.28 %
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.584 (epoch: 49, step: 0) // Avg time/img: 0.1417 s
# loss: 0.5732 (epoch: 49, step: 50) // Avg time/img: 0.1344 s
# loss: 0.5727 (epoch: 49, step: 100) // Avg time/img: 0.1331 s
# loss: 0.5731 (epoch: 49, step: 150) // Avg time/img: 0.1326 s
# loss: 0.573 (epoch: 49, step: 200) // Avg time/img: 0.1330 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.7362 (epoch: 49, step: 0) // Avg time/img: 0.0424 s
# VAL loss: 0.6843 (epoch: 49, step: 50) // Avg time/img: 0.0448 s
# VAL loss: 0.6852 (epoch: 49, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.6637 (epoch: 49, step: 150) // Avg time/img: 0.0445 s
# EPOCH IoU on VAL set:  40.92 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 49)
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.5775 (epoch: 50, step: 0) // Avg time/img: 0.1474 s
# loss: 0.5716 (epoch: 50, step: 50) // Avg time/img: 0.1344 s
# loss: 0.572 (epoch: 50, step: 100) // Avg time/img: 0.1380 s
# loss: 0.5717 (epoch: 50, step: 150) // Avg time/img: 0.1358 s
# loss: 0.5718 (epoch: 50, step: 200) // Avg time/img: 0.1348 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.7099 (epoch: 50, step: 0) // Avg time/img: 0.0517 s
# VAL loss: 0.6859 (epoch: 50, step: 50) // Avg time/img: 0.0455 s
# VAL loss: 0.6921 (epoch: 50, step: 100) // Avg time/img: 0.0446 s
# VAL loss: 0.6701 (epoch: 50, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  40.57 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.5455 (epoch: 51, step: 0) // Avg time/img: 0.1394 s
# loss: 0.5709 (epoch: 51, step: 50) // Avg time/img: 0.1345 s
# loss: 0.57 (epoch: 51, step: 100) // Avg time/img: 0.1335 s
# loss: 0.571 (epoch: 51, step: 150) // Avg time/img: 0.1329 s
# loss: 0.5708 (epoch: 51, step: 200) // Avg time/img: 0.1326 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.6579 (epoch: 51, step: 0) // Avg time/img: 0.0458 s
# VAL loss: 0.6804 (epoch: 51, step: 50) // Avg time/img: 0.0448 s
# VAL loss: 0.6765 (epoch: 51, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.6544 (epoch: 51, step: 150) // Avg time/img: 0.0450 s
# EPOCH IoU on VAL set:  41.38 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 51)
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.568 (epoch: 52, step: 0) // Avg time/img: 0.1597 s
# loss: 0.5674 (epoch: 52, step: 50) // Avg time/img: 0.1349 s
# loss: 0.5673 (epoch: 52, step: 100) // Avg time/img: 0.1388 s
# loss: 0.5684 (epoch: 52, step: 150) // Avg time/img: 0.1363 s
# loss: 0.5695 (epoch: 52, step: 200) // Avg time/img: 0.1352 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.6824 (epoch: 52, step: 0) // Avg time/img: 0.0545 s
# VAL loss: 0.6804 (epoch: 52, step: 50) // Avg time/img: 0.0449 s
# VAL loss: 0.6837 (epoch: 52, step: 100) // Avg time/img: 0.0450 s
# VAL loss: 0.6635 (epoch: 52, step: 150) // Avg time/img: 0.0455 s
# EPOCH IoU on VAL set:  41.99 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 52)
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.5711 (epoch: 53, step: 0) // Avg time/img: 0.1560 s
# loss: 0.5693 (epoch: 53, step: 50) // Avg time/img: 0.1340 s
# loss: 0.5688 (epoch: 53, step: 100) // Avg time/img: 0.1329 s
# loss: 0.5684 (epoch: 53, step: 150) // Avg time/img: 0.1324 s
# loss: 0.5695 (epoch: 53, step: 200) // Avg time/img: 0.1322 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.6795 (epoch: 53, step: 0) // Avg time/img: 0.0400 s
# VAL loss: 0.6741 (epoch: 53, step: 50) // Avg time/img: 0.0445 s
# VAL loss: 0.6737 (epoch: 53, step: 100) // Avg time/img: 0.0446 s
# VAL loss: 0.6533 (epoch: 53, step: 150) // Avg time/img: 0.0445 s
# EPOCH IoU on VAL set:  42.43 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.5519 (epoch: 54, step: 0) // Avg time/img: 0.1606 s
# loss: 0.5708 (epoch: 54, step: 50) // Avg time/img: 0.1352 s
# loss: 0.5704 (epoch: 54, step: 100) // Avg time/img: 0.1381 s
# loss: 0.5701 (epoch: 54, step: 150) // Avg time/img: 0.1361 s
# loss: 0.5686 (epoch: 54, step: 200) // Avg time/img: 0.1350 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.6947 (epoch: 54, step: 0) // Avg time/img: 0.0433 s
# VAL loss: 0.6797 (epoch: 54, step: 50) // Avg time/img: 0.0449 s
# VAL loss: 0.686 (epoch: 54, step: 100) // Avg time/img: 0.0448 s
# VAL loss: 0.6648 (epoch: 54, step: 150) // Avg time/img: 0.0454 s
# EPOCH IoU on VAL set:  41.95 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.5595 (epoch: 55, step: 0) // Avg time/img: 0.1444 s
# loss: 0.5701 (epoch: 55, step: 50) // Avg time/img: 0.1347 s
# loss: 0.5679 (epoch: 55, step: 100) // Avg time/img: 0.1336 s
# loss: 0.5667 (epoch: 55, step: 150) // Avg time/img: 0.1329 s
# loss: 0.5664 (epoch: 55, step: 200) // Avg time/img: 0.1328 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.7298 (epoch: 55, step: 0) // Avg time/img: 0.0443 s
# VAL loss: 0.7131 (epoch: 55, step: 50) // Avg time/img: 0.0450 s
# VAL loss: 0.7215 (epoch: 55, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.6952 (epoch: 55, step: 150) // Avg time/img: 0.0449 s
# EPOCH IoU on VAL set:  39.94 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.5783 (epoch: 56, step: 0) // Avg time/img: 0.1363 s
# loss: 0.5653 (epoch: 56, step: 50) // Avg time/img: 0.1403 s
# loss: 0.5663 (epoch: 56, step: 100) // Avg time/img: 0.1376 s
# loss: 0.5653 (epoch: 56, step: 150) // Avg time/img: 0.1356 s
# loss: 0.5655 (epoch: 56, step: 200) // Avg time/img: 0.1345 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.6338 (epoch: 56, step: 0) // Avg time/img: 0.0476 s
# VAL loss: 0.6725 (epoch: 56, step: 50) // Avg time/img: 0.0449 s
# VAL loss: 0.6707 (epoch: 56, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.6518 (epoch: 56, step: 150) // Avg time/img: 0.0457 s
# EPOCH IoU on VAL set:  42.60 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 56)
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.5706 (epoch: 57, step: 0) // Avg time/img: 0.1541 s
# loss: 0.5597 (epoch: 57, step: 50) // Avg time/img: 0.1345 s
# loss: 0.5615 (epoch: 57, step: 100) // Avg time/img: 0.1335 s
# loss: 0.5631 (epoch: 57, step: 150) // Avg time/img: 0.1327 s
# loss: 0.5636 (epoch: 57, step: 200) // Avg time/img: 0.1326 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.6776 (epoch: 57, step: 0) // Avg time/img: 0.0481 s
# VAL loss: 0.6805 (epoch: 57, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.6856 (epoch: 57, step: 100) // Avg time/img: 0.0451 s
# VAL loss: 0.6629 (epoch: 57, step: 150) // Avg time/img: 0.0452 s
# EPOCH IoU on VAL set:  42.01 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.5456 (epoch: 58, step: 0) // Avg time/img: 0.1479 s
# loss: 0.5652 (epoch: 58, step: 50) // Avg time/img: 0.1339 s
# loss: 0.563 (epoch: 58, step: 100) // Avg time/img: 0.1330 s
# loss: 0.5633 (epoch: 58, step: 150) // Avg time/img: 0.1334 s
# loss: 0.5619 (epoch: 58, step: 200) // Avg time/img: 0.1360 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.6923 (epoch: 58, step: 0) // Avg time/img: 0.0592 s
# VAL loss: 0.6826 (epoch: 58, step: 50) // Avg time/img: 0.0453 s
# VAL loss: 0.6882 (epoch: 58, step: 100) // Avg time/img: 0.0450 s
# VAL loss: 0.6659 (epoch: 58, step: 150) // Avg time/img: 0.0451 s
# EPOCH IoU on VAL set:  42.00 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.5465 (epoch: 59, step: 0) // Avg time/img: 0.1340 s
# loss: 0.5632 (epoch: 59, step: 50) // Avg time/img: 0.1344 s
# loss: 0.561 (epoch: 59, step: 100) // Avg time/img: 0.1332 s
# loss: 0.5614 (epoch: 59, step: 150) // Avg time/img: 0.1326 s
# loss: 0.5619 (epoch: 59, step: 200) // Avg time/img: 0.1323 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.6465 (epoch: 59, step: 0) // Avg time/img: 0.0576 s
# VAL loss: 0.6765 (epoch: 59, step: 50) // Avg time/img: 0.0476 s
# VAL loss: 0.6804 (epoch: 59, step: 100) // Avg time/img: 0.0463 s
# VAL loss: 0.6588 (epoch: 59, step: 150) // Avg time/img: 0.0461 s
# EPOCH IoU on VAL set:  42.48 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.6004 (epoch: 60, step: 0) // Avg time/img: 0.1395 s
# loss: 0.5596 (epoch: 60, step: 50) // Avg time/img: 0.1343 s
# loss: 0.5592 (epoch: 60, step: 100) // Avg time/img: 0.1334 s
# loss: 0.5599 (epoch: 60, step: 150) // Avg time/img: 0.1326 s
# loss: 0.5612 (epoch: 60, step: 200) // Avg time/img: 0.1343 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.6532 (epoch: 60, step: 0) // Avg time/img: 0.0450 s
# VAL loss: 0.6732 (epoch: 60, step: 50) // Avg time/img: 0.0448 s
# VAL loss: 0.6765 (epoch: 60, step: 100) // Avg time/img: 0.0447 s
# VAL loss: 0.6561 (epoch: 60, step: 150) // Avg time/img: 0.0451 s
# EPOCH IoU on VAL set:  42.72 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_encoder_best.pth (epoch: 60)
# ========== DECODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.MainLoss'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 17.92 (epoch: 1, step: 0) // Avg time/img: 0.2456 s
# loss: 16.38 (epoch: 1, step: 50) // Avg time/img: 0.1975 s
# loss: 14.74 (epoch: 1, step: 100) // Avg time/img: 0.1948 s
# loss: 13.23 (epoch: 1, step: 150) // Avg time/img: 0.1940 s
# loss: 11.94 (epoch: 1, step: 200) // Avg time/img: 0.1936 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 5.604 (epoch: 1, step: 0) // Avg time/img: 0.0662 s
# VAL loss: 5.726 (epoch: 1, step: 50) // Avg time/img: 0.0630 s
# VAL loss: 5.552 (epoch: 1, step: 100) // Avg time/img: 0.0625 s
# VAL loss: 5.423 (epoch: 1, step: 150) // Avg time/img: 0.0624 s
# EPOCH IoU on VAL set:  13.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 6.392 (epoch: 2, step: 0) // Avg time/img: 0.2333 s
# loss: 5.409 (epoch: 2, step: 50) // Avg time/img: 0.2064 s
# loss: 5.0 (epoch: 2, step: 100) // Avg time/img: 0.1992 s
# loss: 4.585 (epoch: 2, step: 150) // Avg time/img: 0.1969 s
# loss: 4.344 (epoch: 2, step: 200) // Avg time/img: 0.1957 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 2.863 (epoch: 2, step: 0) // Avg time/img: 0.0675 s
# VAL loss: 3.35 (epoch: 2, step: 50) // Avg time/img: 0.0623 s
# VAL loss: 3.22 (epoch: 2, step: 100) // Avg time/img: 0.0620 s
# VAL loss: 3.061 (epoch: 2, step: 150) // Avg time/img: 0.0620 s
# EPOCH IoU on VAL set:  21.50 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 2.805 (epoch: 3, step: 0) // Avg time/img: 0.2327 s
# loss: 2.908 (epoch: 3, step: 50) // Avg time/img: 0.1956 s
# loss: 2.835 (epoch: 3, step: 100) // Avg time/img: 0.1946 s
# loss: 2.785 (epoch: 3, step: 150) // Avg time/img: 0.1939 s
# loss: 2.77 (epoch: 3, step: 200) // Avg time/img: 0.1942 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 1.928 (epoch: 3, step: 0) // Avg time/img: 0.0695 s
# VAL loss: 2.547 (epoch: 3, step: 50) // Avg time/img: 0.0629 s
# VAL loss: 2.463 (epoch: 3, step: 100) // Avg time/img: 0.0626 s
# VAL loss: 2.313 (epoch: 3, step: 150) // Avg time/img: 0.0630 s
# EPOCH IoU on VAL set:  25.68 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_best.pth (epoch: 3)
# ...
# loss: 0.4913 (epoch: 39, step: 0) // Avg time/img: 0.2038 s
# loss: 0.7195 (epoch: 39, step: 50) // Avg time/img: 0.1944 s
# loss: 0.7181 (epoch: 39, step: 100) // Avg time/img: 0.1932 s
# loss: 0.694 (epoch: 39, step: 150) // Avg time/img: 0.1929 s
# loss: 0.6854 (epoch: 39, step: 200) // Avg time/img: 0.1932 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 1.535 (epoch: 39, step: 0) // Avg time/img: 0.0635 s
# VAL loss: 1.367 (epoch: 39, step: 50) // Avg time/img: 0.0629 s
# VAL loss: 1.367 (epoch: 39, step: 100) // Avg time/img: 0.0632 s
# VAL loss: 1.206 (epoch: 39, step: 150) // Avg time/img: 0.0630 s
# EPOCH IoU on VAL set:  46.62 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_best.pth (epoch: 39)
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.6254 (epoch: 40, step: 0) // Avg time/img: 0.2241 s
# loss: 0.6502 (epoch: 40, step: 50) // Avg time/img: 0.1987 s
# loss: 0.6496 (epoch: 40, step: 100) // Avg time/img: 0.1961 s
# loss: 0.6775 (epoch: 40, step: 150) // Avg time/img: 0.1947 s
# loss: 0.695 (epoch: 40, step: 200) // Avg time/img: 0.1941 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 1.613 (epoch: 40, step: 0) // Avg time/img: 0.0678 s
# VAL loss: 1.479 (epoch: 40, step: 50) // Avg time/img: 0.0631 s
# VAL loss: 1.73 (epoch: 40, step: 100) // Avg time/img: 0.0626 s
# VAL loss: 1.568 (epoch: 40, step: 150) // Avg time/img: 0.0625 s
# EPOCH IoU on VAL set:  44.06 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.7697 (epoch: 41, step: 0) // Avg time/img: 0.2203 s
# loss: 0.6954 (epoch: 41, step: 50) // Avg time/img: 0.1957 s
# loss: 0.6998 (epoch: 41, step: 100) // Avg time/img: 0.1956 s
# loss: 0.6926 (epoch: 41, step: 150) // Avg time/img: 0.1949 s
# loss: 0.6892 (epoch: 41, step: 200) // Avg time/img: 0.1943 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 1.563 (epoch: 41, step: 0) // Avg time/img: 0.0755 s
# VAL loss: 1.383 (epoch: 41, step: 50) // Avg time/img: 0.0629 s
# VAL loss: 1.499 (epoch: 41, step: 100) // Avg time/img: 0.0628 s
# VAL loss: 1.347 (epoch: 41, step: 150) // Avg time/img: 0.0629 s
# EPOCH IoU on VAL set:  44.98 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.8292 (epoch: 42, step: 0) // Avg time/img: 0.2206 s
# loss: 0.6265 (epoch: 42, step: 50) // Avg time/img: 0.1946 s
# loss: 0.6574 (epoch: 42, step: 100) // Avg time/img: 0.1939 s
# loss: 0.6537 (epoch: 42, step: 150) // Avg time/img: 0.1945 s
# loss: 0.6449 (epoch: 42, step: 200) // Avg time/img: 0.1940 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 1.269 (epoch: 42, step: 0) // Avg time/img: 0.0709 s
# VAL loss: 1.349 (epoch: 42, step: 50) // Avg time/img: 0.0638 s
# VAL loss: 1.4 (epoch: 42, step: 100) // Avg time/img: 0.0632 s
# VAL loss: 1.267 (epoch: 42, step: 150) // Avg time/img: 0.0632 s
# EPOCH IoU on VAL set:  45.34 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.6196 (epoch: 43, step: 0) // Avg time/img: 0.2271 s
# loss: 0.6495 (epoch: 43, step: 50) // Avg time/img: 0.1943 s
# loss: 0.6838 (epoch: 43, step: 100) // Avg time/img: 0.1931 s
# loss: 0.6792 (epoch: 43, step: 150) // Avg time/img: 0.1938 s
# loss: 0.664 (epoch: 43, step: 200) // Avg time/img: 0.1943 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 1.515 (epoch: 43, step: 0) // Avg time/img: 0.0720 s
# VAL loss: 1.43 (epoch: 43, step: 50) // Avg time/img: 0.0628 s
# VAL loss: 1.572 (epoch: 43, step: 100) // Avg time/img: 0.0624 s
# VAL loss: 1.413 (epoch: 43, step: 150) // Avg time/img: 0.0625 s
# EPOCH IoU on VAL set:  44.89 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.5645 (epoch: 44, step: 0) // Avg time/img: 0.2241 s
# loss: 0.6084 (epoch: 44, step: 50) // Avg time/img: 0.1939 s
# loss: 0.623 (epoch: 44, step: 100) // Avg time/img: 0.1929 s
# loss: 0.6342 (epoch: 44, step: 150) // Avg time/img: 0.1931 s
# loss: 0.6354 (epoch: 44, step: 200) // Avg time/img: 0.1934 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 1.609 (epoch: 44, step: 0) // Avg time/img: 0.0698 s
# VAL loss: 1.514 (epoch: 44, step: 50) // Avg time/img: 0.0634 s
# VAL loss: 1.646 (epoch: 44, step: 100) // Avg time/img: 0.0629 s
# VAL loss: 1.503 (epoch: 44, step: 150) // Avg time/img: 0.0628 s
# EPOCH IoU on VAL set:  44.61 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.7251 (epoch: 45, step: 0) // Avg time/img: 0.2238 s
# loss: 0.6324 (epoch: 45, step: 50) // Avg time/img: 0.1961 s
# loss: 0.6206 (epoch: 45, step: 100) // Avg time/img: 0.1942 s
# loss: 0.6078 (epoch: 45, step: 150) // Avg time/img: 0.1939 s
# loss: 0.6156 (epoch: 45, step: 200) // Avg time/img: 0.1935 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 1.46 (epoch: 45, step: 0) // Avg time/img: 0.0716 s
# VAL loss: 1.328 (epoch: 45, step: 50) // Avg time/img: 0.0661 s
# VAL loss: 1.457 (epoch: 45, step: 100) // Avg time/img: 0.0638 s
# VAL loss: 1.321 (epoch: 45, step: 150) // Avg time/img: 0.0634 s
# EPOCH IoU on VAL set:  46.21 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.4194 (epoch: 46, step: 0) // Avg time/img: 0.2208 s
# loss: 0.6145 (epoch: 46, step: 50) // Avg time/img: 0.1959 s
# loss: 0.6111 (epoch: 46, step: 100) // Avg time/img: 0.1940 s
# loss: 0.6124 (epoch: 46, step: 150) // Avg time/img: 0.1933 s
# loss: 0.6109 (epoch: 46, step: 200) // Avg time/img: 0.1930 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 1.521 (epoch: 46, step: 0) // Avg time/img: 0.0686 s
# VAL loss: 1.345 (epoch: 46, step: 50) // Avg time/img: 0.0635 s
# VAL loss: 1.443 (epoch: 46, step: 100) // Avg time/img: 0.0629 s
# VAL loss: 1.29 (epoch: 46, step: 150) // Avg time/img: 0.0640 s
# EPOCH IoU on VAL set:  46.65 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_best.pth (epoch: 46)
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.5432 (epoch: 47, step: 0) // Avg time/img: 0.2314 s
# loss: 0.5546 (epoch: 47, step: 50) // Avg time/img: 0.1944 s
# loss: 0.5753 (epoch: 47, step: 100) // Avg time/img: 0.1933 s
# loss: 0.578 (epoch: 47, step: 150) // Avg time/img: 0.1934 s
# loss: 0.5815 (epoch: 47, step: 200) // Avg time/img: 0.1931 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 1.532 (epoch: 47, step: 0) // Avg time/img: 0.0670 s
# VAL loss: 1.328 (epoch: 47, step: 50) // Avg time/img: 0.0639 s
# VAL loss: 1.46 (epoch: 47, step: 100) // Avg time/img: 0.0631 s
# VAL loss: 1.322 (epoch: 47, step: 150) // Avg time/img: 0.0625 s
# EPOCH IoU on VAL set:  46.82 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_best.pth (epoch: 47)
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.5821 (epoch: 48, step: 0) // Avg time/img: 0.2336 s
# loss: 0.5985 (epoch: 48, step: 50) // Avg time/img: 0.2016 s
# loss: 0.6015 (epoch: 48, step: 100) // Avg time/img: 0.1969 s
# loss: 0.595 (epoch: 48, step: 150) // Avg time/img: 0.1952 s
# loss: 0.5944 (epoch: 48, step: 200) // Avg time/img: 0.1948 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 1.388 (epoch: 48, step: 0) // Avg time/img: 0.0680 s
# VAL loss: 1.417 (epoch: 48, step: 50) // Avg time/img: 0.0634 s
# VAL loss: 1.591 (epoch: 48, step: 100) // Avg time/img: 0.0629 s
# VAL loss: 1.465 (epoch: 48, step: 150) // Avg time/img: 0.0632 s
# EPOCH IoU on VAL set:  46.21 %
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.7741 (epoch: 49, step: 0) // Avg time/img: 0.2075 s
# loss: 0.6155 (epoch: 49, step: 50) // Avg time/img: 0.1944 s
# loss: 0.5958 (epoch: 49, step: 100) // Avg time/img: 0.1957 s
# loss: 0.5895 (epoch: 49, step: 150) // Avg time/img: 0.1945 s
# loss: 0.5845 (epoch: 49, step: 200) // Avg time/img: 0.1939 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 1.29 (epoch: 49, step: 0) // Avg time/img: 0.0678 s
# VAL loss: 1.339 (epoch: 49, step: 50) // Avg time/img: 0.0634 s
# VAL loss: 1.488 (epoch: 49, step: 100) // Avg time/img: 0.0629 s
# VAL loss: 1.37 (epoch: 49, step: 150) // Avg time/img: 0.0628 s
# EPOCH IoU on VAL set:  46.96 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_best.pth (epoch: 49)
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.4417 (epoch: 50, step: 0) // Avg time/img: 0.2276 s
# loss: 0.5692 (epoch: 50, step: 50) // Avg time/img: 0.1947 s
# loss: 0.5711 (epoch: 50, step: 100) // Avg time/img: 0.1934 s
# loss: 0.5767 (epoch: 50, step: 150) // Avg time/img: 0.1930 s
# loss: 0.5749 (epoch: 50, step: 200) // Avg time/img: 0.1932 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 1.457 (epoch: 50, step: 0) // Avg time/img: 0.0651 s
# VAL loss: 1.31 (epoch: 50, step: 50) // Avg time/img: 0.0669 s
# VAL loss: 1.385 (epoch: 50, step: 100) // Avg time/img: 0.0648 s
# VAL loss: 1.244 (epoch: 50, step: 150) // Avg time/img: 0.0641 s
# EPOCH IoU on VAL set:  47.38 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_best.pth (epoch: 50)
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.4991 (epoch: 51, step: 0) // Avg time/img: 0.2314 s
# loss: 0.5703 (epoch: 51, step: 50) // Avg time/img: 0.1945 s
# loss: 0.5802 (epoch: 51, step: 100) // Avg time/img: 0.1940 s
# loss: 0.5749 (epoch: 51, step: 150) // Avg time/img: 0.1933 s
# loss: 0.5745 (epoch: 51, step: 200) // Avg time/img: 0.1935 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 1.302 (epoch: 51, step: 0) // Avg time/img: 0.0714 s
# VAL loss: 1.311 (epoch: 51, step: 50) // Avg time/img: 0.0630 s
# VAL loss: 1.44 (epoch: 51, step: 100) // Avg time/img: 0.0636 s
# VAL loss: 1.32 (epoch: 51, step: 150) // Avg time/img: 0.0632 s
# EPOCH IoU on VAL set:  47.26 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.5698 (epoch: 52, step: 0) // Avg time/img: 0.1996 s
# loss: 0.5617 (epoch: 52, step: 50) // Avg time/img: 0.1937 s
# loss: 0.5407 (epoch: 52, step: 100) // Avg time/img: 0.1938 s
# loss: 0.5595 (epoch: 52, step: 150) // Avg time/img: 0.1931 s
# loss: 0.5561 (epoch: 52, step: 200) // Avg time/img: 0.1929 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 1.082 (epoch: 52, step: 0) // Avg time/img: 0.0706 s
# VAL loss: 1.276 (epoch: 52, step: 50) // Avg time/img: 0.0631 s
# VAL loss: 1.412 (epoch: 52, step: 100) // Avg time/img: 0.0630 s
# VAL loss: 1.282 (epoch: 52, step: 150) // Avg time/img: 0.0641 s
# EPOCH IoU on VAL set:  47.31 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.4435 (epoch: 53, step: 0) // Avg time/img: 0.2282 s
# loss: 0.5747 (epoch: 53, step: 50) // Avg time/img: 0.1908 s
# loss: 0.5563 (epoch: 53, step: 100) // Avg time/img: 0.1913 s
# loss: 0.5584 (epoch: 53, step: 150) // Avg time/img: 0.1919 s
# loss: 0.554 (epoch: 53, step: 200) // Avg time/img: 0.1918 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 1.047 (epoch: 53, step: 0) // Avg time/img: 0.0700 s
# VAL loss: 1.188 (epoch: 53, step: 50) // Avg time/img: 0.0637 s
# VAL loss: 1.257 (epoch: 53, step: 100) // Avg time/img: 0.0634 s
# VAL loss: 1.136 (epoch: 53, step: 150) // Avg time/img: 0.0631 s
# EPOCH IoU on VAL set:  48.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-test-2/4/model_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.5592 (epoch: 54, step: 0) // Avg time/img: 0.2248 s
# loss: 0.5237 (epoch: 54, step: 50) // Avg time/img: 0.1981 s
# loss: 0.5484 (epoch: 54, step: 100) // Avg time/img: 0.1951 s
# loss: 0.5492 (epoch: 54, step: 150) // Avg time/img: 0.1945 s
# loss: 0.5529 (epoch: 54, step: 200) // Avg time/img: 0.1944 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 1.128 (epoch: 54, step: 0) // Avg time/img: 0.0708 s
# VAL loss: 1.319 (epoch: 54, step: 50) // Avg time/img: 0.0636 s
# VAL loss: 1.452 (epoch: 54, step: 100) // Avg time/img: 0.0629 s
# VAL loss: 1.306 (epoch: 54, step: 150) // Avg time/img: 0.0629 s
# EPOCH IoU on VAL set:  47.12 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.6438 (epoch: 55, step: 0) // Avg time/img: 0.2120 s
# loss: 0.5668 (epoch: 55, step: 50) // Avg time/img: 0.1964 s
# loss: 0.5578 (epoch: 55, step: 100) // Avg time/img: 0.1971 s
# loss: 0.5535 (epoch: 55, step: 150) // Avg time/img: 0.1954 s
# loss: 0.5494 (epoch: 55, step: 200) // Avg time/img: 0.1946 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 1.242 (epoch: 55, step: 0) // Avg time/img: 0.0681 s
# VAL loss: 1.33 (epoch: 55, step: 50) // Avg time/img: 0.0630 s
# VAL loss: 1.467 (epoch: 55, step: 100) // Avg time/img: 0.0629 s
# VAL loss: 1.336 (epoch: 55, step: 150) // Avg time/img: 0.0631 s
# EPOCH IoU on VAL set:  46.69 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.4906 (epoch: 56, step: 0) // Avg time/img: 0.2200 s
# loss: 0.5458 (epoch: 56, step: 50) // Avg time/img: 0.1953 s
# loss: 0.5278 (epoch: 56, step: 100) // Avg time/img: 0.1952 s
# loss: 0.5339 (epoch: 56, step: 150) // Avg time/img: 0.1943 s
# loss: 0.5424 (epoch: 56, step: 200) // Avg time/img: 0.1939 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 1.241 (epoch: 56, step: 0) // Avg time/img: 0.0696 s
# VAL loss: 1.304 (epoch: 56, step: 50) // Avg time/img: 0.0637 s
# VAL loss: 1.471 (epoch: 56, step: 100) // Avg time/img: 0.0634 s
# VAL loss: 1.359 (epoch: 56, step: 150) // Avg time/img: 0.0630 s
# EPOCH IoU on VAL set:  47.38 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.4202 (epoch: 57, step: 0) // Avg time/img: 0.2303 s
# loss: 0.5348 (epoch: 57, step: 50) // Avg time/img: 0.1943 s
# loss: 0.526 (epoch: 57, step: 100) // Avg time/img: 0.1950 s
# loss: 0.5341 (epoch: 57, step: 150) // Avg time/img: 0.1945 s
# loss: 0.5355 (epoch: 57, step: 200) // Avg time/img: 0.1944 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 1.355 (epoch: 57, step: 0) // Avg time/img: 0.0703 s
# VAL loss: 1.322 (epoch: 57, step: 50) // Avg time/img: 0.0630 s
# VAL loss: 1.482 (epoch: 57, step: 100) // Avg time/img: 0.0628 s
# VAL loss: 1.355 (epoch: 57, step: 150) // Avg time/img: 0.0627 s
# EPOCH IoU on VAL set:  47.29 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.5336 (epoch: 58, step: 0) // Avg time/img: 0.2187 s
# loss: 0.5603 (epoch: 58, step: 50) // Avg time/img: 0.1941 s
# loss: 0.5435 (epoch: 58, step: 100) // Avg time/img: 0.1939 s
# loss: 0.5347 (epoch: 58, step: 150) // Avg time/img: 0.1937 s
# loss: 0.5277 (epoch: 58, step: 200) // Avg time/img: 0.1943 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 1.27 (epoch: 58, step: 0) // Avg time/img: 0.0677 s
# VAL loss: 1.256 (epoch: 58, step: 50) // Avg time/img: 0.0631 s
# VAL loss: 1.343 (epoch: 58, step: 100) // Avg time/img: 0.0629 s
# VAL loss: 1.218 (epoch: 58, step: 150) // Avg time/img: 0.0630 s
# EPOCH IoU on VAL set:  47.75 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.4254 (epoch: 59, step: 0) // Avg time/img: 0.2056 s
# loss: 0.534 (epoch: 59, step: 50) // Avg time/img: 0.1952 s
# loss: 0.5212 (epoch: 59, step: 100) // Avg time/img: 0.1936 s
# loss: 0.5237 (epoch: 59, step: 150) // Avg time/img: 0.1930 s
# loss: 0.5231 (epoch: 59, step: 200) // Avg time/img: 0.1937 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 1.238 (epoch: 59, step: 0) // Avg time/img: 0.0700 s
# VAL loss: 1.266 (epoch: 59, step: 50) // Avg time/img: 0.0632 s
# VAL loss: 1.369 (epoch: 59, step: 100) // Avg time/img: 0.0631 s
# VAL loss: 1.234 (epoch: 59, step: 150) // Avg time/img: 0.0628 s
# EPOCH IoU on VAL set:  47.94 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.5447 (epoch: 60, step: 0) // Avg time/img: 0.2288 s
# loss: 0.5226 (epoch: 60, step: 50) // Avg time/img: 0.1940 s
# loss: 0.5111 (epoch: 60, step: 100) // Avg time/img: 0.1929 s
# loss: 0.5231 (epoch: 60, step: 150) // Avg time/img: 0.1926 s
# loss: 0.5271 (epoch: 60, step: 200) // Avg time/img: 0.1926 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 1.413 (epoch: 60, step: 0) // Avg time/img: 0.1066 s
# VAL loss: 1.311 (epoch: 60, step: 50) // Avg time/img: 0.0659 s
# VAL loss: 1.422 (epoch: 60, step: 100) // Avg time/img: 0.0642 s
# VAL loss: 1.276 (epoch: 60, step: 150) // Avg time/img: 0.0635 s
# EPOCH IoU on VAL set:  47.86 %
# ========== TRAINING FINISHED ===========

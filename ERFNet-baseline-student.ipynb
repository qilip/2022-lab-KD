# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet model definition

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)
    

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3x1_1 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1,0), bias=True)

        self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3x1_2 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1*dilated,0), bias=True, dilation = (dilated,1))

        self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3x1_1(input)
        output = F.relu(output)
        output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3x1_2(output)
        output = F.relu(output)
        output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 3):    #5 times -> 3 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 1):    #2 times -> 1 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output


class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target


class CrossEntropyLoss2d(torch.nn.Module):

    def __init__(self, weight=None):
        super().__init__()

        self.loss = torch.nn.NLLLoss2d(weight)

    def forward(self, outputs, targets):
        return self.loss(torch.nn.functional.log_softmax(outputs, dim=1), targets)


def train(args, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = CrossEntropyLoss2d(weight)
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train()
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0])
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 

            loss = criterion(outputs, targets[:, 0])
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Model
    # assert os.path.exists(args.model + ".py"), "Error: model definition not found"
    # model_file = importlib.import_module(args.model)
    model = Net(NUM_CLASSES)
    # copyfile(args.model + ".py", savedir + '/' + args.model + ".py")
    
    if args.cuda:
        model = torch.nn.DataParallel(model).cuda()
    
    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        """
        try:
            model.load_state_dict(torch.load(args.state))
        except AssertionError:
            model.load_state_dict(torch.load(args.state,
                map_location=lambda storage, loc: storage))
        #When model is saved as DataParallel it adds a model. to each key. To remove:
        #state_dict = {k.partition('model.')[2]: v for k,v in state_dict}
        #https://discuss.pytorch.org/t/prefix-parameter-names-in-saved-model-if-trained-by-multi-gpu/494
        """
        def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict keys are there
            own_state = model.state_dict()
            for name, param in state_dict.items():
                if name not in own_state:
                     continue
                own_state[name].copy_(param)
            return model

        #print(torch.load(args.state))
        model = load_my_state_dict(model, torch.load(args.state))

    """
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            #m.weight.data.normal_(0.0, 0.02)
            n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
            m.weight.data.normal_(0, math.sqrt(2. / n))
        elif classname.find('BatchNorm') != -1:
            #m.weight.data.normal_(1.0, 0.02)
            m.weight.data.fill_(1)
            m.bias.data.fill_(0)
    #TO ACCESS MODEL IN DataParallel: next(model.children())
    #next(model.children()).decoder.apply(weights_init)
    #Reinitialize weights for decoder
    
    next(model.children()).decoder.layers.apply(weights_init)
    next(model.children()).decoder.output_conv.apply(weights_init)
    #print(model.state_dict())
    f = open('weights5.txt', 'w')
    f.write(str(model.state_dict()))
    f.close()
    """

    # train(args, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=60)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=3)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 4.117 (epoch: 1, step: 0) // Avg time/img: 2.1490 s
# loss: 1.519 (epoch: 1, step: 50) // Avg time/img: 0.0904 s
# loss: 1.325 (epoch: 1, step: 100) // Avg time/img: 0.0707 s
# loss: 1.194 (epoch: 1, step: 150) // Avg time/img: 0.0637 s
# loss: 1.117 (epoch: 1, step: 200) // Avg time/img: 0.0613 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.451 (epoch: 1, step: 0) // Avg time/img: 0.0179 s
# VAL loss: 1.301 (epoch: 1, step: 50) // Avg time/img: 0.0171 s
# VAL loss: 1.256 (epoch: 1, step: 100) // Avg time/img: 0.0171 s
# VAL loss: 1.168 (epoch: 1, step: 150) // Avg time/img: 0.0170 s
# EPOCH IoU on VAL set:  17.77 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 1.038 (epoch: 2, step: 0) // Avg time/img: 0.0615 s
# loss: 0.8648 (epoch: 2, step: 50) // Avg time/img: 0.0499 s
# loss: 0.8357 (epoch: 2, step: 100) // Avg time/img: 0.0504 s
# loss: 0.8098 (epoch: 2, step: 150) // Avg time/img: 0.0506 s
# loss: 0.7985 (epoch: 2, step: 200) // Avg time/img: 0.0509 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.192 (epoch: 2, step: 0) // Avg time/img: 0.0194 s
# VAL loss: 1.177 (epoch: 2, step: 50) // Avg time/img: 0.0193 s
# VAL loss: 1.153 (epoch: 2, step: 100) // Avg time/img: 0.0206 s
# VAL loss: 1.005 (epoch: 2, step: 150) // Avg time/img: 0.0214 s
# EPOCH IoU on VAL set:  21.14 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.5077 (epoch: 3, step: 0) // Avg time/img: 0.0694 s
# loss: 0.7346 (epoch: 3, step: 50) // Avg time/img: 0.0502 s
# loss: 0.7061 (epoch: 3, step: 100) // Avg time/img: 0.0498 s
# loss: 0.7054 (epoch: 3, step: 150) // Avg time/img: 0.0497 s
# loss: 0.7079 (epoch: 3, step: 200) // Avg time/img: 0.0501 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 1.151 (epoch: 3, step: 0) // Avg time/img: 0.0207 s
# VAL loss: 1.108 (epoch: 3, step: 50) // Avg time/img: 0.0201 s
# VAL loss: 1.072 (epoch: 3, step: 100) // Avg time/img: 0.0208 s
# VAL loss: 0.932 (epoch: 3, step: 150) // Avg time/img: 0.0208 s
# EPOCH IoU on VAL set:  23.19 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 0.4654 (epoch: 4, step: 0) // Avg time/img: 0.0879 s
# loss: 0.6069 (epoch: 4, step: 50) // Avg time/img: 0.0506 s
# loss: 0.6277 (epoch: 4, step: 100) // Avg time/img: 0.0500 s
# loss: 0.6363 (epoch: 4, step: 150) // Avg time/img: 0.0501 s
# loss: 0.6409 (epoch: 4, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 0.8011 (epoch: 4, step: 0) // Avg time/img: 0.0288 s
# VAL loss: 1.0 (epoch: 4, step: 50) // Avg time/img: 0.0216 s
# VAL loss: 0.9548 (epoch: 4, step: 100) // Avg time/img: 0.0215 s
# VAL loss: 0.8434 (epoch: 4, step: 150) // Avg time/img: 0.0209 s
# EPOCH IoU on VAL set:  26.00 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.5625 (epoch: 5, step: 0) // Avg time/img: 0.0502 s
# loss: 0.6382 (epoch: 5, step: 50) // Avg time/img: 0.0494 s
# loss: 0.612 (epoch: 5, step: 100) // Avg time/img: 0.0499 s
# loss: 0.59 (epoch: 5, step: 150) // Avg time/img: 0.0497 s
# loss: 0.5908 (epoch: 5, step: 200) // Avg time/img: 0.0497 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 0.888 (epoch: 5, step: 0) // Avg time/img: 0.0174 s
# VAL loss: 0.9626 (epoch: 5, step: 50) // Avg time/img: 0.0194 s
# VAL loss: 0.945 (epoch: 5, step: 100) // Avg time/img: 0.0205 s
# VAL loss: 0.8242 (epoch: 5, step: 150) // Avg time/img: 0.0210 s
# EPOCH IoU on VAL set:  26.61 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 5)
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004623387553722673
# loss: 0.4081 (epoch: 6, step: 0) // Avg time/img: 0.0695 s
# loss: 0.5157 (epoch: 6, step: 50) // Avg time/img: 0.0517 s
# loss: 0.5404 (epoch: 6, step: 100) // Avg time/img: 0.0508 s
# loss: 0.55 (epoch: 6, step: 150) // Avg time/img: 0.0506 s
# loss: 0.5447 (epoch: 6, step: 200) // Avg time/img: 0.0508 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 1.06 (epoch: 6, step: 0) // Avg time/img: 0.0197 s
# VAL loss: 0.9629 (epoch: 6, step: 50) // Avg time/img: 0.0217 s
# VAL loss: 0.9126 (epoch: 6, step: 100) // Avg time/img: 0.0215 s
# VAL loss: 0.7945 (epoch: 6, step: 150) // Avg time/img: 0.0215 s
# EPOCH IoU on VAL set:  27.87 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.6162 (epoch: 7, step: 0) // Avg time/img: 0.0719 s
# loss: 0.5224 (epoch: 7, step: 50) // Avg time/img: 0.0522 s
# loss: 0.5393 (epoch: 7, step: 100) // Avg time/img: 0.0509 s
# loss: 0.5377 (epoch: 7, step: 150) // Avg time/img: 0.0508 s
# loss: 0.5245 (epoch: 7, step: 200) // Avg time/img: 0.0507 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 1.115 (epoch: 7, step: 0) // Avg time/img: 0.0206 s
# VAL loss: 1.023 (epoch: 7, step: 50) // Avg time/img: 0.0231 s
# VAL loss: 0.9773 (epoch: 7, step: 100) // Avg time/img: 0.0219 s
# VAL loss: 0.8396 (epoch: 7, step: 150) // Avg time/img: 0.0219 s
# EPOCH IoU on VAL set:  28.34 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 7)
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.00044717978378742816
# loss: 0.4046 (epoch: 8, step: 0) // Avg time/img: 0.0694 s
# loss: 0.5013 (epoch: 8, step: 50) // Avg time/img: 0.0499 s
# loss: 0.4921 (epoch: 8, step: 100) // Avg time/img: 0.0508 s
# loss: 0.5079 (epoch: 8, step: 150) // Avg time/img: 0.0506 s
# loss: 0.5027 (epoch: 8, step: 200) // Avg time/img: 0.0507 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 1.431 (epoch: 8, step: 0) // Avg time/img: 0.0169 s
# VAL loss: 1.137 (epoch: 8, step: 50) // Avg time/img: 0.0205 s
# VAL loss: 1.025 (epoch: 8, step: 100) // Avg time/img: 0.0214 s
# VAL loss: 0.8612 (epoch: 8, step: 150) // Avg time/img: 0.0209 s
# EPOCH IoU on VAL set:  28.28 %
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.5013 (epoch: 9, step: 0) // Avg time/img: 0.0713 s
# loss: 0.52 (epoch: 9, step: 50) // Avg time/img: 0.0499 s
# loss: 0.4845 (epoch: 9, step: 100) // Avg time/img: 0.0498 s
# loss: 0.4811 (epoch: 9, step: 150) // Avg time/img: 0.0497 s
# loss: 0.4776 (epoch: 9, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 0.6475 (epoch: 9, step: 0) // Avg time/img: 0.0190 s
# VAL loss: 0.8732 (epoch: 9, step: 50) // Avg time/img: 0.0215 s
# VAL loss: 0.8497 (epoch: 9, step: 100) // Avg time/img: 0.0206 s
# VAL loss: 0.7309 (epoch: 9, step: 150) // Avg time/img: 0.0206 s
# EPOCH IoU on VAL set:  30.41 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 9)
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.00043196348615140955
# loss: 0.364 (epoch: 10, step: 0) // Avg time/img: 0.0720 s
# loss: 0.455 (epoch: 10, step: 50) // Avg time/img: 0.0511 s
# loss: 0.4495 (epoch: 10, step: 100) // Avg time/img: 0.0507 s
# loss: 0.4441 (epoch: 10, step: 150) // Avg time/img: 0.0505 s
# loss: 0.4439 (epoch: 10, step: 200) // Avg time/img: 0.0501 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 0.6491 (epoch: 10, step: 0) // Avg time/img: 0.0231 s
# VAL loss: 0.8768 (epoch: 10, step: 50) // Avg time/img: 0.0202 s
# VAL loss: 0.831 (epoch: 10, step: 100) // Avg time/img: 0.0208 s
# VAL loss: 0.7196 (epoch: 10, step: 150) // Avg time/img: 0.0209 s
# EPOCH IoU on VAL set:  30.77 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 10)
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.3178 (epoch: 11, step: 0) // Avg time/img: 0.0719 s
# loss: 0.4882 (epoch: 11, step: 50) // Avg time/img: 0.0504 s
# loss: 0.4714 (epoch: 11, step: 100) // Avg time/img: 0.0511 s
# loss: 0.4543 (epoch: 11, step: 150) // Avg time/img: 0.0507 s
# loss: 0.4483 (epoch: 11, step: 200) // Avg time/img: 0.0506 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 1.176 (epoch: 11, step: 0) // Avg time/img: 0.0172 s
# VAL loss: 1.054 (epoch: 11, step: 50) // Avg time/img: 0.0213 s
# VAL loss: 1.015 (epoch: 11, step: 100) // Avg time/img: 0.0218 s
# VAL loss: 0.881 (epoch: 11, step: 150) // Avg time/img: 0.0214 s
# EPOCH IoU on VAL set:  28.64 %
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.0004166873834706844
# loss: 0.417 (epoch: 12, step: 0) // Avg time/img: 0.0682 s
# loss: 0.4077 (epoch: 12, step: 50) // Avg time/img: 0.0493 s
# loss: 0.4293 (epoch: 12, step: 100) // Avg time/img: 0.0498 s
# loss: 0.4183 (epoch: 12, step: 150) // Avg time/img: 0.0498 s
# loss: 0.4219 (epoch: 12, step: 200) // Avg time/img: 0.0501 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.7085 (epoch: 12, step: 0) // Avg time/img: 0.0123 s
# VAL loss: 0.8073 (epoch: 12, step: 50) // Avg time/img: 0.0218 s
# VAL loss: 0.7524 (epoch: 12, step: 100) // Avg time/img: 0.0217 s
# VAL loss: 0.6564 (epoch: 12, step: 150) // Avg time/img: 0.0217 s
# EPOCH IoU on VAL set:  32.86 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 12)
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.4779 (epoch: 13, step: 0) // Avg time/img: 0.0702 s
# loss: 0.4142 (epoch: 13, step: 50) // Avg time/img: 0.0502 s
# loss: 0.3947 (epoch: 13, step: 100) // Avg time/img: 0.0503 s
# loss: 0.3998 (epoch: 13, step: 150) // Avg time/img: 0.0508 s
# loss: 0.4015 (epoch: 13, step: 200) // Avg time/img: 0.0505 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 0.572 (epoch: 13, step: 0) // Avg time/img: 0.0190 s
# VAL loss: 0.7487 (epoch: 13, step: 50) // Avg time/img: 0.0207 s
# VAL loss: 0.7237 (epoch: 13, step: 100) // Avg time/img: 0.0207 s
# VAL loss: 0.6372 (epoch: 13, step: 150) // Avg time/img: 0.0207 s
# EPOCH IoU on VAL set:  33.86 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 13)
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.0004013487836640184
# loss: 0.411 (epoch: 14, step: 0) // Avg time/img: 0.0739 s
# loss: 0.3893 (epoch: 14, step: 50) // Avg time/img: 0.0503 s
# loss: 0.4095 (epoch: 14, step: 100) // Avg time/img: 0.0506 s
# loss: 0.4031 (epoch: 14, step: 150) // Avg time/img: 0.0504 s
# loss: 0.4083 (epoch: 14, step: 200) // Avg time/img: 0.0502 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 0.521 (epoch: 14, step: 0) // Avg time/img: 0.0164 s
# VAL loss: 0.809 (epoch: 14, step: 50) // Avg time/img: 0.0219 s
# VAL loss: 0.779 (epoch: 14, step: 100) // Avg time/img: 0.0225 s
# VAL loss: 0.6789 (epoch: 14, step: 150) // Avg time/img: 0.0220 s
# EPOCH IoU on VAL set:  33.36 %
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.3185 (epoch: 15, step: 0) // Avg time/img: 0.0509 s
# loss: 0.3836 (epoch: 15, step: 50) // Avg time/img: 0.0501 s
# loss: 0.3745 (epoch: 15, step: 100) // Avg time/img: 0.0497 s
# loss: 0.3809 (epoch: 15, step: 150) // Avg time/img: 0.0497 s
# loss: 0.3823 (epoch: 15, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 1.064 (epoch: 15, step: 0) // Avg time/img: 0.0197 s
# VAL loss: 0.9336 (epoch: 15, step: 50) // Avg time/img: 0.0217 s
# VAL loss: 0.8754 (epoch: 15, step: 100) // Avg time/img: 0.0230 s
# VAL loss: 0.7493 (epoch: 15, step: 150) // Avg time/img: 0.0226 s
# EPOCH IoU on VAL set:  33.33 %
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00038594475336178527
# loss: 0.3933 (epoch: 16, step: 0) // Avg time/img: 0.0794 s
# loss: 0.362 (epoch: 16, step: 50) // Avg time/img: 0.0503 s
# loss: 0.3706 (epoch: 16, step: 100) // Avg time/img: 0.0500 s
# loss: 0.3646 (epoch: 16, step: 150) // Avg time/img: 0.0499 s
# loss: 0.3668 (epoch: 16, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.502 (epoch: 16, step: 0) // Avg time/img: 0.0203 s
# VAL loss: 0.7708 (epoch: 16, step: 50) // Avg time/img: 0.0220 s
# VAL loss: 0.7358 (epoch: 16, step: 100) // Avg time/img: 0.0218 s
# VAL loss: 0.6329 (epoch: 16, step: 150) // Avg time/img: 0.0211 s
# EPOCH IoU on VAL set:  35.00 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 16)
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.2853 (epoch: 17, step: 0) // Avg time/img: 0.0492 s
# loss: 0.3499 (epoch: 17, step: 50) // Avg time/img: 0.0496 s
# loss: 0.3543 (epoch: 17, step: 100) // Avg time/img: 0.0503 s
# loss: 0.3555 (epoch: 17, step: 150) // Avg time/img: 0.0501 s
# loss: 0.3589 (epoch: 17, step: 200) // Avg time/img: 0.0499 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.7911 (epoch: 17, step: 0) // Avg time/img: 0.0169 s
# VAL loss: 0.812 (epoch: 17, step: 50) // Avg time/img: 0.0217 s
# VAL loss: 0.7935 (epoch: 17, step: 100) // Avg time/img: 0.0224 s
# VAL loss: 0.6962 (epoch: 17, step: 150) // Avg time/img: 0.0218 s
# EPOCH IoU on VAL set:  34.11 %
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.00037047208454744316
# loss: 0.3238 (epoch: 18, step: 0) // Avg time/img: 0.0517 s
# loss: 0.3176 (epoch: 18, step: 50) // Avg time/img: 0.0504 s
# loss: 0.3317 (epoch: 18, step: 100) // Avg time/img: 0.0508 s
# loss: 0.3399 (epoch: 18, step: 150) // Avg time/img: 0.0511 s
# loss: 0.3503 (epoch: 18, step: 200) // Avg time/img: 0.0508 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 1.272 (epoch: 18, step: 0) // Avg time/img: 0.0180 s
# VAL loss: 0.9904 (epoch: 18, step: 50) // Avg time/img: 0.0223 s
# VAL loss: 1.018 (epoch: 18, step: 100) // Avg time/img: 0.0221 s
# VAL loss: 0.8831 (epoch: 18, step: 150) // Avg time/img: 0.0225 s
# EPOCH IoU on VAL set:  30.88 %
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.6863 (epoch: 19, step: 0) // Avg time/img: 0.0741 s
# loss: 0.3753 (epoch: 19, step: 50) // Avg time/img: 0.0500 s
# loss: 0.358 (epoch: 19, step: 100) // Avg time/img: 0.0500 s
# loss: 0.378 (epoch: 19, step: 150) // Avg time/img: 0.0499 s
# loss: 0.3784 (epoch: 19, step: 200) // Avg time/img: 0.0499 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.7996 (epoch: 19, step: 0) // Avg time/img: 0.0184 s
# VAL loss: 1.034 (epoch: 19, step: 50) // Avg time/img: 0.0231 s
# VAL loss: 1.008 (epoch: 19, step: 100) // Avg time/img: 0.0228 s
# VAL loss: 0.8479 (epoch: 19, step: 150) // Avg time/img: 0.0226 s
# EPOCH IoU on VAL set:  32.05 %
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.0003549272548125162
# loss: 0.327 (epoch: 20, step: 0) // Avg time/img: 0.0638 s
# loss: 0.3616 (epoch: 20, step: 50) // Avg time/img: 0.0496 s
# loss: 0.3518 (epoch: 20, step: 100) // Avg time/img: 0.0505 s
# loss: 0.3549 (epoch: 20, step: 150) // Avg time/img: 0.0506 s
# loss: 0.3472 (epoch: 20, step: 200) // Avg time/img: 0.0504 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.7945 (epoch: 20, step: 0) // Avg time/img: 0.0255 s
# VAL loss: 0.7944 (epoch: 20, step: 50) // Avg time/img: 0.0204 s
# VAL loss: 0.7557 (epoch: 20, step: 100) // Avg time/img: 0.0212 s
# VAL loss: 0.6577 (epoch: 20, step: 150) // Avg time/img: 0.0218 s
# EPOCH IoU on VAL set:  35.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 20)
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.3502 (epoch: 21, step: 0) // Avg time/img: 0.0671 s
# loss: 0.3407 (epoch: 21, step: 50) // Avg time/img: 0.0500 s
# loss: 0.3308 (epoch: 21, step: 100) // Avg time/img: 0.0501 s
# loss: 0.3396 (epoch: 21, step: 150) // Avg time/img: 0.0507 s
# loss: 0.335 (epoch: 21, step: 200) // Avg time/img: 0.0507 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.5694 (epoch: 21, step: 0) // Avg time/img: 0.0176 s
# VAL loss: 0.7246 (epoch: 21, step: 50) // Avg time/img: 0.0207 s
# VAL loss: 0.6828 (epoch: 21, step: 100) // Avg time/img: 0.0207 s
# VAL loss: 0.5918 (epoch: 21, step: 150) // Avg time/img: 0.0210 s
# EPOCH IoU on VAL set:  36.80 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 21)
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.0003393063796290625
# loss: 0.372 (epoch: 22, step: 0) // Avg time/img: 0.0632 s
# loss: 0.3118 (epoch: 22, step: 50) // Avg time/img: 0.0502 s
# loss: 0.321 (epoch: 22, step: 100) // Avg time/img: 0.0499 s
# loss: 0.3173 (epoch: 22, step: 150) // Avg time/img: 0.0500 s
# loss: 0.3242 (epoch: 22, step: 200) // Avg time/img: 0.0499 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.7326 (epoch: 22, step: 0) // Avg time/img: 0.0203 s
# VAL loss: 0.6864 (epoch: 22, step: 50) // Avg time/img: 0.0201 s
# VAL loss: 0.6861 (epoch: 22, step: 100) // Avg time/img: 0.0196 s
# VAL loss: 0.6027 (epoch: 22, step: 150) // Avg time/img: 0.0195 s
# EPOCH IoU on VAL set:  37.34 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 22)
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.3581 (epoch: 23, step: 0) // Avg time/img: 0.0832 s
# loss: 0.3242 (epoch: 23, step: 50) // Avg time/img: 0.0542 s
# loss: 0.3286 (epoch: 23, step: 100) // Avg time/img: 0.0525 s
# loss: 0.3173 (epoch: 23, step: 150) // Avg time/img: 0.0518 s
# loss: 0.3217 (epoch: 23, step: 200) // Avg time/img: 0.0513 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 1.145 (epoch: 23, step: 0) // Avg time/img: 0.0185 s
# VAL loss: 0.9531 (epoch: 23, step: 50) // Avg time/img: 0.0223 s
# VAL loss: 0.8913 (epoch: 23, step: 100) // Avg time/img: 0.0221 s
# VAL loss: 0.754 (epoch: 23, step: 150) // Avg time/img: 0.0223 s
# EPOCH IoU on VAL set:  35.23 %
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.0003236051545417615
# loss: 0.2838 (epoch: 24, step: 0) // Avg time/img: 0.0735 s
# loss: 0.3117 (epoch: 24, step: 50) // Avg time/img: 0.0504 s
# loss: 0.2971 (epoch: 24, step: 100) // Avg time/img: 0.0501 s
# loss: 0.3006 (epoch: 24, step: 150) // Avg time/img: 0.0509 s
# loss: 0.3017 (epoch: 24, step: 200) // Avg time/img: 0.0506 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 0.7704 (epoch: 24, step: 0) // Avg time/img: 0.0147 s
# VAL loss: 0.9934 (epoch: 24, step: 50) // Avg time/img: 0.0196 s
# VAL loss: 0.9659 (epoch: 24, step: 100) // Avg time/img: 0.0211 s
# VAL loss: 0.8057 (epoch: 24, step: 150) // Avg time/img: 0.0218 s
# EPOCH IoU on VAL set:  34.97 %
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.2581 (epoch: 25, step: 0) // Avg time/img: 0.0508 s
# loss: 0.2847 (epoch: 25, step: 50) // Avg time/img: 0.0495 s
# loss: 0.2971 (epoch: 25, step: 100) // Avg time/img: 0.0499 s
# loss: 0.3052 (epoch: 25, step: 150) // Avg time/img: 0.0500 s
# loss: 0.3147 (epoch: 25, step: 200) // Avg time/img: 0.0506 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.9795 (epoch: 25, step: 0) // Avg time/img: 0.0179 s
# VAL loss: 0.8301 (epoch: 25, step: 50) // Avg time/img: 0.0211 s
# VAL loss: 0.7932 (epoch: 25, step: 100) // Avg time/img: 0.0213 s
# VAL loss: 0.6735 (epoch: 25, step: 150) // Avg time/img: 0.0209 s
# EPOCH IoU on VAL set:  36.07 %
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00030781878448615926
# loss: 0.3345 (epoch: 26, step: 0) // Avg time/img: 0.0688 s
# loss: 0.3008 (epoch: 26, step: 50) // Avg time/img: 0.0497 s
# loss: 0.2957 (epoch: 26, step: 100) // Avg time/img: 0.0496 s
# loss: 0.3002 (epoch: 26, step: 150) // Avg time/img: 0.0499 s
# loss: 0.302 (epoch: 26, step: 200) // Avg time/img: 0.0497 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.4152 (epoch: 26, step: 0) // Avg time/img: 0.0167 s
# VAL loss: 0.6596 (epoch: 26, step: 50) // Avg time/img: 0.0203 s
# VAL loss: 0.6291 (epoch: 26, step: 100) // Avg time/img: 0.0204 s
# VAL loss: 0.552 (epoch: 26, step: 150) // Avg time/img: 0.0205 s
# EPOCH IoU on VAL set:  40.59 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 26)
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.3868 (epoch: 27, step: 0) // Avg time/img: 0.0720 s
# loss: 0.2715 (epoch: 27, step: 50) // Avg time/img: 0.0502 s
# loss: 0.2883 (epoch: 27, step: 100) // Avg time/img: 0.0508 s
# loss: 0.2856 (epoch: 27, step: 150) // Avg time/img: 0.0505 s
# loss: 0.2872 (epoch: 27, step: 200) // Avg time/img: 0.0503 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.8555 (epoch: 27, step: 0) // Avg time/img: 0.0242 s
# VAL loss: 0.8873 (epoch: 27, step: 50) // Avg time/img: 0.0196 s
# VAL loss: 0.8642 (epoch: 27, step: 100) // Avg time/img: 0.0211 s
# VAL loss: 0.7318 (epoch: 27, step: 150) // Avg time/img: 0.0213 s
# EPOCH IoU on VAL set:  37.03 %
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00029194189645999016
# loss: 0.2954 (epoch: 28, step: 0) // Avg time/img: 0.0643 s
# loss: 0.3143 (epoch: 28, step: 50) // Avg time/img: 0.0501 s
# loss: 0.2899 (epoch: 28, step: 100) // Avg time/img: 0.0498 s
# loss: 0.2858 (epoch: 28, step: 150) // Avg time/img: 0.0504 s
# loss: 0.2822 (epoch: 28, step: 200) // Avg time/img: 0.0502 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.7767 (epoch: 28, step: 0) // Avg time/img: 0.0232 s
# VAL loss: 0.8219 (epoch: 28, step: 50) // Avg time/img: 0.0221 s
# VAL loss: 0.802 (epoch: 28, step: 100) // Avg time/img: 0.0222 s
# VAL loss: 0.6838 (epoch: 28, step: 150) // Avg time/img: 0.0212 s
# EPOCH IoU on VAL set:  37.09 %
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.2196 (epoch: 29, step: 0) // Avg time/img: 0.0744 s
# loss: 0.2642 (epoch: 29, step: 50) // Avg time/img: 0.0502 s
# loss: 0.2716 (epoch: 29, step: 100) // Avg time/img: 0.0504 s
# loss: 0.274 (epoch: 29, step: 150) // Avg time/img: 0.0501 s
# loss: 0.2774 (epoch: 29, step: 200) // Avg time/img: 0.0502 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.5617 (epoch: 29, step: 0) // Avg time/img: 0.0198 s
# VAL loss: 0.718 (epoch: 29, step: 50) // Avg time/img: 0.0224 s
# VAL loss: 0.6917 (epoch: 29, step: 100) // Avg time/img: 0.0218 s
# VAL loss: 0.615 (epoch: 29, step: 150) // Avg time/img: 0.0219 s
# EPOCH IoU on VAL set:  37.28 %
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.0002759684303703797
# loss: 0.266 (epoch: 30, step: 0) // Avg time/img: 0.0628 s
# loss: 0.291 (epoch: 30, step: 50) // Avg time/img: 0.0495 s
# loss: 0.2774 (epoch: 30, step: 100) // Avg time/img: 0.0509 s
# loss: 0.2819 (epoch: 30, step: 150) // Avg time/img: 0.0511 s
# loss: 0.2789 (epoch: 30, step: 200) // Avg time/img: 0.0510 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.7332 (epoch: 30, step: 0) // Avg time/img: 0.0157 s
# VAL loss: 0.7156 (epoch: 30, step: 50) // Avg time/img: 0.0223 s
# VAL loss: 0.7437 (epoch: 30, step: 100) // Avg time/img: 0.0225 s
# VAL loss: 0.6485 (epoch: 30, step: 150) // Avg time/img: 0.0227 s
# EPOCH IoU on VAL set:  38.41 %
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.1927 (epoch: 31, step: 0) // Avg time/img: 0.0739 s
# loss: 0.2689 (epoch: 31, step: 50) // Avg time/img: 0.0498 s
# loss: 0.2733 (epoch: 31, step: 100) // Avg time/img: 0.0503 s
# loss: 0.2722 (epoch: 31, step: 150) // Avg time/img: 0.0510 s
# loss: 0.2687 (epoch: 31, step: 200) // Avg time/img: 0.0507 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.7847 (epoch: 31, step: 0) // Avg time/img: 0.0220 s
# VAL loss: 0.7869 (epoch: 31, step: 50) // Avg time/img: 0.0208 s
# VAL loss: 0.76 (epoch: 31, step: 100) // Avg time/img: 0.0215 s
# VAL loss: 0.6546 (epoch: 31, step: 150) // Avg time/img: 0.0217 s
# EPOCH IoU on VAL set:  38.30 %
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.0002598915008274931
# loss: 0.4133 (epoch: 32, step: 0) // Avg time/img: 0.0766 s
# loss: 0.2615 (epoch: 32, step: 50) // Avg time/img: 0.0501 s
# loss: 0.2686 (epoch: 32, step: 100) // Avg time/img: 0.0502 s
# loss: 0.2724 (epoch: 32, step: 150) // Avg time/img: 0.0502 s
# loss: 0.27 (epoch: 32, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.5317 (epoch: 32, step: 0) // Avg time/img: 0.0204 s
# VAL loss: 0.7335 (epoch: 32, step: 50) // Avg time/img: 0.0223 s
# VAL loss: 0.7324 (epoch: 32, step: 100) // Avg time/img: 0.0219 s
# VAL loss: 0.634 (epoch: 32, step: 150) // Avg time/img: 0.0213 s
# EPOCH IoU on VAL set:  39.73 %
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.2425 (epoch: 33, step: 0) // Avg time/img: 0.0720 s
# loss: 0.2625 (epoch: 33, step: 50) // Avg time/img: 0.0508 s
# loss: 0.2567 (epoch: 33, step: 100) // Avg time/img: 0.0508 s
# loss: 0.2593 (epoch: 33, step: 150) // Avg time/img: 0.0506 s
# loss: 0.2569 (epoch: 33, step: 200) // Avg time/img: 0.0502 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.4707 (epoch: 33, step: 0) // Avg time/img: 0.0199 s
# VAL loss: 0.6991 (epoch: 33, step: 50) // Avg time/img: 0.0214 s
# VAL loss: 0.6703 (epoch: 33, step: 100) // Avg time/img: 0.0204 s
# VAL loss: 0.5817 (epoch: 33, step: 150) // Avg time/img: 0.0199 s
# EPOCH IoU on VAL set:  39.41 %
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.00024370321958949772
# loss: 0.2974 (epoch: 34, step: 0) // Avg time/img: 0.0624 s
# loss: 0.2558 (epoch: 34, step: 50) // Avg time/img: 0.0503 s
# loss: 0.2518 (epoch: 34, step: 100) // Avg time/img: 0.0500 s
# loss: 0.2504 (epoch: 34, step: 150) // Avg time/img: 0.0504 s
# loss: 0.2552 (epoch: 34, step: 200) // Avg time/img: 0.0503 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.7222 (epoch: 34, step: 0) // Avg time/img: 0.0198 s
# VAL loss: 0.7005 (epoch: 34, step: 50) // Avg time/img: 0.0216 s
# VAL loss: 0.7122 (epoch: 34, step: 100) // Avg time/img: 0.0221 s
# VAL loss: 0.62 (epoch: 34, step: 150) // Avg time/img: 0.0223 s
# EPOCH IoU on VAL set:  39.58 %
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.2267 (epoch: 35, step: 0) // Avg time/img: 0.0742 s
# loss: 0.2537 (epoch: 35, step: 50) // Avg time/img: 0.0501 s
# loss: 0.2538 (epoch: 35, step: 100) // Avg time/img: 0.0506 s
# loss: 0.2529 (epoch: 35, step: 150) // Avg time/img: 0.0506 s
# loss: 0.2517 (epoch: 35, step: 200) // Avg time/img: 0.0507 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.994 (epoch: 35, step: 0) // Avg time/img: 0.0210 s
# VAL loss: 0.8891 (epoch: 35, step: 50) // Avg time/img: 0.0199 s
# VAL loss: 0.9032 (epoch: 35, step: 100) // Avg time/img: 0.0210 s
# VAL loss: 0.7763 (epoch: 35, step: 150) // Avg time/img: 0.0206 s
# EPOCH IoU on VAL set:  37.44 %
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.00022739446367039517
# loss: 0.245 (epoch: 36, step: 0) // Avg time/img: 0.0560 s
# loss: 0.2408 (epoch: 36, step: 50) // Avg time/img: 0.0502 s
# loss: 0.2434 (epoch: 36, step: 100) // Avg time/img: 0.0501 s
# loss: 0.2443 (epoch: 36, step: 150) // Avg time/img: 0.0499 s
# loss: 0.2449 (epoch: 36, step: 200) // Avg time/img: 0.0498 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.5385 (epoch: 36, step: 0) // Avg time/img: 0.0233 s
# VAL loss: 0.6323 (epoch: 36, step: 50) // Avg time/img: 0.0225 s
# VAL loss: 0.6359 (epoch: 36, step: 100) // Avg time/img: 0.0225 s
# VAL loss: 0.5631 (epoch: 36, step: 150) // Avg time/img: 0.0217 s
# EPOCH IoU on VAL set:  41.15 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 36)
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.1807 (epoch: 37, step: 0) // Avg time/img: 0.0717 s
# loss: 0.2604 (epoch: 37, step: 50) // Avg time/img: 0.0506 s
# loss: 0.2548 (epoch: 37, step: 100) // Avg time/img: 0.0509 s
# loss: 0.2502 (epoch: 37, step: 150) // Avg time/img: 0.0509 s
# loss: 0.2489 (epoch: 37, step: 200) // Avg time/img: 0.0507 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.5022 (epoch: 37, step: 0) // Avg time/img: 0.0175 s
# VAL loss: 0.6793 (epoch: 37, step: 50) // Avg time/img: 0.0197 s
# VAL loss: 0.6577 (epoch: 37, step: 100) // Avg time/img: 0.0203 s
# VAL loss: 0.5677 (epoch: 37, step: 150) // Avg time/img: 0.0205 s
# EPOCH IoU on VAL set:  40.83 %
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.00021095456673472888
# loss: 0.3101 (epoch: 38, step: 0) // Avg time/img: 0.0508 s
# loss: 0.2548 (epoch: 38, step: 50) // Avg time/img: 0.0498 s
# loss: 0.2445 (epoch: 38, step: 100) // Avg time/img: 0.0498 s
# loss: 0.2444 (epoch: 38, step: 150) // Avg time/img: 0.0496 s
# loss: 0.238 (epoch: 38, step: 200) // Avg time/img: 0.0499 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.7279 (epoch: 38, step: 0) // Avg time/img: 0.0178 s
# VAL loss: 0.7165 (epoch: 38, step: 50) // Avg time/img: 0.0210 s
# VAL loss: 0.7142 (epoch: 38, step: 100) // Avg time/img: 0.0206 s
# VAL loss: 0.6217 (epoch: 38, step: 150) // Avg time/img: 0.0201 s
# EPOCH IoU on VAL set:  40.19 %
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.15 (epoch: 39, step: 0) // Avg time/img: 0.0853 s
# loss: 0.2273 (epoch: 39, step: 50) // Avg time/img: 0.0510 s
# loss: 0.2237 (epoch: 39, step: 100) // Avg time/img: 0.0503 s
# loss: 0.2277 (epoch: 39, step: 150) // Avg time/img: 0.0502 s
# loss: 0.2317 (epoch: 39, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.5244 (epoch: 39, step: 0) // Avg time/img: 0.0214 s
# VAL loss: 0.6365 (epoch: 39, step: 50) // Avg time/img: 0.0203 s
# VAL loss: 0.6407 (epoch: 39, step: 100) // Avg time/img: 0.0207 s
# VAL loss: 0.5596 (epoch: 39, step: 150) // Avg time/img: 0.0208 s
# EPOCH IoU on VAL set:  41.73 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 39)
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.2075 (epoch: 40, step: 0) // Avg time/img: 0.0648 s
# loss: 0.2305 (epoch: 40, step: 50) // Avg time/img: 0.0517 s
# loss: 0.2266 (epoch: 40, step: 100) // Avg time/img: 0.0518 s
# loss: 0.2293 (epoch: 40, step: 150) // Avg time/img: 0.0513 s
# loss: 0.233 (epoch: 40, step: 200) // Avg time/img: 0.0509 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.4567 (epoch: 40, step: 0) // Avg time/img: 0.0189 s
# VAL loss: 0.6071 (epoch: 40, step: 50) // Avg time/img: 0.0207 s
# VAL loss: 0.6092 (epoch: 40, step: 100) // Avg time/img: 0.0221 s
# VAL loss: 0.5364 (epoch: 40, step: 150) // Avg time/img: 0.0223 s
# EPOCH IoU on VAL set:  42.95 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 40)
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.2228 (epoch: 41, step: 0) // Avg time/img: 0.0738 s
# loss: 0.2282 (epoch: 41, step: 50) // Avg time/img: 0.0508 s
# loss: 0.2305 (epoch: 41, step: 100) // Avg time/img: 0.0501 s
# loss: 0.2293 (epoch: 41, step: 150) // Avg time/img: 0.0503 s
# loss: 0.2303 (epoch: 41, step: 200) // Avg time/img: 0.0503 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.4956 (epoch: 41, step: 0) // Avg time/img: 0.0197 s
# VAL loss: 0.6877 (epoch: 41, step: 50) // Avg time/img: 0.0197 s
# VAL loss: 0.6802 (epoch: 41, step: 100) // Avg time/img: 0.0211 s
# VAL loss: 0.5873 (epoch: 41, step: 150) // Avg time/img: 0.0218 s
# EPOCH IoU on VAL set:  41.24 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.2522 (epoch: 42, step: 0) // Avg time/img: 0.0635 s
# loss: 0.2224 (epoch: 42, step: 50) // Avg time/img: 0.0499 s
# loss: 0.2227 (epoch: 42, step: 100) // Avg time/img: 0.0496 s
# loss: 0.2206 (epoch: 42, step: 150) // Avg time/img: 0.0498 s
# loss: 0.2198 (epoch: 42, step: 200) // Avg time/img: 0.0501 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.4903 (epoch: 42, step: 0) // Avg time/img: 0.0187 s
# VAL loss: 0.665 (epoch: 42, step: 50) // Avg time/img: 0.0201 s
# VAL loss: 0.6627 (epoch: 42, step: 100) // Avg time/img: 0.0198 s
# VAL loss: 0.574 (epoch: 42, step: 150) // Avg time/img: 0.0197 s
# EPOCH IoU on VAL set:  42.21 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.2059 (epoch: 43, step: 0) // Avg time/img: 0.0498 s
# loss: 0.2207 (epoch: 43, step: 50) // Avg time/img: 0.0512 s
# loss: 0.2238 (epoch: 43, step: 100) // Avg time/img: 0.0507 s
# loss: 0.2203 (epoch: 43, step: 150) // Avg time/img: 0.0502 s
# loss: 0.22 (epoch: 43, step: 200) // Avg time/img: 0.0499 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.64 (epoch: 43, step: 0) // Avg time/img: 0.0183 s
# VAL loss: 0.7544 (epoch: 43, step: 50) // Avg time/img: 0.0208 s
# VAL loss: 0.793 (epoch: 43, step: 100) // Avg time/img: 0.0198 s
# VAL loss: 0.6733 (epoch: 43, step: 150) // Avg time/img: 0.0200 s
# EPOCH IoU on VAL set:  39.37 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.1675 (epoch: 44, step: 0) // Avg time/img: 0.0717 s
# loss: 0.2307 (epoch: 44, step: 50) // Avg time/img: 0.0503 s
# loss: 0.2241 (epoch: 44, step: 100) // Avg time/img: 0.0512 s
# loss: 0.2164 (epoch: 44, step: 150) // Avg time/img: 0.0509 s
# loss: 0.2187 (epoch: 44, step: 200) // Avg time/img: 0.0504 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.5602 (epoch: 44, step: 0) // Avg time/img: 0.0200 s
# VAL loss: 0.7038 (epoch: 44, step: 50) // Avg time/img: 0.0221 s
# VAL loss: 0.6841 (epoch: 44, step: 100) // Avg time/img: 0.0229 s
# VAL loss: 0.583 (epoch: 44, step: 150) // Avg time/img: 0.0225 s
# EPOCH IoU on VAL set:  41.94 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.1725 (epoch: 45, step: 0) // Avg time/img: 0.0754 s
# loss: 0.2084 (epoch: 45, step: 50) // Avg time/img: 0.0506 s
# loss: 0.2106 (epoch: 45, step: 100) // Avg time/img: 0.0504 s
# loss: 0.212 (epoch: 45, step: 150) // Avg time/img: 0.0508 s
# loss: 0.2135 (epoch: 45, step: 200) // Avg time/img: 0.0509 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.5297 (epoch: 45, step: 0) // Avg time/img: 0.0217 s
# VAL loss: 0.6367 (epoch: 45, step: 50) // Avg time/img: 0.0227 s
# VAL loss: 0.63 (epoch: 45, step: 100) // Avg time/img: 0.0230 s
# VAL loss: 0.5434 (epoch: 45, step: 150) // Avg time/img: 0.0229 s
# EPOCH IoU on VAL set:  43.42 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 45)
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.2787 (epoch: 46, step: 0) // Avg time/img: 0.0732 s
# loss: 0.1996 (epoch: 46, step: 50) // Avg time/img: 0.0506 s
# loss: 0.2089 (epoch: 46, step: 100) // Avg time/img: 0.0504 s
# loss: 0.2082 (epoch: 46, step: 150) // Avg time/img: 0.0502 s
# loss: 0.2121 (epoch: 46, step: 200) // Avg time/img: 0.0502 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.44 (epoch: 46, step: 0) // Avg time/img: 0.0243 s
# VAL loss: 0.6508 (epoch: 46, step: 50) // Avg time/img: 0.0207 s
# VAL loss: 0.6456 (epoch: 46, step: 100) // Avg time/img: 0.0216 s
# VAL loss: 0.5543 (epoch: 46, step: 150) // Avg time/img: 0.0217 s
# EPOCH IoU on VAL set:  42.86 %
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.3206 (epoch: 47, step: 0) // Avg time/img: 0.0740 s
# loss: 0.2133 (epoch: 47, step: 50) // Avg time/img: 0.0520 s
# loss: 0.2079 (epoch: 47, step: 100) // Avg time/img: 0.0517 s
# loss: 0.2094 (epoch: 47, step: 150) // Avg time/img: 0.0513 s
# loss: 0.2072 (epoch: 47, step: 200) // Avg time/img: 0.0510 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.5025 (epoch: 47, step: 0) // Avg time/img: 0.0198 s
# VAL loss: 0.672 (epoch: 47, step: 50) // Avg time/img: 0.0235 s
# VAL loss: 0.6619 (epoch: 47, step: 100) // Avg time/img: 0.0231 s
# VAL loss: 0.5709 (epoch: 47, step: 150) // Avg time/img: 0.0227 s
# EPOCH IoU on VAL set:  43.40 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.15 (epoch: 48, step: 0) // Avg time/img: 0.0771 s
# loss: 0.2081 (epoch: 48, step: 50) // Avg time/img: 0.0510 s
# loss: 0.2115 (epoch: 48, step: 100) // Avg time/img: 0.0513 s
# loss: 0.2111 (epoch: 48, step: 150) // Avg time/img: 0.0509 s
# loss: 0.2081 (epoch: 48, step: 200) // Avg time/img: 0.0507 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.5337 (epoch: 48, step: 0) // Avg time/img: 0.0203 s
# VAL loss: 0.6753 (epoch: 48, step: 50) // Avg time/img: 0.0219 s
# VAL loss: 0.6642 (epoch: 48, step: 100) // Avg time/img: 0.0230 s
# VAL loss: 0.5635 (epoch: 48, step: 150) // Avg time/img: 0.0218 s
# EPOCH IoU on VAL set:  43.04 %
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.2096 (epoch: 49, step: 0) // Avg time/img: 0.0713 s
# loss: 0.194 (epoch: 49, step: 50) // Avg time/img: 0.0499 s
# loss: 0.2028 (epoch: 49, step: 100) // Avg time/img: 0.0497 s
# loss: 0.2052 (epoch: 49, step: 150) // Avg time/img: 0.0503 s
# loss: 0.2037 (epoch: 49, step: 200) // Avg time/img: 0.0503 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.5178 (epoch: 49, step: 0) // Avg time/img: 0.0186 s
# VAL loss: 0.6545 (epoch: 49, step: 50) // Avg time/img: 0.0193 s
# VAL loss: 0.6484 (epoch: 49, step: 100) // Avg time/img: 0.0191 s
# VAL loss: 0.5613 (epoch: 49, step: 150) // Avg time/img: 0.0200 s
# EPOCH IoU on VAL set:  43.14 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.1816 (epoch: 50, step: 0) // Avg time/img: 0.0668 s
# loss: 0.2051 (epoch: 50, step: 50) // Avg time/img: 0.0504 s
# loss: 0.202 (epoch: 50, step: 100) // Avg time/img: 0.0505 s
# loss: 0.2013 (epoch: 50, step: 150) // Avg time/img: 0.0505 s
# loss: 0.198 (epoch: 50, step: 200) // Avg time/img: 0.0505 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.5113 (epoch: 50, step: 0) // Avg time/img: 0.0181 s
# VAL loss: 0.7739 (epoch: 50, step: 50) // Avg time/img: 0.0205 s
# VAL loss: 0.7737 (epoch: 50, step: 100) // Avg time/img: 0.0205 s
# VAL loss: 0.6622 (epoch: 50, step: 150) // Avg time/img: 0.0207 s
# EPOCH IoU on VAL set:  41.84 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.1438 (epoch: 51, step: 0) // Avg time/img: 0.0810 s
# loss: 0.1965 (epoch: 51, step: 50) // Avg time/img: 0.0509 s
# loss: 0.1953 (epoch: 51, step: 100) // Avg time/img: 0.0504 s
# loss: 0.1955 (epoch: 51, step: 150) // Avg time/img: 0.0502 s
# loss: 0.1973 (epoch: 51, step: 200) // Avg time/img: 0.0501 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.4182 (epoch: 51, step: 0) // Avg time/img: 0.0227 s
# VAL loss: 0.654 (epoch: 51, step: 50) // Avg time/img: 0.0216 s
# VAL loss: 0.6581 (epoch: 51, step: 100) // Avg time/img: 0.0225 s
# VAL loss: 0.5712 (epoch: 51, step: 150) // Avg time/img: 0.0218 s
# EPOCH IoU on VAL set:  42.78 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.1793 (epoch: 52, step: 0) // Avg time/img: 0.0712 s
# loss: 0.192 (epoch: 52, step: 50) // Avg time/img: 0.0516 s
# loss: 0.1882 (epoch: 52, step: 100) // Avg time/img: 0.0508 s
# loss: 0.1892 (epoch: 52, step: 150) // Avg time/img: 0.0505 s
# loss: 0.1914 (epoch: 52, step: 200) // Avg time/img: 0.0503 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.4238 (epoch: 52, step: 0) // Avg time/img: 0.0165 s
# VAL loss: 0.6849 (epoch: 52, step: 50) // Avg time/img: 0.0209 s
# VAL loss: 0.6708 (epoch: 52, step: 100) // Avg time/img: 0.0214 s
# VAL loss: 0.5749 (epoch: 52, step: 150) // Avg time/img: 0.0213 s
# EPOCH IoU on VAL set:  43.58 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 52)
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.1968 (epoch: 53, step: 0) // Avg time/img: 0.0717 s
# loss: 0.191 (epoch: 53, step: 50) // Avg time/img: 0.0505 s
# loss: 0.1977 (epoch: 53, step: 100) // Avg time/img: 0.0509 s
# loss: 0.1944 (epoch: 53, step: 150) // Avg time/img: 0.0506 s
# loss: 0.1926 (epoch: 53, step: 200) // Avg time/img: 0.0502 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.4613 (epoch: 53, step: 0) // Avg time/img: 0.0154 s
# VAL loss: 0.6349 (epoch: 53, step: 50) // Avg time/img: 0.0226 s
# VAL loss: 0.6181 (epoch: 53, step: 100) // Avg time/img: 0.0227 s
# VAL loss: 0.5403 (epoch: 53, step: 150) // Avg time/img: 0.0219 s
# EPOCH IoU on VAL set:  44.26 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.2439 (epoch: 54, step: 0) // Avg time/img: 0.0747 s
# loss: 0.1947 (epoch: 54, step: 50) // Avg time/img: 0.0509 s
# loss: 0.1882 (epoch: 54, step: 100) // Avg time/img: 0.0512 s
# loss: 0.1841 (epoch: 54, step: 150) // Avg time/img: 0.0515 s
# loss: 0.1883 (epoch: 54, step: 200) // Avg time/img: 0.0510 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.4309 (epoch: 54, step: 0) // Avg time/img: 0.0226 s
# VAL loss: 0.6349 (epoch: 54, step: 50) // Avg time/img: 0.0202 s
# VAL loss: 0.6449 (epoch: 54, step: 100) // Avg time/img: 0.0215 s
# VAL loss: 0.5571 (epoch: 54, step: 150) // Avg time/img: 0.0220 s
# EPOCH IoU on VAL set:  43.82 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.1203 (epoch: 55, step: 0) // Avg time/img: 0.0534 s
# loss: 0.1824 (epoch: 55, step: 50) // Avg time/img: 0.0501 s
# loss: 0.1852 (epoch: 55, step: 100) // Avg time/img: 0.0502 s
# loss: 0.1855 (epoch: 55, step: 150) // Avg time/img: 0.0502 s
# loss: 0.1864 (epoch: 55, step: 200) // Avg time/img: 0.0505 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.4101 (epoch: 55, step: 0) // Avg time/img: 0.0163 s
# VAL loss: 0.6342 (epoch: 55, step: 50) // Avg time/img: 0.0220 s
# VAL loss: 0.6377 (epoch: 55, step: 100) // Avg time/img: 0.0217 s
# VAL loss: 0.5534 (epoch: 55, step: 150) // Avg time/img: 0.0219 s
# EPOCH IoU on VAL set:  44.16 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.09929 (epoch: 56, step: 0) // Avg time/img: 0.0777 s
# loss: 0.1717 (epoch: 56, step: 50) // Avg time/img: 0.0508 s
# loss: 0.1772 (epoch: 56, step: 100) // Avg time/img: 0.0503 s
# loss: 0.1796 (epoch: 56, step: 150) // Avg time/img: 0.0504 s
# loss: 0.1824 (epoch: 56, step: 200) // Avg time/img: 0.0505 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.4082 (epoch: 56, step: 0) // Avg time/img: 0.0211 s
# VAL loss: 0.6406 (epoch: 56, step: 50) // Avg time/img: 0.0201 s
# VAL loss: 0.6371 (epoch: 56, step: 100) // Avg time/img: 0.0206 s
# VAL loss: 0.5529 (epoch: 56, step: 150) // Avg time/img: 0.0210 s
# EPOCH IoU on VAL set:  44.54 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 56)
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.1863 (epoch: 57, step: 0) // Avg time/img: 0.0692 s
# loss: 0.1803 (epoch: 57, step: 50) // Avg time/img: 0.0513 s
# loss: 0.1802 (epoch: 57, step: 100) // Avg time/img: 0.0506 s
# loss: 0.1822 (epoch: 57, step: 150) // Avg time/img: 0.0505 s
# loss: 0.1832 (epoch: 57, step: 200) // Avg time/img: 0.0503 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.4439 (epoch: 57, step: 0) // Avg time/img: 0.0233 s
# VAL loss: 0.6401 (epoch: 57, step: 50) // Avg time/img: 0.0222 s
# VAL loss: 0.642 (epoch: 57, step: 100) // Avg time/img: 0.0217 s
# VAL loss: 0.5552 (epoch: 57, step: 150) // Avg time/img: 0.0218 s
# EPOCH IoU on VAL set:  44.22 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.2085 (epoch: 58, step: 0) // Avg time/img: 0.0707 s
# loss: 0.1875 (epoch: 58, step: 50) // Avg time/img: 0.0501 s
# loss: 0.1822 (epoch: 58, step: 100) // Avg time/img: 0.0505 s
# loss: 0.1807 (epoch: 58, step: 150) // Avg time/img: 0.0504 s
# loss: 0.1815 (epoch: 58, step: 200) // Avg time/img: 0.0502 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.3853 (epoch: 58, step: 0) // Avg time/img: 0.0204 s
# VAL loss: 0.639 (epoch: 58, step: 50) // Avg time/img: 0.0214 s
# VAL loss: 0.6384 (epoch: 58, step: 100) // Avg time/img: 0.0221 s
# VAL loss: 0.5536 (epoch: 58, step: 150) // Avg time/img: 0.0214 s
# EPOCH IoU on VAL set:  44.54 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.1937 (epoch: 59, step: 0) // Avg time/img: 0.0704 s
# loss: 0.1785 (epoch: 59, step: 50) // Avg time/img: 0.0499 s
# loss: 0.1782 (epoch: 59, step: 100) // Avg time/img: 0.0499 s
# loss: 0.1792 (epoch: 59, step: 150) // Avg time/img: 0.0503 s
# loss: 0.1781 (epoch: 59, step: 200) // Avg time/img: 0.0502 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.4029 (epoch: 59, step: 0) // Avg time/img: 0.0172 s
# VAL loss: 0.6565 (epoch: 59, step: 50) // Avg time/img: 0.0199 s
# VAL loss: 0.6593 (epoch: 59, step: 100) // Avg time/img: 0.0210 s
# VAL loss: 0.5686 (epoch: 59, step: 150) // Avg time/img: 0.0212 s
# EPOCH IoU on VAL set:  43.94 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.172 (epoch: 60, step: 0) // Avg time/img: 0.0745 s
# loss: 0.1763 (epoch: 60, step: 50) // Avg time/img: 0.0501 s
# loss: 0.1789 (epoch: 60, step: 100) // Avg time/img: 0.0500 s
# loss: 0.1779 (epoch: 60, step: 150) // Avg time/img: 0.0501 s
# loss: 0.1783 (epoch: 60, step: 200) // Avg time/img: 0.0505 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.3978 (epoch: 60, step: 0) // Avg time/img: 0.0197 s
# VAL loss: 0.6343 (epoch: 60, step: 50) // Avg time/img: 0.0223 s
# VAL loss: 0.6298 (epoch: 60, step: 100) // Avg time/img: 0.0217 s
# VAL loss: 0.5457 (epoch: 60, step: 150) // Avg time/img: 0.0216 s
# EPOCH IoU on VAL set:  44.60 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_encoder_best.pth (epoch: 60)
# ========== DECODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.047 (epoch: 1, step: 0) // Avg time/img: 0.1621 s
# loss: 2.596 (epoch: 1, step: 50) // Avg time/img: 0.0861 s
# loss: 2.224 (epoch: 1, step: 100) // Avg time/img: 0.0858 s
# loss: 1.936 (epoch: 1, step: 150) // Avg time/img: 0.0854 s
# loss: 1.737 (epoch: 1, step: 200) // Avg time/img: 0.0854 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.076 (epoch: 1, step: 0) // Avg time/img: 0.0328 s
# VAL loss: 1.418 (epoch: 1, step: 50) // Avg time/img: 0.0316 s
# VAL loss: 1.367 (epoch: 1, step: 100) // Avg time/img: 0.0314 s
# VAL loss: 1.218 (epoch: 1, step: 150) // Avg time/img: 0.0318 s
# EPOCH IoU on VAL set:  20.33 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 1.304 (epoch: 2, step: 0) // Avg time/img: 0.1155 s
# loss: 0.8467 (epoch: 2, step: 50) // Avg time/img: 0.0852 s
# loss: 0.8347 (epoch: 2, step: 100) // Avg time/img: 0.0853 s
# loss: 0.8138 (epoch: 2, step: 150) // Avg time/img: 0.0855 s
# loss: 0.8015 (epoch: 2, step: 200) // Avg time/img: 0.0851 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 0.7622 (epoch: 2, step: 0) // Avg time/img: 0.0300 s
# VAL loss: 1.197 (epoch: 2, step: 50) // Avg time/img: 0.0323 s
# VAL loss: 1.145 (epoch: 2, step: 100) // Avg time/img: 0.0326 s
# VAL loss: 1.013 (epoch: 2, step: 150) // Avg time/img: 0.0324 s
# EPOCH IoU on VAL set:  21.80 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.6938 (epoch: 3, step: 0) // Avg time/img: 0.1188 s
# loss: 0.6957 (epoch: 3, step: 50) // Avg time/img: 0.0860 s
# loss: 0.6924 (epoch: 3, step: 100) // Avg time/img: 0.0855 s
# loss: 0.6836 (epoch: 3, step: 150) // Avg time/img: 0.0854 s
# loss: 0.6616 (epoch: 3, step: 200) // Avg time/img: 0.0850 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 0.8381 (epoch: 3, step: 0) // Avg time/img: 0.0313 s
# VAL loss: 1.066 (epoch: 3, step: 50) // Avg time/img: 0.0325 s
# VAL loss: 1.023 (epoch: 3, step: 100) // Avg time/img: 0.0322 s
# VAL loss: 0.8955 (epoch: 3, step: 150) // Avg time/img: 0.0321 s
# EPOCH IoU on VAL set:  26.32 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 0.4357 (epoch: 4, step: 0) // Avg time/img: 0.1197 s
# loss: 0.556 (epoch: 4, step: 50) // Avg time/img: 0.0852 s
# loss: 0.5586 (epoch: 4, step: 100) // Avg time/img: 0.0866 s
# ...
# EPOCH IoU on VAL set:  44.77 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 39)
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.1714 (epoch: 40, step: 0) // Avg time/img: 0.0959 s
# loss: 0.204 (epoch: 40, step: 50) // Avg time/img: 0.0850 s
# loss: 0.2057 (epoch: 40, step: 100) // Avg time/img: 0.0851 s
# loss: 0.2074 (epoch: 40, step: 150) // Avg time/img: 0.0855 s
# loss: 0.2088 (epoch: 40, step: 200) // Avg time/img: 0.0851 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.4576 (epoch: 40, step: 0) // Avg time/img: 0.0309 s
# VAL loss: 0.7351 (epoch: 40, step: 50) // Avg time/img: 0.0310 s
# VAL loss: 0.7036 (epoch: 40, step: 100) // Avg time/img: 0.0316 s
# VAL loss: 0.6046 (epoch: 40, step: 150) // Avg time/img: 0.0312 s
# EPOCH IoU on VAL set:  45.24 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 40)
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.2334 (epoch: 41, step: 0) // Avg time/img: 0.1070 s
# loss: 0.196 (epoch: 41, step: 50) // Avg time/img: 0.0853 s
# loss: 0.1974 (epoch: 41, step: 100) // Avg time/img: 0.0866 s
# loss: 0.2 (epoch: 41, step: 150) // Avg time/img: 0.0860 s
# loss: 0.2004 (epoch: 41, step: 200) // Avg time/img: 0.0854 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.4548 (epoch: 41, step: 0) // Avg time/img: 0.0270 s
# VAL loss: 0.776 (epoch: 41, step: 50) // Avg time/img: 0.0335 s
# VAL loss: 0.7789 (epoch: 41, step: 100) // Avg time/img: 0.0325 s
# VAL loss: 0.682 (epoch: 41, step: 150) // Avg time/img: 0.0321 s
# EPOCH IoU on VAL set:  44.41 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.235 (epoch: 42, step: 0) // Avg time/img: 0.1105 s
# loss: 0.2295 (epoch: 42, step: 50) // Avg time/img: 0.0857 s
# loss: 0.2129 (epoch: 42, step: 100) // Avg time/img: 0.0863 s
# loss: 0.207 (epoch: 42, step: 150) // Avg time/img: 0.0858 s
# loss: 0.2067 (epoch: 42, step: 200) // Avg time/img: 0.0853 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.3769 (epoch: 42, step: 0) // Avg time/img: 0.0429 s
# VAL loss: 0.7236 (epoch: 42, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.7247 (epoch: 42, step: 100) // Avg time/img: 0.0323 s
# VAL loss: 0.6392 (epoch: 42, step: 150) // Avg time/img: 0.0319 s
# EPOCH IoU on VAL set:  45.79 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 42)
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.2025 (epoch: 43, step: 0) // Avg time/img: 0.0814 s
# loss: 0.1901 (epoch: 43, step: 50) // Avg time/img: 0.0890 s
# loss: 0.1963 (epoch: 43, step: 100) // Avg time/img: 0.0867 s
# loss: 0.1961 (epoch: 43, step: 150) // Avg time/img: 0.0858 s
# loss: 0.1968 (epoch: 43, step: 200) // Avg time/img: 0.0853 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.389 (epoch: 43, step: 0) // Avg time/img: 0.0326 s
# VAL loss: 0.7168 (epoch: 43, step: 50) // Avg time/img: 0.0319 s
# VAL loss: 0.6824 (epoch: 43, step: 100) // Avg time/img: 0.0314 s
# VAL loss: 0.5997 (epoch: 43, step: 150) // Avg time/img: 0.0311 s
# EPOCH IoU on VAL set:  46.09 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 43)
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.1474 (epoch: 44, step: 0) // Avg time/img: 0.1054 s
# loss: 0.1908 (epoch: 44, step: 50) // Avg time/img: 0.0853 s
# loss: 0.1915 (epoch: 44, step: 100) // Avg time/img: 0.0850 s
# loss: 0.1919 (epoch: 44, step: 150) // Avg time/img: 0.0846 s
# loss: 0.1916 (epoch: 44, step: 200) // Avg time/img: 0.0851 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.3767 (epoch: 44, step: 0) // Avg time/img: 0.0325 s
# VAL loss: 0.7218 (epoch: 44, step: 50) // Avg time/img: 0.0323 s
# VAL loss: 0.7205 (epoch: 44, step: 100) // Avg time/img: 0.0318 s
# VAL loss: 0.6292 (epoch: 44, step: 150) // Avg time/img: 0.0322 s
# EPOCH IoU on VAL set:  45.86 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.1778 (epoch: 45, step: 0) // Avg time/img: 0.1153 s
# loss: 0.2055 (epoch: 45, step: 50) // Avg time/img: 0.0865 s
# loss: 0.206 (epoch: 45, step: 100) // Avg time/img: 0.0856 s
# loss: 0.2046 (epoch: 45, step: 150) // Avg time/img: 0.0852 s
# loss: 0.2021 (epoch: 45, step: 200) // Avg time/img: 0.0855 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.3512 (epoch: 45, step: 0) // Avg time/img: 0.0377 s
# VAL loss: 0.7101 (epoch: 45, step: 50) // Avg time/img: 0.0310 s
# VAL loss: 0.6989 (epoch: 45, step: 100) // Avg time/img: 0.0307 s
# VAL loss: 0.6131 (epoch: 45, step: 150) // Avg time/img: 0.0314 s
# EPOCH IoU on VAL set:  45.96 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.1357 (epoch: 46, step: 0) // Avg time/img: 0.0878 s
# loss: 0.1862 (epoch: 46, step: 50) // Avg time/img: 0.0847 s
# loss: 0.1849 (epoch: 46, step: 100) // Avg time/img: 0.0851 s
# loss: 0.1854 (epoch: 46, step: 150) // Avg time/img: 0.0853 s
# loss: 0.1875 (epoch: 46, step: 200) // Avg time/img: 0.0848 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.3848 (epoch: 46, step: 0) // Avg time/img: 0.0255 s
# VAL loss: 0.7314 (epoch: 46, step: 50) // Avg time/img: 0.0309 s
# VAL loss: 0.6983 (epoch: 46, step: 100) // Avg time/img: 0.0319 s
# VAL loss: 0.603 (epoch: 46, step: 150) // Avg time/img: 0.0314 s
# EPOCH IoU on VAL set:  46.94 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 46)
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.2138 (epoch: 47, step: 0) // Avg time/img: 0.1142 s
# loss: 0.1821 (epoch: 47, step: 50) // Avg time/img: 0.0865 s
# loss: 0.1873 (epoch: 47, step: 100) // Avg time/img: 0.0870 s
# loss: 0.1874 (epoch: 47, step: 150) // Avg time/img: 0.0858 s
# loss: 0.1879 (epoch: 47, step: 200) // Avg time/img: 0.0854 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.4437 (epoch: 47, step: 0) // Avg time/img: 0.0302 s
# VAL loss: 0.7301 (epoch: 47, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.7285 (epoch: 47, step: 100) // Avg time/img: 0.0319 s
# VAL loss: 0.634 (epoch: 47, step: 150) // Avg time/img: 0.0315 s
# EPOCH IoU on VAL set:  45.92 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.27 (epoch: 48, step: 0) // Avg time/img: 0.1041 s
# loss: 0.18 (epoch: 48, step: 50) // Avg time/img: 0.0858 s
# loss: 0.1825 (epoch: 48, step: 100) // Avg time/img: 0.0864 s
# loss: 0.1811 (epoch: 48, step: 150) // Avg time/img: 0.0857 s
# loss: 0.1841 (epoch: 48, step: 200) // Avg time/img: 0.0851 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.4262 (epoch: 48, step: 0) // Avg time/img: 0.0535 s
# VAL loss: 0.7184 (epoch: 48, step: 50) // Avg time/img: 0.0325 s
# VAL loss: 0.6964 (epoch: 48, step: 100) // Avg time/img: 0.0316 s
# VAL loss: 0.6041 (epoch: 48, step: 150) // Avg time/img: 0.0319 s
# EPOCH IoU on VAL set:  47.44 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 48)
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.2498 (epoch: 49, step: 0) // Avg time/img: 0.1055 s
# loss: 0.181 (epoch: 49, step: 50) // Avg time/img: 0.0869 s
# loss: 0.1827 (epoch: 49, step: 100) // Avg time/img: 0.0858 s
# loss: 0.1837 (epoch: 49, step: 150) // Avg time/img: 0.0855 s
# loss: 0.1841 (epoch: 49, step: 200) // Avg time/img: 0.0852 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.399 (epoch: 49, step: 0) // Avg time/img: 0.0355 s
# VAL loss: 0.7182 (epoch: 49, step: 50) // Avg time/img: 0.0312 s
# VAL loss: 0.7128 (epoch: 49, step: 100) // Avg time/img: 0.0310 s
# VAL loss: 0.6165 (epoch: 49, step: 150) // Avg time/img: 0.0308 s
# EPOCH IoU on VAL set:  47.36 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.1424 (epoch: 50, step: 0) // Avg time/img: 0.1059 s
# loss: 0.1754 (epoch: 50, step: 50) // Avg time/img: 0.0846 s
# loss: 0.1783 (epoch: 50, step: 100) // Avg time/img: 0.0852 s
# loss: 0.1798 (epoch: 50, step: 150) // Avg time/img: 0.0847 s
# loss: 0.1788 (epoch: 50, step: 200) // Avg time/img: 0.0852 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.4082 (epoch: 50, step: 0) // Avg time/img: 0.0315 s
# VAL loss: 0.764 (epoch: 50, step: 50) // Avg time/img: 0.0323 s
# VAL loss: 0.7556 (epoch: 50, step: 100) // Avg time/img: 0.0317 s
# VAL loss: 0.6639 (epoch: 50, step: 150) // Avg time/img: 0.0333 s
# EPOCH IoU on VAL set:  45.66 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.1783 (epoch: 51, step: 0) // Avg time/img: 0.1001 s
# loss: 0.1884 (epoch: 51, step: 50) // Avg time/img: 0.0856 s
# loss: 0.1842 (epoch: 51, step: 100) // Avg time/img: 0.0853 s
# loss: 0.1832 (epoch: 51, step: 150) // Avg time/img: 0.0859 s
# loss: 0.1833 (epoch: 51, step: 200) // Avg time/img: 0.0852 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.429 (epoch: 51, step: 0) // Avg time/img: 0.0244 s
# VAL loss: 0.7579 (epoch: 51, step: 50) // Avg time/img: 0.0313 s
# VAL loss: 0.7604 (epoch: 51, step: 100) // Avg time/img: 0.0317 s
# VAL loss: 0.655 (epoch: 51, step: 150) // Avg time/img: 0.0315 s
# EPOCH IoU on VAL set:  46.59 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.1412 (epoch: 52, step: 0) // Avg time/img: 0.0995 s
# loss: 0.17 (epoch: 52, step: 50) // Avg time/img: 0.0848 s
# loss: 0.1757 (epoch: 52, step: 100) // Avg time/img: 0.0851 s
# loss: 0.1739 (epoch: 52, step: 150) // Avg time/img: 0.0854 s
# loss: 0.1737 (epoch: 52, step: 200) // Avg time/img: 0.0852 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.3981 (epoch: 52, step: 0) // Avg time/img: 0.0319 s
# VAL loss: 0.7488 (epoch: 52, step: 50) // Avg time/img: 0.0310 s
# VAL loss: 0.7399 (epoch: 52, step: 100) // Avg time/img: 0.0316 s
# VAL loss: 0.6395 (epoch: 52, step: 150) // Avg time/img: 0.0315 s
# EPOCH IoU on VAL set:  46.79 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.1278 (epoch: 53, step: 0) // Avg time/img: 0.1060 s
# loss: 0.1675 (epoch: 53, step: 50) // Avg time/img: 0.0877 s
# loss: 0.1695 (epoch: 53, step: 100) // Avg time/img: 0.0878 s
# loss: 0.1707 (epoch: 53, step: 150) // Avg time/img: 0.0867 s
# loss: 0.171 (epoch: 53, step: 200) // Avg time/img: 0.0860 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.3943 (epoch: 53, step: 0) // Avg time/img: 0.0315 s
# VAL loss: 0.7336 (epoch: 53, step: 50) // Avg time/img: 0.0333 s
# VAL loss: 0.7299 (epoch: 53, step: 100) // Avg time/img: 0.0322 s
# VAL loss: 0.6286 (epoch: 53, step: 150) // Avg time/img: 0.0317 s
# EPOCH IoU on VAL set:  47.35 %
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.1595 (epoch: 54, step: 0) // Avg time/img: 0.1152 s
# loss: 0.1686 (epoch: 54, step: 50) // Avg time/img: 0.0885 s
# loss: 0.1749 (epoch: 54, step: 100) // Avg time/img: 0.0864 s
# loss: 0.1743 (epoch: 54, step: 150) // Avg time/img: 0.0856 s
# loss: 0.1732 (epoch: 54, step: 200) // Avg time/img: 0.0850 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.4482 (epoch: 54, step: 0) // Avg time/img: 0.0293 s
# VAL loss: 0.7486 (epoch: 54, step: 50) // Avg time/img: 0.0313 s
# VAL loss: 0.7381 (epoch: 54, step: 100) // Avg time/img: 0.0309 s
# VAL loss: 0.6371 (epoch: 54, step: 150) // Avg time/img: 0.0308 s
# EPOCH IoU on VAL set:  47.36 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.1168 (epoch: 55, step: 0) // Avg time/img: 0.0909 s
# loss: 0.1674 (epoch: 55, step: 50) // Avg time/img: 0.0863 s
# loss: 0.1661 (epoch: 55, step: 100) // Avg time/img: 0.0860 s
# loss: 0.1691 (epoch: 55, step: 150) // Avg time/img: 0.0855 s
# loss: 0.1677 (epoch: 55, step: 200) // Avg time/img: 0.0859 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.4015 (epoch: 55, step: 0) // Avg time/img: 0.0264 s
# VAL loss: 0.7442 (epoch: 55, step: 50) // Avg time/img: 0.0323 s
# VAL loss: 0.7275 (epoch: 55, step: 100) // Avg time/img: 0.0316 s
# VAL loss: 0.6293 (epoch: 55, step: 150) // Avg time/img: 0.0321 s
# EPOCH IoU on VAL set:  47.59 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 55)
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.1396 (epoch: 56, step: 0) // Avg time/img: 0.1076 s
# loss: 0.1704 (epoch: 56, step: 50) // Avg time/img: 0.0843 s
# loss: 0.1688 (epoch: 56, step: 100) // Avg time/img: 0.0849 s
# loss: 0.1674 (epoch: 56, step: 150) // Avg time/img: 0.0849 s
# loss: 0.1671 (epoch: 56, step: 200) // Avg time/img: 0.0850 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.3934 (epoch: 56, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.7326 (epoch: 56, step: 50) // Avg time/img: 0.0317 s
# VAL loss: 0.7096 (epoch: 56, step: 100) // Avg time/img: 0.0325 s
# VAL loss: 0.6111 (epoch: 56, step: 150) // Avg time/img: 0.0323 s
# EPOCH IoU on VAL set:  48.45 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 56)
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.1372 (epoch: 57, step: 0) // Avg time/img: 0.1118 s
# loss: 0.162 (epoch: 57, step: 50) // Avg time/img: 0.0854 s
# loss: 0.1606 (epoch: 57, step: 100) // Avg time/img: 0.0853 s
# loss: 0.1627 (epoch: 57, step: 150) // Avg time/img: 0.0862 s
# loss: 0.1639 (epoch: 57, step: 200) // Avg time/img: 0.0861 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.3866 (epoch: 57, step: 0) // Avg time/img: 0.0328 s
# VAL loss: 0.7167 (epoch: 57, step: 50) // Avg time/img: 0.0324 s
# VAL loss: 0.7017 (epoch: 57, step: 100) // Avg time/img: 0.0329 s
# VAL loss: 0.6132 (epoch: 57, step: 150) // Avg time/img: 0.0323 s
# EPOCH IoU on VAL set:  48.35 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.1554 (epoch: 58, step: 0) // Avg time/img: 0.0891 s
# loss: 0.1632 (epoch: 58, step: 50) // Avg time/img: 0.0848 s
# loss: 0.1636 (epoch: 58, step: 100) // Avg time/img: 0.0862 s
# loss: 0.1659 (epoch: 58, step: 150) // Avg time/img: 0.0854 s
# loss: 0.1637 (epoch: 58, step: 200) // Avg time/img: 0.0851 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.4073 (epoch: 58, step: 0) // Avg time/img: 0.0345 s
# VAL loss: 0.7585 (epoch: 58, step: 50) // Avg time/img: 0.0339 s
# VAL loss: 0.7413 (epoch: 58, step: 100) // Avg time/img: 0.0328 s
# VAL loss: 0.6386 (epoch: 58, step: 150) // Avg time/img: 0.0325 s
# EPOCH IoU on VAL set:  48.16 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.137 (epoch: 59, step: 0) // Avg time/img: 0.1059 s
# loss: 0.1582 (epoch: 59, step: 50) // Avg time/img: 0.0874 s
# loss: 0.1582 (epoch: 59, step: 100) // Avg time/img: 0.0874 s
# loss: 0.1605 (epoch: 59, step: 150) // Avg time/img: 0.0865 s
# loss: 0.1615 (epoch: 59, step: 200) // Avg time/img: 0.0862 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.4001 (epoch: 59, step: 0) // Avg time/img: 0.0274 s
# VAL loss: 0.7491 (epoch: 59, step: 50) // Avg time/img: 0.0311 s
# VAL loss: 0.7227 (epoch: 59, step: 100) // Avg time/img: 0.0312 s
# VAL loss: 0.6215 (epoch: 59, step: 150) // Avg time/img: 0.0314 s
# EPOCH IoU on VAL set:  48.66 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 59)
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.1618 (epoch: 60, step: 0) // Avg time/img: 0.1152 s
# loss: 0.1642 (epoch: 60, step: 50) // Avg time/img: 0.0860 s
# loss: 0.1636 (epoch: 60, step: 100) // Avg time/img: 0.0856 s
# loss: 0.1612 (epoch: 60, step: 150) // Avg time/img: 0.0851 s
# loss: 0.1604 (epoch: 60, step: 200) // Avg time/img: 0.0854 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.3805 (epoch: 60, step: 0) // Avg time/img: 0.0325 s
# VAL loss: 0.7124 (epoch: 60, step: 50) // Avg time/img: 0.0320 s
# VAL loss: 0.6918 (epoch: 60, step: 100) // Avg time/img: 0.0317 s
# VAL loss: 0.5996 (epoch: 60, step: 150) // Avg time/img: 0.0320 s
# EPOCH IoU on VAL set:  49.36 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-baseline-student/model_best.pth (epoch: 60)
# ========== TRAINING FINISHED ===========

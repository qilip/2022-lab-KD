# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet Model Common module

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)

class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

# %% [markdown]
# ## ERFNet Model [Teacher]

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class non_bottleneck (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3_1 = nn.Conv2d(chann, chann, (3,3), stride=1, padding=(1,1), bias=True)

        # self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3_2 = nn.Conv2d(chann, chann, (3, 3), stride=1, padding=(1*dilated,1*dilated), bias=True, dilation = (dilated,dilated))

        # self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3_1(input)
        # output = F.relu(output)
        # output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3_2(output)
        # output = F.relu(output)
        # output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class TEncoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck(128, 0.3, 2))
            self.layers.append(non_bottleneck(128, 0.3, 4))
            self.layers.append(non_bottleneck(128, 0.3, 8))
            self.layers.append(non_bottleneck(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output

class TDecoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck(64, 0, 1))
        self.layers.append(non_bottleneck(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck(16, 0, 1))
        self.layers.append(non_bottleneck(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet Teacher
class TNet(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = TEncoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = TDecoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## ERFNet model definition [Student]

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3x1_1 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1,0), bias=True)

        self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3x1_2 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1*dilated,0), bias=True, dilation = (dilated,1))

        self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3x1_1(input)
        output = F.relu(output)
        output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3x1_2(output)
        output = F.relu(output)
        output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 1):    #1 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 1):    #1 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        # self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        # self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target

class MainLoss(torch.nn.Module):
    def __init__(self, weight=None):
      super().__init__()
      self.celoss = torch.nn.NLLLoss2d(weight) # CrossEntropyLoss2d
      # self.kdloss = torch.nn.KLDivLoss(reduction='batchmean')
      self.kdloss = torch.nn.MSELoss()
    
    def forward(self, outputs, targets, toutputs):
      T = 7 # Temperature
      alpha = 0.7 # alpha

      # 기본 Loss
      general_loss = self.celoss(torch.nn.functional.log_softmax(outputs, dim=1), targets)

      # KD Loss
      # toutputs[0].detach()
      # kd_loss = self.kdloss(F.log_softmax(outputs[0] / T, dim=1), F.softmax(toutputs[0] / T, dim=1)) * (T*T)
      # kd_loss = self.kdloss(F.log_softmax(outputs / T, dim=1), F.softmax(toutputs / T, dim=1)) * (T*T)
      kd_loss = self.kdloss(outputs / T, toutputs / T) * (T*T)

      # Loss
      loss = alpha * general_loss + (1-alpha) * kd_loss
      return loss


def train(args, tmodel, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = MainLoss(weight) # Loss 변경부분
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train() # student model (train mode)
        tmodel.eval() # teacher model (eval mode)
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)
            toutputs = tmodel(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0], toutputs) # Loss
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        tmodel.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 
            toutputs = tmodel(inputs, only_encode=enc)

            loss = criterion(outputs, targets[:, 0], toutputs)
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Teacher Model
    tweightspath = args.tloadDir + args.tloadWeights
    tmodel = TNet(NUM_CLASSES)

    #Load Model
    model = Net(NUM_CLASSES)
    
    if args.cuda:
        tmodel = torch.nn.DataParallel(tmodel).cuda()
        model = torch.nn.DataParallel(model).cuda()

    def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict elements
        own_state = model.state_dict()
        for name, param in state_dict.items():
            if name not in own_state:
                 continue
            own_state[name].copy_(param)
        return model

    tmodel = load_my_state_dict(tmodel, torch.load(tweightspath))
    print ("Teacher Model and weights LOADED successfully")

    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        model = load_my_state_dict(model, torch.load(args.state))


    # train(args, tmodel, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, tmodel, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, tmodel, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--tloadDir',default="/content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/")
    parser.add_argument('--tloadWeights', default="model_best.pth")

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=60)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=3)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# Teacher Model and weights LOADED successfully
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.MainLoss'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.085 (epoch: 1, step: 0) // Avg time/img: 2.5691 s
# loss: 1.511 (epoch: 1, step: 50) // Avg time/img: 0.1327 s
# loss: 1.353 (epoch: 1, step: 100) // Avg time/img: 0.1096 s
# loss: 1.271 (epoch: 1, step: 150) // Avg time/img: 0.1023 s
# loss: 1.222 (epoch: 1, step: 200) // Avg time/img: 0.0978 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.922 (epoch: 1, step: 0) // Avg time/img: 0.0400 s
# VAL loss: 1.386 (epoch: 1, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 1.336 (epoch: 1, step: 100) // Avg time/img: 0.0332 s
# VAL loss: 1.23 (epoch: 1, step: 150) // Avg time/img: 0.0327 s
# EPOCH IoU on VAL set:  17.65 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 0.9702 (epoch: 2, step: 0) // Avg time/img: 0.1060 s
# loss: 0.9951 (epoch: 2, step: 50) // Avg time/img: 0.0926 s
# loss: 0.9796 (epoch: 2, step: 100) // Avg time/img: 0.0927 s
# loss: 0.9846 (epoch: 2, step: 150) // Avg time/img: 0.0930 s
# loss: 0.983 (epoch: 2, step: 200) // Avg time/img: 0.0934 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.323 (epoch: 2, step: 0) // Avg time/img: 0.0477 s
# VAL loss: 1.223 (epoch: 2, step: 50) // Avg time/img: 0.0346 s
# VAL loss: 1.207 (epoch: 2, step: 100) // Avg time/img: 0.0348 s
# VAL loss: 1.102 (epoch: 2, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  19.93 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.8192 (epoch: 3, step: 0) // Avg time/img: 0.1081 s
# loss: 0.8971 (epoch: 3, step: 50) // Avg time/img: 0.0917 s
# loss: 0.9174 (epoch: 3, step: 100) // Avg time/img: 0.0906 s
# loss: 0.9086 (epoch: 3, step: 150) // Avg time/img: 0.0909 s
# loss: 0.9057 (epoch: 3, step: 200) // Avg time/img: 0.0906 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 1.108 (epoch: 3, step: 0) // Avg time/img: 0.0348 s
# VAL loss: 1.086 (epoch: 3, step: 50) // Avg time/img: 0.0335 s
# VAL loss: 1.073 (epoch: 3, step: 100) // Avg time/img: 0.0341 s
# VAL loss: 0.9958 (epoch: 3, step: 150) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  22.79 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 1.057 (epoch: 4, step: 0) // Avg time/img: 0.0951 s
# loss: 0.8835 (epoch: 4, step: 50) // Avg time/img: 0.0912 s
# loss: 0.8754 (epoch: 4, step: 100) // Avg time/img: 0.0925 s
# loss: 0.8795 (epoch: 4, step: 150) // Avg time/img: 0.0915 s
# loss: 0.8749 (epoch: 4, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 1.164 (epoch: 4, step: 0) // Avg time/img: 0.0561 s
# VAL loss: 1.137 (epoch: 4, step: 50) // Avg time/img: 0.0343 s
# VAL loss: 1.126 (epoch: 4, step: 100) // Avg time/img: 0.0335 s
# VAL loss: 1.028 (epoch: 4, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  23.76 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.8657 (epoch: 5, step: 0) // Avg time/img: 0.1068 s
# loss: 0.8462 (epoch: 5, step: 50) // Avg time/img: 0.0928 s
# loss: 0.8325 (epoch: 5, step: 100) // Avg time/img: 0.0916 s
# loss: 0.8204 (epoch: 5, step: 150) // Avg time/img: 0.0911 s
# loss: 0.8237 (epoch: 5, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 1.201 (epoch: 5, step: 0) // Avg time/img: 0.0327 s
# VAL loss: 1.102 (epoch: 5, step: 50) // Avg time/img: 0.0324 s
# VAL loss: 1.083 (epoch: 5, step: 100) // Avg time/img: 0.0330 s
# VAL loss: 1.002 (epoch: 5, step: 150) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  23.72 %
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004623387553722673
# loss: 0.8029 (epoch: 6, step: 0) // Avg time/img: 0.1135 s
# loss: 0.8159 (epoch: 6, step: 50) // Avg time/img: 0.0926 s
# loss: 0.8113 (epoch: 6, step: 100) // Avg time/img: 0.0919 s
# loss: 0.8052 (epoch: 6, step: 150) // Avg time/img: 0.0914 s
# loss: 0.8043 (epoch: 6, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 1.066 (epoch: 6, step: 0) // Avg time/img: 0.0338 s
# VAL loss: 1.105 (epoch: 6, step: 50) // Avg time/img: 0.0338 s
# VAL loss: 1.088 (epoch: 6, step: 100) // Avg time/img: 0.0344 s
# VAL loss: 1.005 (epoch: 6, step: 150) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  24.27 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.8518 (epoch: 7, step: 0) // Avg time/img: 0.0918 s
# loss: 0.795 (epoch: 7, step: 50) // Avg time/img: 0.0918 s
# loss: 0.7681 (epoch: 7, step: 100) // Avg time/img: 0.0914 s
# loss: 0.7776 (epoch: 7, step: 150) // Avg time/img: 0.0914 s
# loss: 0.7742 (epoch: 7, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 1.021 (epoch: 7, step: 0) // Avg time/img: 0.0330 s
# VAL loss: 1.03 (epoch: 7, step: 50) // Avg time/img: 0.0333 s
# VAL loss: 1.009 (epoch: 7, step: 100) // Avg time/img: 0.0343 s
# VAL loss: 0.9377 (epoch: 7, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  27.06 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 7)
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.00044717978378742816
# loss: 0.7407 (epoch: 8, step: 0) // Avg time/img: 0.0903 s
# loss: 0.7612 (epoch: 8, step: 50) // Avg time/img: 0.0914 s
# loss: 0.7679 (epoch: 8, step: 100) // Avg time/img: 0.0917 s
# loss: 0.767 (epoch: 8, step: 150) // Avg time/img: 0.0913 s
# loss: 0.7586 (epoch: 8, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 1.041 (epoch: 8, step: 0) // Avg time/img: 0.0390 s
# VAL loss: 0.9893 (epoch: 8, step: 50) // Avg time/img: 0.0335 s
# VAL loss: 0.9688 (epoch: 8, step: 100) // Avg time/img: 0.0335 s
# VAL loss: 0.8995 (epoch: 8, step: 150) // Avg time/img: 0.0332 s
# EPOCH IoU on VAL set:  28.30 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 8)
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.7276 (epoch: 9, step: 0) // Avg time/img: 0.0955 s
# loss: 0.7514 (epoch: 9, step: 50) // Avg time/img: 0.0922 s
# loss: 0.7603 (epoch: 9, step: 100) // Avg time/img: 0.0915 s
# loss: 0.756 (epoch: 9, step: 150) // Avg time/img: 0.0909 s
# loss: 0.7526 (epoch: 9, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 1.127 (epoch: 9, step: 0) // Avg time/img: 0.0332 s
# VAL loss: 1.026 (epoch: 9, step: 50) // Avg time/img: 0.0331 s
# VAL loss: 0.9954 (epoch: 9, step: 100) // Avg time/img: 0.0332 s
# VAL loss: 0.9127 (epoch: 9, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  27.45 %
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.00043196348615140955
# loss: 0.725 (epoch: 10, step: 0) // Avg time/img: 0.0921 s
# loss: 0.7212 (epoch: 10, step: 50) // Avg time/img: 0.0914 s
# loss: 0.7213 (epoch: 10, step: 100) // Avg time/img: 0.0913 s
# loss: 0.7256 (epoch: 10, step: 150) // Avg time/img: 0.0914 s
# loss: 0.7248 (epoch: 10, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 1.065 (epoch: 10, step: 0) // Avg time/img: 0.0346 s
# VAL loss: 0.9966 (epoch: 10, step: 50) // Avg time/img: 0.0328 s
# VAL loss: 0.9719 (epoch: 10, step: 100) // Avg time/img: 0.0337 s
# VAL loss: 0.8971 (epoch: 10, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  28.76 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 10)
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.7706 (epoch: 11, step: 0) // Avg time/img: 0.0841 s
# loss: 0.7308 (epoch: 11, step: 50) // Avg time/img: 0.0909 s
# loss: 0.7283 (epoch: 11, step: 100) // Avg time/img: 0.0927 s
# loss: 0.7219 (epoch: 11, step: 150) // Avg time/img: 0.0917 s
# loss: 0.717 (epoch: 11, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.7735 (epoch: 11, step: 0) // Avg time/img: 0.0412 s
# VAL loss: 0.9087 (epoch: 11, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.8894 (epoch: 11, step: 100) // Avg time/img: 0.0331 s
# VAL loss: 0.832 (epoch: 11, step: 150) // Avg time/img: 0.0330 s
# EPOCH IoU on VAL set:  30.76 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 11)
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.0004166873834706844
# loss: 0.7006 (epoch: 12, step: 0) // Avg time/img: 0.0920 s
# loss: 0.71 (epoch: 12, step: 50) // Avg time/img: 0.0932 s
# loss: 0.7014 (epoch: 12, step: 100) // Avg time/img: 0.0918 s
# loss: 0.7049 (epoch: 12, step: 150) // Avg time/img: 0.0914 s
# loss: 0.7071 (epoch: 12, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.9553 (epoch: 12, step: 0) // Avg time/img: 0.0328 s
# VAL loss: 0.9678 (epoch: 12, step: 50) // Avg time/img: 0.0336 s
# VAL loss: 0.9428 (epoch: 12, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.8722 (epoch: 12, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  29.79 %
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.6993 (epoch: 13, step: 0) // Avg time/img: 0.0951 s
# loss: 0.694 (epoch: 13, step: 50) // Avg time/img: 0.0932 s
# loss: 0.697 (epoch: 13, step: 100) // Avg time/img: 0.0919 s
# loss: 0.6962 (epoch: 13, step: 150) // Avg time/img: 0.0912 s
# loss: 0.7003 (epoch: 13, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 0.7143 (epoch: 13, step: 0) // Avg time/img: 0.0361 s
# VAL loss: 0.9144 (epoch: 13, step: 50) // Avg time/img: 0.0338 s
# VAL loss: 0.8999 (epoch: 13, step: 100) // Avg time/img: 0.0337 s
# VAL loss: 0.8404 (epoch: 13, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  31.48 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 13)
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.0004013487836640184
# loss: 0.6722 (epoch: 14, step: 0) // Avg time/img: 0.1166 s
# loss: 0.7075 (epoch: 14, step: 50) // Avg time/img: 0.0911 s
# loss: 0.6943 (epoch: 14, step: 100) // Avg time/img: 0.0906 s
# loss: 0.6971 (epoch: 14, step: 150) // Avg time/img: 0.0906 s
# loss: 0.7004 (epoch: 14, step: 200) // Avg time/img: 0.0908 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 0.9094 (epoch: 14, step: 0) // Avg time/img: 0.0362 s
# VAL loss: 0.9359 (epoch: 14, step: 50) // Avg time/img: 0.0349 s
# VAL loss: 0.9113 (epoch: 14, step: 100) // Avg time/img: 0.0346 s
# VAL loss: 0.8566 (epoch: 14, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  30.85 %
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.7344 (epoch: 15, step: 0) // Avg time/img: 0.0936 s
# loss: 0.6996 (epoch: 15, step: 50) // Avg time/img: 0.0906 s
# loss: 0.6853 (epoch: 15, step: 100) // Avg time/img: 0.0912 s
# loss: 0.6891 (epoch: 15, step: 150) // Avg time/img: 0.0911 s
# loss: 0.6851 (epoch: 15, step: 200) // Avg time/img: 0.0906 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 0.7785 (epoch: 15, step: 0) // Avg time/img: 0.0291 s
# VAL loss: 0.9166 (epoch: 15, step: 50) // Avg time/img: 0.0351 s
# VAL loss: 0.8991 (epoch: 15, step: 100) // Avg time/img: 0.0340 s
# VAL loss: 0.8363 (epoch: 15, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  33.14 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 15)
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00038594475336178527
# loss: 0.6707 (epoch: 16, step: 0) // Avg time/img: 0.0933 s
# loss: 0.6786 (epoch: 16, step: 50) // Avg time/img: 0.0927 s
# loss: 0.6835 (epoch: 16, step: 100) // Avg time/img: 0.0915 s
# loss: 0.6837 (epoch: 16, step: 150) // Avg time/img: 0.0910 s
# loss: 0.6838 (epoch: 16, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.7612 (epoch: 16, step: 0) // Avg time/img: 0.0351 s
# VAL loss: 0.9251 (epoch: 16, step: 50) // Avg time/img: 0.0327 s
# VAL loss: 0.9047 (epoch: 16, step: 100) // Avg time/img: 0.0332 s
# VAL loss: 0.8385 (epoch: 16, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  32.68 %
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.6303 (epoch: 17, step: 0) // Avg time/img: 0.0927 s
# loss: 0.6778 (epoch: 17, step: 50) // Avg time/img: 0.0907 s
# loss: 0.6871 (epoch: 17, step: 100) // Avg time/img: 0.0911 s
# loss: 0.6864 (epoch: 17, step: 150) // Avg time/img: 0.0915 s
# loss: 0.6819 (epoch: 17, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.8167 (epoch: 17, step: 0) // Avg time/img: 0.0365 s
# VAL loss: 0.9157 (epoch: 17, step: 50) // Avg time/img: 0.0334 s
# VAL loss: 0.8945 (epoch: 17, step: 100) // Avg time/img: 0.0343 s
# VAL loss: 0.8275 (epoch: 17, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  33.61 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 17)
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.00037047208454744316
# loss: 0.6744 (epoch: 18, step: 0) // Avg time/img: 0.0948 s
# loss: 0.6769 (epoch: 18, step: 50) // Avg time/img: 0.0936 s
# loss: 0.6611 (epoch: 18, step: 100) // Avg time/img: 0.0928 s
# loss: 0.6592 (epoch: 18, step: 150) // Avg time/img: 0.0920 s
# loss: 0.6635 (epoch: 18, step: 200) // Avg time/img: 0.0916 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.8323 (epoch: 18, step: 0) // Avg time/img: 0.0545 s
# VAL loss: 0.9042 (epoch: 18, step: 50) // Avg time/img: 0.0338 s
# VAL loss: 0.8857 (epoch: 18, step: 100) // Avg time/img: 0.0335 s
# VAL loss: 0.8228 (epoch: 18, step: 150) // Avg time/img: 0.0331 s
# EPOCH IoU on VAL set:  33.49 %
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.7109 (epoch: 19, step: 0) // Avg time/img: 0.0936 s
# loss: 0.6538 (epoch: 19, step: 50) // Avg time/img: 0.0932 s
# loss: 0.6601 (epoch: 19, step: 100) // Avg time/img: 0.0919 s
# loss: 0.6637 (epoch: 19, step: 150) // Avg time/img: 0.0912 s
# loss: 0.6665 (epoch: 19, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.6732 (epoch: 19, step: 0) // Avg time/img: 0.0379 s
# VAL loss: 0.8572 (epoch: 19, step: 50) // Avg time/img: 0.0344 s
# VAL loss: 0.8469 (epoch: 19, step: 100) // Avg time/img: 0.0347 s
# VAL loss: 0.7929 (epoch: 19, step: 150) // Avg time/img: 0.0348 s
# EPOCH IoU on VAL set:  34.52 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 19)
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.0003549272548125162
# loss: 0.6321 (epoch: 20, step: 0) // Avg time/img: 0.1061 s
# loss: 0.6398 (epoch: 20, step: 50) // Avg time/img: 0.0912 s
# loss: 0.6494 (epoch: 20, step: 100) // Avg time/img: 0.0909 s
# loss: 0.652 (epoch: 20, step: 150) // Avg time/img: 0.0912 s
# loss: 0.6526 (epoch: 20, step: 200) // Avg time/img: 0.0907 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.7455 (epoch: 20, step: 0) // Avg time/img: 0.0316 s
# VAL loss: 0.8648 (epoch: 20, step: 50) // Avg time/img: 0.0356 s
# VAL loss: 0.8789 (epoch: 20, step: 100) // Avg time/img: 0.0344 s
# VAL loss: 0.8304 (epoch: 20, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  35.32 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 20)
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.6387 (epoch: 21, step: 0) // Avg time/img: 0.0916 s
# loss: 0.6604 (epoch: 21, step: 50) // Avg time/img: 0.0905 s
# loss: 0.654 (epoch: 21, step: 100) // Avg time/img: 0.0913 s
# loss: 0.652 (epoch: 21, step: 150) // Avg time/img: 0.0907 s
# loss: 0.6486 (epoch: 21, step: 200) // Avg time/img: 0.0908 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.7034 (epoch: 21, step: 0) // Avg time/img: 0.0322 s
# VAL loss: 0.8906 (epoch: 21, step: 50) // Avg time/img: 0.0337 s
# VAL loss: 0.9086 (epoch: 21, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.8553 (epoch: 21, step: 150) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  33.70 %
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.0003393063796290625
# loss: 0.6377 (epoch: 22, step: 0) // Avg time/img: 0.1335 s
# loss: 0.6614 (epoch: 22, step: 50) // Avg time/img: 0.0921 s
# loss: 0.6594 (epoch: 22, step: 100) // Avg time/img: 0.0917 s
# loss: 0.6507 (epoch: 22, step: 150) // Avg time/img: 0.0914 s
# loss: 0.653 (epoch: 22, step: 200) // Avg time/img: 0.0917 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.7821 (epoch: 22, step: 0) // Avg time/img: 0.0330 s
# VAL loss: 0.8503 (epoch: 22, step: 50) // Avg time/img: 0.0337 s
# VAL loss: 0.8404 (epoch: 22, step: 100) // Avg time/img: 0.0344 s
# VAL loss: 0.7864 (epoch: 22, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  36.05 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 22)
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.5496 (epoch: 23, step: 0) // Avg time/img: 0.0911 s
# loss: 0.6491 (epoch: 23, step: 50) // Avg time/img: 0.0910 s
# loss: 0.6482 (epoch: 23, step: 100) // Avg time/img: 0.0929 s
# loss: 0.6456 (epoch: 23, step: 150) // Avg time/img: 0.0921 s
# loss: 0.6413 (epoch: 23, step: 200) // Avg time/img: 0.0917 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.8276 (epoch: 23, step: 0) // Avg time/img: 0.0353 s
# VAL loss: 0.8977 (epoch: 23, step: 50) // Avg time/img: 0.0336 s
# VAL loss: 0.8817 (epoch: 23, step: 100) // Avg time/img: 0.0334 s
# VAL loss: 0.8165 (epoch: 23, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  35.03 %
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.0003236051545417615
# loss: 0.6465 (epoch: 24, step: 0) // Avg time/img: 0.0911 s
# loss: 0.6291 (epoch: 24, step: 50) // Avg time/img: 0.0924 s
# loss: 0.6326 (epoch: 24, step: 100) // Avg time/img: 0.0918 s
# loss: 0.6337 (epoch: 24, step: 150) // Avg time/img: 0.0912 s
# loss: 0.6339 (epoch: 24, step: 200) // Avg time/img: 0.0912 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 0.7102 (epoch: 24, step: 0) // Avg time/img: 0.0327 s
# VAL loss: 0.86 (epoch: 24, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.8677 (epoch: 24, step: 100) // Avg time/img: 0.0340 s
# VAL loss: 0.8146 (epoch: 24, step: 150) // Avg time/img: 0.0351 s
# EPOCH IoU on VAL set:  35.72 %
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.5946 (epoch: 25, step: 0) // Avg time/img: 0.0917 s
# loss: 0.625 (epoch: 25, step: 50) // Avg time/img: 0.0908 s
# loss: 0.6248 (epoch: 25, step: 100) // Avg time/img: 0.0910 s
# loss: 0.6325 (epoch: 25, step: 150) // Avg time/img: 0.0911 s
# loss: 0.6309 (epoch: 25, step: 200) // Avg time/img: 0.0907 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.7354 (epoch: 25, step: 0) // Avg time/img: 0.0371 s
# VAL loss: 0.8857 (epoch: 25, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.8686 (epoch: 25, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.8085 (epoch: 25, step: 150) // Avg time/img: 0.0335 s
# EPOCH IoU on VAL set:  34.95 %
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00030781878448615926
# loss: 0.6969 (epoch: 26, step: 0) // Avg time/img: 0.0920 s
# loss: 0.6279 (epoch: 26, step: 50) // Avg time/img: 0.0919 s
# loss: 0.6208 (epoch: 26, step: 100) // Avg time/img: 0.0919 s
# loss: 0.6226 (epoch: 26, step: 150) // Avg time/img: 0.0917 s
# loss: 0.6243 (epoch: 26, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.8035 (epoch: 26, step: 0) // Avg time/img: 0.0343 s
# VAL loss: 0.8777 (epoch: 26, step: 50) // Avg time/img: 0.0348 s
# VAL loss: 0.8622 (epoch: 26, step: 100) // Avg time/img: 0.0337 s
# VAL loss: 0.7998 (epoch: 26, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  36.31 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 26)
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.5912 (epoch: 27, step: 0) // Avg time/img: 0.0962 s
# loss: 0.6267 (epoch: 27, step: 50) // Avg time/img: 0.0933 s
# loss: 0.6202 (epoch: 27, step: 100) // Avg time/img: 0.0923 s
# loss: 0.617 (epoch: 27, step: 150) // Avg time/img: 0.0918 s
# loss: 0.6214 (epoch: 27, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.7286 (epoch: 27, step: 0) // Avg time/img: 0.0300 s
# VAL loss: 0.8517 (epoch: 27, step: 50) // Avg time/img: 0.0337 s
# VAL loss: 0.8453 (epoch: 27, step: 100) // Avg time/img: 0.0342 s
# VAL loss: 0.7901 (epoch: 27, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  37.16 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 27)
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00029194189645999016
# loss: 0.663 (epoch: 28, step: 0) // Avg time/img: 0.0882 s
# loss: 0.6229 (epoch: 28, step: 50) // Avg time/img: 0.0927 s
# loss: 0.6234 (epoch: 28, step: 100) // Avg time/img: 0.0926 s
# loss: 0.6196 (epoch: 28, step: 150) // Avg time/img: 0.0917 s
# loss: 0.6176 (epoch: 28, step: 200) // Avg time/img: 0.0918 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.7049 (epoch: 28, step: 0) // Avg time/img: 0.0399 s
# VAL loss: 0.8703 (epoch: 28, step: 50) // Avg time/img: 0.0333 s
# VAL loss: 0.862 (epoch: 28, step: 100) // Avg time/img: 0.0335 s
# VAL loss: 0.8029 (epoch: 28, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  37.03 %
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.5656 (epoch: 29, step: 0) // Avg time/img: 0.0967 s
# loss: 0.5931 (epoch: 29, step: 50) // Avg time/img: 0.0919 s
# loss: 0.6051 (epoch: 29, step: 100) // Avg time/img: 0.0913 s
# loss: 0.6123 (epoch: 29, step: 150) // Avg time/img: 0.0913 s
# loss: 0.6133 (epoch: 29, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.684 (epoch: 29, step: 0) // Avg time/img: 0.0354 s
# VAL loss: 0.8138 (epoch: 29, step: 50) // Avg time/img: 0.0353 s
# VAL loss: 0.8047 (epoch: 29, step: 100) // Avg time/img: 0.0349 s
# VAL loss: 0.7587 (epoch: 29, step: 150) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  39.02 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 29)
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.0002759684303703797
# loss: 0.5701 (epoch: 30, step: 0) // Avg time/img: 0.1271 s
# loss: 0.6141 (epoch: 30, step: 50) // Avg time/img: 0.0950 s
# loss: 0.6178 (epoch: 30, step: 100) // Avg time/img: 0.0930 s
# loss: 0.6138 (epoch: 30, step: 150) // Avg time/img: 0.0921 s
# loss: 0.6149 (epoch: 30, step: 200) // Avg time/img: 0.0918 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.7928 (epoch: 30, step: 0) // Avg time/img: 0.0369 s
# VAL loss: 0.9358 (epoch: 30, step: 50) // Avg time/img: 0.0331 s
# VAL loss: 0.932 (epoch: 30, step: 100) // Avg time/img: 0.0331 s
# VAL loss: 0.8581 (epoch: 30, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  34.66 %
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.6196 (epoch: 31, step: 0) // Avg time/img: 0.1001 s
# loss: 0.6099 (epoch: 31, step: 50) // Avg time/img: 0.0914 s
# loss: 0.6114 (epoch: 31, step: 100) // Avg time/img: 0.0909 s
# loss: 0.6145 (epoch: 31, step: 150) // Avg time/img: 0.0913 s
# loss: 0.6124 (epoch: 31, step: 200) // Avg time/img: 0.0916 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.7386 (epoch: 31, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.8518 (epoch: 31, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.8435 (epoch: 31, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.7856 (epoch: 31, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  37.66 %
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.0002598915008274931
# loss: 0.684 (epoch: 32, step: 0) // Avg time/img: 0.0939 s
# loss: 0.6204 (epoch: 32, step: 50) // Avg time/img: 0.0912 s
# loss: 0.609 (epoch: 32, step: 100) // Avg time/img: 0.0916 s
# loss: 0.6066 (epoch: 32, step: 150) // Avg time/img: 0.0910 s
# loss: 0.605 (epoch: 32, step: 200) // Avg time/img: 0.0909 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.8056 (epoch: 32, step: 0) // Avg time/img: 0.0356 s
# VAL loss: 0.8521 (epoch: 32, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.8456 (epoch: 32, step: 100) // Avg time/img: 0.0333 s
# VAL loss: 0.7869 (epoch: 32, step: 150) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  37.92 %
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.6593 (epoch: 33, step: 0) // Avg time/img: 0.0953 s
# loss: 0.6155 (epoch: 33, step: 50) // Avg time/img: 0.0923 s
# loss: 0.6018 (epoch: 33, step: 100) // Avg time/img: 0.0916 s
# loss: 0.6002 (epoch: 33, step: 150) // Avg time/img: 0.0918 s
# loss: 0.602 (epoch: 33, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.6446 (epoch: 33, step: 0) // Avg time/img: 0.0336 s
# VAL loss: 0.8075 (epoch: 33, step: 50) // Avg time/img: 0.0335 s
# VAL loss: 0.8036 (epoch: 33, step: 100) // Avg time/img: 0.0346 s
# VAL loss: 0.7576 (epoch: 33, step: 150) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  39.24 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 33)
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.00024370321958949772
# loss: 0.598 (epoch: 34, step: 0) // Avg time/img: 0.1023 s
# loss: 0.5977 (epoch: 34, step: 50) // Avg time/img: 0.0920 s
# loss: 0.6022 (epoch: 34, step: 100) // Avg time/img: 0.0922 s
# loss: 0.6003 (epoch: 34, step: 150) // Avg time/img: 0.0917 s
# loss: 0.6022 (epoch: 34, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.7626 (epoch: 34, step: 0) // Avg time/img: 0.0355 s
# VAL loss: 0.8624 (epoch: 34, step: 50) // Avg time/img: 0.0365 s
# VAL loss: 0.8639 (epoch: 34, step: 100) // Avg time/img: 0.0352 s
# VAL loss: 0.7997 (epoch: 34, step: 150) // Avg time/img: 0.0354 s
# EPOCH IoU on VAL set:  37.30 %
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.5394 (epoch: 35, step: 0) // Avg time/img: 0.0881 s
# loss: 0.6022 (epoch: 35, step: 50) // Avg time/img: 0.0921 s
# loss: 0.6034 (epoch: 35, step: 100) // Avg time/img: 0.0916 s
# loss: 0.604 (epoch: 35, step: 150) // Avg time/img: 0.0920 s
# loss: 0.602 (epoch: 35, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.6859 (epoch: 35, step: 0) // Avg time/img: 0.0385 s
# VAL loss: 0.8594 (epoch: 35, step: 50) // Avg time/img: 0.0337 s
# VAL loss: 0.8686 (epoch: 35, step: 100) // Avg time/img: 0.0344 s
# VAL loss: 0.8058 (epoch: 35, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  37.76 %
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.00022739446367039517
# loss: 0.6626 (epoch: 36, step: 0) // Avg time/img: 0.0911 s
# loss: 0.5885 (epoch: 36, step: 50) // Avg time/img: 0.0916 s
# loss: 0.6015 (epoch: 36, step: 100) // Avg time/img: 0.0924 s
# loss: 0.6017 (epoch: 36, step: 150) // Avg time/img: 0.0926 s
# loss: 0.5974 (epoch: 36, step: 200) // Avg time/img: 0.0919 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.7137 (epoch: 36, step: 0) // Avg time/img: 0.0343 s
# VAL loss: 0.8547 (epoch: 36, step: 50) // Avg time/img: 0.0337 s
# VAL loss: 0.8731 (epoch: 36, step: 100) // Avg time/img: 0.0333 s
# VAL loss: 0.8195 (epoch: 36, step: 150) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  37.42 %
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.5874 (epoch: 37, step: 0) // Avg time/img: 0.0861 s
# loss: 0.5983 (epoch: 37, step: 50) // Avg time/img: 0.0907 s
# loss: 0.5987 (epoch: 37, step: 100) // Avg time/img: 0.0911 s
# loss: 0.5967 (epoch: 37, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5949 (epoch: 37, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.6803 (epoch: 37, step: 0) // Avg time/img: 0.0326 s
# VAL loss: 0.8003 (epoch: 37, step: 50) // Avg time/img: 0.0340 s
# VAL loss: 0.8157 (epoch: 37, step: 100) // Avg time/img: 0.0344 s
# VAL loss: 0.7721 (epoch: 37, step: 150) // Avg time/img: 0.0347 s
# EPOCH IoU on VAL set:  39.41 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 37)
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.00021095456673472888
# loss: 0.5385 (epoch: 38, step: 0) // Avg time/img: 0.0968 s
# loss: 0.5862 (epoch: 38, step: 50) // Avg time/img: 0.0924 s
# loss: 0.5825 (epoch: 38, step: 100) // Avg time/img: 0.0922 s
# loss: 0.5847 (epoch: 38, step: 150) // Avg time/img: 0.0915 s
# loss: 0.5889 (epoch: 38, step: 200) // Avg time/img: 0.0912 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.6529 (epoch: 38, step: 0) // Avg time/img: 0.0336 s
# VAL loss: 0.8249 (epoch: 38, step: 50) // Avg time/img: 0.0333 s
# VAL loss: 0.8301 (epoch: 38, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.7778 (epoch: 38, step: 150) // Avg time/img: 0.0343 s
# EPOCH IoU on VAL set:  38.73 %
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.6991 (epoch: 39, step: 0) // Avg time/img: 0.0868 s
# loss: 0.5855 (epoch: 39, step: 50) // Avg time/img: 0.0916 s
# loss: 0.587 (epoch: 39, step: 100) // Avg time/img: 0.0915 s
# loss: 0.5868 (epoch: 39, step: 150) // Avg time/img: 0.0918 s
# loss: 0.5858 (epoch: 39, step: 200) // Avg time/img: 0.0918 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.7323 (epoch: 39, step: 0) // Avg time/img: 0.0382 s
# VAL loss: 0.9053 (epoch: 39, step: 50) // Avg time/img: 0.0360 s
# VAL loss: 0.9248 (epoch: 39, step: 100) // Avg time/img: 0.0344 s
# VAL loss: 0.8513 (epoch: 39, step: 150) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  36.52 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.5841 (epoch: 40, step: 0) // Avg time/img: 0.0920 s
# loss: 0.5887 (epoch: 40, step: 50) // Avg time/img: 0.0932 s
# loss: 0.5826 (epoch: 40, step: 100) // Avg time/img: 0.0919 s
# loss: 0.58 (epoch: 40, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5781 (epoch: 40, step: 200) // Avg time/img: 0.0917 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.6818 (epoch: 40, step: 0) // Avg time/img: 0.0365 s
# VAL loss: 0.8213 (epoch: 40, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.8252 (epoch: 40, step: 100) // Avg time/img: 0.0334 s
# VAL loss: 0.7716 (epoch: 40, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  39.26 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.537 (epoch: 41, step: 0) // Avg time/img: 0.0933 s
# loss: 0.5838 (epoch: 41, step: 50) // Avg time/img: 0.0915 s
# loss: 0.5877 (epoch: 41, step: 100) // Avg time/img: 0.0923 s
# loss: 0.5878 (epoch: 41, step: 150) // Avg time/img: 0.0918 s
# loss: 0.5835 (epoch: 41, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.6805 (epoch: 41, step: 0) // Avg time/img: 0.0288 s
# VAL loss: 0.8719 (epoch: 41, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.8691 (epoch: 41, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.8015 (epoch: 41, step: 150) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  38.42 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.6137 (epoch: 42, step: 0) // Avg time/img: 0.0923 s
# loss: 0.5637 (epoch: 42, step: 50) // Avg time/img: 0.0938 s
# loss: 0.5717 (epoch: 42, step: 100) // Avg time/img: 0.0925 s
# loss: 0.5721 (epoch: 42, step: 150) // Avg time/img: 0.0919 s
# loss: 0.575 (epoch: 42, step: 200) // Avg time/img: 0.0923 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.6477 (epoch: 42, step: 0) // Avg time/img: 0.0338 s
# VAL loss: 0.8239 (epoch: 42, step: 50) // Avg time/img: 0.0337 s
# VAL loss: 0.8275 (epoch: 42, step: 100) // Avg time/img: 0.0343 s
# VAL loss: 0.7757 (epoch: 42, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  39.58 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 42)
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.4967 (epoch: 43, step: 0) // Avg time/img: 0.1039 s
# loss: 0.5721 (epoch: 43, step: 50) // Avg time/img: 0.0911 s
# loss: 0.5704 (epoch: 43, step: 100) // Avg time/img: 0.0916 s
# loss: 0.5734 (epoch: 43, step: 150) // Avg time/img: 0.0912 s
# loss: 0.5723 (epoch: 43, step: 200) // Avg time/img: 0.0908 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.6961 (epoch: 43, step: 0) // Avg time/img: 0.0377 s
# VAL loss: 0.8428 (epoch: 43, step: 50) // Avg time/img: 0.0337 s
# VAL loss: 0.8484 (epoch: 43, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.7919 (epoch: 43, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  39.39 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.5822 (epoch: 44, step: 0) // Avg time/img: 0.0880 s
# loss: 0.5763 (epoch: 44, step: 50) // Avg time/img: 0.0926 s
# loss: 0.5788 (epoch: 44, step: 100) // Avg time/img: 0.0922 s
# loss: 0.5758 (epoch: 44, step: 150) // Avg time/img: 0.0922 s
# loss: 0.5751 (epoch: 44, step: 200) // Avg time/img: 0.0918 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.7023 (epoch: 44, step: 0) // Avg time/img: 0.0384 s
# VAL loss: 0.8382 (epoch: 44, step: 50) // Avg time/img: 0.0335 s
# VAL loss: 0.8245 (epoch: 44, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.7708 (epoch: 44, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  40.33 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 44)
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.6298 (epoch: 45, step: 0) // Avg time/img: 0.0972 s
# loss: 0.5705 (epoch: 45, step: 50) // Avg time/img: 0.0914 s
# loss: 0.5688 (epoch: 45, step: 100) // Avg time/img: 0.0923 s
# loss: 0.5711 (epoch: 45, step: 150) // Avg time/img: 0.0917 s
# loss: 0.5704 (epoch: 45, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.6969 (epoch: 45, step: 0) // Avg time/img: 0.0390 s
# VAL loss: 0.862 (epoch: 45, step: 50) // Avg time/img: 0.0339 s
# VAL loss: 0.86 (epoch: 45, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.7942 (epoch: 45, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  38.96 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.5477 (epoch: 46, step: 0) // Avg time/img: 0.0941 s
# loss: 0.5616 (epoch: 46, step: 50) // Avg time/img: 0.0914 s
# loss: 0.5691 (epoch: 46, step: 100) // Avg time/img: 0.0911 s
# loss: 0.5673 (epoch: 46, step: 150) // Avg time/img: 0.0917 s
# loss: 0.5665 (epoch: 46, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.6629 (epoch: 46, step: 0) // Avg time/img: 0.0357 s
# VAL loss: 0.826 (epoch: 46, step: 50) // Avg time/img: 0.0342 s
# VAL loss: 0.8361 (epoch: 46, step: 100) // Avg time/img: 0.0343 s
# VAL loss: 0.7839 (epoch: 46, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  40.24 %
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.5374 (epoch: 47, step: 0) // Avg time/img: 0.0919 s
# loss: 0.5748 (epoch: 47, step: 50) // Avg time/img: 0.0945 s
# loss: 0.5672 (epoch: 47, step: 100) // Avg time/img: 0.0925 s
# loss: 0.5681 (epoch: 47, step: 150) // Avg time/img: 0.0916 s
# loss: 0.5668 (epoch: 47, step: 200) // Avg time/img: 0.0916 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.6921 (epoch: 47, step: 0) // Avg time/img: 0.0285 s
# VAL loss: 0.8513 (epoch: 47, step: 50) // Avg time/img: 0.0335 s
# VAL loss: 0.8516 (epoch: 47, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.792 (epoch: 47, step: 150) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  39.38 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.5165 (epoch: 48, step: 0) // Avg time/img: 0.1166 s
# loss: 0.5687 (epoch: 48, step: 50) // Avg time/img: 0.0916 s
# loss: 0.5676 (epoch: 48, step: 100) // Avg time/img: 0.0910 s
# loss: 0.5672 (epoch: 48, step: 150) // Avg time/img: 0.0907 s
# loss: 0.5644 (epoch: 48, step: 200) // Avg time/img: 0.0909 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.6694 (epoch: 48, step: 0) // Avg time/img: 0.0299 s
# VAL loss: 0.8368 (epoch: 48, step: 50) // Avg time/img: 0.0357 s
# VAL loss: 0.8248 (epoch: 48, step: 100) // Avg time/img: 0.0344 s
# VAL loss: 0.7651 (epoch: 48, step: 150) // Avg time/img: 0.0347 s
# EPOCH IoU on VAL set:  41.36 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 48)
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.5254 (epoch: 49, step: 0) // Avg time/img: 0.0989 s
# loss: 0.5523 (epoch: 49, step: 50) // Avg time/img: 0.0923 s
# loss: 0.5567 (epoch: 49, step: 100) // Avg time/img: 0.0918 s
# loss: 0.5567 (epoch: 49, step: 150) // Avg time/img: 0.0918 s
# loss: 0.558 (epoch: 49, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.6602 (epoch: 49, step: 0) // Avg time/img: 0.0388 s
# VAL loss: 0.8654 (epoch: 49, step: 50) // Avg time/img: 0.0351 s
# VAL loss: 0.8594 (epoch: 49, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.7957 (epoch: 49, step: 150) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  40.43 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.5212 (epoch: 50, step: 0) // Avg time/img: 0.0933 s
# loss: 0.5614 (epoch: 50, step: 50) // Avg time/img: 0.0932 s
# loss: 0.564 (epoch: 50, step: 100) // Avg time/img: 0.0930 s
# loss: 0.5659 (epoch: 50, step: 150) // Avg time/img: 0.0919 s
# loss: 0.5604 (epoch: 50, step: 200) // Avg time/img: 0.0918 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.6417 (epoch: 50, step: 0) // Avg time/img: 0.0367 s
# VAL loss: 0.8408 (epoch: 50, step: 50) // Avg time/img: 0.0330 s
# VAL loss: 0.8238 (epoch: 50, step: 100) // Avg time/img: 0.0342 s
# VAL loss: 0.7651 (epoch: 50, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  41.78 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 50)
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.5748 (epoch: 51, step: 0) // Avg time/img: 0.0955 s
# loss: 0.5644 (epoch: 51, step: 50) // Avg time/img: 0.0911 s
# loss: 0.565 (epoch: 51, step: 100) // Avg time/img: 0.0917 s
# loss: 0.5603 (epoch: 51, step: 150) // Avg time/img: 0.0909 s
# loss: 0.559 (epoch: 51, step: 200) // Avg time/img: 0.0907 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.6924 (epoch: 51, step: 0) // Avg time/img: 0.0381 s
# VAL loss: 0.8583 (epoch: 51, step: 50) // Avg time/img: 0.0331 s
# VAL loss: 0.8423 (epoch: 51, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.7809 (epoch: 51, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  40.84 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.5235 (epoch: 52, step: 0) // Avg time/img: 0.0896 s
# loss: 0.5578 (epoch: 52, step: 50) // Avg time/img: 0.0911 s
# loss: 0.5578 (epoch: 52, step: 100) // Avg time/img: 0.0912 s
# loss: 0.554 (epoch: 52, step: 150) // Avg time/img: 0.0916 s
# loss: 0.5548 (epoch: 52, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.6795 (epoch: 52, step: 0) // Avg time/img: 0.0323 s
# VAL loss: 0.8565 (epoch: 52, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.8413 (epoch: 52, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.7792 (epoch: 52, step: 150) // Avg time/img: 0.0335 s
# EPOCH IoU on VAL set:  40.54 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.5177 (epoch: 53, step: 0) // Avg time/img: 0.0978 s
# loss: 0.5628 (epoch: 53, step: 50) // Avg time/img: 0.0918 s
# loss: 0.556 (epoch: 53, step: 100) // Avg time/img: 0.0926 s
# loss: 0.5535 (epoch: 53, step: 150) // Avg time/img: 0.0922 s
# loss: 0.5522 (epoch: 53, step: 200) // Avg time/img: 0.0921 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.7047 (epoch: 53, step: 0) // Avg time/img: 0.0357 s
# VAL loss: 0.8507 (epoch: 53, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.8368 (epoch: 53, step: 100) // Avg time/img: 0.0340 s
# VAL loss: 0.7775 (epoch: 53, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  41.76 %
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.5193 (epoch: 54, step: 0) // Avg time/img: 0.0949 s
# loss: 0.5496 (epoch: 54, step: 50) // Avg time/img: 0.0922 s
# loss: 0.5514 (epoch: 54, step: 100) // Avg time/img: 0.0917 s
# loss: 0.5507 (epoch: 54, step: 150) // Avg time/img: 0.0919 s
# loss: 0.5535 (epoch: 54, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.6624 (epoch: 54, step: 0) // Avg time/img: 0.0359 s
# VAL loss: 0.8552 (epoch: 54, step: 50) // Avg time/img: 0.0338 s
# VAL loss: 0.8363 (epoch: 54, step: 100) // Avg time/img: 0.0347 s
# VAL loss: 0.7754 (epoch: 54, step: 150) // Avg time/img: 0.0344 s
# EPOCH IoU on VAL set:  41.82 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 54)
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.5685 (epoch: 55, step: 0) // Avg time/img: 0.1274 s
# loss: 0.5457 (epoch: 55, step: 50) // Avg time/img: 0.0939 s
# loss: 0.5471 (epoch: 55, step: 100) // Avg time/img: 0.0925 s
# loss: 0.5483 (epoch: 55, step: 150) // Avg time/img: 0.0920 s
# loss: 0.5493 (epoch: 55, step: 200) // Avg time/img: 0.0920 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.6805 (epoch: 55, step: 0) // Avg time/img: 0.0333 s
# VAL loss: 0.8311 (epoch: 55, step: 50) // Avg time/img: 0.0335 s
# VAL loss: 0.8195 (epoch: 55, step: 100) // Avg time/img: 0.0345 s
# VAL loss: 0.7651 (epoch: 55, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  41.75 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.5221 (epoch: 56, step: 0) // Avg time/img: 0.0912 s
# loss: 0.5437 (epoch: 56, step: 50) // Avg time/img: 0.0927 s
# loss: 0.551 (epoch: 56, step: 100) // Avg time/img: 0.0926 s
# loss: 0.5496 (epoch: 56, step: 150) // Avg time/img: 0.0921 s
# loss: 0.5483 (epoch: 56, step: 200) // Avg time/img: 0.0918 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.6946 (epoch: 56, step: 0) // Avg time/img: 0.0341 s
# VAL loss: 0.8615 (epoch: 56, step: 50) // Avg time/img: 0.0328 s
# VAL loss: 0.8487 (epoch: 56, step: 100) // Avg time/img: 0.0332 s
# VAL loss: 0.7887 (epoch: 56, step: 150) // Avg time/img: 0.0332 s
# EPOCH IoU on VAL set:  41.47 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.4822 (epoch: 57, step: 0) // Avg time/img: 0.1025 s
# loss: 0.5489 (epoch: 57, step: 50) // Avg time/img: 0.0923 s
# loss: 0.5466 (epoch: 57, step: 100) // Avg time/img: 0.0920 s
# loss: 0.5447 (epoch: 57, step: 150) // Avg time/img: 0.0915 s
# loss: 0.5477 (epoch: 57, step: 200) // Avg time/img: 0.0916 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.6854 (epoch: 57, step: 0) // Avg time/img: 0.0425 s
# VAL loss: 0.8392 (epoch: 57, step: 50) // Avg time/img: 0.0331 s
# VAL loss: 0.8381 (epoch: 57, step: 100) // Avg time/img: 0.0342 s
# VAL loss: 0.7827 (epoch: 57, step: 150) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  41.37 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.5968 (epoch: 58, step: 0) // Avg time/img: 0.0935 s
# loss: 0.5498 (epoch: 58, step: 50) // Avg time/img: 0.0931 s
# loss: 0.5464 (epoch: 58, step: 100) // Avg time/img: 0.0932 s
# loss: 0.5467 (epoch: 58, step: 150) // Avg time/img: 0.0922 s
# loss: 0.5465 (epoch: 58, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.6511 (epoch: 58, step: 0) // Avg time/img: 0.0411 s
# VAL loss: 0.8168 (epoch: 58, step: 50) // Avg time/img: 0.0336 s
# VAL loss: 0.8032 (epoch: 58, step: 100) // Avg time/img: 0.0335 s
# VAL loss: 0.7496 (epoch: 58, step: 150) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  42.46 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 58)
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.5493 (epoch: 59, step: 0) // Avg time/img: 0.0973 s
# loss: 0.5426 (epoch: 59, step: 50) // Avg time/img: 0.0911 s
# loss: 0.5376 (epoch: 59, step: 100) // Avg time/img: 0.0910 s
# loss: 0.5425 (epoch: 59, step: 150) // Avg time/img: 0.0914 s
# loss: 0.542 (epoch: 59, step: 200) // Avg time/img: 0.0912 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.679 (epoch: 59, step: 0) // Avg time/img: 0.0448 s
# VAL loss: 0.8195 (epoch: 59, step: 50) // Avg time/img: 0.0350 s
# VAL loss: 0.8079 (epoch: 59, step: 100) // Avg time/img: 0.0343 s
# VAL loss: 0.754 (epoch: 59, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  42.61 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 59)
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.5736 (epoch: 60, step: 0) // Avg time/img: 0.0998 s
# loss: 0.5337 (epoch: 60, step: 50) // Avg time/img: 0.0933 s
# loss: 0.5397 (epoch: 60, step: 100) // Avg time/img: 0.0921 s
# loss: 0.5402 (epoch: 60, step: 150) // Avg time/img: 0.0915 s
# loss: 0.5404 (epoch: 60, step: 200) // Avg time/img: 0.0916 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.6575 (epoch: 60, step: 0) // Avg time/img: 0.0270 s
# VAL loss: 0.8116 (epoch: 60, step: 50) // Avg time/img: 0.0334 s
# VAL loss: 0.8022 (epoch: 60, step: 100) // Avg time/img: 0.0335 s
# VAL loss: 0.7498 (epoch: 60, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  42.77 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_encoder_best.pth (epoch: 60)
# ========== DECODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.MainLoss'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 11.26 (epoch: 1, step: 0) // Avg time/img: 0.1583 s
# loss: 10.57 (epoch: 1, step: 50) // Avg time/img: 0.1419 s
# loss: 9.813 (epoch: 1, step: 100) // Avg time/img: 0.1406 s
# loss: 9.036 (epoch: 1, step: 150) // Avg time/img: 0.1391 s
# loss: 8.402 (epoch: 1, step: 200) // Avg time/img: 0.1389 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 4.546 (epoch: 1, step: 0) // Avg time/img: 0.0537 s
# VAL loss: 5.132 (epoch: 1, step: 50) // Avg time/img: 0.0492 s
# VAL loss: 4.97 (epoch: 1, step: 100) // Avg time/img: 0.0495 s
# VAL loss: 4.871 (epoch: 1, step: 150) // Avg time/img: 0.0492 s
# EPOCH IoU on VAL set:  17.95 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 4.451 (epoch: 2, step: 0) // Avg time/img: 0.1431 s
# loss: 4.616 (epoch: 2, step: 50) // Avg time/img: 0.1383 s
# loss: 4.308 (epoch: 2, step: 100) // Avg time/img: 0.1384 s
# loss: 4.015 (epoch: 2, step: 150) // Avg time/img: 0.1382 s
# loss: 3.778 (epoch: 2, step: 200) // Avg time/img: 0.1382 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 2.146 (epoch: 2, step: 0) // Avg time/img: 0.0549 s
# VAL loss: 2.792 (epoch: 2, step: 50) // Avg time/img: 0.0490 s
# VAL loss: 2.686 (epoch: 2, step: 100) // Avg time/img: 0.0491 s
# VAL loss: 2.58 (epoch: 2, step: 150) // Avg time/img: 0.0488 s
# EPOCH IoU on VAL set:  22.50 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 3.243 (epoch: 3, step: 0) // Avg time/img: 0.1481 s
# loss: 2.465 (epoch: 3, step: 50) // Avg time/img: 0.1413 s
# loss: 2.429 (epoch: 3, step: 100) // Avg time/img: 0.1389 s
# loss: 2.376 (epoch: 3, step: 150) // Avg time/img: 0.1386 s
# loss: 2.294 (epoch: 3, step: 200) // Avg time/img: 0.1381 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 1.855 (epoch: 3, step: 0) // Avg time/img: 0.0510 s
# VAL loss: 2.304 (epoch: 3, step: 50) // Avg time/img: 0.0494 s
# VAL loss: 2.233 (epoch: 3, step: 100) // Avg time/img: 0.0491 s
# ...
# VAL loss: 1.25 (epoch: 39, step: 50) // Avg time/img: 0.0505 s
# VAL loss: 1.273 (epoch: 39, step: 100) // Avg time/img: 0.0495 s
# VAL loss: 1.126 (epoch: 39, step: 150) // Avg time/img: 0.0497 s
# EPOCH IoU on VAL set:  45.51 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 39)
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.424 (epoch: 40, step: 0) // Avg time/img: 0.1575 s
# loss: 0.5248 (epoch: 40, step: 50) // Avg time/img: 0.1406 s
# loss: 0.5336 (epoch: 40, step: 100) // Avg time/img: 0.1399 s
# loss: 0.5323 (epoch: 40, step: 150) // Avg time/img: 0.1387 s
# loss: 0.5252 (epoch: 40, step: 200) // Avg time/img: 0.1386 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.8526 (epoch: 40, step: 0) // Avg time/img: 0.0568 s
# VAL loss: 1.344 (epoch: 40, step: 50) // Avg time/img: 0.0498 s
# VAL loss: 1.372 (epoch: 40, step: 100) // Avg time/img: 0.0495 s
# VAL loss: 1.205 (epoch: 40, step: 150) // Avg time/img: 0.0493 s
# EPOCH IoU on VAL set:  44.43 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.5856 (epoch: 41, step: 0) // Avg time/img: 0.1430 s
# loss: 0.5278 (epoch: 41, step: 50) // Avg time/img: 0.1383 s
# loss: 0.5232 (epoch: 41, step: 100) // Avg time/img: 0.1396 s
# loss: 0.5258 (epoch: 41, step: 150) // Avg time/img: 0.1386 s
# loss: 0.5154 (epoch: 41, step: 200) // Avg time/img: 0.1381 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.9728 (epoch: 41, step: 0) // Avg time/img: 0.0534 s
# VAL loss: 1.201 (epoch: 41, step: 50) // Avg time/img: 0.0493 s
# VAL loss: 1.261 (epoch: 41, step: 100) // Avg time/img: 0.0486 s
# VAL loss: 1.118 (epoch: 41, step: 150) // Avg time/img: 0.0493 s
# EPOCH IoU on VAL set:  46.38 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 41)
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.4935 (epoch: 42, step: 0) // Avg time/img: 0.1485 s
# loss: 0.4933 (epoch: 42, step: 50) // Avg time/img: 0.1400 s
# loss: 0.5 (epoch: 42, step: 100) // Avg time/img: 0.1394 s
# loss: 0.4978 (epoch: 42, step: 150) // Avg time/img: 0.1383 s
# loss: 0.5003 (epoch: 42, step: 200) // Avg time/img: 0.1384 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.8799 (epoch: 42, step: 0) // Avg time/img: 0.0545 s
# VAL loss: 1.325 (epoch: 42, step: 50) // Avg time/img: 0.0502 s
# VAL loss: 1.343 (epoch: 42, step: 100) // Avg time/img: 0.0495 s
# VAL loss: 1.177 (epoch: 42, step: 150) // Avg time/img: 0.0496 s
# EPOCH IoU on VAL set:  45.76 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.475 (epoch: 43, step: 0) // Avg time/img: 0.1409 s
# loss: 0.516 (epoch: 43, step: 50) // Avg time/img: 0.1385 s
# loss: 0.5201 (epoch: 43, step: 100) // Avg time/img: 0.1387 s
# loss: 0.5135 (epoch: 43, step: 150) // Avg time/img: 0.1386 s
# loss: 0.5088 (epoch: 43, step: 200) // Avg time/img: 0.1388 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.9223 (epoch: 43, step: 0) // Avg time/img: 0.0527 s
# VAL loss: 1.434 (epoch: 43, step: 50) // Avg time/img: 0.0507 s
# VAL loss: 1.481 (epoch: 43, step: 100) // Avg time/img: 0.0496 s
# VAL loss: 1.272 (epoch: 43, step: 150) // Avg time/img: 0.0492 s
# EPOCH IoU on VAL set:  44.64 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.3889 (epoch: 44, step: 0) // Avg time/img: 0.1428 s
# loss: 0.4966 (epoch: 44, step: 50) // Avg time/img: 0.1386 s
# loss: 0.4988 (epoch: 44, step: 100) // Avg time/img: 0.1391 s
# loss: 0.4968 (epoch: 44, step: 150) // Avg time/img: 0.1390 s
# loss: 0.5 (epoch: 44, step: 200) // Avg time/img: 0.1388 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.8024 (epoch: 44, step: 0) // Avg time/img: 0.0517 s
# VAL loss: 1.38 (epoch: 44, step: 50) // Avg time/img: 0.0489 s
# VAL loss: 1.42 (epoch: 44, step: 100) // Avg time/img: 0.0497 s
# VAL loss: 1.246 (epoch: 44, step: 150) // Avg time/img: 0.0494 s
# EPOCH IoU on VAL set:  44.85 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.4913 (epoch: 45, step: 0) // Avg time/img: 0.1383 s
# loss: 0.4887 (epoch: 45, step: 50) // Avg time/img: 0.1409 s
# loss: 0.4855 (epoch: 45, step: 100) // Avg time/img: 0.1387 s
# loss: 0.4864 (epoch: 45, step: 150) // Avg time/img: 0.1387 s
# loss: 0.4857 (epoch: 45, step: 200) // Avg time/img: 0.1387 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.7315 (epoch: 45, step: 0) // Avg time/img: 0.0523 s
# VAL loss: 1.244 (epoch: 45, step: 50) // Avg time/img: 0.0492 s
# VAL loss: 1.267 (epoch: 45, step: 100) // Avg time/img: 0.0495 s
# VAL loss: 1.103 (epoch: 45, step: 150) // Avg time/img: 0.0492 s
# EPOCH IoU on VAL set:  46.40 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 45)
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.4516 (epoch: 46, step: 0) // Avg time/img: 0.1710 s
# loss: 0.4893 (epoch: 46, step: 50) // Avg time/img: 0.1411 s
# loss: 0.4831 (epoch: 46, step: 100) // Avg time/img: 0.1388 s
# loss: 0.4849 (epoch: 46, step: 150) // Avg time/img: 0.1385 s
# loss: 0.4845 (epoch: 46, step: 200) // Avg time/img: 0.1385 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.7456 (epoch: 46, step: 0) // Avg time/img: 0.0529 s
# VAL loss: 1.233 (epoch: 46, step: 50) // Avg time/img: 0.0496 s
# VAL loss: 1.263 (epoch: 46, step: 100) // Avg time/img: 0.0494 s
# VAL loss: 1.104 (epoch: 46, step: 150) // Avg time/img: 0.0493 s
# EPOCH IoU on VAL set:  46.61 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 46)
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.4536 (epoch: 47, step: 0) // Avg time/img: 0.1589 s
# loss: 0.4664 (epoch: 47, step: 50) // Avg time/img: 0.1407 s
# loss: 0.4825 (epoch: 47, step: 100) // Avg time/img: 0.1386 s
# loss: 0.4865 (epoch: 47, step: 150) // Avg time/img: 0.1385 s
# loss: 0.4854 (epoch: 47, step: 200) // Avg time/img: 0.1380 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.7667 (epoch: 47, step: 0) // Avg time/img: 0.0559 s
# VAL loss: 1.317 (epoch: 47, step: 50) // Avg time/img: 0.0491 s
# VAL loss: 1.325 (epoch: 47, step: 100) // Avg time/img: 0.0489 s
# VAL loss: 1.148 (epoch: 47, step: 150) // Avg time/img: 0.0490 s
# EPOCH IoU on VAL set:  46.00 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.4465 (epoch: 48, step: 0) // Avg time/img: 0.1577 s
# loss: 0.4691 (epoch: 48, step: 50) // Avg time/img: 0.1406 s
# loss: 0.49 (epoch: 48, step: 100) // Avg time/img: 0.1386 s
# loss: 0.4794 (epoch: 48, step: 150) // Avg time/img: 0.1383 s
# loss: 0.4822 (epoch: 48, step: 200) // Avg time/img: 0.1378 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.7452 (epoch: 48, step: 0) // Avg time/img: 0.0527 s
# VAL loss: 1.36 (epoch: 48, step: 50) // Avg time/img: 0.0487 s
# VAL loss: 1.355 (epoch: 48, step: 100) // Avg time/img: 0.0486 s
# VAL loss: 1.177 (epoch: 48, step: 150) // Avg time/img: 0.0489 s
# EPOCH IoU on VAL set:  46.70 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 48)
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.5337 (epoch: 49, step: 0) // Avg time/img: 0.1578 s
# loss: 0.4819 (epoch: 49, step: 50) // Avg time/img: 0.1411 s
# loss: 0.4623 (epoch: 49, step: 100) // Avg time/img: 0.1388 s
# loss: 0.4634 (epoch: 49, step: 150) // Avg time/img: 0.1383 s
# loss: 0.4691 (epoch: 49, step: 200) // Avg time/img: 0.1380 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.7608 (epoch: 49, step: 0) // Avg time/img: 0.0706 s
# VAL loss: 1.285 (epoch: 49, step: 50) // Avg time/img: 0.0494 s
# VAL loss: 1.304 (epoch: 49, step: 100) // Avg time/img: 0.0489 s
# VAL loss: 1.133 (epoch: 49, step: 150) // Avg time/img: 0.0493 s
# EPOCH IoU on VAL set:  46.66 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.4815 (epoch: 50, step: 0) // Avg time/img: 0.1644 s
# loss: 0.4725 (epoch: 50, step: 50) // Avg time/img: 0.1386 s
# loss: 0.4665 (epoch: 50, step: 100) // Avg time/img: 0.1387 s
# loss: 0.4744 (epoch: 50, step: 150) // Avg time/img: 0.1379 s
# loss: 0.4757 (epoch: 50, step: 200) // Avg time/img: 0.1378 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.7639 (epoch: 50, step: 0) // Avg time/img: 0.0802 s
# VAL loss: 1.251 (epoch: 50, step: 50) // Avg time/img: 0.0516 s
# VAL loss: 1.283 (epoch: 50, step: 100) // Avg time/img: 0.0503 s
# VAL loss: 1.119 (epoch: 50, step: 150) // Avg time/img: 0.0500 s
# EPOCH IoU on VAL set:  46.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 50)
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.3753 (epoch: 51, step: 0) // Avg time/img: 0.1501 s
# loss: 0.4342 (epoch: 51, step: 50) // Avg time/img: 0.1392 s
# loss: 0.4559 (epoch: 51, step: 100) // Avg time/img: 0.1386 s
# loss: 0.4641 (epoch: 51, step: 150) // Avg time/img: 0.1379 s
# loss: 0.4614 (epoch: 51, step: 200) // Avg time/img: 0.1380 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.746 (epoch: 51, step: 0) // Avg time/img: 0.0575 s
# VAL loss: 1.232 (epoch: 51, step: 50) // Avg time/img: 0.0518 s
# VAL loss: 1.24 (epoch: 51, step: 100) // Avg time/img: 0.0503 s
# VAL loss: 1.079 (epoch: 51, step: 150) // Avg time/img: 0.0501 s
# EPOCH IoU on VAL set:  46.57 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.4684 (epoch: 52, step: 0) // Avg time/img: 0.1370 s
# loss: 0.4346 (epoch: 52, step: 50) // Avg time/img: 0.1378 s
# loss: 0.4606 (epoch: 52, step: 100) // Avg time/img: 0.1384 s
# loss: 0.46 (epoch: 52, step: 150) // Avg time/img: 0.1377 s
# loss: 0.4602 (epoch: 52, step: 200) // Avg time/img: 0.1379 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.7704 (epoch: 52, step: 0) // Avg time/img: 0.0553 s
# VAL loss: 1.256 (epoch: 52, step: 50) // Avg time/img: 0.0514 s
# VAL loss: 1.263 (epoch: 52, step: 100) // Avg time/img: 0.0501 s
# VAL loss: 1.095 (epoch: 52, step: 150) // Avg time/img: 0.0498 s
# EPOCH IoU on VAL set:  46.74 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.3293 (epoch: 53, step: 0) // Avg time/img: 0.1655 s
# loss: 0.45 (epoch: 53, step: 50) // Avg time/img: 0.1384 s
# loss: 0.4498 (epoch: 53, step: 100) // Avg time/img: 0.1389 s
# loss: 0.4492 (epoch: 53, step: 150) // Avg time/img: 0.1380 s
# loss: 0.4557 (epoch: 53, step: 200) // Avg time/img: 0.1381 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.7489 (epoch: 53, step: 0) // Avg time/img: 0.0577 s
# VAL loss: 1.246 (epoch: 53, step: 50) // Avg time/img: 0.0525 s
# VAL loss: 1.265 (epoch: 53, step: 100) // Avg time/img: 0.0506 s
# VAL loss: 1.1 (epoch: 53, step: 150) // Avg time/img: 0.0503 s
# EPOCH IoU on VAL set:  46.97 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.4301 (epoch: 54, step: 0) // Avg time/img: 0.1576 s
# loss: 0.4534 (epoch: 54, step: 50) // Avg time/img: 0.1386 s
# loss: 0.4422 (epoch: 54, step: 100) // Avg time/img: 0.1388 s
# loss: 0.4491 (epoch: 54, step: 150) // Avg time/img: 0.1380 s
# loss: 0.4523 (epoch: 54, step: 200) // Avg time/img: 0.1383 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.7794 (epoch: 54, step: 0) // Avg time/img: 0.0537 s
# VAL loss: 1.233 (epoch: 54, step: 50) // Avg time/img: 0.0512 s
# VAL loss: 1.256 (epoch: 54, step: 100) // Avg time/img: 0.0501 s
# VAL loss: 1.087 (epoch: 54, step: 150) // Avg time/img: 0.0501 s
# EPOCH IoU on VAL set:  47.36 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 54)
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.3829 (epoch: 55, step: 0) // Avg time/img: 0.1423 s
# loss: 0.4592 (epoch: 55, step: 50) // Avg time/img: 0.1382 s
# loss: 0.4468 (epoch: 55, step: 100) // Avg time/img: 0.1386 s
# loss: 0.4382 (epoch: 55, step: 150) // Avg time/img: 0.1378 s
# loss: 0.4487 (epoch: 55, step: 200) // Avg time/img: 0.1380 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.733 (epoch: 55, step: 0) // Avg time/img: 0.0580 s
# VAL loss: 1.26 (epoch: 55, step: 50) // Avg time/img: 0.0514 s
# VAL loss: 1.282 (epoch: 55, step: 100) // Avg time/img: 0.0497 s
# VAL loss: 1.112 (epoch: 55, step: 150) // Avg time/img: 0.0498 s
# EPOCH IoU on VAL set:  47.08 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.3364 (epoch: 56, step: 0) // Avg time/img: 0.1517 s
# loss: 0.437 (epoch: 56, step: 50) // Avg time/img: 0.1388 s
# loss: 0.4256 (epoch: 56, step: 100) // Avg time/img: 0.1392 s
# loss: 0.4368 (epoch: 56, step: 150) // Avg time/img: 0.1381 s
# loss: 0.4422 (epoch: 56, step: 200) // Avg time/img: 0.1381 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.6857 (epoch: 56, step: 0) // Avg time/img: 0.0601 s
# VAL loss: 1.205 (epoch: 56, step: 50) // Avg time/img: 0.0516 s
# VAL loss: 1.203 (epoch: 56, step: 100) // Avg time/img: 0.0501 s
# VAL loss: 1.047 (epoch: 56, step: 150) // Avg time/img: 0.0496 s
# EPOCH IoU on VAL set:  47.82 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/7-7/model_best.pth (epoch: 56)
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.4461 (epoch: 57, step: 0) // Avg time/img: 0.1655 s
# loss: 0.423 (epoch: 57, step: 50) // Avg time/img: 0.1389 s
# loss: 0.4362 (epoch: 57, step: 100) // Avg time/img: 0.1391 s
# loss: 0.4371 (epoch: 57, step: 150) // Avg time/img: 0.1381 s
# loss: 0.4411 (epoch: 57, step: 200) // Avg time/img: 0.1383 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.7432 (epoch: 57, step: 0) // Avg time/img: 0.0538 s
# VAL loss: 1.228 (epoch: 57, step: 50) // Avg time/img: 0.0515 s
# VAL loss: 1.258 (epoch: 57, step: 100) // Avg time/img: 0.0503 s
# VAL loss: 1.091 (epoch: 57, step: 150) // Avg time/img: 0.0500 s
# EPOCH IoU on VAL set:  47.34 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.4677 (epoch: 58, step: 0) // Avg time/img: 0.1616 s
# loss: 0.4407 (epoch: 58, step: 50) // Avg time/img: 0.1386 s
# loss: 0.4324 (epoch: 58, step: 100) // Avg time/img: 0.1387 s
# loss: 0.4323 (epoch: 58, step: 150) // Avg time/img: 0.1380 s
# loss: 0.4381 (epoch: 58, step: 200) // Avg time/img: 0.1380 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.7494 (epoch: 58, step: 0) // Avg time/img: 0.0542 s
# VAL loss: 1.29 (epoch: 58, step: 50) // Avg time/img: 0.0515 s
# VAL loss: 1.278 (epoch: 58, step: 100) // Avg time/img: 0.0500 s
# VAL loss: 1.101 (epoch: 58, step: 150) // Avg time/img: 0.0494 s
# EPOCH IoU on VAL set:  46.95 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.4128 (epoch: 59, step: 0) // Avg time/img: 0.1435 s
# loss: 0.4241 (epoch: 59, step: 50) // Avg time/img: 0.1383 s
# loss: 0.4344 (epoch: 59, step: 100) // Avg time/img: 0.1384 s
# loss: 0.4373 (epoch: 59, step: 150) // Avg time/img: 0.1377 s
# loss: 0.4365 (epoch: 59, step: 200) // Avg time/img: 0.1379 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.7072 (epoch: 59, step: 0) // Avg time/img: 0.0489 s
# VAL loss: 1.211 (epoch: 59, step: 50) // Avg time/img: 0.0514 s
# VAL loss: 1.219 (epoch: 59, step: 100) // Avg time/img: 0.0504 s
# VAL loss: 1.06 (epoch: 59, step: 150) // Avg time/img: 0.0497 s
# EPOCH IoU on VAL set:  47.73 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.3938 (epoch: 60, step: 0) // Avg time/img: 0.1437 s
# loss: 0.4288 (epoch: 60, step: 50) // Avg time/img: 0.1383 s
# loss: 0.4342 (epoch: 60, step: 100) // Avg time/img: 0.1386 s
# loss: 0.4314 (epoch: 60, step: 150) // Avg time/img: 0.1379 s
# loss: 0.4369 (epoch: 60, step: 200) // Avg time/img: 0.1381 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.7266 (epoch: 60, step: 0) // Avg time/img: 0.0547 s
# VAL loss: 1.221 (epoch: 60, step: 50) // Avg time/img: 0.0511 s
# VAL loss: 1.234 (epoch: 60, step: 100) // Avg time/img: 0.0500 s
# VAL loss: 1.073 (epoch: 60, step: 150) // Avg time/img: 0.0494 s
# EPOCH IoU on VAL set:  47.50 %
# ========== TRAINING FINISHED ===========

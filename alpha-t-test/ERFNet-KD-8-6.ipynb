# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet Model Common module

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)

class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

# %% [markdown]
# ## ERFNet Model [Teacher]

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class non_bottleneck (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3_1 = nn.Conv2d(chann, chann, (3,3), stride=1, padding=(1,1), bias=True)

        # self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3_2 = nn.Conv2d(chann, chann, (3, 3), stride=1, padding=(1*dilated,1*dilated), bias=True, dilation = (dilated,dilated))

        # self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3_1(input)
        # output = F.relu(output)
        # output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3_2(output)
        # output = F.relu(output)
        # output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class TEncoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 5):    #5 times
           self.layers.append(non_bottleneck(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 2):    #2 times
            self.layers.append(non_bottleneck(128, 0.3, 2))
            self.layers.append(non_bottleneck(128, 0.3, 4))
            self.layers.append(non_bottleneck(128, 0.3, 8))
            self.layers.append(non_bottleneck(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output

class TDecoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck(64, 0, 1))
        self.layers.append(non_bottleneck(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck(16, 0, 1))
        self.layers.append(non_bottleneck(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet Teacher
class TNet(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = TEncoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = TDecoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## ERFNet model definition [Student]

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3x1_1 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1,0), bias=True)

        self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3x1_2 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1*dilated,0), bias=True, dilation = (dilated,1))

        self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3x1_1(input)
        output = F.relu(output)
        output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3x1_2(output)
        output = F.relu(output)
        output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 1):    #1 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 1):    #1 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        # self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        # self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target

class MainLoss(torch.nn.Module):
    def __init__(self, weight=None):
      super().__init__()
      self.celoss = torch.nn.NLLLoss2d(weight) # CrossEntropyLoss2d
      # self.kdloss = torch.nn.KLDivLoss(reduction='batchmean')
      self.kdloss = torch.nn.MSELoss()
    
    def forward(self, outputs, targets, toutputs):
      T = 6 # Temperature
      alpha = 0.8 # alpha

      # 기본 Loss
      general_loss = self.celoss(torch.nn.functional.log_softmax(outputs, dim=1), targets)

      # KD Loss
      # toutputs[0].detach()
      # kd_loss = self.kdloss(F.log_softmax(outputs[0] / T, dim=1), F.softmax(toutputs[0] / T, dim=1)) * (T*T)
      # kd_loss = self.kdloss(F.log_softmax(outputs / T, dim=1), F.softmax(toutputs / T, dim=1)) * (T*T)
      kd_loss = self.kdloss(outputs / T, toutputs / T) * (T*T)

      # Loss
      loss = alpha * general_loss + (1-alpha) * kd_loss
      return loss


def train(args, tmodel, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = MainLoss(weight) # Loss 변경부분
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train() # student model (train mode)
        tmodel.eval() # teacher model (eval mode)
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)
            toutputs = tmodel(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0], toutputs) # Loss
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        tmodel.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 
            toutputs = tmodel(inputs, only_encode=enc)

            loss = criterion(outputs, targets[:, 0], toutputs)
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Teacher Model
    tweightspath = args.tloadDir + args.tloadWeights
    tmodel = TNet(NUM_CLASSES)

    #Load Model
    model = Net(NUM_CLASSES)
    
    if args.cuda:
        tmodel = torch.nn.DataParallel(tmodel).cuda()
        model = torch.nn.DataParallel(model).cuda()

    def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict elements
        own_state = model.state_dict()
        for name, param in state_dict.items():
            if name not in own_state:
                 continue
            own_state[name].copy_(param)
        return model

    tmodel = load_my_state_dict(tmodel, torch.load(tweightspath))
    print ("Teacher Model and weights LOADED successfully")

    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        model = load_my_state_dict(model, torch.load(args.state))


    # train(args, tmodel, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, tmodel, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, tmodel, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--tloadDir',default="/content/gdrive/MyDrive/Colab Notebooks/erf-baseline-teacher-150ep/")
    parser.add_argument('--tloadWeights', default="model_best.pth")

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=60)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=3)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# Teacher Model and weights LOADED successfully
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.MainLoss'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.604 (epoch: 1, step: 0) // Avg time/img: 4.0463 s
# loss: 1.528 (epoch: 1, step: 50) // Avg time/img: 0.1601 s
# loss: 1.364 (epoch: 1, step: 100) // Avg time/img: 0.1224 s
# loss: 1.295 (epoch: 1, step: 150) // Avg time/img: 0.1099 s
# loss: 1.236 (epoch: 1, step: 200) // Avg time/img: 0.1040 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.423 (epoch: 1, step: 0) // Avg time/img: 0.0402 s
# VAL loss: 1.305 (epoch: 1, step: 50) // Avg time/img: 0.0325 s
# VAL loss: 1.294 (epoch: 1, step: 100) // Avg time/img: 0.0326 s
# VAL loss: 1.181 (epoch: 1, step: 150) // Avg time/img: 0.0325 s
# EPOCH IoU on VAL set:  18.83 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 1.001 (epoch: 2, step: 0) // Avg time/img: 0.1005 s
# loss: 0.9899 (epoch: 2, step: 50) // Avg time/img: 0.0930 s
# loss: 1.01 (epoch: 2, step: 100) // Avg time/img: 0.0931 s
# loss: 0.9922 (epoch: 2, step: 150) // Avg time/img: 0.0930 s
# loss: 0.9748 (epoch: 2, step: 200) // Avg time/img: 0.0924 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.302 (epoch: 2, step: 0) // Avg time/img: 0.0423 s
# VAL loss: 1.322 (epoch: 2, step: 50) // Avg time/img: 0.0361 s
# VAL loss: 1.277 (epoch: 2, step: 100) // Avg time/img: 0.0346 s
# VAL loss: 1.153 (epoch: 2, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  20.35 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.9209 (epoch: 3, step: 0) // Avg time/img: 0.1159 s
# loss: 0.9265 (epoch: 3, step: 50) // Avg time/img: 0.0925 s
# loss: 0.913 (epoch: 3, step: 100) // Avg time/img: 0.0919 s
# loss: 0.9154 (epoch: 3, step: 150) // Avg time/img: 0.0916 s
# loss: 0.9044 (epoch: 3, step: 200) // Avg time/img: 0.0917 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 1.071 (epoch: 3, step: 0) // Avg time/img: 0.0426 s
# VAL loss: 1.102 (epoch: 3, step: 50) // Avg time/img: 0.0337 s
# VAL loss: 1.068 (epoch: 3, step: 100) // Avg time/img: 0.0333 s
# VAL loss: 0.9769 (epoch: 3, step: 150) // Avg time/img: 0.0339 s
# EPOCH IoU on VAL set:  24.10 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 1.029 (epoch: 4, step: 0) // Avg time/img: 0.1165 s
# loss: 0.8462 (epoch: 4, step: 50) // Avg time/img: 0.0919 s
# loss: 0.8467 (epoch: 4, step: 100) // Avg time/img: 0.0913 s
# loss: 0.8413 (epoch: 4, step: 150) // Avg time/img: 0.0914 s
# loss: 0.8419 (epoch: 4, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 1.475 (epoch: 4, step: 0) // Avg time/img: 0.0338 s
# VAL loss: 1.18 (epoch: 4, step: 50) // Avg time/img: 0.0330 s
# VAL loss: 1.156 (epoch: 4, step: 100) // Avg time/img: 0.0334 s
# VAL loss: 1.062 (epoch: 4, step: 150) // Avg time/img: 0.0330 s
# EPOCH IoU on VAL set:  23.09 %
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 0.6672 (epoch: 5, step: 0) // Avg time/img: 0.0874 s
# loss: 0.8198 (epoch: 5, step: 50) // Avg time/img: 0.0923 s
# loss: 0.8195 (epoch: 5, step: 100) // Avg time/img: 0.0923 s
# loss: 0.8159 (epoch: 5, step: 150) // Avg time/img: 0.0916 s
# loss: 0.8045 (epoch: 5, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 1.134 (epoch: 5, step: 0) // Avg time/img: 0.0357 s
# VAL loss: 1.084 (epoch: 5, step: 50) // Avg time/img: 0.0334 s
# VAL loss: 1.072 (epoch: 5, step: 100) // Avg time/img: 0.0332 s
# VAL loss: 0.9762 (epoch: 5, step: 150) // Avg time/img: 0.0333 s
# EPOCH IoU on VAL set:  25.88 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 5)
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004623387553722673
# loss: 0.8857 (epoch: 6, step: 0) // Avg time/img: 0.0894 s
# loss: 0.7845 (epoch: 6, step: 50) // Avg time/img: 0.0923 s
# loss: 0.7662 (epoch: 6, step: 100) // Avg time/img: 0.0916 s
# loss: 0.7705 (epoch: 6, step: 150) // Avg time/img: 0.0917 s
# loss: 0.7742 (epoch: 6, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 1.31 (epoch: 6, step: 0) // Avg time/img: 0.0356 s
# VAL loss: 1.109 (epoch: 6, step: 50) // Avg time/img: 0.0327 s
# VAL loss: 1.076 (epoch: 6, step: 100) // Avg time/img: 0.0328 s
# VAL loss: 0.976 (epoch: 6, step: 150) // Avg time/img: 0.0333 s
# EPOCH IoU on VAL set:  26.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.9932 (epoch: 7, step: 0) // Avg time/img: 0.1100 s
# loss: 0.7678 (epoch: 7, step: 50) // Avg time/img: 0.0913 s
# loss: 0.7479 (epoch: 7, step: 100) // Avg time/img: 0.0915 s
# loss: 0.7491 (epoch: 7, step: 150) // Avg time/img: 0.0911 s
# loss: 0.7469 (epoch: 7, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 1.088 (epoch: 7, step: 0) // Avg time/img: 0.0324 s
# VAL loss: 1.097 (epoch: 7, step: 50) // Avg time/img: 0.0326 s
# VAL loss: 1.079 (epoch: 7, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.9778 (epoch: 7, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  25.44 %
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.00044717978378742816
# loss: 0.6185 (epoch: 8, step: 0) // Avg time/img: 0.0928 s
# loss: 0.7234 (epoch: 8, step: 50) // Avg time/img: 0.0929 s
# loss: 0.7358 (epoch: 8, step: 100) // Avg time/img: 0.0921 s
# loss: 0.7342 (epoch: 8, step: 150) // Avg time/img: 0.0921 s
# loss: 0.7329 (epoch: 8, step: 200) // Avg time/img: 0.0917 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 1.29 (epoch: 8, step: 0) // Avg time/img: 0.0335 s
# VAL loss: 1.13 (epoch: 8, step: 50) // Avg time/img: 0.0343 s
# VAL loss: 1.082 (epoch: 8, step: 100) // Avg time/img: 0.0335 s
# VAL loss: 0.966 (epoch: 8, step: 150) // Avg time/img: 0.0333 s
# EPOCH IoU on VAL set:  28.06 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 8)
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.7097 (epoch: 9, step: 0) // Avg time/img: 0.0920 s
# loss: 0.7335 (epoch: 9, step: 50) // Avg time/img: 0.0919 s
# loss: 0.7238 (epoch: 9, step: 100) // Avg time/img: 0.0919 s
# loss: 0.7162 (epoch: 9, step: 150) // Avg time/img: 0.0911 s
# loss: 0.7116 (epoch: 9, step: 200) // Avg time/img: 0.0909 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 1.534 (epoch: 9, step: 0) // Avg time/img: 0.0341 s
# VAL loss: 1.125 (epoch: 9, step: 50) // Avg time/img: 0.0327 s
# VAL loss: 1.083 (epoch: 9, step: 100) // Avg time/img: 0.0331 s
# VAL loss: 0.9746 (epoch: 9, step: 150) // Avg time/img: 0.0332 s
# EPOCH IoU on VAL set:  27.92 %
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.00043196348615140955
# loss: 0.9918 (epoch: 10, step: 0) // Avg time/img: 0.0926 s
# loss: 0.7053 (epoch: 10, step: 50) // Avg time/img: 0.0934 s
# loss: 0.7096 (epoch: 10, step: 100) // Avg time/img: 0.0923 s
# loss: 0.7045 (epoch: 10, step: 150) // Avg time/img: 0.0915 s
# loss: 0.7057 (epoch: 10, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 0.9411 (epoch: 10, step: 0) // Avg time/img: 0.0343 s
# VAL loss: 0.9946 (epoch: 10, step: 50) // Avg time/img: 0.0334 s
# VAL loss: 0.9864 (epoch: 10, step: 100) // Avg time/img: 0.0333 s
# VAL loss: 0.9014 (epoch: 10, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  29.87 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 10)
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.7151 (epoch: 11, step: 0) // Avg time/img: 0.0866 s
# loss: 0.6899 (epoch: 11, step: 50) // Avg time/img: 0.0919 s
# loss: 0.6897 (epoch: 11, step: 100) // Avg time/img: 0.0916 s
# loss: 0.6876 (epoch: 11, step: 150) // Avg time/img: 0.0915 s
# loss: 0.6879 (epoch: 11, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.9263 (epoch: 11, step: 0) // Avg time/img: 0.0384 s
# VAL loss: 0.9641 (epoch: 11, step: 50) // Avg time/img: 0.0320 s
# VAL loss: 0.9569 (epoch: 11, step: 100) // Avg time/img: 0.0331 s
# VAL loss: 0.8764 (epoch: 11, step: 150) // Avg time/img: 0.0330 s
# EPOCH IoU on VAL set:  30.93 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 11)
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.0004166873834706844
# loss: 0.7214 (epoch: 12, step: 0) // Avg time/img: 0.0955 s
# loss: 0.6826 (epoch: 12, step: 50) // Avg time/img: 0.0921 s
# loss: 0.6836 (epoch: 12, step: 100) // Avg time/img: 0.0926 s
# loss: 0.6859 (epoch: 12, step: 150) // Avg time/img: 0.0919 s
# loss: 0.6795 (epoch: 12, step: 200) // Avg time/img: 0.0912 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 1.038 (epoch: 12, step: 0) // Avg time/img: 0.0417 s
# VAL loss: 0.9805 (epoch: 12, step: 50) // Avg time/img: 0.0331 s
# VAL loss: 0.9718 (epoch: 12, step: 100) // Avg time/img: 0.0332 s
# VAL loss: 0.8943 (epoch: 12, step: 150) // Avg time/img: 0.0331 s
# EPOCH IoU on VAL set:  30.52 %
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.6399 (epoch: 13, step: 0) // Avg time/img: 0.0910 s
# loss: 0.6585 (epoch: 13, step: 50) // Avg time/img: 0.0912 s
# loss: 0.6528 (epoch: 13, step: 100) // Avg time/img: 0.0922 s
# loss: 0.6643 (epoch: 13, step: 150) // Avg time/img: 0.0919 s
# loss: 0.6643 (epoch: 13, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 0.694 (epoch: 13, step: 0) // Avg time/img: 0.0403 s
# VAL loss: 0.9024 (epoch: 13, step: 50) // Avg time/img: 0.0352 s
# VAL loss: 0.907 (epoch: 13, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.8456 (epoch: 13, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  32.47 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 13)
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.0004013487836640184
# loss: 0.6248 (epoch: 14, step: 0) // Avg time/img: 0.0937 s
# loss: 0.6712 (epoch: 14, step: 50) // Avg time/img: 0.0930 s
# loss: 0.6684 (epoch: 14, step: 100) // Avg time/img: 0.0918 s
# loss: 0.6657 (epoch: 14, step: 150) // Avg time/img: 0.0914 s
# loss: 0.6667 (epoch: 14, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 0.6126 (epoch: 14, step: 0) // Avg time/img: 0.0320 s
# VAL loss: 0.8723 (epoch: 14, step: 50) // Avg time/img: 0.0328 s
# VAL loss: 0.8587 (epoch: 14, step: 100) // Avg time/img: 0.0333 s
# VAL loss: 0.8019 (epoch: 14, step: 150) // Avg time/img: 0.0333 s
# EPOCH IoU on VAL set:  33.25 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 14)
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.5921 (epoch: 15, step: 0) // Avg time/img: 0.1114 s
# loss: 0.6324 (epoch: 15, step: 50) // Avg time/img: 0.0916 s
# loss: 0.656 (epoch: 15, step: 100) // Avg time/img: 0.0909 s
# loss: 0.6583 (epoch: 15, step: 150) // Avg time/img: 0.0906 s
# loss: 0.6546 (epoch: 15, step: 200) // Avg time/img: 0.0908 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 0.8977 (epoch: 15, step: 0) // Avg time/img: 0.0313 s
# VAL loss: 0.9381 (epoch: 15, step: 50) // Avg time/img: 0.0331 s
# VAL loss: 0.9199 (epoch: 15, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.8466 (epoch: 15, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  32.42 %
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00038594475336178527
# loss: 0.7204 (epoch: 16, step: 0) // Avg time/img: 0.0925 s
# loss: 0.6442 (epoch: 16, step: 50) // Avg time/img: 0.0911 s
# loss: 0.6434 (epoch: 16, step: 100) // Avg time/img: 0.0911 s
# loss: 0.6424 (epoch: 16, step: 150) // Avg time/img: 0.0914 s
# loss: 0.647 (epoch: 16, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 0.7151 (epoch: 16, step: 0) // Avg time/img: 0.0339 s
# VAL loss: 0.9395 (epoch: 16, step: 50) // Avg time/img: 0.0364 s
# VAL loss: 0.9434 (epoch: 16, step: 100) // Avg time/img: 0.0348 s
# VAL loss: 0.8712 (epoch: 16, step: 150) // Avg time/img: 0.0343 s
# EPOCH IoU on VAL set:  32.17 %
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.575 (epoch: 17, step: 0) // Avg time/img: 0.1017 s
# loss: 0.5974 (epoch: 17, step: 50) // Avg time/img: 0.0913 s
# loss: 0.6172 (epoch: 17, step: 100) // Avg time/img: 0.0921 s
# loss: 0.6205 (epoch: 17, step: 150) // Avg time/img: 0.0914 s
# loss: 0.6312 (epoch: 17, step: 200) // Avg time/img: 0.0912 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.8402 (epoch: 17, step: 0) // Avg time/img: 0.0367 s
# VAL loss: 0.9062 (epoch: 17, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.8857 (epoch: 17, step: 100) // Avg time/img: 0.0334 s
# VAL loss: 0.8223 (epoch: 17, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  33.26 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 17)
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.00037047208454744316
# loss: 0.5544 (epoch: 18, step: 0) // Avg time/img: 0.1216 s
# loss: 0.6202 (epoch: 18, step: 50) // Avg time/img: 0.0920 s
# loss: 0.6104 (epoch: 18, step: 100) // Avg time/img: 0.0917 s
# loss: 0.618 (epoch: 18, step: 150) // Avg time/img: 0.0913 s
# loss: 0.6232 (epoch: 18, step: 200) // Avg time/img: 0.0917 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.7214 (epoch: 18, step: 0) // Avg time/img: 0.0323 s
# VAL loss: 0.919 (epoch: 18, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.8997 (epoch: 18, step: 100) // Avg time/img: 0.0334 s
# VAL loss: 0.8273 (epoch: 18, step: 150) // Avg time/img: 0.0331 s
# EPOCH IoU on VAL set:  34.02 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 18)
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.7615 (epoch: 19, step: 0) // Avg time/img: 0.0935 s
# loss: 0.6253 (epoch: 19, step: 50) // Avg time/img: 0.0909 s
# loss: 0.6348 (epoch: 19, step: 100) // Avg time/img: 0.0907 s
# loss: 0.6257 (epoch: 19, step: 150) // Avg time/img: 0.0907 s
# loss: 0.6264 (epoch: 19, step: 200) // Avg time/img: 0.0905 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.775 (epoch: 19, step: 0) // Avg time/img: 0.0349 s
# VAL loss: 0.9595 (epoch: 19, step: 50) // Avg time/img: 0.0338 s
# VAL loss: 0.9721 (epoch: 19, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.8903 (epoch: 19, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  32.99 %
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.0003549272548125162
# loss: 0.6291 (epoch: 20, step: 0) // Avg time/img: 0.0949 s
# loss: 0.6298 (epoch: 20, step: 50) // Avg time/img: 0.0927 s
# loss: 0.6172 (epoch: 20, step: 100) // Avg time/img: 0.0924 s
# loss: 0.6145 (epoch: 20, step: 150) // Avg time/img: 0.0917 s
# loss: 0.6101 (epoch: 20, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.8564 (epoch: 20, step: 0) // Avg time/img: 0.0371 s
# VAL loss: 1.054 (epoch: 20, step: 50) // Avg time/img: 0.0338 s
# VAL loss: 1.045 (epoch: 20, step: 100) // Avg time/img: 0.0334 s
# VAL loss: 0.9307 (epoch: 20, step: 150) // Avg time/img: 0.0333 s
# EPOCH IoU on VAL set:  33.17 %
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.6061 (epoch: 21, step: 0) // Avg time/img: 0.0909 s
# loss: 0.6021 (epoch: 21, step: 50) // Avg time/img: 0.0924 s
# loss: 0.6086 (epoch: 21, step: 100) // Avg time/img: 0.0918 s
# loss: 0.6098 (epoch: 21, step: 150) // Avg time/img: 0.0914 s
# loss: 0.6093 (epoch: 21, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.8698 (epoch: 21, step: 0) // Avg time/img: 0.0337 s
# VAL loss: 0.9727 (epoch: 21, step: 50) // Avg time/img: 0.0329 s
# VAL loss: 0.9729 (epoch: 21, step: 100) // Avg time/img: 0.0340 s
# VAL loss: 0.8775 (epoch: 21, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  34.65 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 21)
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.0003393063796290625
# loss: 0.5625 (epoch: 22, step: 0) // Avg time/img: 0.0927 s
# loss: 0.5968 (epoch: 22, step: 50) // Avg time/img: 0.0913 s
# loss: 0.6097 (epoch: 22, step: 100) // Avg time/img: 0.0917 s
# loss: 0.6062 (epoch: 22, step: 150) // Avg time/img: 0.0910 s
# loss: 0.6001 (epoch: 22, step: 200) // Avg time/img: 0.0908 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.6729 (epoch: 22, step: 0) // Avg time/img: 0.0333 s
# VAL loss: 0.9381 (epoch: 22, step: 50) // Avg time/img: 0.0350 s
# VAL loss: 0.9412 (epoch: 22, step: 100) // Avg time/img: 0.0337 s
# VAL loss: 0.8614 (epoch: 22, step: 150) // Avg time/img: 0.0335 s
# EPOCH IoU on VAL set:  35.03 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 22)
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.5304 (epoch: 23, step: 0) // Avg time/img: 0.0963 s
# loss: 0.5876 (epoch: 23, step: 50) // Avg time/img: 0.0928 s
# loss: 0.5924 (epoch: 23, step: 100) // Avg time/img: 0.0916 s
# loss: 0.5917 (epoch: 23, step: 150) // Avg time/img: 0.0912 s
# loss: 0.5891 (epoch: 23, step: 200) // Avg time/img: 0.0909 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.7297 (epoch: 23, step: 0) // Avg time/img: 0.0391 s
# VAL loss: 0.8927 (epoch: 23, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.8879 (epoch: 23, step: 100) // Avg time/img: 0.0333 s
# VAL loss: 0.8164 (epoch: 23, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  35.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 23)
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.0003236051545417615
# loss: 0.5292 (epoch: 24, step: 0) // Avg time/img: 0.0920 s
# loss: 0.5804 (epoch: 24, step: 50) // Avg time/img: 0.0913 s
# loss: 0.5829 (epoch: 24, step: 100) // Avg time/img: 0.0912 s
# loss: 0.5893 (epoch: 24, step: 150) // Avg time/img: 0.0918 s
# loss: 0.5872 (epoch: 24, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 0.763 (epoch: 24, step: 0) // Avg time/img: 0.0290 s
# VAL loss: 0.8768 (epoch: 24, step: 50) // Avg time/img: 0.0334 s
# VAL loss: 0.873 (epoch: 24, step: 100) // Avg time/img: 0.0341 s
# VAL loss: 0.804 (epoch: 24, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  36.75 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 24)
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.6097 (epoch: 25, step: 0) // Avg time/img: 0.0957 s
# loss: 0.5564 (epoch: 25, step: 50) // Avg time/img: 0.0911 s
# loss: 0.5679 (epoch: 25, step: 100) // Avg time/img: 0.0916 s
# loss: 0.5791 (epoch: 25, step: 150) // Avg time/img: 0.0915 s
# loss: 0.583 (epoch: 25, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.6574 (epoch: 25, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.8748 (epoch: 25, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.8585 (epoch: 25, step: 100) // Avg time/img: 0.0333 s
# VAL loss: 0.7859 (epoch: 25, step: 150) // Avg time/img: 0.0333 s
# EPOCH IoU on VAL set:  36.16 %
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00030781878448615926
# loss: 0.5561 (epoch: 26, step: 0) // Avg time/img: 0.0933 s
# loss: 0.5831 (epoch: 26, step: 50) // Avg time/img: 0.0929 s
# loss: 0.5883 (epoch: 26, step: 100) // Avg time/img: 0.0920 s
# loss: 0.5897 (epoch: 26, step: 150) // Avg time/img: 0.0914 s
# loss: 0.592 (epoch: 26, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.8054 (epoch: 26, step: 0) // Avg time/img: 0.0374 s
# VAL loss: 0.87 (epoch: 26, step: 50) // Avg time/img: 0.0327 s
# VAL loss: 0.8627 (epoch: 26, step: 100) // Avg time/img: 0.0322 s
# VAL loss: 0.7842 (epoch: 26, step: 150) // Avg time/img: 0.0324 s
# EPOCH IoU on VAL set:  37.06 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 26)
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.551 (epoch: 27, step: 0) // Avg time/img: 0.1149 s
# loss: 0.5756 (epoch: 27, step: 50) // Avg time/img: 0.0918 s
# loss: 0.5659 (epoch: 27, step: 100) // Avg time/img: 0.0913 s
# loss: 0.5699 (epoch: 27, step: 150) // Avg time/img: 0.0910 s
# loss: 0.5682 (epoch: 27, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.9014 (epoch: 27, step: 0) // Avg time/img: 0.0299 s
# VAL loss: 0.9652 (epoch: 27, step: 50) // Avg time/img: 0.0325 s
# VAL loss: 0.9483 (epoch: 27, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.8566 (epoch: 27, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  34.65 %
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00029194189645999016
# loss: 0.4755 (epoch: 28, step: 0) // Avg time/img: 0.0885 s
# loss: 0.5774 (epoch: 28, step: 50) // Avg time/img: 0.0910 s
# loss: 0.5724 (epoch: 28, step: 100) // Avg time/img: 0.0909 s
# loss: 0.5749 (epoch: 28, step: 150) // Avg time/img: 0.0916 s
# loss: 0.5745 (epoch: 28, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.6392 (epoch: 28, step: 0) // Avg time/img: 0.0345 s
# VAL loss: 0.7954 (epoch: 28, step: 50) // Avg time/img: 0.0346 s
# VAL loss: 0.7779 (epoch: 28, step: 100) // Avg time/img: 0.0349 s
# VAL loss: 0.7219 (epoch: 28, step: 150) // Avg time/img: 0.0342 s
# EPOCH IoU on VAL set:  39.40 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 28)
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.7286 (epoch: 29, step: 0) // Avg time/img: 0.1166 s
# loss: 0.5661 (epoch: 29, step: 50) // Avg time/img: 0.0914 s
# loss: 0.5638 (epoch: 29, step: 100) // Avg time/img: 0.0923 s
# loss: 0.5633 (epoch: 29, step: 150) // Avg time/img: 0.0915 s
# loss: 0.5627 (epoch: 29, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.6112 (epoch: 29, step: 0) // Avg time/img: 0.0370 s
# VAL loss: 0.8195 (epoch: 29, step: 50) // Avg time/img: 0.0333 s
# VAL loss: 0.8028 (epoch: 29, step: 100) // Avg time/img: 0.0331 s
# VAL loss: 0.7428 (epoch: 29, step: 150) // Avg time/img: 0.0332 s
# EPOCH IoU on VAL set:  39.08 %
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.0002759684303703797
# loss: 0.5666 (epoch: 30, step: 0) // Avg time/img: 0.0873 s
# loss: 0.5711 (epoch: 30, step: 50) // Avg time/img: 0.0923 s
# loss: 0.5581 (epoch: 30, step: 100) // Avg time/img: 0.0918 s
# loss: 0.5564 (epoch: 30, step: 150) // Avg time/img: 0.0917 s
# loss: 0.5581 (epoch: 30, step: 200) // Avg time/img: 0.0919 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.6257 (epoch: 30, step: 0) // Avg time/img: 0.0376 s
# VAL loss: 0.8511 (epoch: 30, step: 50) // Avg time/img: 0.0327 s
# VAL loss: 0.8196 (epoch: 30, step: 100) // Avg time/img: 0.0325 s
# VAL loss: 0.7535 (epoch: 30, step: 150) // Avg time/img: 0.0333 s
# EPOCH IoU on VAL set:  37.98 %
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.522 (epoch: 31, step: 0) // Avg time/img: 0.0861 s
# loss: 0.5506 (epoch: 31, step: 50) // Avg time/img: 0.0913 s
# loss: 0.5475 (epoch: 31, step: 100) // Avg time/img: 0.0910 s
# loss: 0.552 (epoch: 31, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5559 (epoch: 31, step: 200) // Avg time/img: 0.0912 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.836 (epoch: 31, step: 0) // Avg time/img: 0.0396 s
# VAL loss: 0.9421 (epoch: 31, step: 50) // Avg time/img: 0.0353 s
# VAL loss: 0.953 (epoch: 31, step: 100) // Avg time/img: 0.0341 s
# VAL loss: 0.8613 (epoch: 31, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  36.00 %
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.0002598915008274931
# loss: 0.5666 (epoch: 32, step: 0) // Avg time/img: 0.0890 s
# loss: 0.5374 (epoch: 32, step: 50) // Avg time/img: 0.0923 s
# loss: 0.5417 (epoch: 32, step: 100) // Avg time/img: 0.0918 s
# loss: 0.5476 (epoch: 32, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5473 (epoch: 32, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.7006 (epoch: 32, step: 0) // Avg time/img: 0.0327 s
# VAL loss: 0.8181 (epoch: 32, step: 50) // Avg time/img: 0.0335 s
# VAL loss: 0.8162 (epoch: 32, step: 100) // Avg time/img: 0.0332 s
# VAL loss: 0.7561 (epoch: 32, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  38.73 %
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.5227 (epoch: 33, step: 0) // Avg time/img: 0.0883 s
# loss: 0.5463 (epoch: 33, step: 50) // Avg time/img: 0.0915 s
# loss: 0.552 (epoch: 33, step: 100) // Avg time/img: 0.0911 s
# loss: 0.5469 (epoch: 33, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5466 (epoch: 33, step: 200) // Avg time/img: 0.0909 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.7584 (epoch: 33, step: 0) // Avg time/img: 0.0344 s
# VAL loss: 0.9213 (epoch: 33, step: 50) // Avg time/img: 0.0344 s
# VAL loss: 0.9339 (epoch: 33, step: 100) // Avg time/img: 0.0343 s
# VAL loss: 0.8453 (epoch: 33, step: 150) // Avg time/img: 0.0340 s
# EPOCH IoU on VAL set:  36.69 %
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.00024370321958949772
# loss: 0.5216 (epoch: 34, step: 0) // Avg time/img: 0.0925 s
# loss: 0.5476 (epoch: 34, step: 50) // Avg time/img: 0.0914 s
# loss: 0.5416 (epoch: 34, step: 100) // Avg time/img: 0.0922 s
# loss: 0.5463 (epoch: 34, step: 150) // Avg time/img: 0.0913 s
# loss: 0.5446 (epoch: 34, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.6189 (epoch: 34, step: 0) // Avg time/img: 0.0379 s
# VAL loss: 0.8143 (epoch: 34, step: 50) // Avg time/img: 0.0331 s
# VAL loss: 0.81 (epoch: 34, step: 100) // Avg time/img: 0.0332 s
# VAL loss: 0.7505 (epoch: 34, step: 150) // Avg time/img: 0.0335 s
# EPOCH IoU on VAL set:  39.21 %
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.7433 (epoch: 35, step: 0) // Avg time/img: 0.0925 s
# loss: 0.5543 (epoch: 35, step: 50) // Avg time/img: 0.0908 s
# loss: 0.5488 (epoch: 35, step: 100) // Avg time/img: 0.0916 s
# loss: 0.5456 (epoch: 35, step: 150) // Avg time/img: 0.0913 s
# loss: 0.5457 (epoch: 35, step: 200) // Avg time/img: 0.0909 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.8212 (epoch: 35, step: 0) // Avg time/img: 0.0355 s
# VAL loss: 0.8872 (epoch: 35, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.885 (epoch: 35, step: 100) // Avg time/img: 0.0340 s
# VAL loss: 0.8073 (epoch: 35, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  38.70 %
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.00022739446367039517
# loss: 0.4881 (epoch: 36, step: 0) // Avg time/img: 0.0974 s
# loss: 0.5413 (epoch: 36, step: 50) // Avg time/img: 0.0913 s
# loss: 0.5364 (epoch: 36, step: 100) // Avg time/img: 0.0921 s
# loss: 0.5365 (epoch: 36, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5403 (epoch: 36, step: 200) // Avg time/img: 0.0912 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.6253 (epoch: 36, step: 0) // Avg time/img: 0.0481 s
# VAL loss: 0.8291 (epoch: 36, step: 50) // Avg time/img: 0.0340 s
# VAL loss: 0.814 (epoch: 36, step: 100) // Avg time/img: 0.0331 s
# VAL loss: 0.7501 (epoch: 36, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  40.05 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 36)
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.6069 (epoch: 37, step: 0) // Avg time/img: 0.0941 s
# loss: 0.5373 (epoch: 37, step: 50) // Avg time/img: 0.0926 s
# loss: 0.5339 (epoch: 37, step: 100) // Avg time/img: 0.0919 s
# loss: 0.5342 (epoch: 37, step: 150) // Avg time/img: 0.0916 s
# loss: 0.5414 (epoch: 37, step: 200) // Avg time/img: 0.0916 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.7773 (epoch: 37, step: 0) // Avg time/img: 0.0318 s
# VAL loss: 0.8727 (epoch: 37, step: 50) // Avg time/img: 0.0325 s
# VAL loss: 0.8566 (epoch: 37, step: 100) // Avg time/img: 0.0326 s
# VAL loss: 0.7812 (epoch: 37, step: 150) // Avg time/img: 0.0329 s
# EPOCH IoU on VAL set:  38.36 %
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.00021095456673472888
# loss: 0.4716 (epoch: 38, step: 0) // Avg time/img: 0.0871 s
# loss: 0.5261 (epoch: 38, step: 50) // Avg time/img: 0.0914 s
# loss: 0.5262 (epoch: 38, step: 100) // Avg time/img: 0.0915 s
# loss: 0.5302 (epoch: 38, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5336 (epoch: 38, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.6685 (epoch: 38, step: 0) // Avg time/img: 0.0343 s
# VAL loss: 0.8445 (epoch: 38, step: 50) // Avg time/img: 0.0345 s
# VAL loss: 0.842 (epoch: 38, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.7742 (epoch: 38, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  39.95 %
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.6615 (epoch: 39, step: 0) // Avg time/img: 0.0948 s
# loss: 0.5395 (epoch: 39, step: 50) // Avg time/img: 0.0924 s
# loss: 0.5314 (epoch: 39, step: 100) // Avg time/img: 0.0917 s
# loss: 0.5287 (epoch: 39, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5292 (epoch: 39, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.6823 (epoch: 39, step: 0) // Avg time/img: 0.0354 s
# VAL loss: 0.85 (epoch: 39, step: 50) // Avg time/img: 0.0322 s
# VAL loss: 0.8607 (epoch: 39, step: 100) // Avg time/img: 0.0328 s
# VAL loss: 0.7912 (epoch: 39, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  39.26 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.4938 (epoch: 40, step: 0) // Avg time/img: 0.0863 s
# loss: 0.5154 (epoch: 40, step: 50) // Avg time/img: 0.0930 s
# loss: 0.5261 (epoch: 40, step: 100) // Avg time/img: 0.0916 s
# loss: 0.524 (epoch: 40, step: 150) // Avg time/img: 0.0917 s
# loss: 0.5271 (epoch: 40, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.7364 (epoch: 40, step: 0) // Avg time/img: 0.0357 s
# VAL loss: 0.9198 (epoch: 40, step: 50) // Avg time/img: 0.0340 s
# VAL loss: 0.8998 (epoch: 40, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.8117 (epoch: 40, step: 150) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  38.77 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.6238 (epoch: 41, step: 0) // Avg time/img: 0.0883 s
# loss: 0.5297 (epoch: 41, step: 50) // Avg time/img: 0.0924 s
# loss: 0.5259 (epoch: 41, step: 100) // Avg time/img: 0.0919 s
# loss: 0.5226 (epoch: 41, step: 150) // Avg time/img: 0.0916 s
# loss: 0.5261 (epoch: 41, step: 200) // Avg time/img: 0.0916 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.6724 (epoch: 41, step: 0) // Avg time/img: 0.0342 s
# VAL loss: 0.7794 (epoch: 41, step: 50) // Avg time/img: 0.0338 s
# VAL loss: 0.7777 (epoch: 41, step: 100) // Avg time/img: 0.0333 s
# VAL loss: 0.7263 (epoch: 41, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  41.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 41)
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.5324 (epoch: 42, step: 0) // Avg time/img: 0.0983 s
# loss: 0.5188 (epoch: 42, step: 50) // Avg time/img: 0.0916 s
# loss: 0.52 (epoch: 42, step: 100) // Avg time/img: 0.0913 s
# loss: 0.5193 (epoch: 42, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5198 (epoch: 42, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.7318 (epoch: 42, step: 0) // Avg time/img: 0.0338 s
# VAL loss: 0.8156 (epoch: 42, step: 50) // Avg time/img: 0.0346 s
# VAL loss: 0.8011 (epoch: 42, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.7356 (epoch: 42, step: 150) // Avg time/img: 0.0336 s
# EPOCH IoU on VAL set:  41.14 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.5299 (epoch: 43, step: 0) // Avg time/img: 0.0936 s
# loss: 0.5194 (epoch: 43, step: 50) // Avg time/img: 0.0923 s
# loss: 0.5205 (epoch: 43, step: 100) // Avg time/img: 0.0917 s
# loss: 0.5161 (epoch: 43, step: 150) // Avg time/img: 0.0917 s
# loss: 0.517 (epoch: 43, step: 200) // Avg time/img: 0.0918 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.6415 (epoch: 43, step: 0) // Avg time/img: 0.0333 s
# VAL loss: 0.8091 (epoch: 43, step: 50) // Avg time/img: 0.0329 s
# VAL loss: 0.8097 (epoch: 43, step: 100) // Avg time/img: 0.0332 s
# VAL loss: 0.7461 (epoch: 43, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  40.56 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.5361 (epoch: 44, step: 0) // Avg time/img: 0.0908 s
# loss: 0.5129 (epoch: 44, step: 50) // Avg time/img: 0.0907 s
# loss: 0.5115 (epoch: 44, step: 100) // Avg time/img: 0.0909 s
# loss: 0.5104 (epoch: 44, step: 150) // Avg time/img: 0.0913 s
# loss: 0.5132 (epoch: 44, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.7998 (epoch: 44, step: 0) // Avg time/img: 0.0279 s
# VAL loss: 0.846 (epoch: 44, step: 50) // Avg time/img: 0.0343 s
# VAL loss: 0.8426 (epoch: 44, step: 100) // Avg time/img: 0.0340 s
# VAL loss: 0.7705 (epoch: 44, step: 150) // Avg time/img: 0.0341 s
# EPOCH IoU on VAL set:  40.65 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.4606 (epoch: 45, step: 0) // Avg time/img: 0.0920 s
# loss: 0.5151 (epoch: 45, step: 50) // Avg time/img: 0.0931 s
# loss: 0.5161 (epoch: 45, step: 100) // Avg time/img: 0.0920 s
# loss: 0.5173 (epoch: 45, step: 150) // Avg time/img: 0.0915 s
# loss: 0.5214 (epoch: 45, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.6493 (epoch: 45, step: 0) // Avg time/img: 0.0356 s
# VAL loss: 0.827 (epoch: 45, step: 50) // Avg time/img: 0.0330 s
# VAL loss: 0.8176 (epoch: 45, step: 100) // Avg time/img: 0.0342 s
# VAL loss: 0.7447 (epoch: 45, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  40.87 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.6082 (epoch: 46, step: 0) // Avg time/img: 0.1061 s
# loss: 0.5254 (epoch: 46, step: 50) // Avg time/img: 0.0917 s
# loss: 0.521 (epoch: 46, step: 100) // Avg time/img: 0.0927 s
# loss: 0.5143 (epoch: 46, step: 150) // Avg time/img: 0.0921 s
# loss: 0.5122 (epoch: 46, step: 200) // Avg time/img: 0.0919 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.7316 (epoch: 46, step: 0) // Avg time/img: 0.0473 s
# VAL loss: 0.7799 (epoch: 46, step: 50) // Avg time/img: 0.0342 s
# VAL loss: 0.7805 (epoch: 46, step: 100) // Avg time/img: 0.0334 s
# VAL loss: 0.7226 (epoch: 46, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  42.27 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 46)
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.4554 (epoch: 47, step: 0) // Avg time/img: 0.0935 s
# loss: 0.5003 (epoch: 47, step: 50) // Avg time/img: 0.0929 s
# loss: 0.5066 (epoch: 47, step: 100) // Avg time/img: 0.0921 s
# loss: 0.5071 (epoch: 47, step: 150) // Avg time/img: 0.0914 s
# loss: 0.5128 (epoch: 47, step: 200) // Avg time/img: 0.0917 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.5773 (epoch: 47, step: 0) // Avg time/img: 0.0333 s
# VAL loss: 0.8117 (epoch: 47, step: 50) // Avg time/img: 0.0329 s
# VAL loss: 0.7994 (epoch: 47, step: 100) // Avg time/img: 0.0333 s
# VAL loss: 0.7342 (epoch: 47, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  42.19 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.5126 (epoch: 48, step: 0) // Avg time/img: 0.0986 s
# loss: 0.5005 (epoch: 48, step: 50) // Avg time/img: 0.0922 s
# loss: 0.5012 (epoch: 48, step: 100) // Avg time/img: 0.0921 s
# loss: 0.5041 (epoch: 48, step: 150) // Avg time/img: 0.0915 s
# loss: 0.5049 (epoch: 48, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.6796 (epoch: 48, step: 0) // Avg time/img: 0.0350 s
# VAL loss: 0.76 (epoch: 48, step: 50) // Avg time/img: 0.0334 s
# VAL loss: 0.7548 (epoch: 48, step: 100) // Avg time/img: 0.0335 s
# VAL loss: 0.7012 (epoch: 48, step: 150) // Avg time/img: 0.0335 s
# EPOCH IoU on VAL set:  43.45 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 48)
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.517 (epoch: 49, step: 0) // Avg time/img: 0.1010 s
# loss: 0.4994 (epoch: 49, step: 50) // Avg time/img: 0.0911 s
# loss: 0.5049 (epoch: 49, step: 100) // Avg time/img: 0.0918 s
# loss: 0.5038 (epoch: 49, step: 150) // Avg time/img: 0.0913 s
# loss: 0.5021 (epoch: 49, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.6109 (epoch: 49, step: 0) // Avg time/img: 0.0372 s
# VAL loss: 0.7909 (epoch: 49, step: 50) // Avg time/img: 0.0328 s
# VAL loss: 0.7814 (epoch: 49, step: 100) // Avg time/img: 0.0331 s
# VAL loss: 0.7185 (epoch: 49, step: 150) // Avg time/img: 0.0331 s
# EPOCH IoU on VAL set:  43.07 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.4713 (epoch: 50, step: 0) // Avg time/img: 0.1233 s
# loss: 0.4978 (epoch: 50, step: 50) // Avg time/img: 0.0919 s
# loss: 0.5004 (epoch: 50, step: 100) // Avg time/img: 0.0914 s
# loss: 0.4997 (epoch: 50, step: 150) // Avg time/img: 0.0911 s
# loss: 0.4972 (epoch: 50, step: 200) // Avg time/img: 0.0913 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.6497 (epoch: 50, step: 0) // Avg time/img: 0.0364 s
# VAL loss: 0.783 (epoch: 50, step: 50) // Avg time/img: 0.0331 s
# VAL loss: 0.7664 (epoch: 50, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.7057 (epoch: 50, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  43.51 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 50)
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.4941 (epoch: 51, step: 0) // Avg time/img: 0.0870 s
# loss: 0.4956 (epoch: 51, step: 50) // Avg time/img: 0.0929 s
# loss: 0.4977 (epoch: 51, step: 100) // Avg time/img: 0.0924 s
# loss: 0.4953 (epoch: 51, step: 150) // Avg time/img: 0.0919 s
# loss: 0.4955 (epoch: 51, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.6379 (epoch: 51, step: 0) // Avg time/img: 0.0368 s
# VAL loss: 0.7951 (epoch: 51, step: 50) // Avg time/img: 0.0330 s
# VAL loss: 0.7876 (epoch: 51, step: 100) // Avg time/img: 0.0329 s
# VAL loss: 0.727 (epoch: 51, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  42.92 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.5047 (epoch: 52, step: 0) // Avg time/img: 0.0890 s
# loss: 0.4931 (epoch: 52, step: 50) // Avg time/img: 0.0913 s
# loss: 0.4966 (epoch: 52, step: 100) // Avg time/img: 0.0912 s
# loss: 0.4954 (epoch: 52, step: 150) // Avg time/img: 0.0915 s
# loss: 0.4955 (epoch: 52, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.6109 (epoch: 52, step: 0) // Avg time/img: 0.0563 s
# VAL loss: 0.8272 (epoch: 52, step: 50) // Avg time/img: 0.0350 s
# VAL loss: 0.8102 (epoch: 52, step: 100) // Avg time/img: 0.0339 s
# VAL loss: 0.7386 (epoch: 52, step: 150) // Avg time/img: 0.0337 s
# EPOCH IoU on VAL set:  41.45 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.4897 (epoch: 53, step: 0) // Avg time/img: 0.0920 s
# loss: 0.4883 (epoch: 53, step: 50) // Avg time/img: 0.0927 s
# loss: 0.4852 (epoch: 53, step: 100) // Avg time/img: 0.0919 s
# loss: 0.4909 (epoch: 53, step: 150) // Avg time/img: 0.0915 s
# loss: 0.492 (epoch: 53, step: 200) // Avg time/img: 0.0917 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.7038 (epoch: 53, step: 0) // Avg time/img: 0.0285 s
# VAL loss: 0.8013 (epoch: 53, step: 50) // Avg time/img: 0.0327 s
# VAL loss: 0.7845 (epoch: 53, step: 100) // Avg time/img: 0.0327 s
# VAL loss: 0.7178 (epoch: 53, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  43.17 %
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.4704 (epoch: 54, step: 0) // Avg time/img: 0.0950 s
# loss: 0.4863 (epoch: 54, step: 50) // Avg time/img: 0.0913 s
# loss: 0.4919 (epoch: 54, step: 100) // Avg time/img: 0.0924 s
# loss: 0.4892 (epoch: 54, step: 150) // Avg time/img: 0.0918 s
# loss: 0.4893 (epoch: 54, step: 200) // Avg time/img: 0.0915 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.6508 (epoch: 54, step: 0) // Avg time/img: 0.0333 s
# VAL loss: 0.7866 (epoch: 54, step: 50) // Avg time/img: 0.0341 s
# VAL loss: 0.7775 (epoch: 54, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.7149 (epoch: 54, step: 150) // Avg time/img: 0.0334 s
# EPOCH IoU on VAL set:  43.39 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.4565 (epoch: 55, step: 0) // Avg time/img: 0.0915 s
# loss: 0.4791 (epoch: 55, step: 50) // Avg time/img: 0.0917 s
# loss: 0.4856 (epoch: 55, step: 100) // Avg time/img: 0.0915 s
# loss: 0.4873 (epoch: 55, step: 150) // Avg time/img: 0.0911 s
# loss: 0.4906 (epoch: 55, step: 200) // Avg time/img: 0.0914 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.6721 (epoch: 55, step: 0) // Avg time/img: 0.0327 s
# VAL loss: 0.824 (epoch: 55, step: 50) // Avg time/img: 0.0335 s
# VAL loss: 0.8237 (epoch: 55, step: 100) // Avg time/img: 0.0343 s
# VAL loss: 0.7493 (epoch: 55, step: 150) // Avg time/img: 0.0338 s
# EPOCH IoU on VAL set:  42.12 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.5053 (epoch: 56, step: 0) // Avg time/img: 0.0881 s
# loss: 0.4925 (epoch: 56, step: 50) // Avg time/img: 0.0916 s
# loss: 0.4883 (epoch: 56, step: 100) // Avg time/img: 0.0917 s
# loss: 0.4879 (epoch: 56, step: 150) // Avg time/img: 0.0912 s
# loss: 0.4876 (epoch: 56, step: 200) // Avg time/img: 0.0908 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.6718 (epoch: 56, step: 0) // Avg time/img: 0.0425 s
# VAL loss: 0.8248 (epoch: 56, step: 50) // Avg time/img: 0.0332 s
# VAL loss: 0.8166 (epoch: 56, step: 100) // Avg time/img: 0.0330 s
# VAL loss: 0.7428 (epoch: 56, step: 150) // Avg time/img: 0.0332 s
# EPOCH IoU on VAL set:  42.87 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.4414 (epoch: 57, step: 0) // Avg time/img: 0.0924 s
# loss: 0.486 (epoch: 57, step: 50) // Avg time/img: 0.0925 s
# loss: 0.4862 (epoch: 57, step: 100) // Avg time/img: 0.0918 s
# loss: 0.4855 (epoch: 57, step: 150) // Avg time/img: 0.0918 s
# loss: 0.4844 (epoch: 57, step: 200) // Avg time/img: 0.0918 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.6759 (epoch: 57, step: 0) // Avg time/img: 0.0362 s
# VAL loss: 0.8034 (epoch: 57, step: 50) // Avg time/img: 0.0333 s
# VAL loss: 0.7904 (epoch: 57, step: 100) // Avg time/img: 0.0338 s
# VAL loss: 0.7225 (epoch: 57, step: 150) // Avg time/img: 0.0333 s
# EPOCH IoU on VAL set:  43.62 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_encoder_best.pth (epoch: 57)
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.4684 (epoch: 58, step: 0) // Avg time/img: 0.0897 s
# loss: 0.4816 (epoch: 58, step: 50) // Avg time/img: 0.0912 s
# loss: 0.4804 (epoch: 58, step: 100) // Avg time/img: 0.0920 s
# loss: 0.4818 (epoch: 58, step: 150) // Avg time/img: 0.0913 s
# loss: 0.4823 (epoch: 58, step: 200) // Avg time/img: 0.0911 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.6736 (epoch: 58, step: 0) // Avg time/img: 0.0348 s
# VAL loss: 0.8345 (epoch: 58, step: 50) // Avg time/img: 0.0327 s
# VAL loss: 0.826 (epoch: 58, step: 100) // Avg time/img: 0.0327 s
# VAL loss: 0.7517 (epoch: 58, step: 150) // Avg time/img: 0.0328 s
# EPOCH IoU on VAL set:  42.81 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.5804 (epoch: 59, step: 0) // Avg time/img: 0.1203 s
# loss: 0.484 (epoch: 59, step: 50) // Avg time/img: 0.0916 s
# loss: 0.4827 (epoch: 59, step: 100) // Avg time/img: 0.0912 s
# loss: 0.4822 (epoch: 59, step: 150) // Avg time/img: 0.0913 s
# loss: 0.4827 (epoch: 59, step: 200) // Avg time/img: 0.0910 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.6267 (epoch: 59, step: 0) // Avg time/img: 0.0381 s
# VAL loss: 0.8076 (epoch: 59, step: 50) // Avg time/img: 0.0327 s
# VAL loss: 0.7961 (epoch: 59, step: 100) // Avg time/img: 0.0336 s
# VAL loss: 0.7262 (epoch: 59, step: 150) // Avg time/img: 0.0332 s
# EPOCH IoU on VAL set:  43.52 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.5243 (epoch: 60, step: 0) // Avg time/img: 0.0901 s
# loss: 0.4934 (epoch: 60, step: 50) // Avg time/img: 0.0907 s
# loss: 0.4862 (epoch: 60, step: 100) // Avg time/img: 0.0911 s
# loss: 0.4859 (epoch: 60, step: 150) // Avg time/img: 0.0908 s
# loss: 0.4809 (epoch: 60, step: 200) // Avg time/img: 0.0905 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.6707 (epoch: 60, step: 0) // Avg time/img: 0.0363 s
# VAL loss: 0.8011 (epoch: 60, step: 50) // Avg time/img: 0.0324 s
# VAL loss: 0.7929 (epoch: 60, step: 100) // Avg time/img: 0.0328 s
# VAL loss: 0.7252 (epoch: 60, step: 150) // Avg time/img: 0.0335 s
# EPOCH IoU on VAL set:  43.51 %
# ========== DECODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.MainLoss'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 8.781 (epoch: 1, step: 0) // Avg time/img: 0.1726 s
# loss: 7.914 (epoch: 1, step: 50) // Avg time/img: 0.1404 s
# loss: 7.291 (epoch: 1, step: 100) // Avg time/img: 0.1393 s
# loss: 6.73 (epoch: 1, step: 150) // Avg time/img: 0.1388 s
# loss: 6.245 (epoch: 1, step: 200) // Avg time/img: 0.1384 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 3.252 (epoch: 1, step: 0) // Avg time/img: 0.0576 s
# VAL loss: 3.925 (epoch: 1, step: 50) // Avg time/img: 0.0496 s
# VAL loss: 3.767 (epoch: 1, step: 100) // Avg time/img: 0.0496 s
# VAL loss: 3.649 (epoch: 1, step: 150) // Avg time/img: 0.0495 s
# EPOCH IoU on VAL set:  21.05 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 3.874 (epoch: 2, step: 0) // Avg time/img: 0.1560 s
# loss: 3.508 (epoch: 2, step: 50) // Avg time/img: 0.1392 s
# loss: 3.246 (epoch: 2, step: 100) // Avg time/img: 0.1393 s
# loss: 3.047 (epoch: 2, step: 150) // Avg time/img: 0.1385 s
# loss: 2.879 (epoch: 2, step: 200) // Avg time/img: 0.1389 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.955 (epoch: 2, step: 0) // Avg time/img: 0.0527 s
# VAL loss: 2.517 (epoch: 2, step: 50) // Avg time/img: 0.0495 s
# VAL loss: 2.399 (epoch: 2, step: 100) // Avg time/img: 0.0497 s
# VAL loss: 2.244 (epoch: 2, step: 150) // Avg time/img: 0.0492 s
# EPOCH IoU on VAL set:  22.38 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 1.681 (epoch: 3, step: 0) // Avg time/img: 0.1643 s
# loss: 1.97 (epoch: 3, step: 50) // Avg time/img: 0.1438 s
# loss: 1.904 (epoch: 3, step: 100) // Avg time/img: 0.1406 s
# loss: 1.834 (epoch: 3, step: 150) // Avg time/img: 0.1393 s
# loss: 1.782 (epoch: 3, step: 200) // Avg time/img: 0.1393 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 2.109 (epoch: 3, step: 0) // Avg time/img: 0.0528 s
# VAL loss: 2.413 (epoch: 3, step: 50) // Avg time/img: 0.0498 s
# VAL loss: 2.364 (epoch: 3, step: 100) // Avg time/img: 0.0493 s
# VAL loss: 2.128 (epoch: 3, step: 150) // Avg time/img: 0.0491 s
# EPOCH IoU on VAL set:  20.13 %
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 1.199 (epoch: 4, step: 0) // Avg time/img: 0.1474 s
# loss: 1.528 (epoch: 4, step: 50) // Avg time/img: 0.1408 s
# loss: 1.444 (epoch: 4, step: 100) // Avg time/img: 0.1389 s
# loss: 1.416 (epoch: 4, step: 150) // Avg time/img: 0.1400 s
# loss: 1.393 (epoch: 4, step: 200) // Avg time/img: 0.1393 s
# ----- VALIDATING - EPOCH 4 -----
# ...
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.3569 (epoch: 39, step: 0) // Avg time/img: 0.1739 s
# loss: 0.4482 (epoch: 39, step: 50) // Avg time/img: 0.1400 s
# loss: 0.4327 (epoch: 39, step: 100) // Avg time/img: 0.1388 s
# loss: 0.4376 (epoch: 39, step: 150) // Avg time/img: 0.1389 s
# loss: 0.4321 (epoch: 39, step: 200) // Avg time/img: 0.1384 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.5855 (epoch: 39, step: 0) // Avg time/img: 0.0534 s
# VAL loss: 1.175 (epoch: 39, step: 50) // Avg time/img: 0.0490 s
# VAL loss: 1.175 (epoch: 39, step: 100) // Avg time/img: 0.0502 s
# VAL loss: 1.018 (epoch: 39, step: 150) // Avg time/img: 0.0498 s
# EPOCH IoU on VAL set:  46.10 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_best.pth (epoch: 39)
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.3295 (epoch: 40, step: 0) // Avg time/img: 0.1623 s
# loss: 0.4068 (epoch: 40, step: 50) // Avg time/img: 0.1418 s
# loss: 0.4066 (epoch: 40, step: 100) // Avg time/img: 0.1393 s
# loss: 0.4184 (epoch: 40, step: 150) // Avg time/img: 0.1394 s
# loss: 0.4167 (epoch: 40, step: 200) // Avg time/img: 0.1388 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.7013 (epoch: 40, step: 0) // Avg time/img: 0.0524 s
# VAL loss: 1.14 (epoch: 40, step: 50) // Avg time/img: 0.0483 s
# VAL loss: 1.193 (epoch: 40, step: 100) // Avg time/img: 0.0498 s
# VAL loss: 1.056 (epoch: 40, step: 150) // Avg time/img: 0.0498 s
# EPOCH IoU on VAL set:  45.93 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.4174 (epoch: 41, step: 0) // Avg time/img: 0.1453 s
# loss: 0.409 (epoch: 41, step: 50) // Avg time/img: 0.1416 s
# loss: 0.4104 (epoch: 41, step: 100) // Avg time/img: 0.1391 s
# loss: 0.4143 (epoch: 41, step: 150) // Avg time/img: 0.1392 s
# loss: 0.4182 (epoch: 41, step: 200) // Avg time/img: 0.1387 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.637 (epoch: 41, step: 0) // Avg time/img: 0.0747 s
# VAL loss: 1.09 (epoch: 41, step: 50) // Avg time/img: 0.0493 s
# VAL loss: 1.095 (epoch: 41, step: 100) // Avg time/img: 0.0487 s
# VAL loss: 0.9688 (epoch: 41, step: 150) // Avg time/img: 0.0494 s
# EPOCH IoU on VAL set:  47.34 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_best.pth (epoch: 41)
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.3456 (epoch: 42, step: 0) // Avg time/img: 0.1576 s
# loss: 0.3983 (epoch: 42, step: 50) // Avg time/img: 0.1388 s
# loss: 0.4145 (epoch: 42, step: 100) // Avg time/img: 0.1389 s
# loss: 0.4109 (epoch: 42, step: 150) // Avg time/img: 0.1381 s
# loss: 0.4219 (epoch: 42, step: 200) // Avg time/img: 0.1381 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.6623 (epoch: 42, step: 0) // Avg time/img: 0.0523 s
# VAL loss: 1.134 (epoch: 42, step: 50) // Avg time/img: 0.0488 s
# VAL loss: 1.156 (epoch: 42, step: 100) // Avg time/img: 0.0494 s
# VAL loss: 1.011 (epoch: 42, step: 150) // Avg time/img: 0.0495 s
# EPOCH IoU on VAL set:  46.09 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.4386 (epoch: 43, step: 0) // Avg time/img: 0.1641 s
# loss: 0.3885 (epoch: 43, step: 50) // Avg time/img: 0.1421 s
# loss: 0.4074 (epoch: 43, step: 100) // Avg time/img: 0.1396 s
# loss: 0.415 (epoch: 43, step: 150) // Avg time/img: 0.1392 s
# loss: 0.4114 (epoch: 43, step: 200) // Avg time/img: 0.1385 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.6704 (epoch: 43, step: 0) // Avg time/img: 0.0542 s
# VAL loss: 1.141 (epoch: 43, step: 50) // Avg time/img: 0.0490 s
# VAL loss: 1.13 (epoch: 43, step: 100) // Avg time/img: 0.0497 s
# VAL loss: 0.9896 (epoch: 43, step: 150) // Avg time/img: 0.0492 s
# EPOCH IoU on VAL set:  45.58 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.421 (epoch: 44, step: 0) // Avg time/img: 0.1496 s
# loss: 0.412 (epoch: 44, step: 50) // Avg time/img: 0.1441 s
# loss: 0.4126 (epoch: 44, step: 100) // Avg time/img: 0.1406 s
# loss: 0.4059 (epoch: 44, step: 150) // Avg time/img: 0.1402 s
# loss: 0.4107 (epoch: 44, step: 200) // Avg time/img: 0.1394 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.7326 (epoch: 44, step: 0) // Avg time/img: 0.0519 s
# VAL loss: 1.16 (epoch: 44, step: 50) // Avg time/img: 0.0493 s
# VAL loss: 1.179 (epoch: 44, step: 100) // Avg time/img: 0.0485 s
# VAL loss: 1.038 (epoch: 44, step: 150) // Avg time/img: 0.0488 s
# EPOCH IoU on VAL set:  46.15 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.4147 (epoch: 45, step: 0) // Avg time/img: 0.1362 s
# loss: 0.4086 (epoch: 45, step: 50) // Avg time/img: 0.1416 s
# loss: 0.4115 (epoch: 45, step: 100) // Avg time/img: 0.1404 s
# loss: 0.4067 (epoch: 45, step: 150) // Avg time/img: 0.1392 s
# loss: 0.4047 (epoch: 45, step: 200) // Avg time/img: 0.1391 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.8507 (epoch: 45, step: 0) // Avg time/img: 0.0491 s
# VAL loss: 1.362 (epoch: 45, step: 50) // Avg time/img: 0.0502 s
# VAL loss: 1.375 (epoch: 45, step: 100) // Avg time/img: 0.0494 s
# VAL loss: 1.185 (epoch: 45, step: 150) // Avg time/img: 0.0497 s
# EPOCH IoU on VAL set:  44.05 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.7294 (epoch: 46, step: 0) // Avg time/img: 0.1435 s
# loss: 0.3992 (epoch: 46, step: 50) // Avg time/img: 0.1389 s
# loss: 0.4027 (epoch: 46, step: 100) // Avg time/img: 0.1402 s
# loss: 0.4047 (epoch: 46, step: 150) // Avg time/img: 0.1389 s
# loss: 0.4036 (epoch: 46, step: 200) // Avg time/img: 0.1390 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.6231 (epoch: 46, step: 0) // Avg time/img: 0.0534 s
# VAL loss: 1.164 (epoch: 46, step: 50) // Avg time/img: 0.0501 s
# VAL loss: 1.182 (epoch: 46, step: 100) // Avg time/img: 0.0496 s
# VAL loss: 1.041 (epoch: 46, step: 150) // Avg time/img: 0.0496 s
# EPOCH IoU on VAL set:  46.36 %
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.2993 (epoch: 47, step: 0) // Avg time/img: 0.1415 s
# loss: 0.3865 (epoch: 47, step: 50) // Avg time/img: 0.1389 s
# loss: 0.3942 (epoch: 47, step: 100) // Avg time/img: 0.1403 s
# loss: 0.3941 (epoch: 47, step: 150) // Avg time/img: 0.1392 s
# loss: 0.3944 (epoch: 47, step: 200) // Avg time/img: 0.1392 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.578 (epoch: 47, step: 0) // Avg time/img: 0.0510 s
# VAL loss: 1.141 (epoch: 47, step: 50) // Avg time/img: 0.0504 s
# VAL loss: 1.174 (epoch: 47, step: 100) // Avg time/img: 0.0494 s
# VAL loss: 1.032 (epoch: 47, step: 150) // Avg time/img: 0.0491 s
# EPOCH IoU on VAL set:  46.49 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.6011 (epoch: 48, step: 0) // Avg time/img: 0.1614 s
# loss: 0.382 (epoch: 48, step: 50) // Avg time/img: 0.1393 s
# loss: 0.3753 (epoch: 48, step: 100) // Avg time/img: 0.1405 s
# loss: 0.3851 (epoch: 48, step: 150) // Avg time/img: 0.1395 s
# loss: 0.3864 (epoch: 48, step: 200) // Avg time/img: 0.1393 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.6384 (epoch: 48, step: 0) // Avg time/img: 0.0484 s
# VAL loss: 1.078 (epoch: 48, step: 50) // Avg time/img: 0.0501 s
# VAL loss: 1.062 (epoch: 48, step: 100) // Avg time/img: 0.0493 s
# VAL loss: 0.9369 (epoch: 48, step: 150) // Avg time/img: 0.0490 s
# EPOCH IoU on VAL set:  47.45 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_best.pth (epoch: 48)
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.34 (epoch: 49, step: 0) // Avg time/img: 0.1572 s
# loss: 0.4006 (epoch: 49, step: 50) // Avg time/img: 0.1391 s
# loss: 0.3857 (epoch: 49, step: 100) // Avg time/img: 0.1395 s
# loss: 0.3806 (epoch: 49, step: 150) // Avg time/img: 0.1394 s
# loss: 0.3793 (epoch: 49, step: 200) // Avg time/img: 0.1393 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.6972 (epoch: 49, step: 0) // Avg time/img: 0.0556 s
# VAL loss: 1.076 (epoch: 49, step: 50) // Avg time/img: 0.0491 s
# VAL loss: 1.1 (epoch: 49, step: 100) // Avg time/img: 0.0486 s
# VAL loss: 0.962 (epoch: 49, step: 150) // Avg time/img: 0.0485 s
# EPOCH IoU on VAL set:  47.90 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_best.pth (epoch: 49)
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.5462 (epoch: 50, step: 0) // Avg time/img: 0.1699 s
# loss: 0.3785 (epoch: 50, step: 50) // Avg time/img: 0.1393 s
# loss: 0.3792 (epoch: 50, step: 100) // Avg time/img: 0.1392 s
# loss: 0.3839 (epoch: 50, step: 150) // Avg time/img: 0.1391 s
# loss: 0.3859 (epoch: 50, step: 200) // Avg time/img: 0.1390 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.6005 (epoch: 50, step: 0) // Avg time/img: 0.0540 s
# VAL loss: 1.116 (epoch: 50, step: 50) // Avg time/img: 0.0493 s
# VAL loss: 1.109 (epoch: 50, step: 100) // Avg time/img: 0.0492 s
# VAL loss: 0.9756 (epoch: 50, step: 150) // Avg time/img: 0.0491 s
# EPOCH IoU on VAL set:  46.79 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.3773 (epoch: 51, step: 0) // Avg time/img: 0.1789 s
# loss: 0.3725 (epoch: 51, step: 50) // Avg time/img: 0.1401 s
# loss: 0.3724 (epoch: 51, step: 100) // Avg time/img: 0.1393 s
# loss: 0.3755 (epoch: 51, step: 150) // Avg time/img: 0.1396 s
# loss: 0.3767 (epoch: 51, step: 200) // Avg time/img: 0.1390 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.7494 (epoch: 51, step: 0) // Avg time/img: 0.0577 s
# VAL loss: 1.194 (epoch: 51, step: 50) // Avg time/img: 0.0491 s
# VAL loss: 1.228 (epoch: 51, step: 100) // Avg time/img: 0.0496 s
# VAL loss: 1.081 (epoch: 51, step: 150) // Avg time/img: 0.0493 s
# EPOCH IoU on VAL set:  46.01 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.3775 (epoch: 52, step: 0) // Avg time/img: 0.1725 s
# loss: 0.3681 (epoch: 52, step: 50) // Avg time/img: 0.1400 s
# loss: 0.368 (epoch: 52, step: 100) // Avg time/img: 0.1384 s
# loss: 0.3666 (epoch: 52, step: 150) // Avg time/img: 0.1395 s
# loss: 0.3668 (epoch: 52, step: 200) // Avg time/img: 0.1389 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.731 (epoch: 52, step: 0) // Avg time/img: 0.0523 s
# VAL loss: 1.077 (epoch: 52, step: 50) // Avg time/img: 0.0493 s
# VAL loss: 1.069 (epoch: 52, step: 100) // Avg time/img: 0.0493 s
# VAL loss: 0.9384 (epoch: 52, step: 150) // Avg time/img: 0.0491 s
# EPOCH IoU on VAL set:  47.31 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.4175 (epoch: 53, step: 0) // Avg time/img: 0.1440 s
# loss: 0.3765 (epoch: 53, step: 50) // Avg time/img: 0.1418 s
# loss: 0.3723 (epoch: 53, step: 100) // Avg time/img: 0.1394 s
# loss: 0.3674 (epoch: 53, step: 150) // Avg time/img: 0.1393 s
# loss: 0.369 (epoch: 53, step: 200) // Avg time/img: 0.1396 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.5844 (epoch: 53, step: 0) // Avg time/img: 0.0534 s
# VAL loss: 1.143 (epoch: 53, step: 50) // Avg time/img: 0.0487 s
# VAL loss: 1.135 (epoch: 53, step: 100) // Avg time/img: 0.0494 s
# VAL loss: 0.997 (epoch: 53, step: 150) // Avg time/img: 0.0491 s
# EPOCH IoU on VAL set:  47.14 %
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.3823 (epoch: 54, step: 0) // Avg time/img: 0.1437 s
# loss: 0.381 (epoch: 54, step: 50) // Avg time/img: 0.1417 s
# loss: 0.3809 (epoch: 54, step: 100) // Avg time/img: 0.1396 s
# loss: 0.3755 (epoch: 54, step: 150) // Avg time/img: 0.1395 s
# loss: 0.3716 (epoch: 54, step: 200) // Avg time/img: 0.1396 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.5964 (epoch: 54, step: 0) // Avg time/img: 0.0514 s
# VAL loss: 1.086 (epoch: 54, step: 50) // Avg time/img: 0.0488 s
# VAL loss: 1.079 (epoch: 54, step: 100) // Avg time/img: 0.0493 s
# VAL loss: 0.9494 (epoch: 54, step: 150) // Avg time/img: 0.0490 s
# EPOCH IoU on VAL set:  47.31 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.6926 (epoch: 55, step: 0) // Avg time/img: 0.1577 s
# loss: 0.3668 (epoch: 55, step: 50) // Avg time/img: 0.1419 s
# loss: 0.3686 (epoch: 55, step: 100) // Avg time/img: 0.1394 s
# loss: 0.3703 (epoch: 55, step: 150) // Avg time/img: 0.1394 s
# loss: 0.3667 (epoch: 55, step: 200) // Avg time/img: 0.1392 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.613 (epoch: 55, step: 0) // Avg time/img: 0.0526 s
# VAL loss: 1.141 (epoch: 55, step: 50) // Avg time/img: 0.0490 s
# VAL loss: 1.116 (epoch: 55, step: 100) // Avg time/img: 0.0492 s
# VAL loss: 0.9733 (epoch: 55, step: 150) // Avg time/img: 0.0489 s
# EPOCH IoU on VAL set:  46.74 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.3005 (epoch: 56, step: 0) // Avg time/img: 0.1443 s
# loss: 0.3707 (epoch: 56, step: 50) // Avg time/img: 0.1416 s
# loss: 0.3651 (epoch: 56, step: 100) // Avg time/img: 0.1392 s
# loss: 0.3641 (epoch: 56, step: 150) // Avg time/img: 0.1392 s
# loss: 0.3643 (epoch: 56, step: 200) // Avg time/img: 0.1392 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.5998 (epoch: 56, step: 0) // Avg time/img: 0.0542 s
# VAL loss: 1.086 (epoch: 56, step: 50) // Avg time/img: 0.0493 s
# VAL loss: 1.054 (epoch: 56, step: 100) // Avg time/img: 0.0495 s
# VAL loss: 0.9216 (epoch: 56, step: 150) // Avg time/img: 0.0491 s
# EPOCH IoU on VAL set:  48.06 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/alpha-t-test/8-6/model_best.pth (epoch: 56)
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.4051 (epoch: 57, step: 0) // Avg time/img: 0.1538 s
# loss: 0.3658 (epoch: 57, step: 50) // Avg time/img: 0.1399 s
# loss: 0.3622 (epoch: 57, step: 100) // Avg time/img: 0.1395 s
# loss: 0.3611 (epoch: 57, step: 150) // Avg time/img: 0.1384 s
# loss: 0.3592 (epoch: 57, step: 200) // Avg time/img: 0.1391 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.6104 (epoch: 57, step: 0) // Avg time/img: 0.0690 s
# VAL loss: 1.16 (epoch: 57, step: 50) // Avg time/img: 0.0494 s
# VAL loss: 1.141 (epoch: 57, step: 100) // Avg time/img: 0.0488 s
# VAL loss: 0.9923 (epoch: 57, step: 150) // Avg time/img: 0.0492 s
# EPOCH IoU on VAL set:  47.39 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.3292 (epoch: 58, step: 0) // Avg time/img: 0.1469 s
# loss: 0.3579 (epoch: 58, step: 50) // Avg time/img: 0.1393 s
# loss: 0.3573 (epoch: 58, step: 100) // Avg time/img: 0.1395 s
# loss: 0.3569 (epoch: 58, step: 150) // Avg time/img: 0.1386 s
# loss: 0.3571 (epoch: 58, step: 200) // Avg time/img: 0.1393 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.5812 (epoch: 58, step: 0) // Avg time/img: 0.0549 s
# VAL loss: 1.109 (epoch: 58, step: 50) // Avg time/img: 0.0500 s
# VAL loss: 1.108 (epoch: 58, step: 100) // Avg time/img: 0.0494 s
# VAL loss: 0.9667 (epoch: 58, step: 150) // Avg time/img: 0.0493 s
# EPOCH IoU on VAL set:  47.54 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.3609 (epoch: 59, step: 0) // Avg time/img: 0.1441 s
# loss: 0.3485 (epoch: 59, step: 50) // Avg time/img: 0.1398 s
# loss: 0.3569 (epoch: 59, step: 100) // Avg time/img: 0.1398 s
# loss: 0.3539 (epoch: 59, step: 150) // Avg time/img: 0.1388 s
# loss: 0.3549 (epoch: 59, step: 200) // Avg time/img: 0.1394 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.5792 (epoch: 59, step: 0) // Avg time/img: 0.0573 s
# VAL loss: 1.115 (epoch: 59, step: 50) // Avg time/img: 0.0504 s
# VAL loss: 1.103 (epoch: 59, step: 100) // Avg time/img: 0.0497 s
# VAL loss: 0.9618 (epoch: 59, step: 150) // Avg time/img: 0.0496 s
# EPOCH IoU on VAL set:  47.67 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.2983 (epoch: 60, step: 0) // Avg time/img: 0.1449 s
# loss: 0.3495 (epoch: 60, step: 50) // Avg time/img: 0.1395 s
# loss: 0.358 (epoch: 60, step: 100) // Avg time/img: 0.1397 s
# loss: 0.3595 (epoch: 60, step: 150) // Avg time/img: 0.1390 s
# loss: 0.3551 (epoch: 60, step: 200) // Avg time/img: 0.1395 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.5743 (epoch: 60, step: 0) // Avg time/img: 0.0645 s
# VAL loss: 1.102 (epoch: 60, step: 50) // Avg time/img: 0.0496 s
# VAL loss: 1.098 (epoch: 60, step: 100) // Avg time/img: 0.0492 s
# VAL loss: 0.9626 (epoch: 60, step: 150) // Avg time/img: 0.0494 s
# EPOCH IoU on VAL set:  47.82 %
# ========== TRAINING FINISHED ===========

# %% [markdown]
# # Baseline
#
# * ERFNet 기본 네트워크

# %% [markdown]
# ## 1. 사전 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load cityscapes dataset

# %%
import numpy as np
import os

from PIL import Image

from torch.utils.data import Dataset

EXTENSIONS = ['.jpg', '.png']

def load_image(file):
    return Image.open(file)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS)

def is_label(filename):
    return filename.endswith("_labelTrainIds.png")

def image_path(root, basename, extension):
    return os.path.join(root, f'{basename}{extension}')

def image_path_city(root, name):
    return os.path.join(root, f'{name}')

def image_basename(filename):
    return os.path.basename(os.path.splitext(filename)[0])

class VOC12(Dataset):

    def __init__(self, root, input_transform=None, target_transform=None):
        self.images_root = os.path.join(root, 'images')
        self.labels_root = os.path.join(root, 'labels')

        self.filenames = [image_basename(f)
            for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenames.sort()

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        filename = self.filenames[index]

        with open(image_path(self.images_root, filename, '.jpg'), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path(self.labels_root, filename, '.png'), 'rb') as f:
            label = load_image(f).convert('P')

        if self.input_transform is not None:
            image = self.input_transform(image)
        if self.target_transform is not None:
            label = self.target_transform(label)

        return image, label

    def __len__(self):
        return len(self.filenames)




class cityscapes(Dataset):

    def __init__(self, root, co_transform=None, subset='train'):
        self.images_root = os.path.join(root, 'leftImg8bit/')
        self.labels_root = os.path.join(root, 'gtFine/')
        
        self.images_root += subset
        self.labels_root += subset

        print (self.images_root)
        #self.filenames = [image_basename(f) for f in os.listdir(self.images_root) if is_image(f)]
        self.filenames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.images_root)) for f in fn if is_image(f)]
        self.filenames.sort()

        #[os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(".")) for f in fn]
        #self.filenamesGt = [image_basename(f) for f in os.listdir(self.labels_root) if is_image(f)]
        self.filenamesGt = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(self.labels_root)) for f in fn if is_label(f)]
        self.filenamesGt.sort()

        self.co_transform = co_transform # ADDED THIS


    def __getitem__(self, index):
        filename = self.filenames[index]
        filenameGt = self.filenamesGt[index]

        with open(image_path_city(self.images_root, filename), 'rb') as f:
            image = load_image(f).convert('RGB')
        with open(image_path_city(self.labels_root, filenameGt), 'rb') as f:
            label = load_image(f).convert('P')

        if self.co_transform is not None:
            image, label = self.co_transform(image, label)

        return image, label

    def __len__(self):
        return len(self.filenames)

# %% [markdown]
# ## ERFNet model definition

# %%
# ERFNet full model definition for Pytorch
# Sept 2017
# Eduardo Romera
#######################

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

class DownsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()

        self.conv = nn.Conv2d(ninput, noutput-ninput, (3, 3), stride=2, padding=1, bias=True)
        self.pool = nn.MaxPool2d(2, stride=2)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = torch.cat([self.conv(input), self.pool(input)], 1)
        output = self.bn(output)
        return F.relu(output)
    

class non_bottleneck_1d (nn.Module):
    def __init__(self, chann, dropprob, dilated):        
        super().__init__()

        self.conv3x1_1 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1,0), bias=True)

        self.conv1x3_1 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1), bias=True)

        self.bn1 = nn.BatchNorm2d(chann, eps=1e-03)

        self.conv3x1_2 = nn.Conv2d(chann, chann, (3, 1), stride=1, padding=(1*dilated,0), bias=True, dilation = (dilated,1))

        self.conv1x3_2 = nn.Conv2d(chann, chann, (1,3), stride=1, padding=(0,1*dilated), bias=True, dilation = (1, dilated))

        self.bn2 = nn.BatchNorm2d(chann, eps=1e-03)

        self.dropout = nn.Dropout2d(dropprob)
        

    def forward(self, input):

        output = self.conv3x1_1(input)
        output = F.relu(output)
        output = self.conv1x3_1(output)
        output = self.bn1(output)
        output = F.relu(output)

        output = self.conv3x1_2(output)
        output = F.relu(output)
        output = self.conv1x3_2(output)
        output = self.bn2(output)

        if (self.dropout.p != 0):
            output = self.dropout(output)
        
        return F.relu(output+input)    #+input = identity (residual connection)


class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.initial_block = DownsamplerBlock(3,16)

        self.layers = nn.ModuleList()

        self.layers.append(DownsamplerBlock(16,64))

        for x in range(0, 1):    #5 times -> 1 times
           self.layers.append(non_bottleneck_1d(64, 0.03, 1)) 

        self.layers.append(DownsamplerBlock(64,128))

        for x in range(0, 1):    #2 times -> 1 times
            self.layers.append(non_bottleneck_1d(128, 0.3, 2))
            self.layers.append(non_bottleneck_1d(128, 0.3, 4))
            # self.layers.append(non_bottleneck_1d(128, 0.3, 8))
            # self.layers.append(non_bottleneck_1d(128, 0.3, 16))

        #Only in encoder mode:
        self.output_conv = nn.Conv2d(128, num_classes, 1, stride=1, padding=0, bias=True)

    def forward(self, input, predict=False):
        output = self.initial_block(input)

        for layer in self.layers:
            output = layer(output)

        if predict:
            output = self.output_conv(output)

        return output


class UpsamplerBlock (nn.Module):
    def __init__(self, ninput, noutput):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ninput, noutput, 3, stride=2, padding=1, output_padding=1, bias=True)
        self.bn = nn.BatchNorm2d(noutput, eps=1e-3)

    def forward(self, input):
        output = self.conv(input)
        output = self.bn(output)
        return F.relu(output)

class Decoder (nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(UpsamplerBlock(128,64))
        self.layers.append(non_bottleneck_1d(64, 0, 1))
        # self.layers.append(non_bottleneck_1d(64, 0, 1))

        self.layers.append(UpsamplerBlock(64,16))
        self.layers.append(non_bottleneck_1d(16, 0, 1))
        # self.layers.append(non_bottleneck_1d(16, 0, 1))

        self.output_conv = nn.ConvTranspose2d( 16, num_classes, 2, stride=2, padding=0, output_padding=0, bias=True)

    def forward(self, input):
        output = input

        for layer in self.layers:
            output = layer(output)

        output = self.output_conv(output)

        return output

#ERFNet
class Net(nn.Module):
    def __init__(self, num_classes, encoder=None):  #use encoder to pass pretrained encoder
        super().__init__()

        if (encoder == None):
            self.encoder = Encoder(num_classes)
        else:
            self.encoder = encoder
        self.decoder = Decoder(num_classes)

    def forward(self, input, only_encode=False):
        if only_encode:
            return self.encoder.forward(input, predict=True)
        else:
            output = self.encoder(input)    #predict=False by default
            return self.decoder.forward(output)

# %% [markdown]
# ## Calculate IoU on each epoch during training

# %%
import torch

class iouEval:

    def __init__(self, nClasses, ignoreIndex=19):
        self.nClasses = nClasses
        self.ignoreIndex = ignoreIndex if nClasses>ignoreIndex else -1 #if ignoreIndex is larger than nClasses, consider no ignoreIndex
        self.reset()

    def reset (self):
        classes = self.nClasses if self.ignoreIndex==-1 else self.nClasses-1
        self.tp = torch.zeros(classes).double()
        self.fp = torch.zeros(classes).double()
        self.fn = torch.zeros(classes).double()        

    def addBatch(self, x, y):   #x=preds, y=targets
        #sizes should be "batch_size x nClasses x H x W"

        if (x.is_cuda or y.is_cuda):
            x = x.cuda()
            y = y.cuda()

        #if size is "batch_size x 1 x H x W" scatter to onehot
        if (x.size(1) == 1):
            x_onehot = torch.zeros(x.size(0), self.nClasses, x.size(2), x.size(3))  
            if x.is_cuda:
                x_onehot = x_onehot.cuda()
            x_onehot.scatter_(1, x, 1).float()
        else:
            x_onehot = x.float()

        if (y.size(1) == 1):
            y_onehot = torch.zeros(y.size(0), self.nClasses, y.size(2), y.size(3))
            if y.is_cuda:
                y_onehot = y_onehot.cuda()
            y_onehot.scatter_(1, y, 1).float()
        else:
            y_onehot = y.float()

        if (self.ignoreIndex != -1): 
            ignores = y_onehot[:,self.ignoreIndex].unsqueeze(1)
            x_onehot = x_onehot[:, :self.ignoreIndex]
            y_onehot = y_onehot[:, :self.ignoreIndex]
        else:
            ignores=0

        tpmult = x_onehot * y_onehot    #times prediction and gt coincide is 1
        tp = torch.sum(torch.sum(torch.sum(tpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fpmult = x_onehot * (1-y_onehot-ignores) #times prediction says its that class and gt says its not (subtracting cases when its ignore label!)
        fp = torch.sum(torch.sum(torch.sum(fpmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze()
        fnmult = (1-x_onehot) * (y_onehot) #times prediction says its not that class and gt says it is
        fn = torch.sum(torch.sum(torch.sum(fnmult, dim=0, keepdim=True), dim=2, keepdim=True), dim=3, keepdim=True).squeeze() 

        self.tp += tp.double().cpu()
        self.fp += fp.double().cpu()
        self.fn += fn.double().cpu()

    def getIoU(self):
        num = self.tp
        den = self.tp + self.fp + self.fn + 1e-15
        iou = num / den
        return torch.mean(iou), iou     #returns "iou mean", "iou per class"

# Class for colors
class colors:
    RED       = '\033[31;1m'
    GREEN     = '\033[32;1m'
    YELLOW    = '\033[33;1m'
    BLUE      = '\033[34;1m'
    MAGENTA   = '\033[35;1m'
    CYAN      = '\033[36;1m'
    BOLD      = '\033[1m'
    UNDERLINE = '\033[4m'
    ENDC      = '\033[0m'

# Colored value output if colorized flag is activated.
def getColorEntry(val):
    if not isinstance(val, float):
        return colors.ENDC
    if (val < .20):
        return colors.RED
    elif (val < .40):
        return colors.YELLOW
    elif (val < .60):
        return colors.BLUE
    elif (val < .80):
        return colors.CYAN
    else:
        return colors.GREEN

# %% [markdown]
# ## Transform

# %%
import numpy as np
import torch

from PIL import Image

def colormap_cityscapes(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)
    cmap[0,:] = np.array([128, 64,128])
    cmap[1,:] = np.array([244, 35,232])
    cmap[2,:] = np.array([ 70, 70, 70])
    cmap[3,:] = np.array([ 102,102,156])
    cmap[4,:] = np.array([ 190,153,153])
    cmap[5,:] = np.array([ 153,153,153])

    cmap[6,:] = np.array([ 250,170, 30])
    cmap[7,:] = np.array([ 220,220,  0])
    cmap[8,:] = np.array([ 107,142, 35])
    cmap[9,:] = np.array([ 152,251,152])
    cmap[10,:] = np.array([ 70,130,180])

    cmap[11,:] = np.array([ 220, 20, 60])
    cmap[12,:] = np.array([ 255,  0,  0])
    cmap[13,:] = np.array([ 0,  0,142])
    cmap[14,:] = np.array([  0,  0, 70])
    cmap[15,:] = np.array([  0, 60,100])

    cmap[16,:] = np.array([  0, 80,100])
    cmap[17,:] = np.array([  0,  0,230])
    cmap[18,:] = np.array([ 119, 11, 32])
    cmap[19,:] = np.array([ 0,  0,  0])
    
    return cmap


def colormap(n):
    cmap=np.zeros([n, 3]).astype(np.uint8)

    for i in np.arange(n):
        r, g, b = np.zeros(3)

        for j in np.arange(8):
            r = r + (1<<(7-j))*((i&(1<<(3*j))) >> (3*j))
            g = g + (1<<(7-j))*((i&(1<<(3*j+1))) >> (3*j+1))
            b = b + (1<<(7-j))*((i&(1<<(3*j+2))) >> (3*j+2))

        cmap[i,:] = np.array([r, g, b])

    return cmap

class Relabel:

    def __init__(self, olabel, nlabel):
        self.olabel = olabel
        self.nlabel = nlabel

    def __call__(self, tensor):
        assert (isinstance(tensor, torch.LongTensor) or isinstance(tensor, torch.ByteTensor)) , 'tensor needs to be LongTensor'
        tensor[tensor == self.olabel] = self.nlabel
        return tensor


class ToLabel:

    def __call__(self, image):
        return torch.from_numpy(np.array(image)).long().unsqueeze(0)


class Colorize:

    def __init__(self, n=22):
        #self.cmap = colormap(256)
        self.cmap = colormap_cityscapes(256)
        self.cmap[n] = self.cmap[-1]
        self.cmap = torch.from_numpy(self.cmap[:n])

    def __call__(self, gray_image):
        size = gray_image.size()
        #print(size)
        color_image = torch.ByteTensor(3, size[1], size[2]).fill_(0)
        #color_image = torch.ByteTensor(3, size[0], size[1]).fill_(0)

        #for label in range(1, len(self.cmap)):
        for label in range(0, len(self.cmap)):
            mask = gray_image[0] == label
            #mask = gray_image == label

            color_image[0][mask] = self.cmap[label][0]
            color_image[1][mask] = self.cmap[label][1]
            color_image[2][mask] = self.cmap[label][2]

        return color_image

# %% [markdown]
# ## Main

# %%
import os
import random
import time
import numpy as np
import torch
import math
import warnings

from PIL import Image, ImageOps
from argparse import ArgumentParser

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, Normalize, Resize, Pad
from torchvision.transforms import ToTensor, ToPILImage

import importlib

from shutil import copyfile


warnings.filterwarnings(action='ignore')

NUM_CHANNELS = 3
NUM_CLASSES = 20 #pascal=22, cityscapes=20

color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=512):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # do something to both images
        input =  Resize(self.height, Image.BILINEAR)(input)
        target = Resize(self.height, Image.NEAREST)(target)

        if(self.augment):
            # Random hflip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding
            transX = random.randint(-2, 2) 
            transY = random.randint(-2, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=255) #pad label filling with 255
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        if (self.enc):
            target = Resize(int(self.height/8), Image.NEAREST)(target)
        target = ToLabel()(target)
        target = Relabel(255, 19)(target)

        return input, target


class CrossEntropyLoss2d(torch.nn.Module):

    def __init__(self, weight=None):
        super().__init__()

        self.loss = torch.nn.NLLLoss2d(weight)

    def forward(self, outputs, targets):
        return self.loss(torch.nn.functional.log_softmax(outputs, dim=1), targets)


def train(args, model, enc=False):
    best_acc = 0

    #TODO: calculate weights by processing dataset histogram (now its being set by hand from the torch values)
    #create a loder to run all images and calculate histogram of labels, then create weight array using class balancing

    weight = torch.ones(NUM_CLASSES)
    if (enc):
        weight[0] = 2.3653597831726	
        weight[1] = 4.4237880706787	
        weight[2] = 2.9691488742828	
        weight[3] = 5.3442072868347	
        weight[4] = 5.2983593940735	
        weight[5] = 5.2275490760803	
        weight[6] = 5.4394111633301	
        weight[7] = 5.3659925460815	
        weight[8] = 3.4170460700989	
        weight[9] = 5.2414722442627	
        weight[10] = 4.7376127243042	
        weight[11] = 5.2286224365234	
        weight[12] = 5.455126285553	
        weight[13] = 4.3019247055054	
        weight[14] = 5.4264230728149	
        weight[15] = 5.4331531524658	
        weight[16] = 5.433765411377	
        weight[17] = 5.4631009101868	
        weight[18] = 5.3947434425354
    else:
        weight[0] = 2.8149201869965	
        weight[1] = 6.9850029945374	
        weight[2] = 3.7890393733978	
        weight[3] = 9.9428062438965	
        weight[4] = 9.7702074050903	
        weight[5] = 9.5110931396484	
        weight[6] = 10.311357498169	
        weight[7] = 10.026463508606	
        weight[8] = 4.6323022842407	
        weight[9] = 9.5608062744141	
        weight[10] = 7.8698215484619	
        weight[11] = 9.5168733596802	
        weight[12] = 10.373730659485	
        weight[13] = 6.6616044044495	
        weight[14] = 10.260489463806	
        weight[15] = 10.287888526917	
        weight[16] = 10.289801597595	
        weight[17] = 10.405355453491	
        weight[18] = 10.138095855713	

    weight[19] = 0

    # assert os.path.exists(args.datadir), "Error: datadir (dataset directory) could not be loaded"

    co_transform = MyCoTransform(enc, augment=True, height=args.height)#1024)
    co_transform_val = MyCoTransform(enc, augment=False, height=args.height)#1024)
    dataset_train = cityscapes(args.datadir, co_transform, 'train')
    dataset_val = cityscapes(args.datadir, co_transform_val, 'val')

    loader = DataLoader(dataset_train, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=False)

    if args.cuda:
        weight = weight.cuda()
    criterion = CrossEntropyLoss2d(weight)
    print(type(criterion))

    savedir = f'{args.savedir}'
    
    if (enc):
        automated_log_path = savedir + "/automated_log_encoder.txt"
        modeltxtpath = savedir + "/model_encoder.txt"
    else:
        automated_log_path = savedir + "/automated_log.txt"
        modeltxtpath = savedir + "/model.txt"    
    
    if (not os.path.exists(automated_log_path)):    #dont add first line if it exists 
        with open(automated_log_path, "a") as myfile:
            myfile.write("Epoch\t\tTrain-loss\t\tTest-loss\t\tTrain-IoU\t\tTest-IoU\t\tlearningRate")

    with open(modeltxtpath, "w") as myfile:
        myfile.write(str(model))


    #TODO: reduce memory in first gpu: https://discuss.pytorch.org/t/multi-gpu-training-memory-usage-in-balance/4163/4        #https://github.com/pytorch/pytorch/issues/1893

    #optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=2e-4)     ## scheduler 1
    optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4)      ## scheduler 2

    start_epoch = 1
    if args.resume:
        #Must load weights, optimizer, epoch and best value. 
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'

        assert os.path.exists(filenameCheckpoint), "Error: resume option was used but checkpoint was not found in folder"
        checkpoint = torch.load(filenameCheckpoint)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        best_acc = checkpoint['best_acc']
        print("=> Loaded checkpoint at epoch {})".format(checkpoint['epoch']))

    #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5) # set up scheduler     ## scheduler 1
    lambda1 = lambda epoch: pow((1-((epoch-1)/args.num_epochs)),0.9)  ## scheduler 2
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)                             ## scheduler 2

    if args.visualize and args.steps_plot > 0:
        board = Dashboard(args.port)

    for epoch in range(start_epoch, args.num_epochs+1):
        print("----- TRAINING - EPOCH", epoch, "-----")

        scheduler.step(epoch)    ## scheduler 2

        epoch_loss = []
        time_train = []
     
        doIouTrain = args.iouTrain   
        doIouVal =  args.iouVal      

        if (doIouTrain):
            iouEvalTrain = iouEval(NUM_CLASSES)

        usedLr = 0
        for param_group in optimizer.param_groups:
            print("LEARNING RATE: ", param_group['lr'])
            usedLr = float(param_group['lr'])

        model.train()
        for step, (images, labels) in enumerate(loader):

            start_time = time.time()
            #print (labels.size())
            #print (np.unique(labels.numpy()))
            #print("labels: ", np.unique(labels[0].numpy()))
            #labels = torch.ones(4, 1, 512, 1024).long()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images)
            targets = Variable(labels)
            outputs = model(inputs, only_encode=enc)

            #print("targets", np.unique(targets[:, 0].cpu().data.numpy()))

            optimizer.zero_grad()
            loss = criterion(outputs, targets[:, 0])
            loss.backward()
            optimizer.step()

            epoch_loss.append(loss.item())
            time_train.append(time.time() - start_time)

            if (doIouTrain):
                #start_time_iou = time.time()
                iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

            #print(outputs.size())
            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                #image[0] = image[0] * .229 + .485
                #image[1] = image[1] * .224 + .456
                #image[2] = image[2] * .225 + .406
                #print("output", np.unique(outputs[0].cpu().max(0)[1].data.numpy()))
                board.image(image, f'input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss) / len(epoch_loss)
                print(f'loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / args.batch_size))

            
        average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)
        
        iouTrain = 0
        if (doIouTrain):
            iouTrain, iou_classes = iouEvalTrain.getIoU()
            iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
            print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  

        #Validate on 500 val images after each epoch of training
        print("----- VALIDATING - EPOCH", epoch, "-----")
        model.eval()
        epoch_loss_val = []
        time_val = []
        
        if (doIouVal):
            iouEvalVal = iouEval(NUM_CLASSES)

        for step, (images, labels) in enumerate(loader_val):
            start_time = time.time()
            if args.cuda:
                images = images.cuda()
                labels = labels.cuda()

            inputs = Variable(images, volatile=True)    #volatile flag makes it free backward or outputs for eval
            targets = Variable(labels, volatile=True)
            outputs = model(inputs, only_encode=enc) 

            loss = criterion(outputs, targets[:, 0])
            epoch_loss_val.append(loss.item())
            time_val.append(time.time() - start_time)


            #Add batch to calculate TP, FP and FN for iou estimation
            if (doIouVal):
                #start_time_iou = time.time()
                iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
                #print ("Time to add confusion matrix: ", time.time() - start_time_iou)

            if args.visualize and args.steps_plot > 0 and step % args.steps_plot == 0:
                start_time_plot = time.time()
                image = inputs[0].cpu().data
                board.image(image, f'VAL input (epoch: {epoch}, step: {step})')
                if isinstance(outputs, list):   #merge gpu tensors
                    board.image(color_transform(outputs[0][0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                else:
                    board.image(color_transform(outputs[0].cpu().max(0)[1].data.unsqueeze(0)),
                    f'VAL output (epoch: {epoch}, step: {step})')
                board.image(color_transform(targets[0].cpu().data),
                    f'VAL target (epoch: {epoch}, step: {step})')
                print ("Time to paint images: ", time.time() - start_time_plot)
            if args.steps_loss > 0 and step % args.steps_loss == 0:
                average = sum(epoch_loss_val) / len(epoch_loss_val)
                print(f'VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                        "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / args.batch_size))
                       

        average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
        #scheduler.step(average_epoch_loss_val, epoch)  ## scheduler 1   # update lr if needed

        iouVal = 0
        if (doIouVal):
            iouVal, iou_classes = iouEvalVal.getIoU()
            iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
            print ("EPOCH IoU on VAL set: ", iouStr, "%") 
           

        # remember best valIoU and save checkpoint
        if iouVal == 0:
            current_acc = -average_epoch_loss_val
        else:
            current_acc = iouVal 
        is_best = current_acc > best_acc
        best_acc = max(current_acc, best_acc)
        if enc:
            filenameCheckpoint = savedir + '/checkpoint_enc.pth.tar'
            filenameBest = savedir + '/model_best_enc.pth.tar'    
        else:
            filenameCheckpoint = savedir + '/checkpoint.pth.tar'
            filenameBest = savedir + '/model_best.pth.tar'
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': str(model),
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filenameCheckpoint, filenameBest)

        #SAVE MODEL AFTER EPOCH
        if (enc):
            filename = f'{savedir}/model_encoder-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_encoder_best.pth'
        else:
            filename = f'{savedir}/model-{epoch:03}.pth'
            filenamebest = f'{savedir}/model_best.pth'
        if args.epochs_save > 0 and step > 0 and step % args.epochs_save == 0:
            torch.save(model.state_dict(), filename)
            print(f'save: {filename} (epoch: {epoch})')
        if (is_best):
            torch.save(model.state_dict(), filenamebest)
            print(f'save: {filenamebest} (epoch: {epoch})')
            if (not enc):
                with open(savedir + "/best.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))   
            else:
                with open(savedir + "/best_encoder.txt", "w") as myfile:
                    myfile.write("Best epoch is %d, with Val-IoU= %.4f" % (epoch, iouVal))           

        #SAVE TO FILE A ROW WITH THE EPOCH RESULT (train loss, val loss, train IoU, val IoU)
        #Epoch		Train-loss		Test-loss	Train-IoU	Test-IoU		learningRate
        with open(automated_log_path, "a") as myfile:
            myfile.write("\n%d\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.4f\t\t%.8f" % (epoch, average_epoch_loss_train, average_epoch_loss_val, iouTrain, iouVal, usedLr ))
    
    return(model)   #return model (convenience for encoder-decoder training)

def save_checkpoint(state, is_best, filenameCheckpoint, filenameBest):
    torch.save(state, filenameCheckpoint)
    if is_best:
        print ("Saving model as best")
        torch.save(state, filenameBest)


def main(args):
    savedir = f'/save/{args.savedir}'

    if not os.path.exists(savedir):
        os.makedirs(savedir)

    with open(savedir + '/opts.txt', "w") as myfile:
        myfile.write(str(args))

    #Load Model
    # assert os.path.exists(args.model + ".py"), "Error: model definition not found"
    # model_file = importlib.import_module(args.model)
    model = Net(NUM_CLASSES)
    # copyfile(args.model + ".py", savedir + '/' + args.model + ".py")
    
    if args.cuda:
        model = torch.nn.DataParallel(model).cuda()
    
    if args.state:
        #if args.state is provided then load this state for training
        #Note: this only loads initialized weights. If you want to resume a training use "--resume" option!!
        """
        try:
            model.load_state_dict(torch.load(args.state))
        except AssertionError:
            model.load_state_dict(torch.load(args.state,
                map_location=lambda storage, loc: storage))
        #When model is saved as DataParallel it adds a model. to each key. To remove:
        #state_dict = {k.partition('model.')[2]: v for k,v in state_dict}
        #https://discuss.pytorch.org/t/prefix-parameter-names-in-saved-model-if-trained-by-multi-gpu/494
        """
        def load_my_state_dict(model, state_dict):  #custom function to load model when not all dict keys are there
            own_state = model.state_dict()
            for name, param in state_dict.items():
                if name not in own_state:
                     continue
                own_state[name].copy_(param)
            return model

        #print(torch.load(args.state))
        model = load_my_state_dict(model, torch.load(args.state))

    """
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            #m.weight.data.normal_(0.0, 0.02)
            n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
            m.weight.data.normal_(0, math.sqrt(2. / n))
        elif classname.find('BatchNorm') != -1:
            #m.weight.data.normal_(1.0, 0.02)
            m.weight.data.fill_(1)
            m.bias.data.fill_(0)
    #TO ACCESS MODEL IN DataParallel: next(model.children())
    #next(model.children()).decoder.apply(weights_init)
    #Reinitialize weights for decoder
    
    next(model.children()).decoder.layers.apply(weights_init)
    next(model.children()).decoder.output_conv.apply(weights_init)
    #print(model.state_dict())
    f = open('weights5.txt', 'w')
    f.write(str(model.state_dict()))
    f.close()
    """

    # train(args, model)
    if (not args.decoder):
        print("========== ENCODER TRAINING ===========")
        model = train(args, model, True) #Train encoder
    #CAREFUL: for some reason, after training encoder alone, the decoder gets weights=0. 
    #We must reinit decoder weights or reload network passing only encoder in order to train decoder
    print("========== DECODER TRAINING ===========")
    if (not args.state):
        if args.pretrainedEncoder:
            print("Loading encoder pretrained in imagenet")
            from erfnet_imagenet import ERFNet as ERFNet_imagenet
            pretrainedEnc = torch.nn.DataParallel(ERFNet_imagenet(1000))
            pretrainedEnc.load_state_dict(torch.load(args.pretrainedEncoder)['state_dict'])
            pretrainedEnc = next(pretrainedEnc.children()).features.encoder
            if (not args.cuda):
                pretrainedEnc = pretrainedEnc.cpu()     #because loaded encoder is probably saved in cuda
        else:
            pretrainedEnc = next(model.children()).encoder
        model = Net(NUM_CLASSES, encoder=pretrainedEnc)  #Add decoder to encoder
        if args.cuda:
            model = torch.nn.DataParallel(model).cuda()
        #When loading encoder reinitialize weights for decoder because they are set to 0 when training dec
    model = train(args, model, False)   #Train decoder
    print("========== TRAINING FINISHED ===========")

if __name__ == '__main__':
    parser = ArgumentParser()
    parser.add_argument('--cuda', action='store_true', default=True)  #NOTE: cpu-only has not been tested so you might have to change code if you deactivate this flag
    parser.add_argument('--model', default="erfnet")
    parser.add_argument('--state')

    parser.add_argument('--port', type=int, default=8097)
    parser.add_argument('--datadir', default='/content/gdrive/MyDrive/Colab Notebooks/cityscapes')
    parser.add_argument('--height', type=int, default=512)
    parser.add_argument('--num-epochs', type=int, default=60)
    parser.add_argument('--num-workers', type=int, default=4)
    parser.add_argument('--batch-size', type=int, default=3)
    parser.add_argument('--steps-loss', type=int, default=50)
    parser.add_argument('--steps-plot', type=int, default=50)
    parser.add_argument('--epochs-save', type=int, default=0)    #You can use this value to save model every X epochs
    parser.add_argument('--savedir', type=str, default='/content/gdrive/MyDrive/Colab Notebooks/erf-student-3')
    parser.add_argument('--decoder', action='store_true')
    parser.add_argument('--pretrainedEncoder') #, default="../trained_models/erfnet_encoder_pretrained.pth.tar")
    parser.add_argument('--visualize', action='store_true', default=False)

    parser.add_argument('--iouTrain', action='store_true', default=False) #recommended: False (takes more time to train otherwise)
    parser.add_argument('--iouVal', action='store_true', default=True)  
    parser.add_argument('--resume', action='store_true')    #Use this flag to load last checkpoint for training  

    main(parser.parse_args(''))
# Out:
# ========== ENCODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.099 (epoch: 1, step: 0) // Avg time/img: 3.9842 s
# loss: 1.469 (epoch: 1, step: 50) // Avg time/img: 0.1039 s
# loss: 1.232 (epoch: 1, step: 100) // Avg time/img: 0.0648 s
# loss: 1.157 (epoch: 1, step: 150) // Avg time/img: 0.0517 s
# loss: 1.116 (epoch: 1, step: 200) // Avg time/img: 0.0450 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.757 (epoch: 1, step: 0) // Avg time/img: 0.0110 s
# VAL loss: 1.471 (epoch: 1, step: 50) // Avg time/img: 0.0099 s
# VAL loss: 1.446 (epoch: 1, step: 100) // Avg time/img: 0.0101 s
# VAL loss: 1.292 (epoch: 1, step: 150) // Avg time/img: 0.0102 s
# EPOCH IoU on VAL set:  17.66 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 1.094 (epoch: 2, step: 0) // Avg time/img: 0.0395 s
# loss: 0.8922 (epoch: 2, step: 50) // Avg time/img: 0.0295 s
# loss: 0.8671 (epoch: 2, step: 100) // Avg time/img: 0.0285 s
# loss: 0.851 (epoch: 2, step: 150) // Avg time/img: 0.0283 s
# loss: 0.8389 (epoch: 2, step: 200) // Avg time/img: 0.0284 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.626 (epoch: 2, step: 0) // Avg time/img: 0.0149 s
# VAL loss: 1.344 (epoch: 2, step: 50) // Avg time/img: 0.0163 s
# VAL loss: 1.312 (epoch: 2, step: 100) // Avg time/img: 0.0159 s
# VAL loss: 1.132 (epoch: 2, step: 150) // Avg time/img: 0.0159 s
# EPOCH IoU on VAL set:  20.42 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.9369 (epoch: 3, step: 0) // Avg time/img: 0.0405 s
# loss: 0.7621 (epoch: 3, step: 50) // Avg time/img: 0.0275 s
# loss: 0.7409 (epoch: 3, step: 100) // Avg time/img: 0.0271 s
# loss: 0.7537 (epoch: 3, step: 150) // Avg time/img: 0.0271 s
# loss: 0.7484 (epoch: 3, step: 200) // Avg time/img: 0.0271 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 1.489 (epoch: 3, step: 0) // Avg time/img: 0.0148 s
# VAL loss: 1.304 (epoch: 3, step: 50) // Avg time/img: 0.0155 s
# VAL loss: 1.261 (epoch: 3, step: 100) // Avg time/img: 0.0159 s
# VAL loss: 1.093 (epoch: 3, step: 150) // Avg time/img: 0.0165 s
# EPOCH IoU on VAL set:  20.94 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 3)
# ----- TRAINING - EPOCH 4 -----
# LEARNING RATE:  0.00047744269081074987
# loss: 0.7184 (epoch: 4, step: 0) // Avg time/img: 0.0418 s
# loss: 0.6573 (epoch: 4, step: 50) // Avg time/img: 0.0281 s
# loss: 0.6769 (epoch: 4, step: 100) // Avg time/img: 0.0277 s
# loss: 0.6868 (epoch: 4, step: 150) // Avg time/img: 0.0275 s
# loss: 0.6736 (epoch: 4, step: 200) // Avg time/img: 0.0274 s
# ----- VALIDATING - EPOCH 4 -----
# VAL loss: 1.67 (epoch: 4, step: 0) // Avg time/img: 0.0137 s
# VAL loss: 1.237 (epoch: 4, step: 50) // Avg time/img: 0.0148 s
# VAL loss: 1.207 (epoch: 4, step: 100) // Avg time/img: 0.0149 s
# VAL loss: 1.048 (epoch: 4, step: 150) // Avg time/img: 0.0148 s
# EPOCH IoU on VAL set:  22.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 4)
# ----- TRAINING - EPOCH 5 -----
# LEARNING RATE:  0.00046989746629436113
# loss: 1.235 (epoch: 5, step: 0) // Avg time/img: 0.0394 s
# loss: 0.6172 (epoch: 5, step: 50) // Avg time/img: 0.0276 s
# loss: 0.625 (epoch: 5, step: 100) // Avg time/img: 0.0273 s
# loss: 0.624 (epoch: 5, step: 150) // Avg time/img: 0.0271 s
# loss: 0.6178 (epoch: 5, step: 200) // Avg time/img: 0.0270 s
# ----- VALIDATING - EPOCH 5 -----
# VAL loss: 1.207 (epoch: 5, step: 0) // Avg time/img: 0.0179 s
# VAL loss: 1.043 (epoch: 5, step: 50) // Avg time/img: 0.0159 s
# VAL loss: 1.05 (epoch: 5, step: 100) // Avg time/img: 0.0155 s
# VAL loss: 0.9246 (epoch: 5, step: 150) // Avg time/img: 0.0153 s
# EPOCH IoU on VAL set:  25.66 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 5)
# ----- TRAINING - EPOCH 6 -----
# LEARNING RATE:  0.0004623387553722673
# loss: 0.7067 (epoch: 6, step: 0) // Avg time/img: 0.0376 s
# loss: 0.6555 (epoch: 6, step: 50) // Avg time/img: 0.0300 s
# loss: 0.6033 (epoch: 6, step: 100) // Avg time/img: 0.0285 s
# loss: 0.5858 (epoch: 6, step: 150) // Avg time/img: 0.0280 s
# loss: 0.5877 (epoch: 6, step: 200) // Avg time/img: 0.0279 s
# ----- VALIDATING - EPOCH 6 -----
# VAL loss: 0.8443 (epoch: 6, step: 0) // Avg time/img: 0.0139 s
# VAL loss: 1.031 (epoch: 6, step: 50) // Avg time/img: 0.0150 s
# VAL loss: 1.011 (epoch: 6, step: 100) // Avg time/img: 0.0151 s
# VAL loss: 0.8881 (epoch: 6, step: 150) // Avg time/img: 0.0153 s
# EPOCH IoU on VAL set:  26.63 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 6)
# ----- TRAINING - EPOCH 7 -----
# LEARNING RATE:  0.00045476628804148113
# loss: 0.559 (epoch: 7, step: 0) // Avg time/img: 0.0407 s
# loss: 0.5784 (epoch: 7, step: 50) // Avg time/img: 0.0276 s
# loss: 0.5736 (epoch: 7, step: 100) // Avg time/img: 0.0273 s
# loss: 0.5852 (epoch: 7, step: 150) // Avg time/img: 0.0275 s
# loss: 0.5744 (epoch: 7, step: 200) // Avg time/img: 0.0274 s
# ----- VALIDATING - EPOCH 7 -----
# VAL loss: 0.8908 (epoch: 7, step: 0) // Avg time/img: 0.0174 s
# VAL loss: 1.104 (epoch: 7, step: 50) // Avg time/img: 0.0155 s
# VAL loss: 1.125 (epoch: 7, step: 100) // Avg time/img: 0.0156 s
# VAL loss: 1.013 (epoch: 7, step: 150) // Avg time/img: 0.0156 s
# EPOCH IoU on VAL set:  25.07 %
# ----- TRAINING - EPOCH 8 -----
# LEARNING RATE:  0.00044717978378742816
# loss: 0.5349 (epoch: 8, step: 0) // Avg time/img: 0.0372 s
# loss: 0.5602 (epoch: 8, step: 50) // Avg time/img: 0.0307 s
# loss: 0.5581 (epoch: 8, step: 100) // Avg time/img: 0.0293 s
# loss: 0.5552 (epoch: 8, step: 150) // Avg time/img: 0.0292 s
# loss: 0.5586 (epoch: 8, step: 200) // Avg time/img: 0.0287 s
# ----- VALIDATING - EPOCH 8 -----
# VAL loss: 1.457 (epoch: 8, step: 0) // Avg time/img: 0.0123 s
# VAL loss: 1.312 (epoch: 8, step: 50) // Avg time/img: 0.0158 s
# VAL loss: 1.264 (epoch: 8, step: 100) // Avg time/img: 0.0156 s
# VAL loss: 1.091 (epoch: 8, step: 150) // Avg time/img: 0.0156 s
# EPOCH IoU on VAL set:  24.50 %
# ----- TRAINING - EPOCH 9 -----
# LEARNING RATE:  0.00043957895096839955
# loss: 0.6066 (epoch: 9, step: 0) // Avg time/img: 0.0397 s
# loss: 0.5332 (epoch: 9, step: 50) // Avg time/img: 0.0272 s
# loss: 0.5312 (epoch: 9, step: 100) // Avg time/img: 0.0273 s
# loss: 0.5214 (epoch: 9, step: 150) // Avg time/img: 0.0273 s
# loss: 0.5213 (epoch: 9, step: 200) // Avg time/img: 0.0273 s
# ----- VALIDATING - EPOCH 9 -----
# VAL loss: 0.9189 (epoch: 9, step: 0) // Avg time/img: 0.0147 s
# VAL loss: 1.075 (epoch: 9, step: 50) // Avg time/img: 0.0156 s
# VAL loss: 1.046 (epoch: 9, step: 100) // Avg time/img: 0.0159 s
# VAL loss: 0.9016 (epoch: 9, step: 150) // Avg time/img: 0.0156 s
# EPOCH IoU on VAL set:  27.25 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 9)
# ----- TRAINING - EPOCH 10 -----
# LEARNING RATE:  0.00043196348615140955
# loss: 0.5115 (epoch: 10, step: 0) // Avg time/img: 0.0390 s
# loss: 0.4823 (epoch: 10, step: 50) // Avg time/img: 0.0283 s
# loss: 0.4901 (epoch: 10, step: 100) // Avg time/img: 0.0275 s
# loss: 0.4953 (epoch: 10, step: 150) // Avg time/img: 0.0274 s
# loss: 0.5093 (epoch: 10, step: 200) // Avg time/img: 0.0277 s
# ----- VALIDATING - EPOCH 10 -----
# VAL loss: 0.8073 (epoch: 10, step: 0) // Avg time/img: 0.0137 s
# VAL loss: 0.9172 (epoch: 10, step: 50) // Avg time/img: 0.0142 s
# VAL loss: 0.9192 (epoch: 10, step: 100) // Avg time/img: 0.0149 s
# VAL loss: 0.8053 (epoch: 10, step: 150) // Avg time/img: 0.0150 s
# EPOCH IoU on VAL set:  29.54 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 10)
# ----- TRAINING - EPOCH 11 -----
# LEARNING RATE:  0.00042433307339459345
# loss: 0.4987 (epoch: 11, step: 0) // Avg time/img: 0.0357 s
# loss: 0.4622 (epoch: 11, step: 50) // Avg time/img: 0.0280 s
# loss: 0.4761 (epoch: 11, step: 100) // Avg time/img: 0.0275 s
# loss: 0.496 (epoch: 11, step: 150) // Avg time/img: 0.0273 s
# loss: 0.4872 (epoch: 11, step: 200) // Avg time/img: 0.0273 s
# ----- VALIDATING - EPOCH 11 -----
# VAL loss: 0.9167 (epoch: 11, step: 0) // Avg time/img: 0.0218 s
# VAL loss: 0.949 (epoch: 11, step: 50) // Avg time/img: 0.0151 s
# VAL loss: 0.9142 (epoch: 11, step: 100) // Avg time/img: 0.0148 s
# VAL loss: 0.797 (epoch: 11, step: 150) // Avg time/img: 0.0148 s
# EPOCH IoU on VAL set:  29.40 %
# ----- TRAINING - EPOCH 12 -----
# LEARNING RATE:  0.0004166873834706844
# loss: 0.3491 (epoch: 12, step: 0) // Avg time/img: 0.0487 s
# loss: 0.4659 (epoch: 12, step: 50) // Avg time/img: 0.0288 s
# loss: 0.4743 (epoch: 12, step: 100) // Avg time/img: 0.0278 s
# loss: 0.4748 (epoch: 12, step: 150) // Avg time/img: 0.0276 s
# loss: 0.4734 (epoch: 12, step: 200) // Avg time/img: 0.0274 s
# ----- VALIDATING - EPOCH 12 -----
# VAL loss: 0.9176 (epoch: 12, step: 0) // Avg time/img: 0.0131 s
# VAL loss: 0.977 (epoch: 12, step: 50) // Avg time/img: 0.0148 s
# VAL loss: 0.9388 (epoch: 12, step: 100) // Avg time/img: 0.0158 s
# VAL loss: 0.8087 (epoch: 12, step: 150) // Avg time/img: 0.0156 s
# EPOCH IoU on VAL set:  29.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 12)
# ----- TRAINING - EPOCH 13 -----
# LEARNING RATE:  0.00040902607302542923
# loss: 0.4318 (epoch: 13, step: 0) // Avg time/img: 0.0386 s
# loss: 0.4989 (epoch: 13, step: 50) // Avg time/img: 0.0273 s
# loss: 0.4911 (epoch: 13, step: 100) // Avg time/img: 0.0271 s
# loss: 0.4785 (epoch: 13, step: 150) // Avg time/img: 0.0272 s
# loss: 0.4736 (epoch: 13, step: 200) // Avg time/img: 0.0272 s
# ----- VALIDATING - EPOCH 13 -----
# VAL loss: 1.035 (epoch: 13, step: 0) // Avg time/img: 0.0151 s
# VAL loss: 1.042 (epoch: 13, step: 50) // Avg time/img: 0.0154 s
# VAL loss: 1.003 (epoch: 13, step: 100) // Avg time/img: 0.0157 s
# VAL loss: 0.8548 (epoch: 13, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  30.44 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 13)
# ----- TRAINING - EPOCH 14 -----
# LEARNING RATE:  0.0004013487836640184
# loss: 0.4688 (epoch: 14, step: 0) // Avg time/img: 0.0392 s
# loss: 0.4466 (epoch: 14, step: 50) // Avg time/img: 0.0273 s
# loss: 0.4382 (epoch: 14, step: 100) // Avg time/img: 0.0275 s
# loss: 0.4309 (epoch: 14, step: 150) // Avg time/img: 0.0273 s
# loss: 0.4342 (epoch: 14, step: 200) // Avg time/img: 0.0272 s
# ----- VALIDATING - EPOCH 14 -----
# VAL loss: 0.8326 (epoch: 14, step: 0) // Avg time/img: 0.0156 s
# VAL loss: 0.8134 (epoch: 14, step: 50) // Avg time/img: 0.0151 s
# VAL loss: 0.7882 (epoch: 14, step: 100) // Avg time/img: 0.0156 s
# VAL loss: 0.6935 (epoch: 14, step: 150) // Avg time/img: 0.0155 s
# EPOCH IoU on VAL set:  33.10 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 14)
# ----- TRAINING - EPOCH 15 -----
# LEARNING RATE:  0.0003936551409577103
# loss: 0.4674 (epoch: 15, step: 0) // Avg time/img: 0.0367 s
# loss: 0.4547 (epoch: 15, step: 50) // Avg time/img: 0.0285 s
# loss: 0.4459 (epoch: 15, step: 100) // Avg time/img: 0.0283 s
# loss: 0.4383 (epoch: 15, step: 150) // Avg time/img: 0.0279 s
# loss: 0.4401 (epoch: 15, step: 200) // Avg time/img: 0.0278 s
# ----- VALIDATING - EPOCH 15 -----
# VAL loss: 0.7534 (epoch: 15, step: 0) // Avg time/img: 0.0161 s
# VAL loss: 0.7914 (epoch: 15, step: 50) // Avg time/img: 0.0155 s
# VAL loss: 0.7794 (epoch: 15, step: 100) // Avg time/img: 0.0153 s
# VAL loss: 0.6914 (epoch: 15, step: 150) // Avg time/img: 0.0153 s
# EPOCH IoU on VAL set:  33.16 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 15)
# ----- TRAINING - EPOCH 16 -----
# LEARNING RATE:  0.00038594475336178527
# loss: 0.4834 (epoch: 16, step: 0) // Avg time/img: 0.0389 s
# loss: 0.4204 (epoch: 16, step: 50) // Avg time/img: 0.0280 s
# loss: 0.4508 (epoch: 16, step: 100) // Avg time/img: 0.0276 s
# loss: 0.4381 (epoch: 16, step: 150) // Avg time/img: 0.0274 s
# loss: 0.4382 (epoch: 16, step: 200) // Avg time/img: 0.0273 s
# ----- VALIDATING - EPOCH 16 -----
# VAL loss: 1.146 (epoch: 16, step: 0) // Avg time/img: 0.0195 s
# VAL loss: 1.117 (epoch: 16, step: 50) // Avg time/img: 0.0151 s
# VAL loss: 1.094 (epoch: 16, step: 100) // Avg time/img: 0.0153 s
# VAL loss: 0.9157 (epoch: 16, step: 150) // Avg time/img: 0.0153 s
# EPOCH IoU on VAL set:  30.17 %
# ----- TRAINING - EPOCH 17 -----
# LEARNING RATE:  0.00037821721103476613
# loss: 0.678 (epoch: 17, step: 0) // Avg time/img: 0.0477 s
# loss: 0.4074 (epoch: 17, step: 50) // Avg time/img: 0.0278 s
# loss: 0.4021 (epoch: 17, step: 100) // Avg time/img: 0.0279 s
# loss: 0.4162 (epoch: 17, step: 150) // Avg time/img: 0.0276 s
# loss: 0.4239 (epoch: 17, step: 200) // Avg time/img: 0.0272 s
# ----- VALIDATING - EPOCH 17 -----
# VAL loss: 0.9179 (epoch: 17, step: 0) // Avg time/img: 0.0163 s
# VAL loss: 0.9369 (epoch: 17, step: 50) // Avg time/img: 0.0158 s
# VAL loss: 0.9198 (epoch: 17, step: 100) // Avg time/img: 0.0156 s
# VAL loss: 0.7916 (epoch: 17, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  32.10 %
# ----- TRAINING - EPOCH 18 -----
# LEARNING RATE:  0.00037047208454744316
# loss: 0.4784 (epoch: 18, step: 0) // Avg time/img: 0.0400 s
# loss: 0.3906 (epoch: 18, step: 50) // Avg time/img: 0.0278 s
# loss: 0.4068 (epoch: 18, step: 100) // Avg time/img: 0.0274 s
# loss: 0.3966 (epoch: 18, step: 150) // Avg time/img: 0.0273 s
# loss: 0.4039 (epoch: 18, step: 200) // Avg time/img: 0.0270 s
# ----- VALIDATING - EPOCH 18 -----
# VAL loss: 0.6522 (epoch: 18, step: 0) // Avg time/img: 0.0136 s
# VAL loss: 0.9171 (epoch: 18, step: 50) // Avg time/img: 0.0157 s
# VAL loss: 0.8945 (epoch: 18, step: 100) // Avg time/img: 0.0156 s
# VAL loss: 0.773 (epoch: 18, step: 150) // Avg time/img: 0.0155 s
# EPOCH IoU on VAL set:  31.76 %
# ----- TRAINING - EPOCH 19 -----
# LEARNING RATE:  0.00036270892346860996
# loss: 0.3054 (epoch: 19, step: 0) // Avg time/img: 0.0380 s
# loss: 0.4119 (epoch: 19, step: 50) // Avg time/img: 0.0276 s
# loss: 0.3956 (epoch: 19, step: 100) // Avg time/img: 0.0282 s
# loss: 0.4 (epoch: 19, step: 150) // Avg time/img: 0.0278 s
# loss: 0.3983 (epoch: 19, step: 200) // Avg time/img: 0.0276 s
# ----- VALIDATING - EPOCH 19 -----
# VAL loss: 0.5406 (epoch: 19, step: 0) // Avg time/img: 0.0103 s
# VAL loss: 0.8439 (epoch: 19, step: 50) // Avg time/img: 0.0156 s
# VAL loss: 0.8179 (epoch: 19, step: 100) // Avg time/img: 0.0156 s
# VAL loss: 0.71 (epoch: 19, step: 150) // Avg time/img: 0.0158 s
# EPOCH IoU on VAL set:  33.86 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 19)
# ----- TRAINING - EPOCH 20 -----
# LEARNING RATE:  0.0003549272548125162
# loss: 0.4877 (epoch: 20, step: 0) // Avg time/img: 0.0442 s
# loss: 0.3723 (epoch: 20, step: 50) // Avg time/img: 0.0288 s
# loss: 0.3754 (epoch: 20, step: 100) // Avg time/img: 0.0277 s
# loss: 0.3823 (epoch: 20, step: 150) // Avg time/img: 0.0275 s
# loss: 0.3955 (epoch: 20, step: 200) // Avg time/img: 0.0276 s
# ----- VALIDATING - EPOCH 20 -----
# VAL loss: 0.6312 (epoch: 20, step: 0) // Avg time/img: 0.0141 s
# VAL loss: 0.776 (epoch: 20, step: 50) // Avg time/img: 0.0155 s
# VAL loss: 0.7615 (epoch: 20, step: 100) // Avg time/img: 0.0154 s
# VAL loss: 0.6685 (epoch: 20, step: 150) // Avg time/img: 0.0154 s
# EPOCH IoU on VAL set:  33.80 %
# ----- TRAINING - EPOCH 21 -----
# LEARNING RATE:  0.00034712658133080355
# loss: 0.322 (epoch: 21, step: 0) // Avg time/img: 0.0412 s
# loss: 0.3646 (epoch: 21, step: 50) // Avg time/img: 0.0287 s
# loss: 0.3866 (epoch: 21, step: 100) // Avg time/img: 0.0283 s
# loss: 0.3977 (epoch: 21, step: 150) // Avg time/img: 0.0282 s
# loss: 0.394 (epoch: 21, step: 200) // Avg time/img: 0.0281 s
# ----- VALIDATING - EPOCH 21 -----
# VAL loss: 0.8025 (epoch: 21, step: 0) // Avg time/img: 0.0105 s
# VAL loss: 0.8957 (epoch: 21, step: 50) // Avg time/img: 0.0156 s
# VAL loss: 0.8485 (epoch: 21, step: 100) // Avg time/img: 0.0154 s
# VAL loss: 0.7285 (epoch: 21, step: 150) // Avg time/img: 0.0153 s
# EPOCH IoU on VAL set:  31.94 %
# ----- TRAINING - EPOCH 22 -----
# LEARNING RATE:  0.0003393063796290625
# loss: 0.286 (epoch: 22, step: 0) // Avg time/img: 0.0365 s
# loss: 0.368 (epoch: 22, step: 50) // Avg time/img: 0.0278 s
# loss: 0.3914 (epoch: 22, step: 100) // Avg time/img: 0.0286 s
# loss: 0.3824 (epoch: 22, step: 150) // Avg time/img: 0.0281 s
# loss: 0.3835 (epoch: 22, step: 200) // Avg time/img: 0.0284 s
# ----- VALIDATING - EPOCH 22 -----
# VAL loss: 0.6933 (epoch: 22, step: 0) // Avg time/img: 0.0143 s
# VAL loss: 1.024 (epoch: 22, step: 50) // Avg time/img: 0.0164 s
# VAL loss: 0.9791 (epoch: 22, step: 100) // Avg time/img: 0.0157 s
# VAL loss: 0.8246 (epoch: 22, step: 150) // Avg time/img: 0.0158 s
# EPOCH IoU on VAL set:  33.18 %
# ----- TRAINING - EPOCH 23 -----
# LEARNING RATE:  0.0003314660980850309
# loss: 0.4001 (epoch: 23, step: 0) // Avg time/img: 0.0430 s
# loss: 0.3473 (epoch: 23, step: 50) // Avg time/img: 0.0266 s
# loss: 0.3591 (epoch: 23, step: 100) // Avg time/img: 0.0276 s
# loss: 0.3639 (epoch: 23, step: 150) // Avg time/img: 0.0289 s
# loss: 0.3661 (epoch: 23, step: 200) // Avg time/img: 0.0289 s
# ----- VALIDATING - EPOCH 23 -----
# VAL loss: 0.6443 (epoch: 23, step: 0) // Avg time/img: 0.0135 s
# VAL loss: 0.8221 (epoch: 23, step: 50) // Avg time/img: 0.0162 s
# VAL loss: 0.8046 (epoch: 23, step: 100) // Avg time/img: 0.0159 s
# VAL loss: 0.7013 (epoch: 23, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  34.36 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 23)
# ----- TRAINING - EPOCH 24 -----
# LEARNING RATE:  0.0003236051545417615
# loss: 0.2281 (epoch: 24, step: 0) // Avg time/img: 0.0401 s
# loss: 0.3941 (epoch: 24, step: 50) // Avg time/img: 0.0273 s
# loss: 0.3987 (epoch: 24, step: 100) // Avg time/img: 0.0276 s
# loss: 0.3814 (epoch: 24, step: 150) // Avg time/img: 0.0278 s
# loss: 0.3781 (epoch: 24, step: 200) // Avg time/img: 0.0279 s
# ----- VALIDATING - EPOCH 24 -----
# VAL loss: 0.7619 (epoch: 24, step: 0) // Avg time/img: 0.0131 s
# VAL loss: 0.9019 (epoch: 24, step: 50) // Avg time/img: 0.0157 s
# VAL loss: 0.8751 (epoch: 24, step: 100) // Avg time/img: 0.0162 s
# VAL loss: 0.7475 (epoch: 24, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  34.41 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 24)
# ----- TRAINING - EPOCH 25 -----
# LEARNING RATE:  0.00031572293374467766
# loss: 0.5892 (epoch: 25, step: 0) // Avg time/img: 0.0393 s
# loss: 0.3299 (epoch: 25, step: 50) // Avg time/img: 0.0271 s
# loss: 0.3527 (epoch: 25, step: 100) // Avg time/img: 0.0271 s
# loss: 0.3613 (epoch: 25, step: 150) // Avg time/img: 0.0276 s
# loss: 0.3702 (epoch: 25, step: 200) // Avg time/img: 0.0275 s
# ----- VALIDATING - EPOCH 25 -----
# VAL loss: 0.7288 (epoch: 25, step: 0) // Avg time/img: 0.0123 s
# VAL loss: 0.8193 (epoch: 25, step: 50) // Avg time/img: 0.0152 s
# VAL loss: 0.7791 (epoch: 25, step: 100) // Avg time/img: 0.0155 s
# VAL loss: 0.6692 (epoch: 25, step: 150) // Avg time/img: 0.0158 s
# EPOCH IoU on VAL set:  35.85 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 25)
# ----- TRAINING - EPOCH 26 -----
# LEARNING RATE:  0.00030781878448615926
# loss: 0.2669 (epoch: 26, step: 0) // Avg time/img: 0.0429 s
# loss: 0.363 (epoch: 26, step: 50) // Avg time/img: 0.0270 s
# loss: 0.3603 (epoch: 26, step: 100) // Avg time/img: 0.0268 s
# loss: 0.3614 (epoch: 26, step: 150) // Avg time/img: 0.0272 s
# loss: 0.3638 (epoch: 26, step: 200) // Avg time/img: 0.0282 s
# ----- VALIDATING - EPOCH 26 -----
# VAL loss: 0.9035 (epoch: 26, step: 0) // Avg time/img: 0.0127 s
# VAL loss: 0.8119 (epoch: 26, step: 50) // Avg time/img: 0.0152 s
# VAL loss: 0.7957 (epoch: 26, step: 100) // Avg time/img: 0.0150 s
# VAL loss: 0.687 (epoch: 26, step: 150) // Avg time/img: 0.0152 s
# EPOCH IoU on VAL set:  35.43 %
# ----- TRAINING - EPOCH 27 -----
# LEARNING RATE:  0.0002998920164149494
# loss: 0.2503 (epoch: 27, step: 0) // Avg time/img: 0.0362 s
# loss: 0.3412 (epoch: 27, step: 50) // Avg time/img: 0.0294 s
# loss: 0.3405 (epoch: 27, step: 100) // Avg time/img: 0.0287 s
# loss: 0.3435 (epoch: 27, step: 150) // Avg time/img: 0.0280 s
# loss: 0.345 (epoch: 27, step: 200) // Avg time/img: 0.0276 s
# ----- VALIDATING - EPOCH 27 -----
# VAL loss: 0.7525 (epoch: 27, step: 0) // Avg time/img: 0.0265 s
# VAL loss: 0.8122 (epoch: 27, step: 50) // Avg time/img: 0.0165 s
# VAL loss: 0.7757 (epoch: 27, step: 100) // Avg time/img: 0.0161 s
# VAL loss: 0.6722 (epoch: 27, step: 150) // Avg time/img: 0.0159 s
# EPOCH IoU on VAL set:  35.87 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 27)
# ----- TRAINING - EPOCH 28 -----
# LEARNING RATE:  0.00029194189645999016
# loss: 0.3955 (epoch: 28, step: 0) // Avg time/img: 0.0395 s
# loss: 0.3461 (epoch: 28, step: 50) // Avg time/img: 0.0283 s
# loss: 0.3565 (epoch: 28, step: 100) // Avg time/img: 0.0275 s
# loss: 0.3458 (epoch: 28, step: 150) // Avg time/img: 0.0281 s
# loss: 0.3448 (epoch: 28, step: 200) // Avg time/img: 0.0279 s
# ----- VALIDATING - EPOCH 28 -----
# VAL loss: 0.594 (epoch: 28, step: 0) // Avg time/img: 0.0122 s
# VAL loss: 0.763 (epoch: 28, step: 50) // Avg time/img: 0.0158 s
# VAL loss: 0.7523 (epoch: 28, step: 100) // Avg time/img: 0.0158 s
# VAL loss: 0.651 (epoch: 28, step: 150) // Avg time/img: 0.0162 s
# EPOCH IoU on VAL set:  37.29 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 28)
# ----- TRAINING - EPOCH 29 -----
# LEARNING RATE:  0.00028396764480896164
# loss: 0.3573 (epoch: 29, step: 0) // Avg time/img: 0.0391 s
# loss: 0.3387 (epoch: 29, step: 50) // Avg time/img: 0.0271 s
# loss: 0.3446 (epoch: 29, step: 100) // Avg time/img: 0.0272 s
# loss: 0.3427 (epoch: 29, step: 150) // Avg time/img: 0.0272 s
# loss: 0.3394 (epoch: 29, step: 200) // Avg time/img: 0.0277 s
# ----- VALIDATING - EPOCH 29 -----
# VAL loss: 0.8035 (epoch: 29, step: 0) // Avg time/img: 0.0151 s
# VAL loss: 0.8756 (epoch: 29, step: 50) // Avg time/img: 0.0159 s
# VAL loss: 0.8376 (epoch: 29, step: 100) // Avg time/img: 0.0157 s
# VAL loss: 0.7104 (epoch: 29, step: 150) // Avg time/img: 0.0158 s
# EPOCH IoU on VAL set:  35.08 %
# ----- TRAINING - EPOCH 30 -----
# LEARNING RATE:  0.0002759684303703797
# loss: 0.3641 (epoch: 30, step: 0) // Avg time/img: 0.0385 s
# loss: 0.3478 (epoch: 30, step: 50) // Avg time/img: 0.0272 s
# loss: 0.3401 (epoch: 30, step: 100) // Avg time/img: 0.0271 s
# loss: 0.3359 (epoch: 30, step: 150) // Avg time/img: 0.0277 s
# loss: 0.3306 (epoch: 30, step: 200) // Avg time/img: 0.0278 s
# ----- VALIDATING - EPOCH 30 -----
# VAL loss: 0.955 (epoch: 30, step: 0) // Avg time/img: 0.0102 s
# VAL loss: 0.8107 (epoch: 30, step: 50) // Avg time/img: 0.0149 s
# VAL loss: 0.7978 (epoch: 30, step: 100) // Avg time/img: 0.0154 s
# VAL loss: 0.6885 (epoch: 30, step: 150) // Avg time/img: 0.0154 s
# EPOCH IoU on VAL set:  35.34 %
# ----- TRAINING - EPOCH 31 -----
# LEARNING RATE:  0.0002679433656340733
# loss: 0.5069 (epoch: 31, step: 0) // Avg time/img: 0.0416 s
# loss: 0.3375 (epoch: 31, step: 50) // Avg time/img: 0.0289 s
# loss: 0.3241 (epoch: 31, step: 100) // Avg time/img: 0.0290 s
# loss: 0.3293 (epoch: 31, step: 150) // Avg time/img: 0.0286 s
# loss: 0.3351 (epoch: 31, step: 200) // Avg time/img: 0.0284 s
# ----- VALIDATING - EPOCH 31 -----
# VAL loss: 0.7428 (epoch: 31, step: 0) // Avg time/img: 0.0162 s
# VAL loss: 0.8146 (epoch: 31, step: 50) // Avg time/img: 0.0161 s
# VAL loss: 0.8128 (epoch: 31, step: 100) // Avg time/img: 0.0159 s
# VAL loss: 0.7044 (epoch: 31, step: 150) // Avg time/img: 0.0160 s
# EPOCH IoU on VAL set:  36.57 %
# ----- TRAINING - EPOCH 32 -----
# LEARNING RATE:  0.0002598915008274931
# loss: 0.1889 (epoch: 32, step: 0) // Avg time/img: 0.0358 s
# loss: 0.3136 (epoch: 32, step: 50) // Avg time/img: 0.0278 s
# loss: 0.3261 (epoch: 32, step: 100) // Avg time/img: 0.0280 s
# loss: 0.3298 (epoch: 32, step: 150) // Avg time/img: 0.0277 s
# loss: 0.3313 (epoch: 32, step: 200) // Avg time/img: 0.0273 s
# ----- VALIDATING - EPOCH 32 -----
# VAL loss: 0.7642 (epoch: 32, step: 0) // Avg time/img: 0.0098 s
# VAL loss: 0.9268 (epoch: 32, step: 50) // Avg time/img: 0.0153 s
# VAL loss: 0.871 (epoch: 32, step: 100) // Avg time/img: 0.0152 s
# VAL loss: 0.7397 (epoch: 32, step: 150) // Avg time/img: 0.0156 s
# EPOCH IoU on VAL set:  35.20 %
# ----- TRAINING - EPOCH 33 -----
# LEARNING RATE:  0.00025181181724366923
# loss: 0.3794 (epoch: 33, step: 0) // Avg time/img: 0.0398 s
# loss: 0.3299 (epoch: 33, step: 50) // Avg time/img: 0.0287 s
# loss: 0.3272 (epoch: 33, step: 100) // Avg time/img: 0.0282 s
# loss: 0.3185 (epoch: 33, step: 150) // Avg time/img: 0.0287 s
# loss: 0.3223 (epoch: 33, step: 200) // Avg time/img: 0.0284 s
# ----- VALIDATING - EPOCH 33 -----
# VAL loss: 0.6085 (epoch: 33, step: 0) // Avg time/img: 0.0149 s
# VAL loss: 0.7836 (epoch: 33, step: 50) // Avg time/img: 0.0155 s
# VAL loss: 0.7623 (epoch: 33, step: 100) // Avg time/img: 0.0160 s
# VAL loss: 0.657 (epoch: 33, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  36.93 %
# ----- TRAINING - EPOCH 34 -----
# LEARNING RATE:  0.00024370321958949772
# loss: 0.3236 (epoch: 34, step: 0) // Avg time/img: 0.0404 s
# loss: 0.3022 (epoch: 34, step: 50) // Avg time/img: 0.0279 s
# loss: 0.299 (epoch: 34, step: 100) // Avg time/img: 0.0270 s
# loss: 0.3076 (epoch: 34, step: 150) // Avg time/img: 0.0271 s
# loss: 0.3132 (epoch: 34, step: 200) // Avg time/img: 0.0271 s
# ----- VALIDATING - EPOCH 34 -----
# VAL loss: 0.6777 (epoch: 34, step: 0) // Avg time/img: 0.0128 s
# VAL loss: 0.7856 (epoch: 34, step: 50) // Avg time/img: 0.0150 s
# VAL loss: 0.7657 (epoch: 34, step: 100) // Avg time/img: 0.0150 s
# VAL loss: 0.6635 (epoch: 34, step: 150) // Avg time/img: 0.0154 s
# EPOCH IoU on VAL set:  37.78 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 34)
# ----- TRAINING - EPOCH 35 -----
# LEARNING RATE:  0.00023556452716873652
# loss: 0.2757 (epoch: 35, step: 0) // Avg time/img: 0.0391 s
# loss: 0.3114 (epoch: 35, step: 50) // Avg time/img: 0.0271 s
# loss: 0.3142 (epoch: 35, step: 100) // Avg time/img: 0.0267 s
# loss: 0.3144 (epoch: 35, step: 150) // Avg time/img: 0.0269 s
# loss: 0.3153 (epoch: 35, step: 200) // Avg time/img: 0.0271 s
# ----- VALIDATING - EPOCH 35 -----
# VAL loss: 0.7378 (epoch: 35, step: 0) // Avg time/img: 0.0092 s
# VAL loss: 0.8966 (epoch: 35, step: 50) // Avg time/img: 0.0148 s
# VAL loss: 0.8652 (epoch: 35, step: 100) // Avg time/img: 0.0149 s
# VAL loss: 0.727 (epoch: 35, step: 150) // Avg time/img: 0.0151 s
# EPOCH IoU on VAL set:  37.11 %
# ----- TRAINING - EPOCH 36 -----
# LEARNING RATE:  0.00022739446367039517
# loss: 0.365 (epoch: 36, step: 0) // Avg time/img: 0.0411 s
# loss: 0.3041 (epoch: 36, step: 50) // Avg time/img: 0.0292 s
# loss: 0.3096 (epoch: 36, step: 100) // Avg time/img: 0.0285 s
# loss: 0.3101 (epoch: 36, step: 150) // Avg time/img: 0.0282 s
# loss: 0.3139 (epoch: 36, step: 200) // Avg time/img: 0.0279 s
# ----- VALIDATING - EPOCH 36 -----
# VAL loss: 0.6365 (epoch: 36, step: 0) // Avg time/img: 0.0165 s
# VAL loss: 0.7856 (epoch: 36, step: 50) // Avg time/img: 0.0145 s
# VAL loss: 0.7724 (epoch: 36, step: 100) // Avg time/img: 0.0149 s
# VAL loss: 0.662 (epoch: 36, step: 150) // Avg time/img: 0.0151 s
# EPOCH IoU on VAL set:  37.87 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 36)
# ----- TRAINING - EPOCH 37 -----
# LEARNING RATE:  0.00021919164527704348
# loss: 0.3257 (epoch: 37, step: 0) // Avg time/img: 0.0423 s
# loss: 0.3241 (epoch: 37, step: 50) // Avg time/img: 0.0288 s
# loss: 0.3163 (epoch: 37, step: 100) // Avg time/img: 0.0283 s
# loss: 0.3141 (epoch: 37, step: 150) // Avg time/img: 0.0276 s
# loss: 0.3121 (epoch: 37, step: 200) // Avg time/img: 0.0275 s
# ----- VALIDATING - EPOCH 37 -----
# VAL loss: 0.8362 (epoch: 37, step: 0) // Avg time/img: 0.0219 s
# VAL loss: 0.8927 (epoch: 37, step: 50) // Avg time/img: 0.0166 s
# VAL loss: 0.8872 (epoch: 37, step: 100) // Avg time/img: 0.0161 s
# VAL loss: 0.7468 (epoch: 37, step: 150) // Avg time/img: 0.0160 s
# EPOCH IoU on VAL set:  36.06 %
# ----- TRAINING - EPOCH 38 -----
# LEARNING RATE:  0.00021095456673472888
# loss: 0.2492 (epoch: 38, step: 0) // Avg time/img: 0.0383 s
# loss: 0.2931 (epoch: 38, step: 50) // Avg time/img: 0.0278 s
# loss: 0.2987 (epoch: 38, step: 100) // Avg time/img: 0.0284 s
# loss: 0.2987 (epoch: 38, step: 150) // Avg time/img: 0.0288 s
# loss: 0.2976 (epoch: 38, step: 200) // Avg time/img: 0.0283 s
# ----- VALIDATING - EPOCH 38 -----
# VAL loss: 0.6934 (epoch: 38, step: 0) // Avg time/img: 0.0171 s
# VAL loss: 0.7835 (epoch: 38, step: 50) // Avg time/img: 0.0153 s
# VAL loss: 0.7655 (epoch: 38, step: 100) // Avg time/img: 0.0160 s
# VAL loss: 0.6553 (epoch: 38, step: 150) // Avg time/img: 0.0156 s
# EPOCH IoU on VAL set:  38.34 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 38)
# ----- TRAINING - EPOCH 39 -----
# LEARNING RATE:  0.0002026815849307756
# loss: 0.3582 (epoch: 39, step: 0) // Avg time/img: 0.0405 s
# loss: 0.3083 (epoch: 39, step: 50) // Avg time/img: 0.0278 s
# loss: 0.2931 (epoch: 39, step: 100) // Avg time/img: 0.0278 s
# loss: 0.2939 (epoch: 39, step: 150) // Avg time/img: 0.0280 s
# loss: 0.302 (epoch: 39, step: 200) // Avg time/img: 0.0277 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.9771 (epoch: 39, step: 0) // Avg time/img: 0.0178 s
# VAL loss: 0.9233 (epoch: 39, step: 50) // Avg time/img: 0.0159 s
# VAL loss: 0.9181 (epoch: 39, step: 100) // Avg time/img: 0.0158 s
# VAL loss: 0.7888 (epoch: 39, step: 150) // Avg time/img: 0.0159 s
# EPOCH IoU on VAL set:  35.62 %
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.2112 (epoch: 40, step: 0) // Avg time/img: 0.0406 s
# loss: 0.3212 (epoch: 40, step: 50) // Avg time/img: 0.0269 s
# loss: 0.3139 (epoch: 40, step: 100) // Avg time/img: 0.0269 s
# loss: 0.3067 (epoch: 40, step: 150) // Avg time/img: 0.0272 s
# loss: 0.3014 (epoch: 40, step: 200) // Avg time/img: 0.0278 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.5685 (epoch: 40, step: 0) // Avg time/img: 0.0128 s
# VAL loss: 0.7416 (epoch: 40, step: 50) // Avg time/img: 0.0160 s
# VAL loss: 0.7078 (epoch: 40, step: 100) // Avg time/img: 0.0155 s
# VAL loss: 0.6084 (epoch: 40, step: 150) // Avg time/img: 0.0159 s
# EPOCH IoU on VAL set:  39.42 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 40)
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.2843 (epoch: 41, step: 0) // Avg time/img: 0.0379 s
# loss: 0.2855 (epoch: 41, step: 50) // Avg time/img: 0.0270 s
# loss: 0.2884 (epoch: 41, step: 100) // Avg time/img: 0.0273 s
# loss: 0.2885 (epoch: 41, step: 150) // Avg time/img: 0.0275 s
# loss: 0.2899 (epoch: 41, step: 200) // Avg time/img: 0.0281 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.5724 (epoch: 41, step: 0) // Avg time/img: 0.0129 s
# VAL loss: 0.7817 (epoch: 41, step: 50) // Avg time/img: 0.0154 s
# VAL loss: 0.7573 (epoch: 41, step: 100) // Avg time/img: 0.0158 s
# VAL loss: 0.6456 (epoch: 41, step: 150) // Avg time/img: 0.0158 s
# EPOCH IoU on VAL set:  38.66 %
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.2543 (epoch: 42, step: 0) // Avg time/img: 0.0428 s
# loss: 0.2792 (epoch: 42, step: 50) // Avg time/img: 0.0283 s
# loss: 0.2887 (epoch: 42, step: 100) // Avg time/img: 0.0276 s
# loss: 0.2876 (epoch: 42, step: 150) // Avg time/img: 0.0275 s
# loss: 0.2912 (epoch: 42, step: 200) // Avg time/img: 0.0274 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.7275 (epoch: 42, step: 0) // Avg time/img: 0.0124 s
# VAL loss: 0.8289 (epoch: 42, step: 50) // Avg time/img: 0.0155 s
# VAL loss: 0.7998 (epoch: 42, step: 100) // Avg time/img: 0.0159 s
# VAL loss: 0.6799 (epoch: 42, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  38.69 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.2602 (epoch: 43, step: 0) // Avg time/img: 0.0406 s
# loss: 0.2784 (epoch: 43, step: 50) // Avg time/img: 0.0302 s
# loss: 0.2913 (epoch: 43, step: 100) // Avg time/img: 0.0283 s
# loss: 0.2863 (epoch: 43, step: 150) // Avg time/img: 0.0277 s
# loss: 0.2896 (epoch: 43, step: 200) // Avg time/img: 0.0274 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.6993 (epoch: 43, step: 0) // Avg time/img: 0.0151 s
# VAL loss: 0.8204 (epoch: 43, step: 50) // Avg time/img: 0.0162 s
# VAL loss: 0.7952 (epoch: 43, step: 100) // Avg time/img: 0.0164 s
# VAL loss: 0.6804 (epoch: 43, step: 150) // Avg time/img: 0.0161 s
# EPOCH IoU on VAL set:  38.12 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.1922 (epoch: 44, step: 0) // Avg time/img: 0.0400 s
# loss: 0.2804 (epoch: 44, step: 50) // Avg time/img: 0.0286 s
# loss: 0.2821 (epoch: 44, step: 100) // Avg time/img: 0.0278 s
# loss: 0.2793 (epoch: 44, step: 150) // Avg time/img: 0.0277 s
# loss: 0.2819 (epoch: 44, step: 200) // Avg time/img: 0.0274 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.7043 (epoch: 44, step: 0) // Avg time/img: 0.0097 s
# VAL loss: 0.8018 (epoch: 44, step: 50) // Avg time/img: 0.0154 s
# VAL loss: 0.7849 (epoch: 44, step: 100) // Avg time/img: 0.0160 s
# VAL loss: 0.6763 (epoch: 44, step: 150) // Avg time/img: 0.0159 s
# EPOCH IoU on VAL set:  38.45 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.3296 (epoch: 45, step: 0) // Avg time/img: 0.0413 s
# loss: 0.2733 (epoch: 45, step: 50) // Avg time/img: 0.0275 s
# loss: 0.2756 (epoch: 45, step: 100) // Avg time/img: 0.0282 s
# loss: 0.2746 (epoch: 45, step: 150) // Avg time/img: 0.0283 s
# loss: 0.2779 (epoch: 45, step: 200) // Avg time/img: 0.0280 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.6689 (epoch: 45, step: 0) // Avg time/img: 0.0141 s
# VAL loss: 0.7865 (epoch: 45, step: 50) // Avg time/img: 0.0163 s
# VAL loss: 0.7495 (epoch: 45, step: 100) // Avg time/img: 0.0157 s
# VAL loss: 0.6459 (epoch: 45, step: 150) // Avg time/img: 0.0158 s
# EPOCH IoU on VAL set:  39.66 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 45)
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.223 (epoch: 46, step: 0) // Avg time/img: 0.0408 s
# loss: 0.2904 (epoch: 46, step: 50) // Avg time/img: 0.0283 s
# loss: 0.2788 (epoch: 46, step: 100) // Avg time/img: 0.0291 s
# loss: 0.2751 (epoch: 46, step: 150) // Avg time/img: 0.0288 s
# loss: 0.2735 (epoch: 46, step: 200) // Avg time/img: 0.0285 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.9601 (epoch: 46, step: 0) // Avg time/img: 0.0184 s
# VAL loss: 0.9192 (epoch: 46, step: 50) // Avg time/img: 0.0154 s
# VAL loss: 0.8849 (epoch: 46, step: 100) // Avg time/img: 0.0157 s
# VAL loss: 0.7466 (epoch: 46, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  38.10 %
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.249 (epoch: 47, step: 0) // Avg time/img: 0.0428 s
# loss: 0.2627 (epoch: 47, step: 50) // Avg time/img: 0.0281 s
# loss: 0.2743 (epoch: 47, step: 100) // Avg time/img: 0.0276 s
# loss: 0.2713 (epoch: 47, step: 150) // Avg time/img: 0.0280 s
# loss: 0.2709 (epoch: 47, step: 200) // Avg time/img: 0.0279 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.7057 (epoch: 47, step: 0) // Avg time/img: 0.0160 s
# VAL loss: 0.7985 (epoch: 47, step: 50) // Avg time/img: 0.0155 s
# VAL loss: 0.7789 (epoch: 47, step: 100) // Avg time/img: 0.0159 s
# VAL loss: 0.66 (epoch: 47, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  39.09 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.2483 (epoch: 48, step: 0) // Avg time/img: 0.0348 s
# loss: 0.2541 (epoch: 48, step: 50) // Avg time/img: 0.0275 s
# loss: 0.2606 (epoch: 48, step: 100) // Avg time/img: 0.0272 s
# loss: 0.2678 (epoch: 48, step: 150) // Avg time/img: 0.0279 s
# loss: 0.2643 (epoch: 48, step: 200) // Avg time/img: 0.0278 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.6598 (epoch: 48, step: 0) // Avg time/img: 0.0126 s
# VAL loss: 0.8307 (epoch: 48, step: 50) // Avg time/img: 0.0159 s
# VAL loss: 0.7906 (epoch: 48, step: 100) // Avg time/img: 0.0163 s
# VAL loss: 0.6688 (epoch: 48, step: 150) // Avg time/img: 0.0160 s
# EPOCH IoU on VAL set:  39.57 %
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.2064 (epoch: 49, step: 0) // Avg time/img: 0.0387 s
# loss: 0.27 (epoch: 49, step: 50) // Avg time/img: 0.0284 s
# loss: 0.2733 (epoch: 49, step: 100) // Avg time/img: 0.0282 s
# loss: 0.27 (epoch: 49, step: 150) // Avg time/img: 0.0287 s
# loss: 0.2675 (epoch: 49, step: 200) // Avg time/img: 0.0283 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.7518 (epoch: 49, step: 0) // Avg time/img: 0.0147 s
# VAL loss: 0.9754 (epoch: 49, step: 50) // Avg time/img: 0.0157 s
# VAL loss: 0.9149 (epoch: 49, step: 100) // Avg time/img: 0.0157 s
# VAL loss: 0.753 (epoch: 49, step: 150) // Avg time/img: 0.0158 s
# EPOCH IoU on VAL set:  38.04 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.3075 (epoch: 50, step: 0) // Avg time/img: 0.0366 s
# loss: 0.2649 (epoch: 50, step: 50) // Avg time/img: 0.0275 s
# loss: 0.2803 (epoch: 50, step: 100) // Avg time/img: 0.0273 s
# loss: 0.2711 (epoch: 50, step: 150) // Avg time/img: 0.0274 s
# loss: 0.2635 (epoch: 50, step: 200) // Avg time/img: 0.0271 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.6757 (epoch: 50, step: 0) // Avg time/img: 0.0159 s
# VAL loss: 0.8086 (epoch: 50, step: 50) // Avg time/img: 0.0154 s
# VAL loss: 0.7872 (epoch: 50, step: 100) // Avg time/img: 0.0155 s
# VAL loss: 0.6666 (epoch: 50, step: 150) // Avg time/img: 0.0158 s
# EPOCH IoU on VAL set:  39.78 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 50)
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.2158 (epoch: 51, step: 0) // Avg time/img: 0.0389 s
# loss: 0.266 (epoch: 51, step: 50) // Avg time/img: 0.0271 s
# loss: 0.2612 (epoch: 51, step: 100) // Avg time/img: 0.0266 s
# loss: 0.2592 (epoch: 51, step: 150) // Avg time/img: 0.0266 s
# loss: 0.2575 (epoch: 51, step: 200) // Avg time/img: 0.0271 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.6122 (epoch: 51, step: 0) // Avg time/img: 0.0146 s
# VAL loss: 0.9202 (epoch: 51, step: 50) // Avg time/img: 0.0157 s
# VAL loss: 0.8766 (epoch: 51, step: 100) // Avg time/img: 0.0159 s
# VAL loss: 0.7313 (epoch: 51, step: 150) // Avg time/img: 0.0161 s
# EPOCH IoU on VAL set:  38.89 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.1978 (epoch: 52, step: 0) // Avg time/img: 0.0369 s
# loss: 0.2426 (epoch: 52, step: 50) // Avg time/img: 0.0285 s
# loss: 0.2592 (epoch: 52, step: 100) // Avg time/img: 0.0275 s
# loss: 0.2545 (epoch: 52, step: 150) // Avg time/img: 0.0274 s
# loss: 0.2513 (epoch: 52, step: 200) // Avg time/img: 0.0278 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.65 (epoch: 52, step: 0) // Avg time/img: 0.0196 s
# VAL loss: 0.8552 (epoch: 52, step: 50) // Avg time/img: 0.0160 s
# VAL loss: 0.8218 (epoch: 52, step: 100) // Avg time/img: 0.0157 s
# VAL loss: 0.6914 (epoch: 52, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  39.30 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.2971 (epoch: 53, step: 0) // Avg time/img: 0.0404 s
# loss: 0.2369 (epoch: 53, step: 50) // Avg time/img: 0.0276 s
# loss: 0.2456 (epoch: 53, step: 100) // Avg time/img: 0.0275 s
# loss: 0.248 (epoch: 53, step: 150) // Avg time/img: 0.0276 s
# loss: 0.2527 (epoch: 53, step: 200) // Avg time/img: 0.0276 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.6384 (epoch: 53, step: 0) // Avg time/img: 0.0156 s
# VAL loss: 0.8327 (epoch: 53, step: 50) // Avg time/img: 0.0150 s
# VAL loss: 0.7928 (epoch: 53, step: 100) // Avg time/img: 0.0152 s
# VAL loss: 0.6706 (epoch: 53, step: 150) // Avg time/img: 0.0152 s
# EPOCH IoU on VAL set:  39.91 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.326 (epoch: 54, step: 0) // Avg time/img: 0.0396 s
# loss: 0.2403 (epoch: 54, step: 50) // Avg time/img: 0.0293 s
# loss: 0.2456 (epoch: 54, step: 100) // Avg time/img: 0.0283 s
# loss: 0.2481 (epoch: 54, step: 150) // Avg time/img: 0.0281 s
# loss: 0.2468 (epoch: 54, step: 200) // Avg time/img: 0.0278 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.6079 (epoch: 54, step: 0) // Avg time/img: 0.0143 s
# VAL loss: 0.793 (epoch: 54, step: 50) // Avg time/img: 0.0154 s
# VAL loss: 0.7723 (epoch: 54, step: 100) // Avg time/img: 0.0153 s
# VAL loss: 0.6583 (epoch: 54, step: 150) // Avg time/img: 0.0153 s
# EPOCH IoU on VAL set:  39.94 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 54)
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.3303 (epoch: 55, step: 0) // Avg time/img: 0.0453 s
# loss: 0.2484 (epoch: 55, step: 50) // Avg time/img: 0.0285 s
# loss: 0.2513 (epoch: 55, step: 100) // Avg time/img: 0.0276 s
# loss: 0.2477 (epoch: 55, step: 150) // Avg time/img: 0.0274 s
# loss: 0.2471 (epoch: 55, step: 200) // Avg time/img: 0.0273 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.6666 (epoch: 55, step: 0) // Avg time/img: 0.0145 s
# VAL loss: 0.8245 (epoch: 55, step: 50) // Avg time/img: 0.0158 s
# VAL loss: 0.7911 (epoch: 55, step: 100) // Avg time/img: 0.0154 s
# VAL loss: 0.6705 (epoch: 55, step: 150) // Avg time/img: 0.0152 s
# EPOCH IoU on VAL set:  40.05 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 55)
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.5599 (epoch: 56, step: 0) // Avg time/img: 0.0415 s
# loss: 0.2522 (epoch: 56, step: 50) // Avg time/img: 0.0289 s
# loss: 0.2573 (epoch: 56, step: 100) // Avg time/img: 0.0281 s
# loss: 0.254 (epoch: 56, step: 150) // Avg time/img: 0.0277 s
# loss: 0.2472 (epoch: 56, step: 200) // Avg time/img: 0.0275 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.5762 (epoch: 56, step: 0) // Avg time/img: 0.0125 s
# VAL loss: 0.7752 (epoch: 56, step: 50) // Avg time/img: 0.0158 s
# VAL loss: 0.7424 (epoch: 56, step: 100) // Avg time/img: 0.0157 s
# VAL loss: 0.633 (epoch: 56, step: 150) // Avg time/img: 0.0157 s
# EPOCH IoU on VAL set:  40.73 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 56)
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.2086 (epoch: 57, step: 0) // Avg time/img: 0.0353 s
# loss: 0.2449 (epoch: 57, step: 50) // Avg time/img: 0.0302 s
# loss: 0.2436 (epoch: 57, step: 100) // Avg time/img: 0.0295 s
# loss: 0.2437 (epoch: 57, step: 150) // Avg time/img: 0.0287 s
# loss: 0.2415 (epoch: 57, step: 200) // Avg time/img: 0.0283 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.6358 (epoch: 57, step: 0) // Avg time/img: 0.0121 s
# VAL loss: 0.8265 (epoch: 57, step: 50) // Avg time/img: 0.0157 s
# VAL loss: 0.7922 (epoch: 57, step: 100) // Avg time/img: 0.0154 s
# VAL loss: 0.6679 (epoch: 57, step: 150) // Avg time/img: 0.0156 s
# EPOCH IoU on VAL set:  40.30 %
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.2349 (epoch: 58, step: 0) // Avg time/img: 0.0410 s
# loss: 0.2343 (epoch: 58, step: 50) // Avg time/img: 0.0270 s
# loss: 0.2412 (epoch: 58, step: 100) // Avg time/img: 0.0277 s
# loss: 0.2399 (epoch: 58, step: 150) // Avg time/img: 0.0275 s
# loss: 0.243 (epoch: 58, step: 200) // Avg time/img: 0.0273 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.6087 (epoch: 58, step: 0) // Avg time/img: 0.0117 s
# VAL loss: 0.8405 (epoch: 58, step: 50) // Avg time/img: 0.0155 s
# VAL loss: 0.803 (epoch: 58, step: 100) // Avg time/img: 0.0157 s
# VAL loss: 0.6768 (epoch: 58, step: 150) // Avg time/img: 0.0153 s
# EPOCH IoU on VAL set:  40.10 %
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.1709 (epoch: 59, step: 0) // Avg time/img: 0.0399 s
# loss: 0.2218 (epoch: 59, step: 50) // Avg time/img: 0.0276 s
# loss: 0.225 (epoch: 59, step: 100) // Avg time/img: 0.0280 s
# loss: 0.2373 (epoch: 59, step: 150) // Avg time/img: 0.0279 s
# loss: 0.2397 (epoch: 59, step: 200) // Avg time/img: 0.0283 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.5176 (epoch: 59, step: 0) // Avg time/img: 0.0150 s
# VAL loss: 0.7939 (epoch: 59, step: 50) // Avg time/img: 0.0156 s
# VAL loss: 0.7594 (epoch: 59, step: 100) // Avg time/img: 0.0160 s
# VAL loss: 0.6421 (epoch: 59, step: 150) // Avg time/img: 0.0159 s
# EPOCH IoU on VAL set:  40.71 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.1712 (epoch: 60, step: 0) // Avg time/img: 0.0394 s
# loss: 0.2379 (epoch: 60, step: 50) // Avg time/img: 0.0286 s
# loss: 0.2346 (epoch: 60, step: 100) // Avg time/img: 0.0277 s
# loss: 0.2361 (epoch: 60, step: 150) // Avg time/img: 0.0282 s
# loss: 0.2371 (epoch: 60, step: 200) // Avg time/img: 0.0279 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.5943 (epoch: 60, step: 0) // Avg time/img: 0.0152 s
# VAL loss: 0.7991 (epoch: 60, step: 50) // Avg time/img: 0.0153 s
# VAL loss: 0.7641 (epoch: 60, step: 100) // Avg time/img: 0.0156 s
# VAL loss: 0.6451 (epoch: 60, step: 150) // Avg time/img: 0.0158 s
# EPOCH IoU on VAL set:  40.78 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_encoder_best.pth (epoch: 60)
# ========== DECODER TRAINING ===========
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/train
# /content/gdrive/MyDrive/Colab Notebooks/cityscapes/leftImg8bit/val
# <class '__main__.CrossEntropyLoss2d'>
# ----- TRAINING - EPOCH 1 -----
# LEARNING RATE:  0.0005
# loss: 3.082 (epoch: 1, step: 0) // Avg time/img: 0.0937 s
# loss: 2.694 (epoch: 1, step: 50) // Avg time/img: 0.0506 s
# loss: 2.416 (epoch: 1, step: 100) // Avg time/img: 0.0503 s
# loss: 2.161 (epoch: 1, step: 150) // Avg time/img: 0.0506 s
# loss: 1.948 (epoch: 1, step: 200) // Avg time/img: 0.0503 s
# ----- VALIDATING - EPOCH 1 -----
# VAL loss: 1.024 (epoch: 1, step: 0) // Avg time/img: 0.0255 s
# VAL loss: 1.377 (epoch: 1, step: 50) // Avg time/img: 0.0263 s
# VAL loss: 1.319 (epoch: 1, step: 100) // Avg time/img: 0.0269 s
# VAL loss: 1.199 (epoch: 1, step: 150) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  20.81 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_best.pth (epoch: 1)
# ----- TRAINING - EPOCH 2 -----
# LEARNING RATE:  0.000492493711467861
# loss: 0.9795 (epoch: 2, step: 0) // Avg time/img: 0.0703 s
# loss: 0.9923 (epoch: 2, step: 50) // Avg time/img: 0.0501 s
# loss: 0.9304 (epoch: 2, step: 100) // Avg time/img: 0.0497 s
# loss: 0.9009 (epoch: 2, step: 150) // Avg time/img: 0.0500 s
# loss: 0.8806 (epoch: 2, step: 200) // Avg time/img: 0.0498 s
# ----- VALIDATING - EPOCH 2 -----
# VAL loss: 1.139 (epoch: 2, step: 0) // Avg time/img: 0.0223 s
# VAL loss: 1.267 (epoch: 2, step: 50) // Avg time/img: 0.0266 s
# VAL loss: 1.218 (epoch: 2, step: 100) // Avg time/img: 0.0266 s
# VAL loss: 1.095 (epoch: 2, step: 150) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  21.21 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_best.pth (epoch: 2)
# ----- TRAINING - EPOCH 3 -----
# LEARNING RATE:  0.0004849746889841331
# loss: 0.8789 (epoch: 3, step: 0) // Avg time/img: 0.0724 s
# loss: 0.78 (epoch: 3, step: 50) // Avg time/img: 0.0500 s
# loss: 0.7258 (epoch: 3, step: 100) // Avg time/img: 0.0502 s
# loss: 0.7124 (epoch: 3, step: 150) // Avg time/img: 0.0500 s
# loss: 0.7182 (epoch: 3, step: 200) // Avg time/img: 0.0498 s
# ----- VALIDATING - EPOCH 3 -----
# VAL loss: 0.7022 (epoch: 3, step: 0) // Avg time/img: 0.0268 s
# VAL loss: 1.221 (epoch: 3, step: 50) // Avg time/img: 0.0275 s
# VAL loss: 1.155 (epoch: 3, step: 100) // Avg time/img: 0.0265 s
# ...
# loss: 0.2488 (epoch: 39, step: 0) // Avg time/img: 0.0722 s
# loss: 0.2534 (epoch: 39, step: 50) // Avg time/img: 0.0509 s
# loss: 0.2598 (epoch: 39, step: 100) // Avg time/img: 0.0504 s
# loss: 0.2629 (epoch: 39, step: 150) // Avg time/img: 0.0501 s
# loss: 0.2598 (epoch: 39, step: 200) // Avg time/img: 0.0497 s
# ----- VALIDATING - EPOCH 39 -----
# VAL loss: 0.5261 (epoch: 39, step: 0) // Avg time/img: 0.0213 s
# VAL loss: 0.791 (epoch: 39, step: 50) // Avg time/img: 0.0265 s
# VAL loss: 0.7867 (epoch: 39, step: 100) // Avg time/img: 0.0263 s
# VAL loss: 0.6902 (epoch: 39, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  41.47 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_best.pth (epoch: 39)
# ----- TRAINING - EPOCH 40 -----
# LEARNING RATE:  0.00019437089939938174
# loss: 0.1945 (epoch: 40, step: 0) // Avg time/img: 0.0714 s
# loss: 0.265 (epoch: 40, step: 50) // Avg time/img: 0.0512 s
# loss: 0.2641 (epoch: 40, step: 100) // Avg time/img: 0.0505 s
# loss: 0.2661 (epoch: 40, step: 150) // Avg time/img: 0.0502 s
# loss: 0.2641 (epoch: 40, step: 200) // Avg time/img: 0.0498 s
# ----- VALIDATING - EPOCH 40 -----
# VAL loss: 0.5531 (epoch: 40, step: 0) // Avg time/img: 0.0225 s
# VAL loss: 0.8915 (epoch: 40, step: 50) // Avg time/img: 0.0272 s
# VAL loss: 0.8598 (epoch: 40, step: 100) // Avg time/img: 0.0265 s
# VAL loss: 0.7358 (epoch: 40, step: 150) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  41.03 %
# ----- TRAINING - EPOCH 41 -----
# LEARNING RATE:  0.00018602052900565077
# loss: 0.2986 (epoch: 41, step: 0) // Avg time/img: 0.0688 s
# loss: 0.2512 (epoch: 41, step: 50) // Avg time/img: 0.0515 s
# loss: 0.2546 (epoch: 41, step: 100) // Avg time/img: 0.0510 s
# loss: 0.2554 (epoch: 41, step: 150) // Avg time/img: 0.0504 s
# loss: 0.2544 (epoch: 41, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 41 -----
# VAL loss: 0.6167 (epoch: 41, step: 0) // Avg time/img: 0.0223 s
# VAL loss: 0.8684 (epoch: 41, step: 50) // Avg time/img: 0.0267 s
# VAL loss: 0.8313 (epoch: 41, step: 100) // Avg time/img: 0.0264 s
# VAL loss: 0.7077 (epoch: 41, step: 150) // Avg time/img: 0.0267 s
# EPOCH IoU on VAL set:  42.47 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_best.pth (epoch: 41)
# ----- TRAINING - EPOCH 42 -----
# LEARNING RATE:  0.00017762828382899407
# loss: 0.2163 (epoch: 42, step: 0) // Avg time/img: 0.0543 s
# loss: 0.2617 (epoch: 42, step: 50) // Avg time/img: 0.0488 s
# loss: 0.2515 (epoch: 42, step: 100) // Avg time/img: 0.0491 s
# loss: 0.2519 (epoch: 42, step: 150) // Avg time/img: 0.0498 s
# loss: 0.2518 (epoch: 42, step: 200) // Avg time/img: 0.0495 s
# ----- VALIDATING - EPOCH 42 -----
# VAL loss: 0.6359 (epoch: 42, step: 0) // Avg time/img: 0.0241 s
# VAL loss: 0.9354 (epoch: 42, step: 50) // Avg time/img: 0.0272 s
# VAL loss: 0.9258 (epoch: 42, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.7941 (epoch: 42, step: 150) // Avg time/img: 0.0263 s
# EPOCH IoU on VAL set:  39.78 %
# ----- TRAINING - EPOCH 43 -----
# LEARNING RATE:  0.00016919173095082495
# loss: 0.1464 (epoch: 43, step: 0) // Avg time/img: 0.0714 s
# loss: 0.2397 (epoch: 43, step: 50) // Avg time/img: 0.0519 s
# loss: 0.2417 (epoch: 43, step: 100) // Avg time/img: 0.0506 s
# loss: 0.2492 (epoch: 43, step: 150) // Avg time/img: 0.0510 s
# loss: 0.2518 (epoch: 43, step: 200) // Avg time/img: 0.0509 s
# ----- VALIDATING - EPOCH 43 -----
# VAL loss: 0.836 (epoch: 43, step: 0) // Avg time/img: 0.0213 s
# VAL loss: 0.9734 (epoch: 43, step: 50) // Avg time/img: 0.0262 s
# VAL loss: 0.9207 (epoch: 43, step: 100) // Avg time/img: 0.0263 s
# VAL loss: 0.7832 (epoch: 43, step: 150) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  40.28 %
# ----- TRAINING - EPOCH 44 -----
# LEARNING RATE:  0.0001607081524100206
# loss: 0.2742 (epoch: 44, step: 0) // Avg time/img: 0.0752 s
# loss: 0.2393 (epoch: 44, step: 50) // Avg time/img: 0.0503 s
# loss: 0.2515 (epoch: 44, step: 100) // Avg time/img: 0.0507 s
# loss: 0.2569 (epoch: 44, step: 150) // Avg time/img: 0.0505 s
# loss: 0.2542 (epoch: 44, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 44 -----
# VAL loss: 0.7443 (epoch: 44, step: 0) // Avg time/img: 0.0208 s
# VAL loss: 0.9467 (epoch: 44, step: 50) // Avg time/img: 0.0265 s
# VAL loss: 0.9348 (epoch: 44, step: 100) // Avg time/img: 0.0265 s
# VAL loss: 0.7931 (epoch: 44, step: 150) // Avg time/img: 0.0268 s
# EPOCH IoU on VAL set:  40.11 %
# ----- TRAINING - EPOCH 45 -----
# LEARNING RATE:  0.00015217449296258857
# loss: 0.2207 (epoch: 45, step: 0) // Avg time/img: 0.0819 s
# loss: 0.2415 (epoch: 45, step: 50) // Avg time/img: 0.0508 s
# loss: 0.2382 (epoch: 45, step: 100) // Avg time/img: 0.0503 s
# loss: 0.2384 (epoch: 45, step: 150) // Avg time/img: 0.0499 s
# loss: 0.2424 (epoch: 45, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 45 -----
# VAL loss: 0.5471 (epoch: 45, step: 0) // Avg time/img: 0.0233 s
# VAL loss: 0.878 (epoch: 45, step: 50) // Avg time/img: 0.0262 s
# VAL loss: 0.8731 (epoch: 45, step: 100) // Avg time/img: 0.0268 s
# VAL loss: 0.7517 (epoch: 45, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  40.10 %
# ----- TRAINING - EPOCH 46 -----
# LEARNING RATE:  0.00014358729437462936
# loss: 0.2646 (epoch: 46, step: 0) // Avg time/img: 0.0577 s
# loss: 0.233 (epoch: 46, step: 50) // Avg time/img: 0.0490 s
# loss: 0.2426 (epoch: 46, step: 100) // Avg time/img: 0.0494 s
# loss: 0.2431 (epoch: 46, step: 150) // Avg time/img: 0.0491 s
# loss: 0.246 (epoch: 46, step: 200) // Avg time/img: 0.0495 s
# ----- VALIDATING - EPOCH 46 -----
# VAL loss: 0.5262 (epoch: 46, step: 0) // Avg time/img: 0.0279 s
# VAL loss: 0.813 (epoch: 46, step: 50) // Avg time/img: 0.0270 s
# VAL loss: 0.8002 (epoch: 46, step: 100) // Avg time/img: 0.0264 s
# VAL loss: 0.6872 (epoch: 46, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  42.37 %
# ----- TRAINING - EPOCH 47 -----
# LEARNING RATE:  0.00013494261163740181
# loss: 0.2686 (epoch: 47, step: 0) // Avg time/img: 0.0596 s
# loss: 0.2478 (epoch: 47, step: 50) // Avg time/img: 0.0500 s
# loss: 0.2394 (epoch: 47, step: 100) // Avg time/img: 0.0503 s
# loss: 0.2389 (epoch: 47, step: 150) // Avg time/img: 0.0504 s
# loss: 0.2391 (epoch: 47, step: 200) // Avg time/img: 0.0503 s
# ----- VALIDATING - EPOCH 47 -----
# VAL loss: 0.6673 (epoch: 47, step: 0) // Avg time/img: 0.0235 s
# VAL loss: 0.8861 (epoch: 47, step: 50) // Avg time/img: 0.0263 s
# VAL loss: 0.8788 (epoch: 47, step: 100) // Avg time/img: 0.0268 s
# VAL loss: 0.7519 (epoch: 47, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  40.97 %
# ----- TRAINING - EPOCH 48 -----
# LEARNING RATE:  0.00012623590446718072
# loss: 0.2912 (epoch: 48, step: 0) // Avg time/img: 0.0691 s
# loss: 0.2287 (epoch: 48, step: 50) // Avg time/img: 0.0502 s
# loss: 0.2349 (epoch: 48, step: 100) // Avg time/img: 0.0499 s
# loss: 0.2373 (epoch: 48, step: 150) // Avg time/img: 0.0496 s
# loss: 0.2361 (epoch: 48, step: 200) // Avg time/img: 0.0495 s
# ----- VALIDATING - EPOCH 48 -----
# VAL loss: 0.61 (epoch: 48, step: 0) // Avg time/img: 0.0227 s
# VAL loss: 0.8925 (epoch: 48, step: 50) // Avg time/img: 0.0268 s
# VAL loss: 0.8607 (epoch: 48, step: 100) // Avg time/img: 0.0262 s
# VAL loss: 0.7392 (epoch: 48, step: 150) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  41.42 %
# ----- TRAINING - EPOCH 49 -----
# LEARNING RATE:  0.00011746189430880188
# loss: 0.1758 (epoch: 49, step: 0) // Avg time/img: 0.0700 s
# loss: 0.2297 (epoch: 49, step: 50) // Avg time/img: 0.0514 s
# loss: 0.2267 (epoch: 49, step: 100) // Avg time/img: 0.0502 s
# loss: 0.2326 (epoch: 49, step: 150) // Avg time/img: 0.0496 s
# loss: 0.2347 (epoch: 49, step: 200) // Avg time/img: 0.0496 s
# ----- VALIDATING - EPOCH 49 -----
# VAL loss: 0.5935 (epoch: 49, step: 0) // Avg time/img: 0.0228 s
# VAL loss: 0.8669 (epoch: 49, step: 50) // Avg time/img: 0.0265 s
# VAL loss: 0.8615 (epoch: 49, step: 100) // Avg time/img: 0.0264 s
# VAL loss: 0.744 (epoch: 49, step: 150) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  41.66 %
# ----- TRAINING - EPOCH 50 -----
# LEARNING RATE:  0.00010861437203680056
# loss: 0.2587 (epoch: 50, step: 0) // Avg time/img: 0.0653 s
# loss: 0.2396 (epoch: 50, step: 50) // Avg time/img: 0.0498 s
# loss: 0.2381 (epoch: 50, step: 100) // Avg time/img: 0.0497 s
# loss: 0.2309 (epoch: 50, step: 150) // Avg time/img: 0.0501 s
# loss: 0.234 (epoch: 50, step: 200) // Avg time/img: 0.0499 s
# ----- VALIDATING - EPOCH 50 -----
# VAL loss: 0.554 (epoch: 50, step: 0) // Avg time/img: 0.0215 s
# VAL loss: 0.8808 (epoch: 50, step: 50) // Avg time/img: 0.0266 s
# VAL loss: 0.8796 (epoch: 50, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.7625 (epoch: 50, step: 150) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  40.61 %
# ----- TRAINING - EPOCH 51 -----
# LEARNING RATE:  9.96859332376096e-05
# loss: 0.1844 (epoch: 51, step: 0) // Avg time/img: 0.0538 s
# loss: 0.2275 (epoch: 51, step: 50) // Avg time/img: 0.0510 s
# loss: 0.231 (epoch: 51, step: 100) // Avg time/img: 0.0505 s
# loss: 0.228 (epoch: 51, step: 150) // Avg time/img: 0.0500 s
# loss: 0.2275 (epoch: 51, step: 200) // Avg time/img: 0.0500 s
# ----- VALIDATING - EPOCH 51 -----
# VAL loss: 0.5768 (epoch: 51, step: 0) // Avg time/img: 0.0184 s
# VAL loss: 0.8676 (epoch: 51, step: 50) // Avg time/img: 0.0260 s
# VAL loss: 0.863 (epoch: 51, step: 100) // Avg time/img: 0.0264 s
# VAL loss: 0.7422 (epoch: 51, step: 150) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  42.12 %
# ----- TRAINING - EPOCH 52 -----
# LEARNING RATE:  9.066760365683728e-05
# loss: 0.3449 (epoch: 52, step: 0) // Avg time/img: 0.0595 s
# loss: 0.2179 (epoch: 52, step: 50) // Avg time/img: 0.0493 s
# loss: 0.2284 (epoch: 52, step: 100) // Avg time/img: 0.0495 s
# loss: 0.2317 (epoch: 52, step: 150) // Avg time/img: 0.0497 s
# loss: 0.2293 (epoch: 52, step: 200) // Avg time/img: 0.0496 s
# ----- VALIDATING - EPOCH 52 -----
# VAL loss: 0.6111 (epoch: 52, step: 0) // Avg time/img: 0.0220 s
# VAL loss: 0.892 (epoch: 52, step: 50) // Avg time/img: 0.0276 s
# VAL loss: 0.8778 (epoch: 52, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.7542 (epoch: 52, step: 150) // Avg time/img: 0.0266 s
# EPOCH IoU on VAL set:  41.62 %
# ----- TRAINING - EPOCH 53 -----
# LEARNING RATE:  8.154829161610912e-05
# loss: 0.1679 (epoch: 53, step: 0) // Avg time/img: 0.0511 s
# loss: 0.2223 (epoch: 53, step: 50) // Avg time/img: 0.0495 s
# loss: 0.2199 (epoch: 53, step: 100) // Avg time/img: 0.0493 s
# loss: 0.2256 (epoch: 53, step: 150) // Avg time/img: 0.0495 s
# loss: 0.2264 (epoch: 53, step: 200) // Avg time/img: 0.0496 s
# ----- VALIDATING - EPOCH 53 -----
# VAL loss: 0.5856 (epoch: 53, step: 0) // Avg time/img: 0.0250 s
# VAL loss: 0.865 (epoch: 53, step: 50) // Avg time/img: 0.0265 s
# VAL loss: 0.8434 (epoch: 53, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.7196 (epoch: 53, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  42.81 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_best.pth (epoch: 53)
# ----- TRAINING - EPOCH 54 -----
# LEARNING RATE:  7.231395505915424e-05
# loss: 0.1641 (epoch: 54, step: 0) // Avg time/img: 0.0772 s
# loss: 0.2251 (epoch: 54, step: 50) // Avg time/img: 0.0500 s
# loss: 0.2202 (epoch: 54, step: 100) // Avg time/img: 0.0512 s
# loss: 0.2174 (epoch: 54, step: 150) // Avg time/img: 0.0507 s
# loss: 0.221 (epoch: 54, step: 200) // Avg time/img: 0.0501 s
# ----- VALIDATING - EPOCH 54 -----
# VAL loss: 0.5303 (epoch: 54, step: 0) // Avg time/img: 0.0289 s
# VAL loss: 0.8466 (epoch: 54, step: 50) // Avg time/img: 0.0275 s
# VAL loss: 0.8338 (epoch: 54, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.7162 (epoch: 54, step: 150) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  42.44 %
# ----- TRAINING - EPOCH 55 -----
# LEARNING RATE:  6.294627058970836e-05
# loss: 0.2232 (epoch: 55, step: 0) // Avg time/img: 0.0642 s
# loss: 0.2136 (epoch: 55, step: 50) // Avg time/img: 0.0495 s
# loss: 0.2188 (epoch: 55, step: 100) // Avg time/img: 0.0496 s
# loss: 0.2167 (epoch: 55, step: 150) // Avg time/img: 0.0498 s
# loss: 0.2169 (epoch: 55, step: 200) // Avg time/img: 0.0502 s
# ----- VALIDATING - EPOCH 55 -----
# VAL loss: 0.577 (epoch: 55, step: 0) // Avg time/img: 0.0242 s
# VAL loss: 0.8861 (epoch: 55, step: 50) // Avg time/img: 0.0256 s
# VAL loss: 0.8745 (epoch: 55, step: 100) // Avg time/img: 0.0272 s
# VAL loss: 0.7465 (epoch: 55, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  42.16 %
# ----- TRAINING - EPOCH 56 -----
# LEARNING RATE:  5.3420368916117334e-05
# loss: 0.1632 (epoch: 56, step: 0) // Avg time/img: 0.0540 s
# loss: 0.2165 (epoch: 56, step: 50) // Avg time/img: 0.0505 s
# loss: 0.2179 (epoch: 56, step: 100) // Avg time/img: 0.0502 s
# loss: 0.2179 (epoch: 56, step: 150) // Avg time/img: 0.0498 s
# loss: 0.2161 (epoch: 56, step: 200) // Avg time/img: 0.0497 s
# ----- VALIDATING - EPOCH 56 -----
# VAL loss: 0.6158 (epoch: 56, step: 0) // Avg time/img: 0.0181 s
# VAL loss: 0.9212 (epoch: 56, step: 50) // Avg time/img: 0.0259 s
# VAL loss: 0.8987 (epoch: 56, step: 100) // Avg time/img: 0.0258 s
# VAL loss: 0.7669 (epoch: 56, step: 150) // Avg time/img: 0.0259 s
# EPOCH IoU on VAL set:  41.61 %
# ----- TRAINING - EPOCH 57 -----
# LEARNING RATE:  4.370064743465832e-05
# loss: 0.2741 (epoch: 57, step: 0) // Avg time/img: 0.0562 s
# loss: 0.2227 (epoch: 57, step: 50) // Avg time/img: 0.0488 s
# loss: 0.22 (epoch: 57, step: 100) // Avg time/img: 0.0497 s
# loss: 0.2184 (epoch: 57, step: 150) // Avg time/img: 0.0504 s
# loss: 0.2171 (epoch: 57, step: 200) // Avg time/img: 0.0501 s
# ----- VALIDATING - EPOCH 57 -----
# VAL loss: 0.5772 (epoch: 57, step: 0) // Avg time/img: 0.0250 s
# VAL loss: 0.8564 (epoch: 57, step: 50) // Avg time/img: 0.0273 s
# VAL loss: 0.8486 (epoch: 57, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.7297 (epoch: 57, step: 150) // Avg time/img: 0.0262 s
# EPOCH IoU on VAL set:  42.82 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_best.pth (epoch: 57)
# ----- TRAINING - EPOCH 58 -----
# LEARNING RATE:  3.373207119183911e-05
# loss: 0.2274 (epoch: 58, step: 0) // Avg time/img: 0.0652 s
# loss: 0.2059 (epoch: 58, step: 50) // Avg time/img: 0.0499 s
# loss: 0.2088 (epoch: 58, step: 100) // Avg time/img: 0.0495 s
# loss: 0.2089 (epoch: 58, step: 150) // Avg time/img: 0.0494 s
# loss: 0.2121 (epoch: 58, step: 200) // Avg time/img: 0.0496 s
# ----- VALIDATING - EPOCH 58 -----
# VAL loss: 0.5753 (epoch: 58, step: 0) // Avg time/img: 0.0233 s
# VAL loss: 0.8327 (epoch: 58, step: 50) // Avg time/img: 0.0259 s
# VAL loss: 0.8262 (epoch: 58, step: 100) // Avg time/img: 0.0263 s
# VAL loss: 0.7124 (epoch: 58, step: 150) // Avg time/img: 0.0265 s
# EPOCH IoU on VAL set:  43.13 %
# Saving model as best
# save: /content/gdrive/MyDrive/Colab Notebooks/erf-student-3/model_best.pth (epoch: 58)
# ----- TRAINING - EPOCH 59 -----
# LEARNING RATE:  2.3418597108060762e-05
# loss: 0.2086 (epoch: 59, step: 0) // Avg time/img: 0.0663 s
# loss: 0.201 (epoch: 59, step: 50) // Avg time/img: 0.0499 s
# loss: 0.1971 (epoch: 59, step: 100) // Avg time/img: 0.0502 s
# loss: 0.2039 (epoch: 59, step: 150) // Avg time/img: 0.0498 s
# loss: 0.2085 (epoch: 59, step: 200) // Avg time/img: 0.0496 s
# ----- VALIDATING - EPOCH 59 -----
# VAL loss: 0.569 (epoch: 59, step: 0) // Avg time/img: 0.0248 s
# VAL loss: 0.8636 (epoch: 59, step: 50) // Avg time/img: 0.0262 s
# VAL loss: 0.8559 (epoch: 59, step: 100) // Avg time/img: 0.0259 s
# VAL loss: 0.7347 (epoch: 59, step: 150) // Avg time/img: 0.0261 s
# EPOCH IoU on VAL set:  42.73 %
# ----- TRAINING - EPOCH 60 -----
# LEARNING RATE:  1.254971545512439e-05
# loss: 0.2214 (epoch: 60, step: 0) // Avg time/img: 0.0582 s
# loss: 0.212 (epoch: 60, step: 50) // Avg time/img: 0.0498 s
# loss: 0.2062 (epoch: 60, step: 100) // Avg time/img: 0.0497 s
# loss: 0.2073 (epoch: 60, step: 150) // Avg time/img: 0.0500 s
# loss: 0.2108 (epoch: 60, step: 200) // Avg time/img: 0.0501 s
# ----- VALIDATING - EPOCH 60 -----
# VAL loss: 0.5586 (epoch: 60, step: 0) // Avg time/img: 0.0250 s
# VAL loss: 0.8437 (epoch: 60, step: 50) // Avg time/img: 0.0271 s
# VAL loss: 0.8329 (epoch: 60, step: 100) // Avg time/img: 0.0267 s
# VAL loss: 0.7164 (epoch: 60, step: 150) // Avg time/img: 0.0264 s
# EPOCH IoU on VAL set:  42.98 %
# ========== TRAINING FINISHED ===========
